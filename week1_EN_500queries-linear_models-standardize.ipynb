# %% [markdown]
# ## tasks
# ### 1: Form training and testing periods as discussed (2 test periods, last 2*365 days). Be careful tp scale data only based on data from the training set. You may use (from Python) MinMaxScaler, standardisation (StandardScaler) or the default scaler in Python's elastic net.
# ### 2:Estimate the current flu rates by training an elastic net model. Use a Pearson correlation filter (r > 0.3) on the training data to reduce the amount of queries prior to training an elastic net (reminder: not all 1000 queries I provided are related to flu!). Report performance on the two test sets using three metrics: mean absolute error, root mean squared error and Pearson's correlation.
# ### 3: If there is time, begin work on traditional forecasting models (you've identified seasonal ARIMA and Hult-Winters).

# %%
# import libraries
import numpy as np
import pandas as pd
import random
import csv
import scipy.stats as stats
import seaborn as sns
from collections import Counter
from collections import defaultdict
import math
from sklearn.linear_model import ElasticNet
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from random import randint
from sklearn.linear_model import Ridge
from sklearn import linear_model

import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm
from statsmodels.nonparametric.kde import KDEUnivariate
from statsmodels.nonparametric import smoothers_lowess
from pandas import Series, DataFrame
from patsy import dmatrices
from sklearn import datasets, svm

# initialize the plotting sizes
# set size
plt.rc('figure', figsize=(10, 5))
# subplots size
fizsize_with_subplots = (10, 10)
# histogram size
bin_size = 10

# %%
# Loading data
dates = pd.read_csv('data/dates.csv',header=None)
queries = pd.read_csv('data/queries.csv',header=None)
X = pd.read_csv('data/X.csv',header=None)
y = pd.read_csv('data/y.csv',header=None)

X.columns = queries

# %%
# data preprocessing and train-test split
# this data is well formed with no missing value and other symbols or labels that are non numerical.
# splitting the data into train and test

# Here we want the first 500 queries
X = X.iloc[:, 0: 500]

# first with the last year as test
# for convinience, pick the two validation set starting from 1/3 and 2/3 of the training set,
# 10% of training set as validation, here use 400 data points, two 200 periods.
test_size =365
length = X.shape[0]
l =(X.shape[0]-test_size)//3

train1_X = pd.concat([X[0:l],X[l+200:2*l],X[2*l+200:length-test_size]])
val1_X = pd.concat([X[l:l+200],X[2*l:2*l+200]])
train1_y = pd.concat([y[0:l],y[l+200:2*l],y[2*l+200:length-test_size]])
val1_y = pd.concat([y[l:l+200],y[2*l:2*l+200]])
test1_X = X[length-test_size:]
test1_y = y[length-test_size:]

# second with the last 2 year as test
test_size2 =365*2
l2 =(X.shape[0]-test_size2)//3

train2_X = pd.concat([X[0:l2],X[l2+180:2*l2],X[2*l2+180:length-test_size2]])
val2_X = pd.concat([X[l2:l2+180],X[2*l2:2*l2+180]])
train2_y = pd.concat([y[0:l2],y[l2+180:2*l2],y[2*l2+180:length-test_size2]])
val2_y = pd.concat([y[l2:l2+180],y[2*l2:2*l2+180]])
test2_X = X[length-test_size2:]
test2_y = y[length-test_size2:]

print('X shape: ',X.shape,'  y shape: ',y.shape)
print('train1 X:',train1_X.shape,' train1 y:',train1_y.shape,' Test1 X shape:',test1_X.shape, ' Test1 y shape:',test1_y.shape)
print('validation1 X:',val1_X.shape,' validation1 y:',val1_y.shape)
print('train2 X:',train2_X.shape,' train2 y:',train2_y.shape,' Test2 X:',test2_X.shape,' Test2 y:',test2_y.shape)
print('validation2 X:',val2_X.shape,' validation2 y:',val2_y.shape)
# Out:
# X shape:  (4383, 500)   y shape:  (4383, 1)
# train1 X: (3618, 500)  train1 y: (3618, 1)  Test1 X shape: (365, 500)  Test1 y shape: (365, 1)
# validation1 X: (400, 500)  validation1 y: (400, 1)
# train2 X: (3293, 500)  train2 y: (3293, 1)  Test2 X: (730, 500)  Test2 y: (730, 1)
# validation2 X: (360, 500)  validation2 y: (360, 1)

# %%
train_size = train1_X.shape[0]
corrs = np.zeros((X.shape[1],1))
for i in range(0,X.shape[1]):
    if X.sum(axis=1)[i] == 0:
        corrs[i] = 0
    else:
        corrs[i] = np.corrcoef(X.iloc[0:train_size,i],y.iloc[0:train_size,0])[0,1]
        
corrs.shape,X.columns.shape,X.columns[0],X.columns[499]
# Out:
# ((500, 1), (500,), ('flu',), ('symptoms of kidney infection',))

# %%
def corr_filter(df_X,df_Xval,df_Xtest,corrs,threshold):
    X = df_X.copy()
    X_test = df_Xtest.copy()
    X_val = df_Xval.copy()
    col_corr = set() # Set of all the names of deleted columns
    for i in range(0,500):
            if corrs[i,0] < threshold: 
                #print(X.columns[i])
                colname = df_X.columns[i]
                del X[colname] # deleting the column from the dataset
                del X_test[colname] 
                del X_val[colname]

    return X,X_val,X_test

# %% [markdown]
# ## Fixing pearson correlation filter r>=0.2

# %%
#train1_X0,test1_X0 = corr_filter(train1_X,test1_X,corrs,0.1)
train1_X1,val1_X1,test1_X1 = corr_filter(train1_X,val1_X,test1_X,corrs,0.2)
#train1_X2,test1_X2 = corr_filter(train1_X,test1_X,corrs,0.3)
#train1_X3,test1_X3 = corr_filter(train1_X,test1_X,corrs,0.4)

# %%
#print('For correlation filter r>=0.1, we select feature number: ',train1_X0.shape[1])
print('For correlation filter r>=0.2, we select feature number: ',train1_X1.shape[1])
#print('For correlation filter r>=0.3, we select feature number: ',train1_X2.shape[1])
#print('For correlation filter r>=0.4, we select feature number: ',train1_X3.shape[1])
# Out:
# For correlation filter r>=0.2, we select feature number:  215

# %%
# Defien the mearure matrics, MAE, RMSE, CORR
# define three metrics: mean absolute error, root mean squared error and Pearson's correlation.
from sklearn.metrics import mean_absolute_error
# mae = mean_absolute_error(y_actual, y_pred)

from sklearn.metrics import mean_squared_error
from math import sqrt
# rmse = sqrt(mean_squared_error(y_actual, y_pred))

# np.correcoef returns Pearson product-moment correlation coefficients
def pearson_r(x,y):   
    corr_mat = np.corrcoef(x,y)
    return corr_mat[0,1]
# r = pearson_r(y_actual,y_pred)


# Generalise the function for convinient tuning
def ridge(a,train_X,train_y,test_X,test_y):
    # scaling and modeling
    scalerX = StandardScaler()
    scalerX.fit(train_X)
    train_X = scalerX.transform(train_X)
    test_X = scalerX.transform(test_X)
    
    scalery = StandardScaler() 
    scalery.fit(train_y) 
    train_y = scalery.transform(train_y) 
    
    
    alpha=a
    ri = Ridge(alpha, copy_X=True, fit_intercept=True, max_iter=None,
      normalize=False, random_state=None, solver='auto', tol=0.001)
  
    ri.fit(train_X,train_y)

    y_pred1 = ri.predict(test_X)
    y_pred1 = scalery.inverse_transform(y_pred1)

    mae1 = mean_absolute_error(test_y, y_pred1)
    #print('The mean absolute error is: ',mae1)

    rmse1 = sqrt(mean_squared_error(test_y, y_pred1))
    #print('The root mean squared error is: ',rmse1)
    
    corr_y = test_y.copy()
    corr_y['y_act'] = test_y
    corr_y['y_pred']= y_pred1
    corr = np.corrcoef(corr_y['y_act'],corr_y['y_pred'])[0,1]
    #print('The correlation is: ',corr)
    
    return rmse1, mae1,corr

# %% [markdown]
# # scaling and modeling
# scaler = MinMaxScaler()
# train1_X0_scaled = scaler.fit_transform(train1_X0)
# test1_X0_scaled = scaler.transform(test1_x0)
#
# train1_X1_scaled = scaler.fit_transform(train1_X1)
# test1_X1_scaled = scaler.transform(test1_x1)
#
# train1_X2_scaled = scaler.fit_transform(train1_X2)
# test1_X2_scaled = scaler.transform(test1_x2)
#
# train1_X3_scaled = scaler.fit_transform(train1_X3)
# test1_X3_scaled = scaler.transform(test1_x3)

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.1, 310 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train1_X0,train1_y,test1_X0,test1_y))

# %%
para = np.arange(0, 10000000, 10000)
rmse=100000
mae=1000000
corr=0
for a in para:
    print('alpha:',a)
    rmse0,mae0,corr0 = ridge(a,train1_X1,train1_y,val1_X1,val1_y)
    if rmse0< rmse:
        rmse=rmse0
        mae=mae0
        corr = corr0
        print('========================================')
        print('Best RMSE is updated! ' )
        print('The mean absolute error is: ',mae)
        print('The root mean squared error is: ',rmse)
        print('The correlation is: ',corr)
        print('----------------------------------------')
# Out:
# alpha: 0
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  23.84991227284693
# The root mean squared error is:  49.25516226820323
# The correlation is:  0.7491690821004
# ----------------------------------------
# alpha: 10000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  18.72112640895357
# The root mean squared error is:  36.07439467584889
# The correlation is:  0.8079109470589398
# ----------------------------------------
# alpha: 20000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  16.403153649263285
# The root mean squared error is:  31.13621656074955
# The correlation is:  0.8007177669253068
# ----------------------------------------
# alpha: 30000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.79540135344137
# The root mean squared error is:  27.951852784150542
# The correlation is:  0.7956867916535015
# ----------------------------------------
# alpha: 40000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.608370939392104
# The root mean squared error is:  25.648474764894363
# The correlation is:  0.7919725881167161
# ----------------------------------------
# alpha: 50000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.70594188011567
# The root mean squared error is:  23.86917652194656
# The correlation is:  0.7891121464518925
# ----------------------------------------
# alpha: 60000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  11.964166756805655
# The root mean squared error is:  22.442146736649764
# The correlation is:  0.7868399175031757
# ----------------------------------------
# alpha: 70000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  11.338884616084437
# The root mean squared error is:  21.272964551842627
# The correlation is:  0.7849911503161157
# ----------------------------------------
# alpha: 80000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.83442520169351
# The root mean squared error is:  20.303911137114955
# The correlation is:  0.7834576431363917
# ----------------------------------------
# alpha: 90000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.402829055755335
# The root mean squared error is:  19.49650554990373
# The correlation is:  0.7821652262815465
# ----------------------------------------
# alpha: 100000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.059608502597717
# The root mean squared error is:  18.823213817515168
# The correlation is:  0.781061307104297
# ----------------------------------------
# alpha: 110000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.802920234017229
# The root mean squared error is:  18.26318512981611
# The correlation is:  0.7801075419927088
# ----------------------------------------
# alpha: 120000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.618729073821445
# The root mean squared error is:  17.799913636033157
# The correlation is:  0.7792753143495548
# ----------------------------------------
# alpha: 130000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.492010225920335
# The root mean squared error is:  17.41988702396285
# The correlation is:  0.7785428347438954
# ----------------------------------------
# alpha: 140000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.393800940063272
# The root mean squared error is:  17.111769611079215
# The correlation is:  0.7778932208208603
# ----------------------------------------
# alpha: 150000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.33223484909534
# The root mean squared error is:  16.865887728085415
# The correlation is:  0.7773131907726233
# ----------------------------------------
# alpha: 160000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.294023435225142
# The root mean squared error is:  16.673891702009975
# The correlation is:  0.7767921530235579
# ----------------------------------------
# alpha: 170000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.272519827195918
# The root mean squared error is:  16.52852353876954
# The correlation is:  0.7763215586574882
# ----------------------------------------
# alpha: 180000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.281707507691243
# The root mean squared error is:  16.42344912783882
# The correlation is:  0.7758944321810174
# ----------------------------------------
# alpha: 190000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.306474850536134
# The root mean squared error is:  16.35313063683481
# The correlation is:  0.7755050258570703
# ----------------------------------------
# alpha: 200000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.347137257929255
# The root mean squared error is:  16.312724620208655
# The correlation is:  0.7751485612569184
# ----------------------------------------
# alpha: 210000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.409335178983515
# The root mean squared error is:  16.297997240292997
# The correlation is:  0.7748210334059543
# ----------------------------------------
# alpha: 220000
# alpha: 230000
# alpha: 240000
# alpha: 250000
# alpha: 260000
# alpha: 270000
# alpha: 280000
# alpha: 290000
# alpha: 300000
# alpha: 310000
# alpha: 320000
# alpha: 330000
# alpha: 340000
# alpha: 350000
# alpha: 360000
# alpha: 370000
# alpha: 380000
# alpha: 390000
# alpha: 400000
# alpha: 410000
# alpha: 420000
# alpha: 430000
# alpha: 440000
# alpha: 450000
# alpha: 460000
# alpha: 470000
# alpha: 480000
# alpha: 490000
# alpha: 500000
# alpha: 510000
# alpha: 520000
# alpha: 530000
# alpha: 540000
# alpha: 550000
# alpha: 560000
# alpha: 570000
# alpha: 580000
# alpha: 590000
# alpha: 600000
# alpha: 610000
# alpha: 620000
# alpha: 630000
# alpha: 640000
# alpha: 650000
# alpha: 660000
# alpha: 670000
# alpha: 680000
# alpha: 690000
# alpha: 700000
# alpha: 710000
# alpha: 720000
# alpha: 730000
# alpha: 740000
# alpha: 750000
# alpha: 760000
# alpha: 770000
# alpha: 780000
# alpha: 790000
# alpha: 800000
# alpha: 810000
# alpha: 820000
# alpha: 830000
# alpha: 840000
# alpha: 850000
# alpha: 860000
# alpha: 870000
# alpha: 880000
# alpha: 890000
# alpha: 900000
# alpha: 910000
# alpha: 920000
# alpha: 930000
# alpha: 940000
# alpha: 950000
# alpha: 960000
# alpha: 970000
# alpha: 980000
# alpha: 990000
# alpha: 1000000
# alpha: 1010000
# alpha: 1020000
# alpha: 1030000
# alpha: 1040000
# alpha: 1050000
# alpha: 1060000
# alpha: 1070000
# alpha: 1080000
# alpha: 1090000
# alpha: 1100000
# alpha: 1110000
# alpha: 1120000
# alpha: 1130000
# alpha: 1140000
# alpha: 1150000
# alpha: 1160000
# alpha: 1170000
# alpha: 1180000
# alpha: 1190000
# alpha: 1200000
# alpha: 1210000
# alpha: 1220000
# alpha: 1230000
# alpha: 1240000
# alpha: 1250000
# alpha: 1260000
# alpha: 1270000
# alpha: 1280000
# alpha: 1290000
# alpha: 1300000
# alpha: 1310000
# alpha: 1320000
# alpha: 1330000
# alpha: 1340000
# alpha: 1350000
# alpha: 1360000
# alpha: 1370000
# alpha: 1380000
# alpha: 1390000
# alpha: 1400000
# alpha: 1410000
# alpha: 1420000
# alpha: 1430000
# alpha: 1440000
# alpha: 1450000
# alpha: 1460000
# alpha: 1470000
# alpha: 1480000
# alpha: 1490000
# alpha: 1500000
# alpha: 1510000
# alpha: 1520000
# alpha: 1530000
# alpha: 1540000
# alpha: 1550000
# alpha: 1560000
# alpha: 1570000
# alpha: 1580000
# alpha: 1590000
# alpha: 1600000
# alpha: 1610000
# alpha: 1620000
# alpha: 1630000
# alpha: 1640000
# alpha: 1650000
# alpha: 1660000
# alpha: 1670000
# alpha: 1680000
# alpha: 1690000
# alpha: 1700000
# alpha: 1710000
# alpha: 1720000
# alpha: 1730000
# alpha: 1740000
# alpha: 1750000
# alpha: 1760000
# alpha: 1770000
# alpha: 1780000
# alpha: 1790000
# alpha: 1800000
# alpha: 1810000
# alpha: 1820000
# alpha: 1830000
# alpha: 1840000
# alpha: 1850000
# alpha: 1860000
# alpha: 1870000
# alpha: 1880000
# alpha: 1890000
# alpha: 1900000
# alpha: 1910000
# alpha: 1920000
# alpha: 1930000
# alpha: 1940000
# alpha: 1950000
# alpha: 1960000
# alpha: 1970000
# alpha: 1980000
# alpha: 1990000
# alpha: 2000000
# alpha: 2010000
# alpha: 2020000
# alpha: 2030000
# alpha: 2040000
# alpha: 2050000
# alpha: 2060000
# alpha: 2070000
# alpha: 2080000
# alpha: 2090000
# alpha: 2100000
# alpha: 2110000
# alpha: 2120000
# alpha: 2130000
# alpha: 2140000
# alpha: 2150000
# alpha: 2160000
# alpha: 2170000
# alpha: 2180000
# alpha: 2190000
# alpha: 2200000
# alpha: 2210000
# alpha: 2220000
# alpha: 2230000
# alpha: 2240000
# alpha: 2250000
# alpha: 2260000
# alpha: 2270000
# alpha: 2280000
# alpha: 2290000
# alpha: 2300000
# alpha: 2310000
# alpha: 2320000
# alpha: 2330000
# alpha: 2340000
# alpha: 2350000
# alpha: 2360000
# alpha: 2370000
# alpha: 2380000
# alpha: 2390000
# alpha: 2400000
# alpha: 2410000
# alpha: 2420000
# alpha: 2430000
# alpha: 2440000
# alpha: 2450000
# alpha: 2460000
# alpha: 2470000
# alpha: 2480000
# alpha: 2490000
# alpha: 2500000
# alpha: 2510000
# alpha: 2520000
# alpha: 2530000
# alpha: 2540000
# alpha: 2550000
# alpha: 2560000
# alpha: 2570000
# alpha: 2580000
# alpha: 2590000
# alpha: 2600000
# alpha: 2610000
# alpha: 2620000
# alpha: 2630000
# alpha: 2640000
# alpha: 2650000
# alpha: 2660000
# alpha: 2670000
# alpha: 2680000
# alpha: 2690000
# alpha: 2700000
# alpha: 2710000
# alpha: 2720000
# alpha: 2730000
# alpha: 2740000
# alpha: 2750000
# alpha: 2760000
# alpha: 2770000
# alpha: 2780000
# alpha: 2790000
# alpha: 2800000
# alpha: 2810000
# alpha: 2820000
# alpha: 2830000
# alpha: 2840000
# alpha: 2850000
# alpha: 2860000
# alpha: 2870000
# alpha: 2880000
# alpha: 2890000
# alpha: 2900000
# alpha: 2910000
# alpha: 2920000
# alpha: 2930000
# alpha: 2940000
# alpha: 2950000
# alpha: 2960000
# alpha: 2970000
# alpha: 2980000
# alpha: 2990000
# alpha: 3000000
# alpha: 3010000
# alpha: 3020000
# alpha: 3030000
# alpha: 3040000
# alpha: 3050000
# alpha: 3060000
# alpha: 3070000
# alpha: 3080000
# alpha: 3090000
# alpha: 3100000
# alpha: 3110000
# alpha: 3120000
# alpha: 3130000
# alpha: 3140000
# alpha: 3150000
# alpha: 3160000
# alpha: 3170000
# alpha: 3180000
# alpha: 3190000
# alpha: 3200000
# alpha: 3210000
# alpha: 3220000
# alpha: 3230000
# alpha: 3240000
# alpha: 3250000
# alpha: 3260000
# alpha: 3270000
# alpha: 3280000
# alpha: 3290000
# alpha: 3300000
# alpha: 3310000
# alpha: 3320000
# alpha: 3330000
# alpha: 3340000
# alpha: 3350000
# alpha: 3360000
# alpha: 3370000
# alpha: 3380000
# alpha: 3390000
# alpha: 3400000
# alpha: 3410000
# alpha: 3420000
# alpha: 3430000
# alpha: 3440000
# alpha: 3450000
# alpha: 3460000
# alpha: 3470000
# alpha: 3480000
# alpha: 3490000
# alpha: 3500000
# alpha: 3510000
# alpha: 3520000
# alpha: 3530000
# alpha: 3540000
# alpha: 3550000
# alpha: 3560000
# alpha: 3570000
# alpha: 3580000
# alpha: 3590000
# alpha: 3600000
# alpha: 3610000
# alpha: 3620000
# alpha: 3630000
# alpha: 3640000
# alpha: 3650000
# alpha: 3660000
# alpha: 3670000
# alpha: 3680000
# alpha: 3690000
# alpha: 3700000
# alpha: 3710000
# alpha: 3720000
# alpha: 3730000
# alpha: 3740000
# alpha: 3750000
# alpha: 3760000
# alpha: 3770000
# alpha: 3780000
# alpha: 3790000
# alpha: 3800000
# alpha: 3810000
# alpha: 3820000
# alpha: 3830000
# alpha: 3840000
# alpha: 3850000
# alpha: 3860000
# alpha: 3870000
# alpha: 3880000
# alpha: 3890000
# alpha: 3900000
# alpha: 3910000
# alpha: 3920000
# alpha: 3930000
# alpha: 3940000
# alpha: 3950000
# alpha: 3960000
# alpha: 3970000
# alpha: 3980000
# alpha: 3990000
# alpha: 4000000
# alpha: 4010000
# alpha: 4020000
# alpha: 4030000
# alpha: 4040000
# alpha: 4050000
# alpha: 4060000
# alpha: 4070000
# alpha: 4080000
# alpha: 4090000
# alpha: 4100000
# alpha: 4110000
# alpha: 4120000
# alpha: 4130000
# alpha: 4140000
# alpha: 4150000
# alpha: 4160000
# alpha: 4170000
# alpha: 4180000
# alpha: 4190000
# alpha: 4200000
# alpha: 4210000
# alpha: 4220000
# alpha: 4230000
# alpha: 4240000
# alpha: 4250000
# alpha: 4260000
# alpha: 4270000
# alpha: 4280000
# alpha: 4290000
# alpha: 4300000
# alpha: 4310000
# alpha: 4320000
# alpha: 4330000
# alpha: 4340000
# alpha: 4350000
# alpha: 4360000
# alpha: 4370000
# alpha: 4380000
# alpha: 4390000
# alpha: 4400000
# alpha: 4410000
# alpha: 4420000
# alpha: 4430000
# alpha: 4440000
# alpha: 4450000
# alpha: 4460000
# alpha: 4470000
# alpha: 4480000
# alpha: 4490000
# alpha: 4500000
# alpha: 4510000
# alpha: 4520000
# alpha: 4530000
# alpha: 4540000
# alpha: 4550000
# alpha: 4560000
# alpha: 4570000
# alpha: 4580000
# alpha: 4590000
# alpha: 4600000
# alpha: 4610000
# alpha: 4620000
# alpha: 4630000
# alpha: 4640000
# alpha: 4650000
# alpha: 4660000
# alpha: 4670000
# alpha: 4680000
# alpha: 4690000
# alpha: 4700000
# alpha: 4710000
# alpha: 4720000
# alpha: 4730000
# alpha: 4740000
# alpha: 4750000
# alpha: 4760000
# alpha: 4770000
# alpha: 4780000
# alpha: 4790000
# alpha: 4800000
# alpha: 4810000
# alpha: 4820000
# alpha: 4830000
# alpha: 4840000
# alpha: 4850000
# alpha: 4860000
# alpha: 4870000
# alpha: 4880000
# alpha: 4890000
# alpha: 4900000
# alpha: 4910000
# alpha: 4920000
# alpha: 4930000
# alpha: 4940000
# alpha: 4950000
# alpha: 4960000
# alpha: 4970000
# alpha: 4980000
# alpha: 4990000
# alpha: 5000000
# alpha: 5010000
# alpha: 5020000
# alpha: 5030000
# alpha: 5040000
# alpha: 5050000
# alpha: 5060000
# alpha: 5070000
# alpha: 5080000
# alpha: 5090000
# alpha: 5100000
# alpha: 5110000
# alpha: 5120000
# alpha: 5130000
# alpha: 5140000
# alpha: 5150000
# alpha: 5160000
# alpha: 5170000
# alpha: 5180000
# alpha: 5190000
# alpha: 5200000
# alpha: 5210000
# alpha: 5220000
# alpha: 5230000
# alpha: 5240000
# alpha: 5250000
# alpha: 5260000
# alpha: 5270000
# alpha: 5280000
# alpha: 5290000
# alpha: 5300000
# alpha: 5310000
# alpha: 5320000
# alpha: 5330000
# alpha: 5340000
# alpha: 5350000
# alpha: 5360000
# alpha: 5370000
# alpha: 5380000
# alpha: 5390000
# alpha: 5400000
# alpha: 5410000
# alpha: 5420000
# alpha: 5430000
# alpha: 5440000
# alpha: 5450000
# alpha: 5460000
# alpha: 5470000
# alpha: 5480000
# alpha: 5490000
# alpha: 5500000
# alpha: 5510000
# alpha: 5520000
# alpha: 5530000
# alpha: 5540000
# alpha: 5550000
# alpha: 5560000
# alpha: 5570000
# alpha: 5580000
# alpha: 5590000
# alpha: 5600000
# alpha: 5610000
# alpha: 5620000
# alpha: 5630000
# alpha: 5640000
# alpha: 5650000
# alpha: 5660000
# alpha: 5670000
# alpha: 5680000
# alpha: 5690000
# alpha: 5700000
# alpha: 5710000
# alpha: 5720000
# alpha: 5730000
# alpha: 5740000
# alpha: 5750000
# alpha: 5760000
# alpha: 5770000
# alpha: 5780000
# alpha: 5790000
# alpha: 5800000
# alpha: 5810000
# alpha: 5820000
# alpha: 5830000
# alpha: 5840000
# alpha: 5850000
# alpha: 5860000
# alpha: 5870000
# alpha: 5880000
# alpha: 5890000
# alpha: 5900000
# alpha: 5910000
# alpha: 5920000
# alpha: 5930000
# alpha: 5940000
# alpha: 5950000
# alpha: 5960000
# alpha: 5970000
# alpha: 5980000
# alpha: 5990000
# alpha: 6000000
# alpha: 6010000
# alpha: 6020000
# alpha: 6030000
# alpha: 6040000
# alpha: 6050000
# alpha: 6060000
# alpha: 6070000
# alpha: 6080000
# alpha: 6090000
# alpha: 6100000
# alpha: 6110000
# alpha: 6120000
# alpha: 6130000
# alpha: 6140000
# alpha: 6150000
# alpha: 6160000
# alpha: 6170000
# alpha: 6180000
# alpha: 6190000
# alpha: 6200000
# alpha: 6210000
# alpha: 6220000
# alpha: 6230000
# alpha: 6240000
# alpha: 6250000
# alpha: 6260000
# alpha: 6270000
# alpha: 6280000
# alpha: 6290000
# alpha: 6300000
# alpha: 6310000
# alpha: 6320000
# alpha: 6330000
# alpha: 6340000
# alpha: 6350000
# alpha: 6360000
# alpha: 6370000
# alpha: 6380000
# alpha: 6390000
# alpha: 6400000
# alpha: 6410000
# alpha: 6420000
# alpha: 6430000
# alpha: 6440000
# alpha: 6450000
# alpha: 6460000
# alpha: 6470000
# alpha: 6480000
# alpha: 6490000
# alpha: 6500000
# alpha: 6510000
# alpha: 6520000
# alpha: 6530000
# alpha: 6540000
# alpha: 6550000
# alpha: 6560000
# alpha: 6570000
# alpha: 6580000
# alpha: 6590000
# alpha: 6600000
# alpha: 6610000
# alpha: 6620000
# alpha: 6630000
# alpha: 6640000
# alpha: 6650000
# alpha: 6660000
# alpha: 6670000
# alpha: 6680000
# alpha: 6690000
# alpha: 6700000
# alpha: 6710000
# alpha: 6720000
# alpha: 6730000
# alpha: 6740000
# alpha: 6750000
# alpha: 6760000
# alpha: 6770000
# alpha: 6780000
# alpha: 6790000
# alpha: 6800000
# alpha: 6810000
# alpha: 6820000
# alpha: 6830000
# alpha: 6840000
# alpha: 6850000
# alpha: 6860000
# alpha: 6870000
# alpha: 6880000
# alpha: 6890000
# alpha: 6900000
# alpha: 6910000
# alpha: 6920000
# alpha: 6930000
# alpha: 6940000
# alpha: 6950000
# alpha: 6960000
# alpha: 6970000
# alpha: 6980000
# alpha: 6990000
# alpha: 7000000
# alpha: 7010000
# alpha: 7020000
# alpha: 7030000
# alpha: 7040000
# alpha: 7050000
# alpha: 7060000
# alpha: 7070000
# alpha: 7080000
# alpha: 7090000
# alpha: 7100000
# alpha: 7110000
# alpha: 7120000
# alpha: 7130000
# alpha: 7140000
# alpha: 7150000
# alpha: 7160000
# alpha: 7170000
# alpha: 7180000
# alpha: 7190000
# alpha: 7200000
# alpha: 7210000
# alpha: 7220000
# alpha: 7230000
# alpha: 7240000
# alpha: 7250000
# alpha: 7260000
# alpha: 7270000
# alpha: 7280000
# alpha: 7290000
# alpha: 7300000
# alpha: 7310000
# alpha: 7320000
# alpha: 7330000
# alpha: 7340000
# alpha: 7350000
# alpha: 7360000
# alpha: 7370000
# alpha: 7380000
# alpha: 7390000
# alpha: 7400000
# alpha: 7410000
# alpha: 7420000
# alpha: 7430000
# alpha: 7440000
# alpha: 7450000
# alpha: 7460000
# alpha: 7470000
# alpha: 7480000
# alpha: 7490000
# alpha: 7500000
# alpha: 7510000
# alpha: 7520000
# alpha: 7530000
# alpha: 7540000
# alpha: 7550000
# alpha: 7560000
# alpha: 7570000
# alpha: 7580000
# alpha: 7590000
# alpha: 7600000
# alpha: 7610000
# alpha: 7620000
# alpha: 7630000
# alpha: 7640000
# alpha: 7650000
# alpha: 7660000
# alpha: 7670000
# alpha: 7680000
# alpha: 7690000
# alpha: 7700000
# alpha: 7710000
# alpha: 7720000
# alpha: 7730000
# alpha: 7740000
# alpha: 7750000
# alpha: 7760000
# alpha: 7770000
# alpha: 7780000
# alpha: 7790000
# alpha: 7800000
# alpha: 7810000
# alpha: 7820000
# alpha: 7830000
# alpha: 7840000
# alpha: 7850000
# alpha: 7860000
# alpha: 7870000
# alpha: 7880000
# alpha: 7890000
# alpha: 7900000
# alpha: 7910000
# alpha: 7920000
# alpha: 7930000
# alpha: 7940000
# alpha: 7950000
# alpha: 7960000
# alpha: 7970000
# alpha: 7980000
# alpha: 7990000
# alpha: 8000000
# alpha: 8010000
# alpha: 8020000
# alpha: 8030000
# alpha: 8040000
# alpha: 8050000
# alpha: 8060000
# alpha: 8070000
# alpha: 8080000
# alpha: 8090000
# alpha: 8100000
# alpha: 8110000
# alpha: 8120000
# alpha: 8130000
# alpha: 8140000
# alpha: 8150000
# alpha: 8160000
# alpha: 8170000
# alpha: 8180000
# alpha: 8190000
# alpha: 8200000
# alpha: 8210000
# alpha: 8220000
# alpha: 8230000
# alpha: 8240000
# alpha: 8250000
# alpha: 8260000
# alpha: 8270000
# alpha: 8280000
# alpha: 8290000
# alpha: 8300000
# alpha: 8310000
# alpha: 8320000
# alpha: 8330000
# alpha: 8340000
# alpha: 8350000
# alpha: 8360000
# alpha: 8370000
# alpha: 8380000
# alpha: 8390000
# alpha: 8400000
# alpha: 8410000
# alpha: 8420000
# alpha: 8430000
# alpha: 8440000
# alpha: 8450000
# alpha: 8460000
# alpha: 8470000
# alpha: 8480000
# alpha: 8490000
# alpha: 8500000
# alpha: 8510000
# alpha: 8520000
# alpha: 8530000
# alpha: 8540000
# alpha: 8550000
# alpha: 8560000
# alpha: 8570000
# alpha: 8580000
# alpha: 8590000
# alpha: 8600000
# alpha: 8610000
# alpha: 8620000
# alpha: 8630000
# alpha: 8640000
# alpha: 8650000
# alpha: 8660000
# alpha: 8670000
# alpha: 8680000
# alpha: 8690000
# alpha: 8700000
# alpha: 8710000
# alpha: 8720000
# alpha: 8730000
# alpha: 8740000
# alpha: 8750000
# alpha: 8760000
# alpha: 8770000
# alpha: 8780000
# alpha: 8790000
# alpha: 8800000
# alpha: 8810000
# alpha: 8820000
# alpha: 8830000
# alpha: 8840000
# alpha: 8850000
# alpha: 8860000
# alpha: 8870000
# alpha: 8880000
# alpha: 8890000
# alpha: 8900000
# alpha: 8910000
# alpha: 8920000
# alpha: 8930000
# alpha: 8940000
# alpha: 8950000
# alpha: 8960000
# alpha: 8970000
# alpha: 8980000
# alpha: 8990000
# alpha: 9000000
# alpha: 9010000
# alpha: 9020000
# alpha: 9030000
# alpha: 9040000
# alpha: 9050000
# alpha: 9060000
# alpha: 9070000
# alpha: 9080000
# alpha: 9090000
# alpha: 9100000
# alpha: 9110000
# alpha: 9120000
# alpha: 9130000
# alpha: 9140000
# alpha: 9150000
# alpha: 9160000
# alpha: 9170000
# alpha: 9180000
# alpha: 9190000
# alpha: 9200000
# alpha: 9210000
# alpha: 9220000
# alpha: 9230000
# alpha: 9240000
# alpha: 9250000
# alpha: 9260000
# alpha: 9270000
# alpha: 9280000
# alpha: 9290000
# alpha: 9300000
# alpha: 9310000
# alpha: 9320000
# alpha: 9330000
# alpha: 9340000
# alpha: 9350000
# alpha: 9360000
# alpha: 9370000
# alpha: 9380000
# alpha: 9390000
# alpha: 9400000
# alpha: 9410000
# alpha: 9420000
# alpha: 9430000
# alpha: 9440000
# alpha: 9450000
# alpha: 9460000
# alpha: 9470000
# alpha: 9480000
# alpha: 9490000
# alpha: 9500000
# alpha: 9510000
# alpha: 9520000
# alpha: 9530000
# alpha: 9540000
# alpha: 9550000
# alpha: 9560000
# alpha: 9570000
# alpha: 9580000
# alpha: 9590000
# alpha: 9600000
# alpha: 9610000
# alpha: 9620000
# alpha: 9630000
# alpha: 9640000
# alpha: 9650000
# alpha: 9660000
# alpha: 9670000
# alpha: 9680000
# alpha: 9690000
# alpha: 9700000
# alpha: 9710000
# alpha: 9720000
# alpha: 9730000
# alpha: 9740000
# alpha: 9750000
# alpha: 9760000
# alpha: 9770000
# alpha: 9780000
# alpha: 9790000
# alpha: 9800000
# alpha: 9810000
# alpha: 9820000
# alpha: 9830000
# alpha: 9840000
# alpha: 9850000
# alpha: 9860000
# alpha: 9870000
# alpha: 9880000
# alpha: 9890000
# alpha: 9900000
# alpha: 9910000
# alpha: 9920000
# alpha: 9930000
# alpha: 9940000
# alpha: 9950000
# alpha: 9960000
# alpha: 9970000
# alpha: 9980000
# alpha: 9990000

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.3, 150 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train1_X2,train1_y,test1_X2,test1_y))

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.4, 103 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train1_X3,train1_y,test1_X3,test1_y))

# %%
para =[0,210000]
rmse=100000
mae=1000000
corr=0
for a in para:
    print('alpha:',a)
    rmse0,mae0,corr0 = ridge(a,train1_X1,train1_y,val1_X1,val1_y)
    if rmse0< rmse:
        rmse=rmse0
        mae=mae0
        corr = corr0
        print('========================================')
        print('Best RMSE is updated! ' )
        print('The mean absolute error is: ',mae)
        print('The root mean squared error is: ',rmse)
        print('The correlation is: ',corr)
        print('----------------------------------------')
# Out:
# alpha: 0
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  23.84991227284693
# The root mean squared error is:  49.25516226820323
# The correlation is:  0.7491690821004
# ----------------------------------------
# alpha: 210000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.409335178983515
# The root mean squared error is:  16.297997240292997
# The correlation is:  0.7748210334059543
# ----------------------------------------

# %% [markdown]
# ## For the last 2 years as the testing set

# %%
train_size = 3653
corrs2 = np.zeros((X.shape[1],1))
for i in range(0,X.shape[1]):
    if X.sum(axis=1)[i] == 0:
        corrs2[i] = 0
    else:
        corrs2[i] = np.corrcoef(X.iloc[0:train_size,i],y.iloc[0:train_size,0])[0,1]
        
corrs2.shape,X.columns.shape,X.columns[0],X.columns[499]
# Out:
# ((500, 1), (500,), ('flu',), ('symptoms of kidney infection',))

# %%
#train2_X0,test2_X0 = corr_filter(train2_X,test2_X,corrs2,0.1)
train2_X1,val2_X1,test2_X1 = corr_filter(train2_X,val2_X,test2_X,corrs2,0.2)
#train2_X2,test2_X2 = corr_filter(train2_X,test2_X,corrs2,0.3)
#train2_X3,test2_X3 = corr_filter(train2_X,test2_X,corrs2,0.4)

# %%
#print('For correlation filter r>0.1, we select feature number: ',train2_X0.shape[1])
print('For correlation filter r>0.2, we select feature number: ',train2_X1.shape[1])
#print('For correlation filter r>0.3, we select feature number: ',train2_X2.shape[1])
#print('For correlation filter r>0.4, we select feature number: ',train2_X3.shape[1])
# Out:
# For correlation filter r>0.2, we select feature number:  215

# %% [markdown]
# # scaling and modeling
# scaler = MinMaxScaler()
# train2_X0_scaled = scaler.fit_transform(train2_X0)
# test2_X0_scaled = scaler.transform(test2_X0)
#
# train2_X1_scaled = scaler.fit_transform(train2_X1)
# test2_X1_scaled = scaler.transform(test2_X1)
#
# train2_X2_scaled = scaler.fit_transform(train2_X2)
# test2_X2_scaled = scaler.transform(test2_X2)
#
# train2_X3_scaled = scaler.fit_transform(train2_X3)
# test2_X3_scaled = scaler.transform(test2_X3)

# %% [markdown]
# para = range(1,100)
# para = np.arange(0.01, 10.0, 0.01)
# rmse=100000
# mae=1000000
# corr=0
# for a in para:
#     print('alpha:',a)
#     rmse0,mae0,corr0 = ridge(a,train1_X1,train1_y,val1_X1,val1_y)
#     if rmse0< rmse:
#         rmse=rmse0
#         mae=mae0
#         corr = corr0
#         print('========================================')
#         print('Best RMSE is updated! ' )
#         print('The mean absolute error is: ',mae)
#         print('The root mean squared error is: ',rmse)
#         print('The correlation is: ',corr)
#         print('----------------------------------------')

# %%
para =np.arange(0, 10000000, 10000)
rmse=100000
mae=1000000
corr=0
for a in para:
    print('alpha:',a)
    rmse0,mae0,corr0 = ridge(a,train2_X1,train2_y,val2_X1,val2_y)
    if rmse0< rmse:
        rmse=rmse0
        mae=mae0
        corr = corr0
        print('========================================')
        print('Best RMSE is updated! ' )
        print('The mean absolute error is: ',mae)
        print('The root mean squared error is: ',rmse)
        print('The correlation is: ',corr)
        print('----------------------------------------')
# Out:
# alpha: 0
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  5.701643382564393
# The root mean squared error is:  14.41849934736827
# The correlation is:  0.2993203937806601
# ----------------------------------------
# alpha: 10000
# alpha: 20000
# alpha: 30000
# alpha: 40000
# alpha: 50000
# alpha: 60000
# alpha: 70000
# alpha: 80000
# alpha: 90000
# alpha: 100000
# alpha: 110000
# alpha: 120000
# alpha: 130000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.625116530231743
# The root mean squared error is:  14.243350836654377
# The correlation is:  0.1212054653660179
# ----------------------------------------
# alpha: 140000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.593353912384872
# The root mean squared error is:  13.9927409462112
# The correlation is:  0.12038414279285284
# ----------------------------------------
# alpha: 150000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.563390233066975
# The root mean squared error is:  13.755110951543923
# The correlation is:  0.11966121056570772
# ----------------------------------------
# alpha: 160000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.5348010061132715
# The root mean squared error is:  13.52982231902451
# The correlation is:  0.11901992801469775
# ----------------------------------------
# alpha: 170000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.5073463983785995
# The root mean squared error is:  13.31621632530415
# The correlation is:  0.11844715971921191
# ----------------------------------------
# alpha: 180000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.481135384811651
# The root mean squared error is:  13.113637364163301
# The correlation is:  0.11793245201523751
# ----------------------------------------
# alpha: 190000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.456053654525734
# The root mean squared error is:  12.92144703323391
# The correlation is:  0.11746738019696587
# ----------------------------------------
# alpha: 200000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.4325074758123035
# The root mean squared error is:  12.739032367789097
# The correlation is:  0.11704507796126093
# ----------------------------------------
# alpha: 210000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.410388646624369
# The root mean squared error is:  12.56581032708885
# The correlation is:  0.11665989226321123
# ----------------------------------------
# alpha: 220000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.388947058260914
# The root mean squared error is:  12.401229873882713
# The correlation is:  0.11630712617685689
# ----------------------------------------
# alpha: 230000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.3683330758571035
# The root mean squared error is:  12.24477251321108
# The correlation is:  0.11598284460541644
# ----------------------------------------
# alpha: 240000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.349069648208962
# The root mean squared error is:  12.095951856480477
# The correlation is:  0.11568372559308517
# ----------------------------------------
# alpha: 250000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.330527494866397
# The root mean squared error is:  11.954312583655547
# The correlation is:  0.11540694520358227
# ----------------------------------------
# alpha: 260000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.312525455395982
# The root mean squared error is:  11.819429050350825
# The correlation is:  0.1151500874333909
# ----------------------------------------
# alpha: 270000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.295424766261027
# The root mean squared error is:  11.690903703332129
# The correlation is:  0.11491107302235463
# ----------------------------------------
# alpha: 280000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.278831267710204
# The root mean squared error is:  11.568365412388099
# The correlation is:  0.11468810268763403
# ----------------------------------------
# alpha: 290000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.26272536801855
# The root mean squared error is:  11.4514677891947
# The correlation is:  0.11447961147929513
# ----------------------------------------
# alpha: 300000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.247093038363913
# The root mean squared error is:  11.339887538564136
# The correlation is:  0.1142842317931282
# ----------------------------------------
# alpha: 310000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.231919697245261
# The root mean squared error is:  11.233322870368697
# The correlation is:  0.1141007631818407
# ----------------------------------------
# alpha: 320000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.217190488408861
# The root mean squared error is:  11.131491988837178
# The correlation is:  0.11392814754876408
# ----------------------------------------
# alpha: 330000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.202890490885816
# The root mean squared error is:  11.034131668086218
# The correlation is:  0.11376544863576515
# ----------------------------------------
# alpha: 340000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.189121025302397
# The root mean squared error is:  10.94099591749154
# The correlation is:  0.11361183496169035
# ----------------------------------------
# alpha: 350000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.175868469288303
# The root mean squared error is:  10.851854737021803
# The correlation is:  0.11346656555207912
# ----------------------------------------
# alpha: 360000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.16299324135972
# The root mean squared error is:  10.766492960400662
# The correlation is:  0.11332897794112054
# ----------------------------------------
# alpha: 370000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.150481800464114
# The root mean squared error is:  10.684709182550698
# The correlation is:  0.11319847803435275
# ----------------------------------------
# alpha: 380000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.138320977846572
# The root mean squared error is:  10.606314766942711
# The correlation is:  0.1130745315036793
# ----------------------------------------
# alpha: 390000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.126498008180342
# The root mean squared error is:  10.531132928042203
# The correlation is:  0.11295665645094181
# ----------------------------------------
# alpha: 400000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.115000549207231
# The root mean squared error is:  10.458997883882887
# The correlation is:  0.11284441712696382
# ----------------------------------------
# alpha: 410000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.103816692502687
# The root mean squared error is:  10.38975407381536
# The correlation is:  0.11273741853294936
# ----------------------------------------
# alpha: 420000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.092934967416313
# The root mean squared error is:  10.323255436614753
# The correlation is:  0.11263530176284964
# ----------------------------------------
# alpha: 430000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.082344339799157
# The root mean squared error is:  10.259364744340067
# The correlation is:  0.11253773997063499
# ----------------------------------------
# alpha: 440000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.072034206785298
# The root mean squared error is:  10.197952987589943
# The correlation is:  0.11244443486674398
# ----------------------------------------
# alpha: 450000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.061994388625529
# The root mean squared error is:  10.138898808073161
# The correlation is:  0.11235511366439045
# ----------------------------------------
# alpha: 460000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.052215118358524
# The root mean squared error is:  10.082087974693374
# The correlation is:  0.11226952640971657
# ----------------------------------------
# alpha: 470000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.04268702993729
# The root mean squared error is:  10.027412899626453
# The correlation is:  0.11218744364063205
# ----------------------------------------
# alpha: 480000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.033538563751634
# The root mean squared error is:  9.974772191139161
# The correlation is:  0.11210865432805665
# ----------------------------------------
# alpha: 490000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.02463610762625
# The root mean squared error is:  9.92407024015584
# The correlation is:  0.11203296406058927
# ----------------------------------------
# alpha: 500000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.015954848829067
# The root mean squared error is:  9.875216837822927
# The correlation is:  0.1119601934396603
# ----------------------------------------
# alpha: 510000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.007487061943
# The root mean squared error is:  9.828126821548537
# The correlation is:  0.11189017665722169
# ----------------------------------------
# alpha: 520000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.9992253442765024
# The root mean squared error is:  9.782719747205437
# The correlation is:  0.11182276023219236
# ----------------------------------------
# alpha: 530000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.991162602537588
# The root mean squared error is:  9.73891958538087
# The correlation is:  0.11175780188535783
# ----------------------------------------
# alpha: 540000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.983292039719039
# The root mean squared error is:  9.696654439736372
# The correlation is:  0.11169516953533337
# ----------------------------------------
# alpha: 550000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.975607142275247
# The root mean squared error is:  9.65585628570571
# The correlation is:  0.11163474040065569
# ----------------------------------------
# alpha: 560000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.968101667649598
# The root mean squared error is:  9.616460727910015
# The correlation is:  0.11157640019513841
# ----------------------------------------
# alpha: 570000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.960832977523473
# The root mean squared error is:  9.578406774807556
# The correlation is:  0.11152004240537691
# ----------------------------------------
# alpha: 580000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.953770280547557
# The root mean squared error is:  9.541636629221586
# The correlation is:  0.11146556764077924
# ----------------------------------------
# alpha: 590000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.946867279326822
# The root mean squared error is:  9.506095493505043
# The correlation is:  0.11141288304776652
# ----------------------------------------
# alpha: 600000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.940118790688876
# The root mean squared error is:  9.471731388205779
# The correlation is:  0.11136190178086795
# ----------------------------------------
# alpha: 610000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.9335535303018645
# The root mean squared error is:  9.438494983191813
# The correlation is:  0.11131254252436622
# ----------------------------------------
# alpha: 620000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.927313659163956
# The root mean squared error is:  9.406339440283272
# The correlation is:  0.11126472905894252
# ----------------------------------------
# alpha: 630000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.921209067582666
# The root mean squared error is:  9.375220266517363
# The correlation is:  0.11121838986845618
# ----------------------------------------
# alpha: 640000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.915235524298533
# The root mean squared error is:  9.345095177244994
# The correlation is:  0.11117345778259037
# ----------------------------------------
# alpha: 650000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.909388965192231
# The root mean squared error is:  9.315923968323936
# The correlation is:  0.11112986965159942
# ----------------------------------------
# alpha: 660000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.90366548570213
# The root mean squared error is:  9.287668396733494
# The correlation is:  0.11108756604984543
# ----------------------------------------
# alpha: 670000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.898061333593648
# The root mean squared error is:  9.260292068990704
# The correlation is:  0.11104649100519194
# ----------------------------------------
# alpha: 680000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.892572902068342
# The root mean squared error is:  9.233760336798198
# The correlation is:  0.11100659175166129
# ----------------------------------------
# alpha: 690000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.887196723200212
# The root mean squared error is:  9.208040199399571
# The correlation is:  0.11096781850305462
# ----------------------------------------
# alpha: 700000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.881929461686157
# The root mean squared error is:  9.183100212159973
# The correlation is:  0.11093012424548995
# ----------------------------------------
# alpha: 710000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.876767908897485
# The root mean squared error is:  9.158910400927791
# The correlation is:  0.1108934645470398
# ----------------------------------------
# alpha: 720000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.871708977219385
# The root mean squared error is:  9.13544218176821
# The correlation is:  0.11085779738284433
# ----------------------------------------
# alpha: 730000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.866749694665381
# The root mean squared error is:  9.112668285691333
# The correlation is:  0.11082308297425368
# ----------------------------------------
# alpha: 740000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.861887199754006
# The root mean squared error is:  9.09056268802688
# The correlation is:  0.11078928364070137
# ----------------------------------------
# alpha: 750000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.857118736635356
# The root mean squared error is:  9.069100542124117
# The correlation is:  0.11075636366314995
# ----------------------------------------
# alpha: 760000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.852441650455396
# The root mean squared error is:  9.048258117080293
# The correlation is:  0.11072428915806684
# ----------------------------------------
# alpha: 770000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.847853382946434
# The root mean squared error is:  9.0280127392233
# The correlation is:  0.11069302796099485
# ----------------------------------------
# alpha: 780000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.843351468232506
# The root mean squared error is:  9.008342737094896
# The correlation is:  0.11066254951887575
# ----------------------------------------
# alpha: 790000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.838933528838964
# The root mean squared error is:  8.989227389699833
# The correlation is:  0.1106328247903684
# ----------------------------------------
# alpha: 800000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.834597271895884
# The root mean squared error is:  8.970646877803505
# The correlation is:  0.11060382615347787
# ----------------------------------------
# alpha: 810000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.830340485525506
# The root mean squared error is:  8.952582238076857
# The correlation is:  0.11057552731987627
# ----------------------------------------
# alpha: 820000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.826161035404251
# The root mean squared error is:  8.935015319901904
# The correlation is:  0.1105479032553576
# ----------------------------------------
# alpha: 830000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.822056861490406
# The root mean squared error is:  8.91792874466473
# The correlation is:  0.11052093010591985
# ----------------------------------------
# alpha: 840000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.8180259749088945
# The root mean squared error is:  8.901305867375408
# The correlation is:  0.11049458512901403
# ----------------------------------------
# alpha: 850000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.8140664549850944
# The root mean squared error is:  8.885130740465586
# The correlation is:  0.11046884662954613
# ----------------------------------------
# alpha: 860000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.810176446419958
# The root mean squared error is:  8.869388079625232
# The correlation is:  0.11044369390025022
# ----------------------------------------
# alpha: 870000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.8063541565991725
# The root mean squared error is:  8.854063231549668
# The correlation is:  0.11041910716609002
# ----------------------------------------
# alpha: 880000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.80259785302942
# The root mean squared error is:  8.839142143477076
# The correlation is:  0.1103950675323745
# ----------------------------------------
# alpha: 890000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.798905860895179
# The root mean squared error is:  8.824611334405022
# The correlation is:  0.11037155693630071
# ----------------------------------------
# alpha: 900000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.795276560729861
# The root mean squared error is:  8.810457867882112
# The correlation is:  0.11034855810166287
# ----------------------------------------
# alpha: 910000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.791708386195413
# The root mean squared error is:  8.796669326278128
# The correlation is:  0.11032605449648943
# ----------------------------------------
# alpha: 920000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.788199821964772
# The root mean squared error is:  8.783233786442482
# The correlation is:  0.11030403029338884
# ----------------------------------------
# alpha: 930000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.784749401701958
# The root mean squared error is:  8.770139796666934
# The correlation is:  0.11028247033240408
# ----------------------------------------
# alpha: 940000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.781355706134775
# The root mean squared error is:  8.757376354874172
# The correlation is:  0.11026136008619347
# ----------------------------------------
# alpha: 950000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.778017361215423
# The root mean squared error is:  8.744932887959019
# The correlation is:  0.11024068562736875
# ----------------------------------------
# alpha: 960000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.774733036364559
# The root mean squared error is:  8.732799232213964
# The correlation is:  0.11022043359783605
# ----------------------------------------
# alpha: 970000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.771501442794574
# The root mean squared error is:  8.720965614775094
# The correlation is:  0.11020059117999903
# ----------------------------------------
# alpha: 980000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.768321331908094
# The root mean squared error is:  8.70942263602874
# The correlation is:  0.11018114606969166
# ----------------------------------------
# alpha: 990000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.765191493767945
# The root mean squared error is:  8.698161252923024
# The correlation is:  0.11016208645072247
# ----------------------------------------
# alpha: 1000000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.762110755634982
# The root mean squared error is:  8.687172763132027
# The correlation is:  0.11014340097091802
# ----------------------------------------
# alpha: 1010000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.759077980570425
# The root mean squared error is:  8.676448790023718
# The correlation is:  0.11012507871956452
# ----------------------------------------
# alpha: 1020000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.756092066099485
# The root mean squared error is:  8.665981268385796
# The correlation is:  0.11010710920615281
# ----------------------------------------
# alpha: 1030000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.75315194293327
# The root mean squared error is:  8.655762430866602
# The correlation is:  0.11008948234033986
# ----------------------------------------
# alpha: 1040000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.750256573746101
# The root mean squared error is:  8.645784795090833
# The correlation is:  0.11007218841304615
# ----------------------------------------
# alpha: 1050000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.747404952005507
# The root mean squared error is:  8.636041151412371
# The correlation is:  0.11005521807861497
# ----------------------------------------
# alpha: 1060000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.744596100852386
# The root mean squared error is:  8.626524551268862
# The correlation is:  0.11003856233796358
# ----------------------------------------
# alpha: 1070000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.74182907202884
# The root mean squared error is:  8.61722829610482
# The correlation is:  0.1100222125226642
# ----------------------------------------
# alpha: 1080000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.73910294485143
# The root mean squared error is:  8.608145926832101
# The correlation is:  0.11000616027989343
# ----------------------------------------
# alpha: 1090000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.73641682522765
# The root mean squared error is:  8.599271213798465
# The correlation is:  0.10999039755819795
# ----------------------------------------
# alpha: 1100000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.733769844713562
# The root mean squared error is:  8.590598147236722
# The correlation is:  0.10997491659402193
# ----------------------------------------
# alpha: 1110000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.731161159610651
# The root mean squared error is:  8.582120928168596
# The correlation is:  0.10995970989895247
# ----------------------------------------
# alpha: 1120000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.728589950100018
# The root mean squared error is:  8.573833959738982
# The correlation is:  0.10994477024763599
# ----------------------------------------
# alpha: 1130000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.726090371618601
# The root mean squared error is:  8.565731838957737
# The correlation is:  0.10993009066632713
# ----------------------------------------
# alpha: 1140000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.7236327890258885
# The root mean squared error is:  8.557809348827453
# The correlation is:  0.10991566442202934
# ----------------------------------------
# alpha: 1150000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.721209759757053
# The root mean squared error is:  8.550061450836969
# The correlation is:  0.10990148501219459
# ----------------------------------------
# alpha: 1160000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.7188205645276895
# The root mean squared error is:  8.542483277801509
# The correlation is:  0.10988754615494635
# ----------------------------------------
# alpha: 1170000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.716464503732152
# The root mean squared error is:  8.535070127031469
# The correlation is:  0.10987384177979669
# ----------------------------------------
# alpha: 1180000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.714140896781414
# The root mean squared error is:  8.527817453812887
# The correlation is:  0.10986036601882812
# ----------------------------------------
# alpha: 1190000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.711849081467138
# The root mean squared error is:  8.520720865183668
# The correlation is:  0.10984711319831272
# ----------------------------------------
# alpha: 1200000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.709588413350826
# The root mean squared error is:  8.513776113990396
# The correlation is:  0.10983407783074517
# ----------------------------------------
# alpha: 1210000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.707358265176879
# The root mean squared error is:  8.50697909321161
# The correlation is:  0.10982125460726301
# ----------------------------------------
# alpha: 1220000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.705158026308526
# The root mean squared error is:  8.500325830534049
# The correlation is:  0.10980863839043652
# ----------------------------------------
# alpha: 1230000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.702987102185578
# The root mean squared error is:  8.493812483169217
# The correlation is:  0.10979622420740233
# ----------------------------------------
# alpha: 1240000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.700844913803068
# The root mean squared error is:  8.487435332898315
# The correlation is:  0.10978400724332715
# ----------------------------------------
# alpha: 1250000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.69873089720984
# The root mean squared error is:  8.481190781334199
# The correlation is:  0.10977198283517837
# ----------------------------------------
# alpha: 1260000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.696644503026217
# The root mean squared error is:  8.475075345389698
# The correlation is:  0.10976014646578833
# ----------------------------------------
# alpha: 1270000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.69458519597991
# The root mean squared error is:  8.469085652942177
# The correlation is:  0.10974849375819482
# ----------------------------------------
# alpha: 1280000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.692552454459407
# The root mean squared error is:  8.463218438684795
# The correlation is:  0.10973702047024263
# ----------------------------------------
# alpha: 1290000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.690545770084048
# The root mean squared error is:  8.457470540155418
# The correlation is:  0.1097257224894329
# ----------------------------------------
# alpha: 1300000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.688564647290098
# The root mean squared error is:  8.45183889393462
# The correlation is:  0.10971459582800681
# ----------------------------------------
# alpha: 1310000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.686608602932127
# The root mean squared error is:  8.446320532004695
# The correlation is:  0.10970363661825164
# ----------------------------------------
# alpha: 1320000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.684677165899047
# The root mean squared error is:  8.440912578261997
# The correlation is:  0.10969284110801665
# ----------------------------------------
# alpha: 1330000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.682769876744199
# The root mean squared error is:  8.435612245175344
# The correlation is:  0.10968220565642857
# ----------------------------------------
# alpha: 1340000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.680886287328875
# The root mean squared error is:  8.430416830583617
# The correlation is:  0.10967172672979694
# ----------------------------------------
# alpha: 1350000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.679025960478739
# The root mean squared error is:  8.425323714626018
# The correlation is:  0.1096614008976982
# ----------------------------------------
# alpha: 1360000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.677188469652616
# The root mean squared error is:  8.420330356798821
# The correlation is:  0.10965122482923059
# ----------------------------------------
# alpha: 1370000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.675373398623099
# The root mean squared error is:  8.415434293132735
# The correlation is:  0.10964119528943102
# ----------------------------------------
# alpha: 1380000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.673580341168528
# The root mean squared error is:  8.410633133485323
# The correlation is:  0.10963130913584455
# ----------------------------------------
# alpha: 1390000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.671808900775874
# The root mean squared error is:  8.405924558943212
# The correlation is:  0.10962156331524245
# ----------------------------------------
# alpha: 1400000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.670058690354049
# The root mean squared error is:  8.401306319329068
# The correlation is:  0.10961195486047626
# ----------------------------------------
# alpha: 1410000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.668329331957262
# The root mean squared error is:  8.396776230808591
# The correlation is:  0.10960248088746534
# ----------------------------------------
# alpha: 1420000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.6666204565179985
# The root mean squared error is:  8.392332173593006
# The correlation is:  0.10959313859231079
# ----------------------------------------
# alpha: 1430000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.664931703589234
# The root mean squared error is:  8.387972089732779
# The correlation is:  0.10958392524852717
# ----------------------------------------
# alpha: 1440000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.663262721095524
# The root mean squared error is:  8.383693980998455
# The correlation is:  0.1095748382043891
# ----------------------------------------
# alpha: 1450000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.661613165092612
# The root mean squared error is:  8.379495906844761
# The correlation is:  0.10956587488038684
# ----------------------------------------
# alpha: 1460000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.659982699535213
# The root mean squared error is:  8.375375982454306
# The correlation is:  0.10955703276678373
# ----------------------------------------
# alpha: 1470000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.6583709960526924
# The root mean squared error is:  8.371332376857328
# The correlation is:  0.10954830942127292
# ----------------------------------------
# alpha: 1480000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.656777733732262
# The root mean squared error is:  8.367363311124226
# The correlation is:  0.10953970246672826
# ----------------------------------------
# alpha: 1490000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.655202598909464
# The root mean squared error is:  8.363467056627636
# The correlation is:  0.1095312095890434
# ----------------------------------------
# alpha: 1500000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.65364528496564
# The root mean squared error is:  8.359641933371089
# The correlation is:  0.10952282853505763
# ----------------------------------------
# alpha: 1510000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.6521054921320975
# The root mean squared error is:  8.35588630838137
# The correlation is:  0.10951455711056216
# ----------------------------------------
# alpha: 1520000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.650582927300757
# The root mean squared error is:  8.352198594161806
# The correlation is:  0.10950639317838481
# ----------------------------------------
# alpha: 1530000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.649077303840997
# The root mean squared error is:  8.34857724720394
# The correlation is:  0.10949833465654854
# ----------------------------------------
# alpha: 1540000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.647588341422488
# The root mean squared error is:  8.34502076655507
# The correlation is:  0.10949037951650048
# ----------------------------------------
# alpha: 1550000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.646115765843766
# The root mean squared error is:  8.341527692439298
# The correlation is:  0.10948252578140999
# ----------------------------------------
# alpha: 1560000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.64465930886636
# The root mean squared error is:  8.338096604929847
# The correlation is:  0.10947477152452972
# ----------------------------------------
# alpha: 1570000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.643218708054238
# The root mean squared error is:  8.334726122670494
# The correlation is:  0.10946711486762042
# ----------------------------------------
# alpha: 1580000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.641793706618407
# The root mean squared error is:  8.331414901644074
# The correlation is:  0.10945955397943236
# ----------------------------------------
# alpha: 1590000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.640384053266419
# The root mean squared error is:  8.328161633986086
# The correlation is:  0.10945208707424675
# ----------------------------------------
# alpha: 1600000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.638989502056682
# The root mean squared error is:  8.324965046841589
# The correlation is:  0.10944471241046777
# ----------------------------------------
# alpha: 1610000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.637609812257344
# The root mean squared error is:  8.321823901263524
# The correlation is:  0.10943742828926876
# ----------------------------------------
# alpha: 1620000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.636244748209583
# The root mean squared error is:  8.318736991150876
# The correlation is:  0.10943023305328796
# ----------------------------------------
# alpha: 1630000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.634894079195189
# The root mean squared error is:  8.315703142224956
# The correlation is:  0.10942312508536954
# ----------------------------------------
# alpha: 1640000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.6335575793082295
# The root mean squared error is:  8.312721211042323
# The correlation is:  0.10941610280735288
# ----------------------------------------
# alpha: 1650000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.6322350273306885
# The root mean squared error is:  8.309790084042845
# The correlation is:  0.10940916467890373
# ----------------------------------------
# alpha: 1660000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.630926206611934
# The root mean squared error is:  8.306908676631494
# The correlation is:  0.10940230919638774
# ----------------------------------------
# alpha: 1670000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.6296309049518465
# The root mean squared error is:  8.304075932292509
# The correlation is:  0.10939553489178369
# ----------------------------------------
# alpha: 1680000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.628348914487525
# The root mean squared error is:  8.301290821734693
# The correlation is:  0.10938884033163546
# ----------------------------------------
# alpha: 1690000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.627080031583412
# The root mean squared error is:  8.298552342066541
# The correlation is:  0.10938222411604061
# ----------------------------------------
# alpha: 1700000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.625824056724734
# The root mean squared error is:  8.295859516000084
# The correlation is:  0.10937568487767431
# ----------------------------------------
# alpha: 1710000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.6245807944141255
# The root mean squared error is:  8.293211391082279
# The correlation is:  0.10936922128084671
# ----------------------------------------
# alpha: 1720000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.62335005307136
# The root mean squared error is:  8.290607038952917
# The correlation is:  0.10936283202059423
# ----------------------------------------
# alpha: 1730000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.622131644936025
# The root mean squared error is:  8.288045554627967
# The correlation is:  0.10935651582179985
# ----------------------------------------
# alpha: 1740000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.620925385973105
# The root mean squared error is:  8.2855260558074
# The correlation is:  0.10935027143834564
# ----------------------------------------
# alpha: 1750000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.619731095781324
# The root mean squared error is:  8.283047682206567
# The correlation is:  0.10934409765229228
# ----------------------------------------
# alpha: 1760000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.618548597504178
# The root mean squared error is:  8.280609594910187
# The correlation is:  0.10933799327308746
# ----------------------------------------
# alpha: 1770000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.617377717743546
# The root mean squared error is:  8.278210975748104
# The correlation is:  0.10933195713680012
# ----------------------------------------
# alpha: 1780000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.616218286475833
# The root mean squared error is:  8.275851026692012
# The correlation is:  0.10932598810538059
# ----------------------------------------
# alpha: 1790000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.615070136970504
# The root mean squared error is:  8.273528969272284
# The correlation is:  0.10932008506594523
# ----------------------------------------
# alpha: 1800000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.613933105710975
# The root mean squared error is:  8.271244044014246
# The correlation is:  0.10931424693008442
# ----------------------------------------
# alpha: 1810000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.612807032317768
# The root mean squared error is:  8.268995509893053
# The correlation is:  0.10930847263319324
# ----------------------------------------
# alpha: 1820000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.611691759473839
# The root mean squared error is:  8.266782643806588
# The correlation is:  0.10930276113382495
# ----------------------------------------
# alpha: 1830000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.610587132852033
# The root mean squared error is:  8.264604740065622
# The correlation is:  0.10929711141306395
# ----------------------------------------
# alpha: 1840000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.609493001044588
# The root mean squared error is:  8.26246110990065
# The correlation is:  0.10929152247391974
# ----------------------------------------
# alpha: 1850000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.608409215494607
# The root mean squared error is:  8.260351080984762
# The correlation is:  0.10928599334074109
# ----------------------------------------
# alpha: 1860000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.607335630429451
# The root mean squared error is:  8.258273996971981
# The correlation is:  0.10928052305864704
# ----------------------------------------
# alpha: 1870000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.606272102795987
# The root mean squared error is:  8.256229217050475
# The correlation is:  0.109275110692978
# ----------------------------------------
# alpha: 1880000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.605218492197627
# The root mean squared error is:  8.254216115510138
# The correlation is:  0.10926975532876279
# ----------------------------------------
# alpha: 1890000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.604174660833102
# The root mean squared error is:  8.252234081323984
# The correlation is:  0.10926445607020299
# ----------------------------------------
# alpha: 1900000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.603140473436916
# The root mean squared error is:  8.250282517742882
# The correlation is:  0.10925921204017362
# ----------------------------------------
# alpha: 1910000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.6021157972214315
# The root mean squared error is:  8.248360841903136
# The correlation is:  0.10925402237973862
# ----------------------------------------
# alpha: 1920000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.601100501820532
# The root mean squared error is:  8.246468484446458
# The correlation is:  0.10924888624768202
# ----------------------------------------
# alpha: 1930000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.60014005897526
# The root mean squared error is:  8.244604889151894
# The correlation is:  0.10924380282005361
# ----------------------------------------
# alpha: 1940000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.599193075710759
# The root mean squared error is:  8.242769512579274
# The correlation is:  0.10923877128972748
# ----------------------------------------
# alpha: 1950000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.598254641389425
# The root mean squared error is:  8.240961823723786
# The correlation is:  0.10923379086597548
# ----------------------------------------
# alpha: 1960000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.597324640977748
# The root mean squared error is:  8.239181303681267
# The correlation is:  0.10922886077405283
# ----------------------------------------
# alpha: 1970000
# ...
# ----------------------------------------
# alpha: 7500000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.452647334817488
# The root mean squared error is:  8.095635307170292
# The correlation is:  0.10851360058657929
# ----------------------------------------
# alpha: 7510000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.452577118389912
# The root mean squared error is:  8.095631966892629
# The correlation is:  0.10851326120823596
# ----------------------------------------
# alpha: 7520000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.4525070824726996
# The root mean squared error is:  8.095628707429526
# The correlation is:  0.10851292273019858
# ----------------------------------------
# alpha: 7530000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.452437226370739
# The root mean squared error is:  8.095625528190434
# The correlation is:  0.108512585148889
# ----------------------------------------
# alpha: 7540000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.452367549392492
# The root mean squared error is:  8.095622428589275
# The correlation is:  0.10851224846074847
# ----------------------------------------
# alpha: 7550000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.452298050849955
# The root mean squared error is:  8.095619408044394
# The correlation is:  0.10851191266223717
# ----------------------------------------
# alpha: 7560000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.452228730058645
# The root mean squared error is:  8.09561646597853
# The correlation is:  0.10851157774983346
# ----------------------------------------
# alpha: 7570000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.452159586337577
# The root mean squared error is:  8.095613601818771
# The correlation is:  0.10851124372003487
# ----------------------------------------
# alpha: 7580000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.452090619009234
# The root mean squared error is:  8.09561081499652
# The correlation is:  0.10851091056935684
# ----------------------------------------
# alpha: 7590000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.45202182739956
# The root mean squared error is:  8.095608104947464
# The correlation is:  0.10851057829433323
# ----------------------------------------
# alpha: 7600000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.45195321083792
# The root mean squared error is:  8.09560547111153
# The correlation is:  0.10851024689151662
# ----------------------------------------
# alpha: 7610000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.4518847686570915
# The root mean squared error is:  8.095602912932852
# The correlation is:  0.10850991635747677
# ----------------------------------------
# alpha: 7620000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.451816500193236
# The root mean squared error is:  8.09560042985974
# The correlation is:  0.10850958668880215
# ----------------------------------------
# alpha: 7630000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.4517484047858815
# The root mean squared error is:  8.095598021344639
# The correlation is:  0.10850925788209873
# ----------------------------------------
# alpha: 7640000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.4516804817779
# The root mean squared error is:  8.095595686844096
# The correlation is:  0.10850892993399026
# ----------------------------------------
# alpha: 7650000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.451612730515482
# The root mean squared error is:  8.095593425818727
# The correlation is:  0.10850860284111817
# ----------------------------------------
# alpha: 7660000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.451545150348127
# The root mean squared error is:  8.095591237733183
# The correlation is:  0.1085082766001413
# ----------------------------------------
# alpha: 7670000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.451477740628605
# The root mean squared error is:  8.095589122056118
# The correlation is:  0.10850795120773578
# ----------------------------------------
# alpha: 7680000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.451410500712955
# The root mean squared error is:  8.095587078260149
# The correlation is:  0.10850762666059538
# ----------------------------------------
# alpha: 7690000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.451343429960452
# The root mean squared error is:  8.095585105821828
# The correlation is:  0.10850730295543067
# ----------------------------------------
# alpha: 7700000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.4512765277335875
# The root mean squared error is:  8.095583204221608
# The correlation is:  0.10850698008896935
# ----------------------------------------
# alpha: 7710000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.451209793398056
# The root mean squared error is:  8.095581372943817
# The correlation is:  0.10850665805795598
# ----------------------------------------
# alpha: 7720000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.451143226322732
# The root mean squared error is:  8.095579611476607
# The correlation is:  0.1085063368591521
# ----------------------------------------
# alpha: 7730000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.451076825879643
# The root mean squared error is:  8.09557791931195
# The correlation is:  0.108506016489336
# ----------------------------------------
# alpha: 7740000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.4510105914439615
# The root mean squared error is:  8.09557629594558
# The correlation is:  0.10850569694530231
# ----------------------------------------
# alpha: 7750000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.450944522393977
# The root mean squared error is:  8.095574740876978
# The correlation is:  0.1085053782238626
# ----------------------------------------
# alpha: 7760000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.450878618111078
# The root mean squared error is:  8.095573253609336
# The correlation is:  0.10850506032184429
# ----------------------------------------
# alpha: 7770000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.450812877979737
# The root mean squared error is:  8.095571833649526
# The correlation is:  0.10850474323609159
# ----------------------------------------
# alpha: 7780000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.450747301387489
# The root mean squared error is:  8.09557048050807
# The correlation is:  0.10850442696346453
# ----------------------------------------
# alpha: 7790000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.450681887724907
# The root mean squared error is:  8.095569193699104
# The correlation is:  0.10850411150083955
# ----------------------------------------
# alpha: 7800000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.450616636385593
# The root mean squared error is:  8.095567972740367
# The correlation is:  0.10850379684510866
# ----------------------------------------
# alpha: 7810000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.4505515467661505
# The root mean squared error is:  8.095566817153149
# The correlation is:  0.10850348299318005
# ----------------------------------------
# alpha: 7820000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.450486618266172
# The root mean squared error is:  8.095565726462269
# The correlation is:  0.10850316994197785
# ----------------------------------------
# alpha: 7830000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.450421850288217
# The root mean squared error is:  8.095564700196059
# The correlation is:  0.10850285768844124
# ----------------------------------------
# alpha: 7840000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.4503572422377955
# The root mean squared error is:  8.095563737886314
# The correlation is:  0.1085025462295258
# ----------------------------------------
# alpha: 7850000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.450292793523349
# The root mean squared error is:  8.09556283906828
# The correlation is:  0.10850223556220204
# ----------------------------------------
# alpha: 7860000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.450228503556231
# The root mean squared error is:  8.095562003280618
# The correlation is:  0.10850192568345549
# ----------------------------------------
# alpha: 7870000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.450164371750694
# The root mean squared error is:  8.095561230065375
# The correlation is:  0.10850161659028797
# ----------------------------------------
# alpha: 7880000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.450100397523864
# The root mean squared error is:  8.095560518967964
# The correlation is:  0.10850130827971585
# ----------------------------------------
# alpha: 7890000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.450036580295731
# The root mean squared error is:  8.09555986953713
# The correlation is:  0.10850100074877074
# ----------------------------------------
# alpha: 7900000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.449972919489129
# The root mean squared error is:  8.095559281324922
# The correlation is:  0.10850069399449899
# ----------------------------------------
# alpha: 7910000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.44990941452971
# The root mean squared error is:  8.095558753886671
# The correlation is:  0.10850038801396236
# ----------------------------------------
# alpha: 7920000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.449846064845944
# The root mean squared error is:  8.09555828678096
# The correlation is:  0.10850008280423658
# ----------------------------------------
# alpha: 7930000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.449782869869081
# The root mean squared error is:  8.0955578795696
# The correlation is:  0.10849977836241316
# ----------------------------------------
# alpha: 7940000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.449719829033155
# The root mean squared error is:  8.0955575318176
# The correlation is:  0.10849947468559742
# ----------------------------------------
# alpha: 7950000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.449656941774953
# The root mean squared error is:  8.095557243093142
# The correlation is:  0.1084991717709097
# ----------------------------------------
# alpha: 7960000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.449594207534
# The root mean squared error is:  8.09555701296756
# The correlation is:  0.10849886961548444
# ----------------------------------------
# alpha: 7970000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.449531625752549
# The root mean squared error is:  8.095556841015311
# The correlation is:  0.1084985682164703
# ----------------------------------------
# alpha: 7980000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.4494691958755554
# The root mean squared error is:  8.095556726813946
# The correlation is:  0.10849826757103084
# ----------------------------------------
# alpha: 7990000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.449406917350668
# The root mean squared error is:  8.09555666994409
# The correlation is:  0.1084979676763432
# ----------------------------------------
# alpha: 8000000
# alpha: 8010000
# alpha: 8020000
# alpha: 8030000
# alpha: 8040000
# alpha: 8050000
# alpha: 8060000
# alpha: 8070000
# alpha: 8080000
# alpha: 8090000
# alpha: 8100000
# alpha: 8110000
# alpha: 8120000
# alpha: 8130000
# alpha: 8140000
# alpha: 8150000
# alpha: 8160000
# alpha: 8170000
# alpha: 8180000
# alpha: 8190000
# alpha: 8200000
# alpha: 8210000
# alpha: 8220000
# alpha: 8230000
# alpha: 8240000
# alpha: 8250000
# alpha: 8260000
# alpha: 8270000
# alpha: 8280000
# alpha: 8290000
# alpha: 8300000
# alpha: 8310000
# alpha: 8320000
# alpha: 8330000
# alpha: 8340000
# alpha: 8350000
# alpha: 8360000
# alpha: 8370000
# alpha: 8380000
# alpha: 8390000
# alpha: 8400000
# alpha: 8410000
# alpha: 8420000
# alpha: 8430000
# alpha: 8440000
# alpha: 8450000
# alpha: 8460000
# alpha: 8470000
# alpha: 8480000
# alpha: 8490000
# alpha: 8500000
# alpha: 8510000
# alpha: 8520000
# alpha: 8530000
# alpha: 8540000
# alpha: 8550000
# alpha: 8560000
# alpha: 8570000
# alpha: 8580000
# alpha: 8590000
# alpha: 8600000
# alpha: 8610000
# alpha: 8620000
# alpha: 8630000
# alpha: 8640000
# alpha: 8650000
# alpha: 8660000
# alpha: 8670000
# alpha: 8680000
# alpha: 8690000
# alpha: 8700000
# alpha: 8710000
# alpha: 8720000
# alpha: 8730000
# alpha: 8740000
# alpha: 8750000
# alpha: 8760000
# alpha: 8770000
# alpha: 8780000
# alpha: 8790000
# alpha: 8800000
# alpha: 8810000
# alpha: 8820000
# alpha: 8830000
# alpha: 8840000
# alpha: 8850000
# alpha: 8860000
# alpha: 8870000
# alpha: 8880000
# alpha: 8890000
# alpha: 8900000
# alpha: 8910000
# alpha: 8920000
# alpha: 8930000
# alpha: 8940000
# alpha: 8950000
# alpha: 8960000
# alpha: 8970000
# alpha: 8980000
# alpha: 8990000
# alpha: 9000000
# alpha: 9010000
# alpha: 9020000
# alpha: 9030000
# alpha: 9040000
# alpha: 9050000
# alpha: 9060000
# alpha: 9070000
# alpha: 9080000
# alpha: 9090000
# alpha: 9100000
# alpha: 9110000
# alpha: 9120000
# alpha: 9130000
# alpha: 9140000
# alpha: 9150000
# alpha: 9160000
# alpha: 9170000
# alpha: 9180000
# alpha: 9190000
# alpha: 9200000
# alpha: 9210000
# alpha: 9220000
# alpha: 9230000
# alpha: 9240000
# alpha: 9250000
# alpha: 9260000
# alpha: 9270000
# alpha: 9280000
# alpha: 9290000
# alpha: 9300000
# alpha: 9310000
# alpha: 9320000
# alpha: 9330000
# alpha: 9340000
# alpha: 9350000
# alpha: 9360000
# alpha: 9370000
# alpha: 9380000
# alpha: 9390000
# alpha: 9400000
# alpha: 9410000
# alpha: 9420000
# alpha: 9430000
# alpha: 9440000
# alpha: 9450000
# alpha: 9460000
# alpha: 9470000
# alpha: 9480000
# alpha: 9490000
# alpha: 9500000
# alpha: 9510000
# alpha: 9520000
# alpha: 9530000
# alpha: 9540000
# alpha: 9550000
# alpha: 9560000
# alpha: 9570000
# alpha: 9580000
# alpha: 9590000
# alpha: 9600000
# alpha: 9610000
# alpha: 9620000
# alpha: 9630000
# alpha: 9640000
# alpha: 9650000
# alpha: 9660000
# alpha: 9670000
# alpha: 9680000
# alpha: 9690000
# alpha: 9700000
# alpha: 9710000
# alpha: 9720000
# alpha: 9730000
# alpha: 9740000
# alpha: 9750000
# alpha: 9760000
# alpha: 9770000
# alpha: 9780000
# alpha: 9790000
# alpha: 9800000
# alpha: 9810000
# alpha: 9820000
# alpha: 9830000
# alpha: 9840000
# alpha: 9850000
# alpha: 9860000
# alpha: 9870000
# alpha: 9880000
# alpha: 9890000
# alpha: 9900000
# alpha: 9910000
# alpha: 9920000
# alpha: 9930000
# alpha: 9940000
# alpha: 9950000
# alpha: 9960000
# alpha: 9970000
# alpha: 9980000
# alpha: 9990000

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.3, 154 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train2_X2,train2_y,test2_X2,test2_y))

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.4, 105 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train2_X3,train2_y,test2_X3,test2_y))

# %%
## tuned alpha based on validation set, then measure the performance for test set.
## Fixing l1-ratio = 0.3
para = [0,7990000]
rmse=100000
mae=1000000
corr=0
for a in para:
    print('alpha:',a)
    rmse0,mae0,corr0 = ridge(a,train1_X1,train1_y,val1_X1,val1_y)
    if rmse0< rmse:
        rmse=rmse0
        mae=mae0
        corr = corr0
        print('========================================')
        print('Best RMSE is updated! ' )
        print('The mean absolute error is: ',mae)
        print('The root mean squared error is: ',rmse)
        print('The correlation is: ',corr)
        print('----------------------------------------')
# Out:
# alpha: 0
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  23.84991227284693
# The root mean squared error is:  49.25516226820323
# The correlation is:  0.7491690821004
# ----------------------------------------
# alpha: 7990000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.983334575979702
# The root mean squared error is:  27.37858452479817
# The correlation is:  0.7673283115474481
# ----------------------------------------
