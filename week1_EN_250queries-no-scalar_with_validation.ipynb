# %% [markdown]
# ## tasks
# ### 1: Form training and testing periods as discussed (2 test periods, last 2*365 days). Be careful tp scale data only based on data from the training set. You may use (from Python) MinMaxScaler, standardisation (StandardScaler) or the default scaler in Python's elastic net.
# ### 2:Estimate the current flu rates by training an elastic net model. Use a Pearson correlation filter (r > 0.3) on the training data to reduce the amount of queries prior to training an elastic net (reminder: not all 1000 queries I provided are related to flu!). Report performance on the two test sets using three metrics: mean absolute error, root mean squared error and Pearson's correlation.
# ### 3: If there is time, begin work on traditional forecasting models (you've identified seasonal ARIMA and Hult-Winters).

# %%
# import libraries
import numpy as np
import pandas as pd
import random
import csv
import scipy.stats as stats
import seaborn as sns
from collections import Counter
from collections import defaultdict
import math
from sklearn.linear_model import ElasticNet
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from random import randint

import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm
from statsmodels.nonparametric.kde import KDEUnivariate
from statsmodels.nonparametric import smoothers_lowess
from pandas import Series, DataFrame
from patsy import dmatrices
from sklearn import datasets, svm

# initialize the plotting sizes
# set size
plt.rc('figure', figsize=(10, 5))
# subplots size
fizsize_with_subplots = (10, 10)
# histogram size
bin_size = 10

# %%
# Loading data
dates = pd.read_csv('data/dates.csv',header=None)
queries = pd.read_csv('data/queries.csv',header=None)
X = pd.read_csv('data/X.csv',header=None)
y = pd.read_csv('data/y.csv',header=None)

X.columns = queries

# %%
# data preprocessing and train-test split
# this data is well formed with no missing value and other symbols or labels that are non numerical.
# splitting the data into train and test

# Here we want the first 500 queries
X = X.iloc[:, 0: 250]

# first with the last year as test
# for convinience, pick the two validation set starting from 1/3 and 2/3 of the training set,
# 10% of training set as validation, here use 400 data points, two 200 periods.
test_size =365
length = X.shape[0]
l =(X.shape[0]-test_size)//3

train1_X = pd.concat([X[0:l],X[l+200:2*l],X[2*l+200:length-test_size]])
val1_X = pd.concat([X[l:l+200],X[2*l:2*l+200]])
train1_y = pd.concat([y[0:l],y[l+200:2*l],y[2*l+200:length-test_size]])
val1_y = pd.concat([y[l:l+200],y[2*l:2*l+200]])
test1_X = X[length-test_size:]
test1_y = y[length-test_size:]

# second with the last 2 year as test
test_size2 =365*2
l2 =(X.shape[0]-test_size2)//3

train2_X = pd.concat([X[0:l2],X[l2+180:2*l2],X[2*l2+180:length-test_size2]])
val2_X = pd.concat([X[l2:l2+180],X[2*l2:2*l2+180]])
train2_y = pd.concat([y[0:l2],y[l2+180:2*l2],y[2*l2+180:length-test_size2]])
val2_y = pd.concat([y[l2:l2+180],y[2*l2:2*l2+180]])
test2_X = X[length-test_size2:]
test2_y = y[length-test_size2:]

print('X shape: ',X.shape,'  y shape: ',y.shape)
print('train1 X:',train1_X.shape,' train1 y:',train1_y.shape,' Test1 X shape:',test1_X.shape, ' Test1 y shape:',test1_y.shape)
print('validation1 X:',val1_X.shape,' validation1 y:',val1_y.shape)
print('train2 X:',train2_X.shape,' train2 y:',train2_y.shape,' Test2 X:',test2_X.shape,' Test2 y:',test2_y.shape)
print('validation2 X:',val2_X.shape,' validation2 y:',val2_y.shape)
# Out:
# X shape:  (4383, 250)   y shape:  (4383, 1)
# train1 X: (3618, 250)  train1 y: (3618, 1)  Test1 X shape: (365, 250)  Test1 y shape: (365, 1)
# validation1 X: (400, 250)  validation1 y: (400, 1)
# train2 X: (3293, 250)  train2 y: (3293, 1)  Test2 X: (730, 250)  Test2 y: (730, 1)
# validation2 X: (360, 250)  validation2 y: (360, 1)

# %%
train_size = train1_X.shape[0]
corrs = np.zeros((X.shape[1],1))
for i in range(0,X.shape[1]):
    if X.sum(axis=1)[i] == 0:
        corrs[i] = 0
    else:
        corrs[i] = np.corrcoef(X.iloc[0:train_size,i],y.iloc[0:train_size,0])[0,1]
        
corrs.shape,X.columns.shape,X.columns[0],X.columns[249]
# Out:
# ((250, 1), (250,), ('flu',), ('flu incubation',))

# %%
def corr_filter(df_X,df_Xval,df_Xtest,corrs,threshold):
    X = df_X.copy()
    X_test = df_Xtest.copy()
    X_val = df_Xval.copy()
    col_corr = set() # Set of all the names of deleted columns
    for i in range(0,250):
            if corrs[i,0] < threshold: 
                #print(X.columns[i])
                colname = df_X.columns[i]
                del X[colname] # deleting the column from the dataset
                del X_test[colname] 
                del X_val[colname]

    return X,X_val,X_test

# %% [markdown]
# ## Fixing pearson correlation filter r>=0.2

# %%
#train1_X0,test1_X0 = corr_filter(train1_X,test1_X,corrs,0.1)
train1_X1,val1_X1,test1_X1 = corr_filter(train1_X,val1_X,test1_X,corrs,0.2)
#train1_X2,test1_X2 = corr_filter(train1_X,test1_X,corrs,0.3)
#train1_X3,test1_X3 = corr_filter(train1_X,test1_X,corrs,0.4)

# %%
#print('For correlation filter r>=0.1, we select feature number: ',train1_X0.shape[1])
print('For correlation filter r>=0.2, we select feature number: ',train1_X1.shape[1])
#print('For correlation filter r>=0.3, we select feature number: ',train1_X2.shape[1])
#print('For correlation filter r>=0.4, we select feature number: ',train1_X3.shape[1])
# Out:
# For correlation filter r>=0.2, we select feature number:  157

# %%
# Defien the mearure matrics, MAE, RMSE, CORR
# define three metrics: mean absolute error, root mean squared error and Pearson's correlation.
from sklearn.metrics import mean_absolute_error
# mae = mean_absolute_error(y_actual, y_pred)

from sklearn.metrics import mean_squared_error
from math import sqrt
# rmse = sqrt(mean_squared_error(y_actual, y_pred))

# np.correcoef returns Pearson product-moment correlation coefficients
def pearson_r(x,y):   
    corr_mat = np.corrcoef(x,y)
    return corr_mat[0,1]
# r = pearson_r(y_actual,y_pred)


# Generalise the function for convinient tuning
def eNet(a,l,train_X,train_y,test_X,test_y):
    alpha = a
    l1_ratio = l
    enet = ElasticNet(alpha=a, l1_ratio=l, normalize=False,max_iter=10000)
    enet.fit(train_X,train_y)
    print('Nonzero weights: %d from %d' % (len(np.nonzero(enet.coef_)[0]), len(enet.coef_)))
    y_pred1 = enet.predict(test_X)

    mae1 = mean_absolute_error(test_y, y_pred1)
    #print('The mean absolute error is: ',mae1)

    rmse1 = sqrt(mean_squared_error(test_y, y_pred1))
    #print('The root mean squared error is: ',rmse1)
    
    corr_y = test_y.copy()
    corr_y['y_act'] = test_y
    corr_y['y_pred']= y_pred1
    corr = np.corrcoef(corr_y['y_act'],corr_y['y_pred'])[0,1]
    #print('The correlation is: ',corr)
    
    return rmse1, mae1,corr

# %% [markdown]
# # scaling and modeling
# scaler = MinMaxScaler()
# train1_X0_scaled = scaler.fit_transform(train1_X0)
# test1_X0_scaled = scaler.transform(test1_x0)
#
# train1_X1_scaled = scaler.fit_transform(train1_X1)
# test1_X1_scaled = scaler.transform(test1_x1)
#
# train1_X2_scaled = scaler.fit_transform(train1_X2)
# test1_X2_scaled = scaler.transform(test1_x2)
#
# train1_X3_scaled = scaler.fit_transform(train1_X3)
# test1_X3_scaled = scaler.transform(test1_x3)

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.1, 310 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train1_X0,train1_y,test1_X0,test1_y))

# %%
## Fixing l1-ratio = 0.3, only tuning alpha.
para = range(1,400)
para_l=[0.3]
rmse=100000
mae=1000000
corr=0
print('For correlation filter r>=0.2, 212 features are selected')
for a in para:
    for l in para_l:
        print('alpha:',a,' L1-ratio:',l)
        rmse0,mae0,corr0 = eNet(a,l,train1_X1,train1_y,val1_X1,val1_y)
        if rmse0< rmse:
            rmse=rmse0
            mae=mae0
            corr = corr0
            print('========================================')
            print('Best RMSE is updated! ' )
            print('The mean absolute error is: ',mae)
            print('The root mean squared error is: ',rmse)
            print('The correlation is: ',corr)
            print('----------------------------------------')
# Out:
# For correlation filter r>=0.2, 212 features are selected
# alpha: 1  L1-ratio: 0.3
# Nonzero weights: 136 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.999130057518933
# The root mean squared error is:  46.118053398873684
# The correlation is:  0.7760919674903088
# ----------------------------------------
# alpha: 2  L1-ratio: 0.3
# Nonzero weights: 120 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.53179426896336
# The root mean squared error is:  44.76688615909705
# The correlation is:  0.7950867960507111
# ----------------------------------------
# alpha: 3  L1-ratio: 0.3
# Nonzero weights: 110 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.890202271058264
# The root mean squared error is:  43.13786725712112
# The correlation is:  0.8115744866082267
# ----------------------------------------
# alpha: 4  L1-ratio: 0.3
# Nonzero weights: 100 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.406409317158094
# The root mean squared error is:  41.810163148205284
# The correlation is:  0.8247583603321067
# ----------------------------------------
# alpha: 5  L1-ratio: 0.3
# Nonzero weights: 95 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.193990178037676
# The root mean squared error is:  41.02412465927817
# The correlation is:  0.8353340965322713
# ----------------------------------------
# alpha: 6  L1-ratio: 0.3
# Nonzero weights: 90 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.009418192590342
# The root mean squared error is:  40.34020969633216
# The correlation is:  0.8450449011686252
# ----------------------------------------
# alpha: 7  L1-ratio: 0.3
# Nonzero weights: 80 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.684563883641623
# The root mean squared error is:  39.362656286621714
# The correlation is:  0.855282387785194
# ----------------------------------------
# alpha: 8  L1-ratio: 0.3
# Nonzero weights: 75 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.345333120292707
# The root mean squared error is:  38.3939151231134
# The correlation is:  0.8651451320761125
# ----------------------------------------
# alpha: 9  L1-ratio: 0.3
# Nonzero weights: 69 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.13688144470584
# The root mean squared error is:  37.75027717118037
# The correlation is:  0.8739798253330845
# ----------------------------------------
# alpha: 10  L1-ratio: 0.3
# Nonzero weights: 64 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.041014274948452
# The root mean squared error is:  37.43105757630064
# The correlation is:  0.879463727163809
# ----------------------------------------
# alpha: 11  L1-ratio: 0.3
# Nonzero weights: 60 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  19.86684179912946
# The root mean squared error is:  36.965471948581964
# The correlation is:  0.88430511688555
# ----------------------------------------
# alpha: 12  L1-ratio: 0.3
# Nonzero weights: 58 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  19.64693300740727
# The root mean squared error is:  36.42153823742131
# The correlation is:  0.889112627103766
# ----------------------------------------
# alpha: 13  L1-ratio: 0.3
# Nonzero weights: 53 from 157
# alpha: 14  L1-ratio: 0.3
# Nonzero weights: 53 from 157
# alpha: 15  L1-ratio: 0.3
# Nonzero weights: 49 from 157
# alpha: 16  L1-ratio: 0.3
# Nonzero weights: 49 from 157
# alpha: 17  L1-ratio: 0.3
# Nonzero weights: 48 from 157
# alpha: 18  L1-ratio: 0.3
# Nonzero weights: 45 from 157
# alpha: 19  L1-ratio: 0.3
# Nonzero weights: 45 from 157
# alpha: 20  L1-ratio: 0.3
# Nonzero weights: 42 from 157
# alpha: 21  L1-ratio: 0.3
# Nonzero weights: 41 from 157
# alpha: 22  L1-ratio: 0.3
# Nonzero weights: 40 from 157
# alpha: 23  L1-ratio: 0.3
# Nonzero weights: 40 from 157
# alpha: 24  L1-ratio: 0.3
# Nonzero weights: 40 from 157
# alpha: 25  L1-ratio: 0.3
# Nonzero weights: 39 from 157
# alpha: 26  L1-ratio: 0.3
# Nonzero weights: 39 from 157
# alpha: 27  L1-ratio: 0.3
# Nonzero weights: 37 from 157
# alpha: 28  L1-ratio: 0.3
# Nonzero weights: 34 from 157
# alpha: 29  L1-ratio: 0.3
# Nonzero weights: 34 from 157
# alpha: 30  L1-ratio: 0.3
# Nonzero weights: 32 from 157
# alpha: 31  L1-ratio: 0.3
# Nonzero weights: 32 from 157
# alpha: 32  L1-ratio: 0.3
# Nonzero weights: 30 from 157
# alpha: 33  L1-ratio: 0.3
# Nonzero weights: 30 from 157
# alpha: 34  L1-ratio: 0.3
# Nonzero weights: 29 from 157
# alpha: 35  L1-ratio: 0.3
# Nonzero weights: 29 from 157
# alpha: 36  L1-ratio: 0.3
# Nonzero weights: 28 from 157
# alpha: 37  L1-ratio: 0.3
# Nonzero weights: 28 from 157
# alpha: 38  L1-ratio: 0.3
# Nonzero weights: 28 from 157
# alpha: 39  L1-ratio: 0.3
# Nonzero weights: 27 from 157
# alpha: 40  L1-ratio: 0.3
# Nonzero weights: 27 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  19.647931575724137
# The root mean squared error is:  36.256075331198595
# The correlation is:  0.9108359103460999
# ----------------------------------------
# alpha: 41  L1-ratio: 0.3
# Nonzero weights: 27 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  19.554214845226255
# The root mean squared error is:  36.0417273328277
# The correlation is:  0.9114060954574774
# ----------------------------------------
# alpha: 42  L1-ratio: 0.3
# Nonzero weights: 26 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  19.445332952239685
# The root mean squared error is:  35.79643550134384
# The correlation is:  0.9120878623686925
# ----------------------------------------
# alpha: 43  L1-ratio: 0.3
# Nonzero weights: 25 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  19.337904628169884
# The root mean squared error is:  35.555053750852615
# The correlation is:  0.912750794205193
# ----------------------------------------
# alpha: 44  L1-ratio: 0.3
# Nonzero weights: 25 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  19.230611511967954
# The root mean squared error is:  35.314854487528386
# The correlation is:  0.9134034741014642
# ----------------------------------------
# alpha: 45  L1-ratio: 0.3
# Nonzero weights: 25 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  19.123184920929976
# The root mean squared error is:  35.07529067184115
# The correlation is:  0.9140486414172639
# ----------------------------------------
# alpha: 46  L1-ratio: 0.3
# Nonzero weights: 24 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  19.017653275662646
# The root mean squared error is:  34.84057787672916
# The correlation is:  0.9146781775089665
# ----------------------------------------
# alpha: 47  L1-ratio: 0.3
# Nonzero weights: 24 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  18.913730461972783
# The root mean squared error is:  34.61008843796191
# The correlation is:  0.9152910953651757
# ----------------------------------------
# alpha: 48  L1-ratio: 0.3
# Nonzero weights: 23 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  18.807572186751283
# The root mean squared error is:  34.37466846756541
# The correlation is:  0.9158875264174475
# ----------------------------------------
# alpha: 49  L1-ratio: 0.3
# Nonzero weights: 21 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  18.6983304926902
# The root mean squared error is:  34.131743207443876
# The correlation is:  0.9164800569805808
# ----------------------------------------
# alpha: 50  L1-ratio: 0.3
# Nonzero weights: 21 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  18.581635270299394
# The root mean squared error is:  33.8760153270298
# The correlation is:  0.9171091280901537
# ----------------------------------------
# alpha: 51  L1-ratio: 0.3
# Nonzero weights: 20 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  18.484037108488852
# The root mean squared error is:  33.66063059471824
# The correlation is:  0.917685254176398
# ----------------------------------------
# alpha: 52  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  18.44575827244355
# The root mean squared error is:  33.571023818206015
# The correlation is:  0.918174121456786
# ----------------------------------------
# alpha: 53  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  18.418757563860332
# The root mean squared error is:  33.507469809247986
# The correlation is:  0.9186345876774353
# ----------------------------------------
# alpha: 54  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  18.390699841476202
# The root mean squared error is:  33.44224610471042
# The correlation is:  0.9190952532444169
# ----------------------------------------
# alpha: 55  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  18.362511568241455
# The root mean squared error is:  33.37735616315034
# The correlation is:  0.919547887661917
# ----------------------------------------
# alpha: 56  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  18.335484468002154
# The root mean squared error is:  33.31535061489667
# The correlation is:  0.9199823900692474
# ----------------------------------------
# alpha: 57  L1-ratio: 0.3
# Nonzero weights: 18 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  18.26132668720683
# The root mean squared error is:  33.1573994804938
# The correlation is:  0.9205243982650664
# ----------------------------------------
# alpha: 58  L1-ratio: 0.3
# Nonzero weights: 18 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  18.163741741927346
# The root mean squared error is:  32.95027973521518
# The correlation is:  0.9210046619160985
# ----------------------------------------
# alpha: 59  L1-ratio: 0.3
# Nonzero weights: 18 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  18.068343402932378
# The root mean squared error is:  32.747968495499215
# The correlation is:  0.9214659474528606
# ----------------------------------------
# alpha: 60  L1-ratio: 0.3
# Nonzero weights: 17 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  17.972080504153922
# The root mean squared error is:  32.544501412018214
# The correlation is:  0.9219263798862614
# ----------------------------------------
# alpha: 61  L1-ratio: 0.3
# Nonzero weights: 17 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  17.876325818129867
# The root mean squared error is:  32.34227616202042
# The correlation is:  0.9223763176503319
# ----------------------------------------
# alpha: 62  L1-ratio: 0.3
# Nonzero weights: 17 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  17.777725492500252
# The root mean squared error is:  32.13514019317515
# The correlation is:  0.9228375906776254
# ----------------------------------------
# alpha: 63  L1-ratio: 0.3
# Nonzero weights: 16 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  17.67972035801768
# The root mean squared error is:  31.9298107767397
# The correlation is:  0.9232878800249362
# ----------------------------------------
# alpha: 64  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  17.586400965648117
# The root mean squared error is:  31.73250668358554
# The correlation is:  0.9236731812528675
# ----------------------------------------
# alpha: 65  L1-ratio: 0.3
# Nonzero weights: 14 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  17.49046573775039
# The root mean squared error is:  31.530291037415115
# The correlation is:  0.9240632937045296
# ----------------------------------------
# alpha: 66  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  17.40847686762516
# The root mean squared error is:  31.356735165794863
# The correlation is:  0.9243758357457853
# ----------------------------------------
# alpha: 67  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  17.334883123872494
# The root mean squared error is:  31.20143839051861
# The correlation is:  0.9246497973145147
# ----------------------------------------
# alpha: 68  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  17.261943757214556
# The root mean squared error is:  31.04782909016929
# The correlation is:  0.9249160227376673
# ----------------------------------------
# alpha: 69  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  17.18992614043079
# The root mean squared error is:  30.896230302764497
# The correlation is:  0.9251735633937431
# ----------------------------------------
# alpha: 70  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  17.11114936208522
# The root mean squared error is:  30.73031519020393
# The correlation is:  0.9254875233910247
# ----------------------------------------
# alpha: 71  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  17.03420416097794
# The root mean squared error is:  30.56740598412948
# The correlation is:  0.9257992777239659
# ----------------------------------------
# alpha: 72  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  16.95943867984533
# The root mean squared error is:  30.408810970778145
# The correlation is:  0.9260962315923379
# ----------------------------------------
# alpha: 73  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  16.884642247703127
# The root mean squared error is:  30.250537008747067
# The correlation is:  0.9263900967321248
# ----------------------------------------
# alpha: 74  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  16.80997382410617
# The root mean squared error is:  30.09289078122685
# The correlation is:  0.9266799285738866
# ----------------------------------------
# alpha: 75  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  16.732851638102453
# The root mean squared error is:  29.930995341957548
# The correlation is:  0.9269796264797467
# ----------------------------------------
# alpha: 76  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  16.65857490467977
# The root mean squared error is:  29.774867947923923
# The correlation is:  0.9272603833028598
# ----------------------------------------
# alpha: 77  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  16.58248108685252
# The root mean squared error is:  29.615755514356685
# The correlation is:  0.9275474993232007
# ----------------------------------------
# alpha: 78  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  16.521209994083073
# The root mean squared error is:  29.48339279968901
# The correlation is:  0.9277038255860941
# ----------------------------------------
# alpha: 79  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  16.46289395761236
# The root mean squared error is:  29.356801535305372
# The correlation is:  0.9278422495436082
# ----------------------------------------
# alpha: 80  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  16.404630414845464
# The root mean squared error is:  29.23052192917144
# The correlation is:  0.9279786535820285
# ----------------------------------------
# alpha: 81  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  16.343985298737994
# The root mean squared error is:  29.10002886769001
# The correlation is:  0.9281248451093969
# ----------------------------------------
# alpha: 82  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  16.28615570749854
# The root mean squared error is:  28.975040612316533
# The correlation is:  0.9282553580771303
# ----------------------------------------
# alpha: 83  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  16.228445953642925
# The root mean squared error is:  28.85051283090035
# The correlation is:  0.9283834228194145
# ----------------------------------------
# alpha: 84  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  16.168453710659005
# The root mean squared error is:  28.721958397552854
# The correlation is:  0.92852065841435
# ----------------------------------------
# alpha: 85  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  16.11147497072075
# The root mean squared error is:  28.599222678364068
# The correlation is:  0.928641514738362
# ----------------------------------------
# alpha: 86  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  16.052834965475345
# The root mean squared error is:  28.47247743053383
# The correlation is:  0.9287714763417924
# ----------------------------------------
# alpha: 87  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.995383721388352
# The root mean squared error is:  28.346941460504254
# The correlation is:  0.9288970464299726
# ----------------------------------------
# alpha: 88  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.938536785356828
# The root mean squared error is:  28.222788240263103
# The correlation is:  0.9290177764146377
# ----------------------------------------
# alpha: 89  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.882405308744557
# The root mean squared error is:  28.100206515847237
# The correlation is:  0.9291331097952784
# ----------------------------------------
# alpha: 90  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.8277187231316
# The root mean squared error is:  27.98039835117985
# The correlation is:  0.9292374278773471
# ----------------------------------------
# alpha: 91  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.776609291681138
# The root mean squared error is:  27.86683786790007
# The correlation is:  0.9293126354427982
# ----------------------------------------
# alpha: 92  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.726666386669656
# The root mean squared error is:  27.755655409856793
# The correlation is:  0.9293809315181419
# ----------------------------------------
# alpha: 93  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.677193081370287
# The root mean squared error is:  27.645530302078804
# The correlation is:  0.92944542154801
# ----------------------------------------
# alpha: 94  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.629042220417123
# The root mean squared error is:  27.538193638836912
# The correlation is:  0.9295027659362243
# ----------------------------------------
# alpha: 95  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.580893220170685
# The root mean squared error is:  27.43092214474464
# The correlation is:  0.9295583335962068
# ----------------------------------------
# alpha: 96  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.532850537853008
# The root mean squared error is:  27.324174725157242
# The correlation is:  0.9296123096216141
# ----------------------------------------
# alpha: 97  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.486068113376659
# The root mean squared error is:  27.219819686833755
# The correlation is:  0.9296588810421387
# ----------------------------------------
# alpha: 98  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.437855869876195
# The root mean squared error is:  27.11315031925564
# The correlation is:  0.9297106686149563
# ----------------------------------------
# alpha: 99  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.383287689141987
# The root mean squared error is:  26.995189194382586
# The correlation is:  0.9297878789844573
# ----------------------------------------
# alpha: 100  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.331311125716864
# The root mean squared error is:  26.882010911311813
# The correlation is:  0.9298517473050377
# ----------------------------------------
# alpha: 101  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.278770624963839
# The root mean squared error is:  26.76801554811051
# The correlation is:  0.9299161730109909
# ----------------------------------------
# alpha: 102  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.225761601432545
# The root mean squared error is:  26.653398431378385
# The correlation is:  0.9299807199467263
# ----------------------------------------
# alpha: 103  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.172014887269205
# The root mean squared error is:  26.537684082416163
# The correlation is:  0.9300464662527336
# ----------------------------------------
# alpha: 104  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.118030885121485
# The root mean squared error is:  26.42180081529282
# The correlation is:  0.9301111983048913
# ----------------------------------------
# alpha: 105  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.066300102466611
# The root mean squared error is:  26.31028580691826
# The correlation is:  0.9301648082165072
# ----------------------------------------
# alpha: 106  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.011609114465376
# The root mean squared error is:  26.193655104941577
# The correlation is:  0.9302282748187948
# ----------------------------------------
# alpha: 107  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.956783713377
# The root mean squared error is:  26.07706602712393
# The correlation is:  0.9302900569968412
# ----------------------------------------
# alpha: 108  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.901911566702893
# The root mean squared error is:  25.96068183646671
# The correlation is:  0.9303497359481233
# ----------------------------------------
# alpha: 109  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.846732007112935
# The root mean squared error is:  25.844038850442217
# The correlation is:  0.9304082702390098
# ----------------------------------------
# alpha: 110  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.794164236507342
# The root mean squared error is:  25.732183015472632
# The correlation is:  0.9304547288622425
# ----------------------------------------
# alpha: 111  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.738992861985864
# The root mean squared error is:  25.615895285566996
# The correlation is:  0.9305089715424751
# ----------------------------------------
# alpha: 112  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.68631834744124
# The root mean squared error is:  25.504358952924946
# The correlation is:  0.9305513104803381
# ----------------------------------------
# alpha: 113  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.631464248032566
# The root mean squared error is:  25.389239727616303
# The correlation is:  0.9305994017529355
# ----------------------------------------
# alpha: 114  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.577067149037532
# The root mean squared error is:  25.275240827305687
# The correlation is:  0.9306432420679939
# ----------------------------------------
# alpha: 115  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.522447425450455
# The root mean squared error is:  25.161160020478647
# The correlation is:  0.9306853014723592
# ----------------------------------------
# alpha: 116  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.470389358012103
# The root mean squared error is:  25.051814203785334
# The correlation is:  0.9307157893330306
# ----------------------------------------
# alpha: 117  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.41563910836207
# The root mean squared error is:  24.937970984897103
# The correlation is:  0.9307534196975448
# ----------------------------------------
# alpha: 118  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.360750845089498
# The root mean squared error is:  24.824214288277563
# The correlation is:  0.9307887709641547
# ----------------------------------------
# alpha: 119  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.308492414318357
# The root mean squared error is:  24.71529686161643
# The correlation is:  0.9308125389654994
# ----------------------------------------
# alpha: 120  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.253694004081858
# The root mean squared error is:  24.60205756806264
# The correlation is:  0.9308426358714439
# ----------------------------------------
# alpha: 121  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.201428198245681
# The root mean squared error is:  24.4935655121127
# The correlation is:  0.9308614741571984
# ----------------------------------------
# alpha: 122  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.146275859611821
# The root mean squared error is:  24.380388431395826
# The correlation is:  0.9308870043822925
# ----------------------------------------
# alpha: 123  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.093452785728225
# The root mean squared error is:  24.271591272791625
# The correlation is:  0.9309020808277696
# ----------------------------------------
# alpha: 124  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.040665838274235
# The root mean squared error is:  24.163189843495854
# The correlation is:  0.9309142291402231
# ----------------------------------------
# alpha: 125  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.987861516234938
# The root mean squared error is:  24.055096038592808
# The correlation is:  0.930923576851647
# ----------------------------------------
# alpha: 126  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.935098985348002
# The root mean squared error is:  23.947415749395407
# The correlation is:  0.9309298994793591
# ----------------------------------------
# alpha: 127  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.879694629009261
# The root mean squared error is:  23.835580237002375
# The correlation is:  0.9309410858154891
# ----------------------------------------
# alpha: 128  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.826991609219254
# The root mean squared error is:  23.72871361417904
# The correlation is:  0.93094115851168
# ----------------------------------------
# alpha: 129  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.77732396956334
# The root mean squared error is:  23.627146727126153
# The correlation is:  0.9309264223458404
# ----------------------------------------
# alpha: 130  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.72816850756585
# The root mean squared error is:  23.526318409041696
# The correlation is:  0.9308984360245013
# ----------------------------------------
# alpha: 131  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.679945650116272
# The root mean squared error is:  23.42735039932438
# The correlation is:  0.9308657402932953
# ----------------------------------------
# alpha: 132  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.632028337453573
# The root mean squared error is:  23.32917903970848
# The correlation is:  0.930830049332847
# ----------------------------------------
# alpha: 133  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.584253928915905
# The root mean squared error is:  23.23153030860313
# The correlation is:  0.9307917879905443
# ----------------------------------------
# alpha: 134  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.536563750430899
# The root mean squared error is:  23.134307307174335
# The correlation is:  0.9307510924606367
# ----------------------------------------
# alpha: 135  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.488915327111602
# The root mean squared error is:  23.03744135251798
# The correlation is:  0.9307080481798204
# ----------------------------------------
# alpha: 136  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.441336163308296
# The root mean squared error is:  22.94098089801329
# The correlation is:  0.9306625652021252
# ----------------------------------------
# alpha: 137  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.393822079098195
# The root mean squared error is:  22.84492138873614
# The correlation is:  0.9306146328587201
# ----------------------------------------
# alpha: 138  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.346369941488742
# The root mean squared error is:  22.749260109880492
# The correlation is:  0.9305642371302184
# ----------------------------------------
# alpha: 139  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.298981611136353
# The root mean squared error is:  22.6540026511845
# The correlation is:  0.9305113520668304
# ----------------------------------------
# alpha: 140  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.251637048869402
# The root mean squared error is:  22.559118692058973
# The correlation is:  0.9304559997920568
# ----------------------------------------
# alpha: 141  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.204318201269906
# The root mean squared error is:  22.46458162800822
# The correlation is:  0.9303981939016454
# ----------------------------------------
# alpha: 142  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.157048484922111
# The root mean squared error is:  22.370432798054736
# The correlation is:  0.9303378577456298
# ----------------------------------------
# alpha: 143  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.109832990201953
# The root mean squared error is:  22.276683318394124
# The correlation is:  0.9302749565169959
# ----------------------------------------
# alpha: 144  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.065741819615099
# The root mean squared error is:  22.19124612701191
# The correlation is:  0.9302444617898348
# ----------------------------------------
# alpha: 145  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.029312770142496
# The root mean squared error is:  22.126086626379465
# The correlation is:  0.9303025028855101
# ----------------------------------------
# alpha: 146  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.992949176845782
# The root mean squared error is:  22.061183938601026
# The correlation is:  0.9303582427212864
# ----------------------------------------
# alpha: 147  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.956683926825631
# The root mean squared error is:  21.996499671311017
# The correlation is:  0.9304117152385446
# ----------------------------------------
# alpha: 148  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.920486304899743
# The root mean squared error is:  21.932085979397854
# The correlation is:  0.9304628410514899
# ----------------------------------------
# alpha: 149  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.884318063579347
# The root mean squared error is:  21.867946413729488
# The correlation is:  0.9305116038596455
# ----------------------------------------
# alpha: 150  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.84818704700862
# The root mean squared error is:  21.804094753846826
# The correlation is:  0.9305579761881636
# ----------------------------------------
# alpha: 151  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.812105967176858
# The root mean squared error is:  21.74055202186074
# The correlation is:  0.930601924468667
# ----------------------------------------
# alpha: 152  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.77367548778896
# The root mean squared error is:  21.672918080292117
# The correlation is:  0.9306480493009518
# ----------------------------------------
# alpha: 153  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.738041978126962
# The root mean squared error is:  21.609940756029506
# The correlation is:  0.9306870142901658
# ----------------------------------------
# alpha: 154  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.702450759415356
# The root mean squared error is:  21.54726516636388
# The correlation is:  0.9307235296763433
# ----------------------------------------
# alpha: 155  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.666864728759327
# The root mean squared error is:  21.484834748324968
# The correlation is:  0.9307576383416261
# ----------------------------------------
# alpha: 156  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.631305640675528
# The root mean squared error is:  21.42268511023219
# The correlation is:  0.9307892917775791
# ----------------------------------------
# alpha: 157  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.597999112377135
# The root mean squared error is:  21.364758770395124
# The correlation is:  0.930818443901182
# ----------------------------------------
# alpha: 158  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.56563614188142
# The root mean squared error is:  21.308660962136955
# The correlation is:  0.930845491772771
# ----------------------------------------
# alpha: 159  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.533313210609478
# The root mean squared error is:  21.252807915914367
# The correlation is:  0.9308706686190293
# ----------------------------------------
# alpha: 160  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.501048003279996
# The root mean squared error is:  21.197187643859884
# The correlation is:  0.9308939774753291
# ----------------------------------------
# alpha: 161  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.468927632537152
# The root mean squared error is:  21.141802535649376
# The correlation is:  0.9309154092147421
# ----------------------------------------
# alpha: 162  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.4368385421036
# The root mean squared error is:  21.086651518176208
# The correlation is:  0.9309349573146517
# ----------------------------------------
# alpha: 163  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.404786392084496
# The root mean squared error is:  21.03174406131258
# The correlation is:  0.9309526081352701
# ----------------------------------------
# alpha: 164  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.372755467575885
# The root mean squared error is:  20.97705719871337
# The correlation is:  0.9309683691854947
# ----------------------------------------
# alpha: 165  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.3407449437068
# The root mean squared error is:  20.922590750186277
# The correlation is:  0.9309822313298809
# ----------------------------------------
# alpha: 166  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.308765196202621
# The root mean squared error is:  20.868361357814983
# The correlation is:  0.9309941762018779
# ----------------------------------------
# alpha: 167  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.276816189521211
# The root mean squared error is:  20.81436987026514
# The correlation is:  0.9310041956954916
# ----------------------------------------
# alpha: 168  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.24489785328359
# The root mean squared error is:  20.76061708741158
# The correlation is:  0.9310122817293147
# ----------------------------------------
# alpha: 169  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.213010126011504
# The root mean squared error is:  20.707103826134833
# The correlation is:  0.9310184262089295
# ----------------------------------------
# alpha: 170  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.181160261222038
# The root mean squared error is:  20.65384170332024
# The correlation is:  0.9310226169400458
# ----------------------------------------
# alpha: 171  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.149321458890547
# The root mean squared error is:  20.60079210759101
# The correlation is:  0.9310248604874264
# ----------------------------------------
# alpha: 172  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.11472708826911
# The root mean squared error is:  20.54390733356966
# The correlation is:  0.9310263400380193
# ----------------------------------------
# alpha: 173  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.082926214164656
# The root mean squared error is:  20.491326648131643
# The correlation is:  0.9310244733776427
# ----------------------------------------
# alpha: 174  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.051155679361091
# The root mean squared error is:  20.43899021829982
# The correlation is:  0.9310206191346695
# ----------------------------------------
# alpha: 175  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.019421135921142
# The root mean squared error is:  20.38690713952506
# The correlation is:  0.9310147677908357
# ----------------------------------------
# alpha: 176  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  11.987724812036056
# The root mean squared error is:  20.33508144235454
# The correlation is:  0.9310069118889625
# ----------------------------------------
# alpha: 177  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  11.95605894597209
# The root mean squared error is:  20.283502794668642
# The correlation is:  0.9309970456693452
# ----------------------------------------
# alpha: 178  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  11.924423502538728
# The root mean squared error is:  20.232172077135832
# The correlation is:  0.9309851610397248
# ----------------------------------------
# alpha: 179  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  11.89281874020442
# The root mean squared error is:  20.181090589479073
# The correlation is:  0.9309712499184588
# ----------------------------------------
# alpha: 180  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  11.861541961198833
# The root mean squared error is:  20.13027210958394
# The correlation is:  0.9309553050672208
# ----------------------------------------
# alpha: 181  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  11.831923189652588
# The root mean squared error is:  20.079704057164275
# The correlation is:  0.9309373188385057
# ----------------------------------------
# alpha: 182  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  11.803283731886868
# The root mean squared error is:  20.02939427432183
# The correlation is:  0.9309172842527209
# ----------------------------------------
# alpha: 183  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  11.776601640239733
# The root mean squared error is:  19.979293963017973
# The correlation is:  0.930895184087817
# ...
# The correlation is:  0.9287563930160219
# ----------------------------------------
# alpha: 219  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  11.045258307340884
# The root mean squared error is:  18.34959411853722
# The correlation is:  0.92865452781619
# ----------------------------------------
# alpha: 220  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  11.028685886483638
# The root mean squared error is:  18.30943623291406
# The correlation is:  0.9285503011491181
# ----------------------------------------
# alpha: 221  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  11.012127930107212
# The root mean squared error is:  18.269565559795737
# The correlation is:  0.9284437051494432
# ----------------------------------------
# alpha: 222  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.995585488549004
# The root mean squared error is:  18.22998522350121
# The correlation is:  0.9283347385848536
# ----------------------------------------
# alpha: 223  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.979058217992382
# The root mean squared error is:  18.19069538100885
# The correlation is:  0.9282233922526801
# ----------------------------------------
# alpha: 224  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.962747323113122
# The root mean squared error is:  18.151695951325962
# The correlation is:  0.9281096559868578
# ----------------------------------------
# alpha: 225  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.946909588014664
# The root mean squared error is:  18.11298692401464
# The correlation is:  0.9279935195111632
# ----------------------------------------
# alpha: 226  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.931410207260603
# The root mean squared error is:  18.074549629401254
# The correlation is:  0.9278749108211417
# ----------------------------------------
# alpha: 227  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.92286747666927
# The root mean squared error is:  18.050594241877405
# The correlation is:  0.9278026092968081
# ----------------------------------------
# alpha: 228  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.92211759934579
# The root mean squared error is:  18.043725994086362
# The correlation is:  0.9277452914256094
# ----------------------------------------
# alpha: 229  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.923876272931338
# The root mean squared error is:  18.04249356149523
# The correlation is:  0.9277215664134284
# ----------------------------------------
# alpha: 230  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.925524047569795
# The root mean squared error is:  18.04099022424016
# The correlation is:  0.9276960078786686
# ----------------------------------------
# alpha: 231  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.926898365676507
# The root mean squared error is:  18.03881052411365
# The correlation is:  0.9276659352414682
# ----------------------------------------
# alpha: 232  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.9283951417982
# The root mean squared error is:  18.036944472181652
# The correlation is:  0.9276378506033511
# ----------------------------------------
# alpha: 233  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.929976088651182
# The root mean squared error is:  18.03529565179913
# The correlation is:  0.9276111316787816
# ----------------------------------------
# alpha: 234  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.931612325386327
# The root mean squared error is:  18.03379155125368
# The correlation is:  0.9275853068794395
# ----------------------------------------
# alpha: 235  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.93329433156668
# The root mean squared error is:  18.032408135298898
# The correlation is:  0.9275602219365671
# ----------------------------------------
# alpha: 236  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.9350166130464
# The root mean squared error is:  18.031131484882987
# The correlation is:  0.9275357882181161
# ----------------------------------------
# alpha: 237  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.936318234135559
# The root mean squared error is:  18.028815931406704
# The correlation is:  0.9275043688401993
# ----------------------------------------
# alpha: 238  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.93809335090997
# The root mean squared error is:  18.027683967246013
# The correlation is:  0.9274807781470795
# ----------------------------------------
# alpha: 239  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.939443941193247
# The root mean squared error is:  18.025505235387428
# The correlation is:  0.9274501206956434
# ----------------------------------------
# alpha: 240  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.9412560677917
# The root mean squared error is:  18.02447805666484
# The correlation is:  0.9274271160019634
# ----------------------------------------
# alpha: 241  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.942643134301463
# The root mean squared error is:  18.02240444719059
# The correlation is:  0.9273970196705834
# ----------------------------------------
# alpha: 242  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.944493079446683
# The root mean squared error is:  18.021483604668628
# The correlation is:  0.9273746184802971
# ----------------------------------------
# alpha: 243  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.945685099150614
# The root mean squared error is:  18.02026584179508
# The correlation is:  0.9273570569834028
# ----------------------------------------
# alpha: 244  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 245  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 246  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 247  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 248  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 249  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 250  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 251  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 252  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 253  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 254  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 255  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 256  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 257  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 258  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 259  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 260  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 261  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 262  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 263  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 264  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 265  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 266  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 267  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 268  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 269  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 270  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 271  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 272  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 273  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 274  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 275  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 276  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 277  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 278  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 279  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 280  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 281  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# alpha: 282  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 283  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 284  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 285  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 286  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 287  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 288  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 289  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 290  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 291  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 292  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 293  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 294  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 295  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 296  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 297  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 298  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 299  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 300  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 301  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 302  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 303  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 304  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 305  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 306  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 307  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 308  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 309  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 310  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 311  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 312  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 313  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 314  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 315  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 316  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 317  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 318  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 319  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 320  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 321  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 322  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 323  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 324  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 325  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 326  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 327  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 328  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 329  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 330  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 331  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 332  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 333  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 334  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 335  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 336  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 337  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 338  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 339  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 340  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 341  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 342  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 343  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 344  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 345  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 346  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 347  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 348  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 349  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 350  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 351  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 352  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 353  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 354  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 355  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 356  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 357  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 358  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 359  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 360  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 361  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 362  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 363  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 364  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 365  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 366  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 367  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 368  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 369  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 370  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 371  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 372  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 373  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 374  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 375  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 376  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 377  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 378  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 379  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 380  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 381  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 382  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 383  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 384  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 385  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 386  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 387  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 388  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 389  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 390  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 391  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 392  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 393  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 394  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 395  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 396  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 397  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 398  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 399  L1-ratio: 0.3
# Nonzero weights: 2 from 157

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.3, 150 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train1_X2,train1_y,test1_X2,test1_y))

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.4, 103 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train1_X3,train1_y,test1_X3,test1_y))

# %%
## tuned alpha based on validation set, then measure the performance for test set.
## Fixing l1-ratio = 0.3
para = [243]
para_l=[0.3]
rmse=100000
mae=1000000
corr=0
for a in para:
    for l in para_l:
        print('alpha:',a,' L1-ratio:',l)
        rmse0,mae0,corr0 = eNet(a,l,train1_X1,train1_y,test1_X1,test1_y)
        if rmse0< rmse:
            rmse=rmse0
            mae=mae0
            corr = corr0
            print('========================================')
            print('Best RMSE is updated! ' )
            print('The mean absolute error is: ',mae)
            print('The root mean squared error is: ',rmse)
            print('The correlation is: ',corr)
            print('----------------------------------------')
# Out:
# alpha: 243  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.057406461316006
# The root mean squared error is:  3.4791986971928814
# The correlation is:  0.8702428004449374
# ----------------------------------------

# %% [markdown]
# ## For the last 2 years as the testing set

# %%
train_size = 3653
corrs2 = np.zeros((X.shape[1],1))
for i in range(0,X.shape[1]):
    if X.sum(axis=1)[i] == 0:
        corrs2[i] = 0
    else:
        corrs2[i] = np.corrcoef(X.iloc[0:train_size,i],y.iloc[0:train_size,0])[0,1]
        
corrs2.shape,X.columns.shape,X.columns[0],X.columns[249]
# Out:
# ((250, 1), (250,), ('flu',), ('flu incubation',))

# %%
#train2_X0,test2_X0 = corr_filter(train2_X,test2_X,corrs2,0.1)
train2_X1,val2_X1,test2_X1 = corr_filter(train2_X,val2_X,test2_X,corrs2,0.2)
#train2_X2,test2_X2 = corr_filter(train2_X,test2_X,corrs2,0.3)
#train2_X3,test2_X3 = corr_filter(train2_X,test2_X,corrs2,0.4)

# %%
#print('For correlation filter r>0.1, we select feature number: ',train2_X0.shape[1])
print('For correlation filter r>0.2, we select feature number: ',train2_X1.shape[1])
#print('For correlation filter r>0.3, we select feature number: ',train2_X2.shape[1])
#print('For correlation filter r>0.4, we select feature number: ',train2_X3.shape[1])
# Out:
# For correlation filter r>0.2, we select feature number:  157

# %% [markdown]
# # scaling and modeling
# scaler = MinMaxScaler()
# train2_X0_scaled = scaler.fit_transform(train2_X0)
# test2_X0_scaled = scaler.transform(test2_X0)
#
# train2_X1_scaled = scaler.fit_transform(train2_X1)
# test2_X1_scaled = scaler.transform(test2_X1)
#
# train2_X2_scaled = scaler.fit_transform(train2_X2)
# test2_X2_scaled = scaler.transform(test2_X2)
#
# train2_X3_scaled = scaler.fit_transform(train2_X3)
# test2_X3_scaled = scaler.transform(test2_X3)

# %% [markdown]
# para = range(1,100)
# para_l=[0.3]
# rmse=100000
# mae=1000000
# corr=0
# print('For correlation filter r>=0.1, 303 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         rmse0,mae0,corr0 = eNet(a,l,train2_X1,train2_y,val2_X1,val2_y)
#         if rmse0< rmse:
#             rmse=rmse0
#             mae=mae0
#             corr = corr0
#             print('========================================')
#             print('Best RMSE is updated! ' )
#             print('The mean absolute error is: ',mae)
#             print('The root mean squared error is: ',rmse)
#             print('The correlation is: ',corr)
#             print('----------------------------------------')

# %%
para = range(1,300)
para_l=[0.3]
rmse=100000
mae=1000000
corr=0
print('For correlation filter r>=0.1, 303 features are selected')
for a in para:
    for l in para_l:
        print('alpha:',a,' L1-ratio:',l)
        rmse0,mae0,corr0 = eNet(a,l,train2_X1,train2_y,val2_X1,val2_y)
        if rmse0< rmse:
            rmse=rmse0
            mae=mae0
            corr = corr0
            print('========================================')
            print('Best RMSE is updated! ' )
            print('The mean absolute error is: ',mae)
            print('The root mean squared error is: ',rmse)
            print('The correlation is: ',corr)
            print('----------------------------------------')
# Out:
# For correlation filter r>=0.1, 303 features are selected
# alpha: 1  L1-ratio: 0.3
# Nonzero weights: 145 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.671115108748183
# The root mean squared error is:  9.716962876951671
# The correlation is:  0.405634299952857
# ----------------------------------------
# alpha: 2  L1-ratio: 0.3
# Nonzero weights: 127 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.546050398791747
# The root mean squared error is:  9.246737052850373
# The correlation is:  0.41970787208318444
# ----------------------------------------
# alpha: 3  L1-ratio: 0.3
# Nonzero weights: 115 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.42809703034297
# The root mean squared error is:  8.834858669518795
# The correlation is:  0.43396075011980706
# ----------------------------------------
# alpha: 4  L1-ratio: 0.3
# Nonzero weights: 103 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.321663019611135
# The root mean squared error is:  8.449403727344333
# The correlation is:  0.44946888189125217
# ----------------------------------------
# alpha: 5  L1-ratio: 0.3
# Nonzero weights: 97 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.22066165642885
# The root mean squared error is:  8.086413349827513
# The correlation is:  0.46599190968375026
# ----------------------------------------
# alpha: 6  L1-ratio: 0.3
# Nonzero weights: 93 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.129070271427183
# The root mean squared error is:  7.758768996470016
# The correlation is:  0.4821898538661736
# ----------------------------------------
# alpha: 7  L1-ratio: 0.3
# Nonzero weights: 88 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.062087838589337
# The root mean squared error is:  7.509783501209075
# The correlation is:  0.4953916056094694
# ----------------------------------------
# alpha: 8  L1-ratio: 0.3
# Nonzero weights: 83 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.015439588729911
# The root mean squared error is:  7.338637233505156
# The correlation is:  0.5048387547236893
# ----------------------------------------
# alpha: 9  L1-ratio: 0.3
# Nonzero weights: 80 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.976890338985883
# The root mean squared error is:  7.195391518062138
# The correlation is:  0.5127444370217001
# ----------------------------------------
# alpha: 10  L1-ratio: 0.3
# Nonzero weights: 79 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.942863285985619
# The root mean squared error is:  7.061139420401629
# The correlation is:  0.5205745585657128
# ----------------------------------------
# alpha: 11  L1-ratio: 0.3
# Nonzero weights: 73 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9114388796121013
# The root mean squared error is:  6.938154807386442
# The correlation is:  0.5283693986471677
# ----------------------------------------
# alpha: 12  L1-ratio: 0.3
# Nonzero weights: 71 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.877037485255366
# The root mean squared error is:  6.802636308360851
# The correlation is:  0.5380160430606764
# ----------------------------------------
# alpha: 13  L1-ratio: 0.3
# Nonzero weights: 70 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.843089502477164
# The root mean squared error is:  6.667446569947369
# The correlation is:  0.548471722076339
# ----------------------------------------
# alpha: 14  L1-ratio: 0.3
# Nonzero weights: 68 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.8106769487170533
# The root mean squared error is:  6.541931647164725
# The correlation is:  0.5588556444909021
# ----------------------------------------
# alpha: 15  L1-ratio: 0.3
# Nonzero weights: 61 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.782649381204687
# The root mean squared error is:  6.4380021906728615
# The correlation is:  0.567860728577183
# ----------------------------------------
# alpha: 16  L1-ratio: 0.3
# Nonzero weights: 55 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.759932680170499
# The root mean squared error is:  6.352715840900696
# The correlation is:  0.5756540499768823
# ----------------------------------------
# alpha: 17  L1-ratio: 0.3
# Nonzero weights: 52 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.7411172473912777
# The root mean squared error is:  6.285119475460514
# The correlation is:  0.5822423385027105
# ----------------------------------------
# alpha: 18  L1-ratio: 0.3
# Nonzero weights: 49 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.7221628523928345
# The root mean squared error is:  6.227951286841057
# The correlation is:  0.5880232609064366
# ----------------------------------------
# alpha: 19  L1-ratio: 0.3
# Nonzero weights: 47 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.7034428292761326
# The root mean squared error is:  6.17636347899198
# The correlation is:  0.5934057648572687
# ----------------------------------------
# alpha: 20  L1-ratio: 0.3
# Nonzero weights: 46 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.7004422203099296
# The root mean squared error is:  6.1641368322676175
# The correlation is:  0.5942610664256212
# ----------------------------------------
# alpha: 21  L1-ratio: 0.3
# Nonzero weights: 45 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6980768254582133
# The root mean squared error is:  6.154053623080605
# The correlation is:  0.5948817417608024
# ----------------------------------------
# alpha: 22  L1-ratio: 0.3
# Nonzero weights: 44 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.689752489415704
# The root mean squared error is:  6.1261559707300055
# The correlation is:  0.5977983600885927
# ----------------------------------------
# alpha: 23  L1-ratio: 0.3
# Nonzero weights: 43 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.680509321038404
# The root mean squared error is:  6.096450231521929
# The correlation is:  0.6011051266278684
# ----------------------------------------
# alpha: 24  L1-ratio: 0.3
# Nonzero weights: 43 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6741328080819144
# The root mean squared error is:  6.075748341341522
# The correlation is:  0.6034114501609993
# ----------------------------------------
# alpha: 25  L1-ratio: 0.3
# Nonzero weights: 42 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.667776970762754
# The root mean squared error is:  6.056425843305963
# The correlation is:  0.6056218127753503
# ----------------------------------------
# alpha: 26  L1-ratio: 0.3
# Nonzero weights: 42 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6607567773546603
# The root mean squared error is:  6.037595409541149
# The correlation is:  0.6078498089741644
# ----------------------------------------
# alpha: 27  L1-ratio: 0.3
# Nonzero weights: 42 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.654057813932785
# The root mean squared error is:  6.020807255136334
# The correlation is:  0.6098839790918096
# ----------------------------------------
# alpha: 28  L1-ratio: 0.3
# Nonzero weights: 42 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6452411588783473
# The root mean squared error is:  6.000627131022469
# The correlation is:  0.6125093178451402
# ----------------------------------------
# alpha: 29  L1-ratio: 0.3
# Nonzero weights: 41 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.638778274153861
# The root mean squared error is:  5.987954753522455
# The correlation is:  0.6141277962338357
# ----------------------------------------
# alpha: 30  L1-ratio: 0.3
# Nonzero weights: 41 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.632773650197482
# The root mean squared error is:  5.977764040243814
# The correlation is:  0.615455933018631
# ----------------------------------------
# alpha: 31  L1-ratio: 0.3
# Nonzero weights: 41 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6269387594339038
# The root mean squared error is:  5.969359227925628
# The correlation is:  0.6165716044000372
# ----------------------------------------
# alpha: 32  L1-ratio: 0.3
# Nonzero weights: 41 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.621498164887815
# The root mean squared error is:  5.962544404476867
# The correlation is:  0.6174945699349111
# ----------------------------------------
# alpha: 33  L1-ratio: 0.3
# Nonzero weights: 40 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.619755503343462
# The root mean squared error is:  5.960104331549468
# The correlation is:  0.6177692528427337
# ----------------------------------------
# alpha: 34  L1-ratio: 0.3
# Nonzero weights: 38 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.619038626051776
# The root mean squared error is:  5.959522517737643
# The correlation is:  0.6177825000448601
# ----------------------------------------
# alpha: 35  L1-ratio: 0.3
# Nonzero weights: 38 from 157
# alpha: 36  L1-ratio: 0.3
# Nonzero weights: 38 from 157
# alpha: 37  L1-ratio: 0.3
# Nonzero weights: 38 from 157
# alpha: 38  L1-ratio: 0.3
# Nonzero weights: 37 from 157
# alpha: 39  L1-ratio: 0.3
# Nonzero weights: 37 from 157
# alpha: 40  L1-ratio: 0.3
# Nonzero weights: 37 from 157
# alpha: 41  L1-ratio: 0.3
# Nonzero weights: 33 from 157
# alpha: 42  L1-ratio: 0.3
# Nonzero weights: 33 from 157
# alpha: 43  L1-ratio: 0.3
# Nonzero weights: 33 from 157
# alpha: 44  L1-ratio: 0.3
# Nonzero weights: 32 from 157
# alpha: 45  L1-ratio: 0.3
# Nonzero weights: 32 from 157
# alpha: 46  L1-ratio: 0.3
# Nonzero weights: 32 from 157
# alpha: 47  L1-ratio: 0.3
# Nonzero weights: 32 from 157
# alpha: 48  L1-ratio: 0.3
# Nonzero weights: 32 from 157
# alpha: 49  L1-ratio: 0.3
# Nonzero weights: 32 from 157
# alpha: 50  L1-ratio: 0.3
# Nonzero weights: 30 from 157
# alpha: 51  L1-ratio: 0.3
# Nonzero weights: 30 from 157
# alpha: 52  L1-ratio: 0.3
# Nonzero weights: 30 from 157
# alpha: 53  L1-ratio: 0.3
# Nonzero weights: 30 from 157
# alpha: 54  L1-ratio: 0.3
# Nonzero weights: 30 from 157
# alpha: 55  L1-ratio: 0.3
# Nonzero weights: 30 from 157
# alpha: 56  L1-ratio: 0.3
# Nonzero weights: 29 from 157
# alpha: 57  L1-ratio: 0.3
# Nonzero weights: 28 from 157
# alpha: 58  L1-ratio: 0.3
# Nonzero weights: 28 from 157
# alpha: 59  L1-ratio: 0.3
# Nonzero weights: 28 from 157
# alpha: 60  L1-ratio: 0.3
# Nonzero weights: 27 from 157
# alpha: 61  L1-ratio: 0.3
# Nonzero weights: 27 from 157
# alpha: 62  L1-ratio: 0.3
# Nonzero weights: 27 from 157
# alpha: 63  L1-ratio: 0.3
# Nonzero weights: 27 from 157
# alpha: 64  L1-ratio: 0.3
# Nonzero weights: 27 from 157
# alpha: 65  L1-ratio: 0.3
# Nonzero weights: 26 from 157
# alpha: 66  L1-ratio: 0.3
# Nonzero weights: 26 from 157
# alpha: 67  L1-ratio: 0.3
# Nonzero weights: 26 from 157
# alpha: 68  L1-ratio: 0.3
# Nonzero weights: 26 from 157
# alpha: 69  L1-ratio: 0.3
# Nonzero weights: 24 from 157
# alpha: 70  L1-ratio: 0.3
# Nonzero weights: 23 from 157
# alpha: 71  L1-ratio: 0.3
# Nonzero weights: 23 from 157
# alpha: 72  L1-ratio: 0.3
# Nonzero weights: 23 from 157
# alpha: 73  L1-ratio: 0.3
# Nonzero weights: 23 from 157
# alpha: 74  L1-ratio: 0.3
# Nonzero weights: 22 from 157
# alpha: 75  L1-ratio: 0.3
# Nonzero weights: 20 from 157
# alpha: 76  L1-ratio: 0.3
# Nonzero weights: 20 from 157
# alpha: 77  L1-ratio: 0.3
# Nonzero weights: 20 from 157
# alpha: 78  L1-ratio: 0.3
# Nonzero weights: 20 from 157
# alpha: 79  L1-ratio: 0.3
# Nonzero weights: 18 from 157
# alpha: 80  L1-ratio: 0.3
# Nonzero weights: 18 from 157
# alpha: 81  L1-ratio: 0.3
# Nonzero weights: 18 from 157
# alpha: 82  L1-ratio: 0.3
# Nonzero weights: 17 from 157
# alpha: 83  L1-ratio: 0.3
# Nonzero weights: 16 from 157
# alpha: 84  L1-ratio: 0.3
# Nonzero weights: 16 from 157
# alpha: 85  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 86  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 87  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 88  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 89  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 90  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 91  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 92  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 93  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 94  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 95  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 96  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 97  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 98  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 99  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 100  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 101  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 102  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 103  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 104  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 105  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 106  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 107  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 108  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 109  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 110  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# alpha: 111  L1-ratio: 0.3
# Nonzero weights: 14 from 157
# alpha: 112  L1-ratio: 0.3
# Nonzero weights: 14 from 157
# alpha: 113  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# alpha: 114  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# alpha: 115  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# alpha: 116  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# alpha: 117  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# alpha: 118  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# alpha: 119  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# alpha: 120  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# alpha: 121  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# alpha: 122  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# alpha: 123  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# alpha: 124  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# alpha: 125  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 126  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 127  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 128  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 129  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 130  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 131  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 132  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 133  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 134  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 135  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 136  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 137  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 138  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 139  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 140  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 141  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 142  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 143  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 144  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 145  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# alpha: 146  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 147  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 148  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 149  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 150  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 151  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 152  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 153  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 154  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 155  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 156  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 157  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 158  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 159  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 160  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 161  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 162  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 163  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 164  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# alpha: 165  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# alpha: 166  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# alpha: 167  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# alpha: 168  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# alpha: 169  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 170  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 171  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 172  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 173  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 174  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 175  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 176  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 177  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 178  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 179  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 180  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 181  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# alpha: 182  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# alpha: 183  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# alpha: 184  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# alpha: 185  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# alpha: 186  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# alpha: 187  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# alpha: 188  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# alpha: 189  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# alpha: 190  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# alpha: 191  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# alpha: 192  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# alpha: 193  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# alpha: 194  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 195  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 196  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 197  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 198  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 199  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 200  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 201  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 202  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 203  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 204  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 205  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 206  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 207  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 208  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 209  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 210  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 211  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 212  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 213  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 214  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 215  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 216  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 217  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 218  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 219  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 220  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 221  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 222  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 223  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 224  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 225  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 226  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 227  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 228  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 229  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 230  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 231  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 232  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 233  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 234  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 235  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 236  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 237  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 238  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 239  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 240  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 241  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 242  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 243  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 244  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 245  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 246  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 247  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 248  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 249  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 250  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 251  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 252  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 253  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 254  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 255  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 256  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 257  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 258  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 259  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 260  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 261  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 262  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 263  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 264  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 265  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 266  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 267  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 268  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 269  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 270  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 271  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 272  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 273  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 274  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 275  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 276  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 277  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 278  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 279  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 280  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 281  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 282  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 283  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 284  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 285  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 286  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 287  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 288  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 289  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 290  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 291  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 292  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 293  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 294  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 295  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 296  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 297  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 298  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 299  L1-ratio: 0.3
# Nonzero weights: 6 from 157

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.3, 154 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train2_X2,train2_y,test2_X2,test2_y))

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.4, 105 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train2_X3,train2_y,test2_X3,test2_y))

# %%
## tuned alpha based on validation set, then measure the performance for test set.
## Fixing l1-ratio = 0.3
para = [34]
para_l=[0.3]
rmse=100000
mae=1000000
corr=0
print('For correlation filter r>=0.2, 212 features are selected')
for a in para:
    for l in para_l:
        print('alpha:',a,' L1-ratio:',l)
        rmse0,mae0,corr0 = eNet(a,l,train2_X1,train2_y,test2_X1,test2_y)
        if rmse0< rmse:
            rmse=rmse0
            mae=mae0
            corr = corr0
            print('========================================')
            print('Best RMSE is updated! ' )
            print('The mean absolute error is: ',mae)
            print('The root mean squared error is: ',rmse)
            print('The correlation is: ',corr)
            print('----------------------------------------')
# Out:
# For correlation filter r>=0.2, 212 features are selected
# alpha: 34  L1-ratio: 0.3
# Nonzero weights: 38 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  2.887066578096806
# The root mean squared error is:  3.4216594534068885
# The correlation is:  0.892312479509743
# ----------------------------------------
