# %% [markdown]
# ## tasks
# ### 1: Form training and testing periods as discussed (2 test periods, last 2*365 days). Be careful tp scale data only based on data from the training set. You may use (from Python) MinMaxScaler, standardisation (StandardScaler) or the default scaler in Python's elastic net.
# ### 2:Estimate the current flu rates by training an elastic net model. Use a Pearson correlation filter (r > 0.3) on the training data to reduce the amount of queries prior to training an elastic net (reminder: not all 1000 queries I provided are related to flu!). Report performance on the two test sets using three metrics: mean absolute error, root mean squared error and Pearson's correlation.
# ### 3: If there is time, begin work on traditional forecasting models (you've identified seasonal ARIMA and Hult-Winters).

# %%
# import libraries
import numpy as np
import pandas as pd
import random
import csv
import scipy.stats as stats
import seaborn as sns
from collections import Counter
from collections import defaultdict
import math
from sklearn.linear_model import ElasticNet
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from random import randint

import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm
from statsmodels.nonparametric.kde import KDEUnivariate
from statsmodels.nonparametric import smoothers_lowess
from pandas import Series, DataFrame
from patsy import dmatrices
from sklearn import datasets, svm

# initialize the plotting sizes
# set size
plt.rc('figure', figsize=(10, 5))
# subplots size
fizsize_with_subplots = (10, 10)
# histogram size
bin_size = 10

# %%
# Loading data
dates = pd.read_csv('data/dates.csv',header=None)
queries = pd.read_csv('data/queries.csv',header=None)
X = pd.read_csv('data/X.csv',header=None)
y = pd.read_csv('data/y.csv',header=None)

X.columns = queries

# %%
# data preprocessing and train-test split
# this data is well formed with no missing value and other symbols or labels that are non numerical.
# splitting the data into train and test

# Here we want the first 500 queries
X = X.iloc[:, 0: 250]

# first with the last year as test
# for convinience, pick the two validation set starting from 1/3 and 2/3 of the training set,
# 10% of training set as validation, here use 400 data points, two 200 periods.
test_size =365
length = X.shape[0]
l =(X.shape[0]-test_size)//3

train1_X = pd.concat([X[0:l],X[l+200:2*l],X[2*l+200:length-test_size]])
val1_X = pd.concat([X[l:l+200],X[2*l:2*l+200]])
train1_y = pd.concat([y[0:l],y[l+200:2*l],y[2*l+200:length-test_size]])
val1_y = pd.concat([y[l:l+200],y[2*l:2*l+200]])
test1_X = X[length-test_size:]
test1_y = y[length-test_size:]

# second with the last 2 year as test
test_size2 =365*2
l2 =(X.shape[0]-test_size2)//3

train2_X = pd.concat([X[0:l2],X[l2+180:2*l2],X[2*l2+180:length-test_size2]])
val2_X = pd.concat([X[l2:l2+180],X[2*l2:2*l2+180]])
train2_y = pd.concat([y[0:l2],y[l2+180:2*l2],y[2*l2+180:length-test_size2]])
val2_y = pd.concat([y[l2:l2+180],y[2*l2:2*l2+180]])
test2_X = X[length-test_size2:]
test2_y = y[length-test_size2:]

print('X shape: ',X.shape,'  y shape: ',y.shape)
print('train1 X:',train1_X.shape,' train1 y:',train1_y.shape,' Test1 X shape:',test1_X.shape, ' Test1 y shape:',test1_y.shape)
print('validation1 X:',val1_X.shape,' validation1 y:',val1_y.shape)
print('train2 X:',train2_X.shape,' train2 y:',train2_y.shape,' Test2 X:',test2_X.shape,' Test2 y:',test2_y.shape)
print('validation2 X:',val2_X.shape,' validation2 y:',val2_y.shape)
# Out:
# X shape:  (4383, 250)   y shape:  (4383, 1)
# train1 X: (3618, 250)  train1 y: (3618, 1)  Test1 X shape: (365, 250)  Test1 y shape: (365, 1)
# validation1 X: (400, 250)  validation1 y: (400, 1)
# train2 X: (3293, 250)  train2 y: (3293, 1)  Test2 X: (730, 250)  Test2 y: (730, 1)
# validation2 X: (360, 250)  validation2 y: (360, 1)

# %%
train_size = train1_X.shape[0]
corrs = np.zeros((X.shape[1],1))
for i in range(0,X.shape[1]):
    if X.sum(axis=1)[i] == 0:
        corrs[i] = 0
    else:
        corrs[i] = np.corrcoef(X.iloc[0:train_size,i],y.iloc[0:train_size,0])[0,1]
        
corrs.shape,X.columns.shape,X.columns[0],X.columns[249]
# Out:
# ((250, 1), (250,), ('flu',), ('flu incubation',))

# %%
def corr_filter(df_X,df_Xval,df_Xtest,corrs,threshold):
    X = df_X.copy()
    X_test = df_Xtest.copy()
    X_val = df_Xval.copy()
    col_corr = set() # Set of all the names of deleted columns
    for i in range(0,250):
            if corrs[i,0] < threshold: 
                #print(X.columns[i])
                colname = df_X.columns[i]
                del X[colname] # deleting the column from the dataset
                del X_test[colname] 
                del X_val[colname]

    return X,X_val,X_test

# %% [markdown]
# ## Fixing pearson correlation filter r>=0.2

# %%
#train1_X0,test1_X0 = corr_filter(train1_X,test1_X,corrs,0.1)
train1_X1,val1_X1,test1_X1 = corr_filter(train1_X,val1_X,test1_X,corrs,0.2)
#train1_X2,test1_X2 = corr_filter(train1_X,test1_X,corrs,0.3)
#train1_X3,test1_X3 = corr_filter(train1_X,test1_X,corrs,0.4)

# %%
#print('For correlation filter r>=0.1, we select feature number: ',train1_X0.shape[1])
print('For correlation filter r>=0.2, we select feature number: ',train1_X1.shape[1])
#print('For correlation filter r>=0.3, we select feature number: ',train1_X2.shape[1])
#print('For correlation filter r>=0.4, we select feature number: ',train1_X3.shape[1])
# Out:
# For correlation filter r>=0.2, we select feature number:  157

# %%
# Defien the mearure matrics, MAE, RMSE, CORR
# define three metrics: mean absolute error, root mean squared error and Pearson's correlation.
from sklearn.metrics import mean_absolute_error
# mae = mean_absolute_error(y_actual, y_pred)

from sklearn.metrics import mean_squared_error
from math import sqrt
# rmse = sqrt(mean_squared_error(y_actual, y_pred))

# np.correcoef returns Pearson product-moment correlation coefficients
def pearson_r(x,y):   
    corr_mat = np.corrcoef(x,y)
    return corr_mat[0,1]
# r = pearson_r(y_actual,y_pred)


# Generalise the function for convinient tuning
def eNet(a,l,train_X,train_y,test_X,test_y):
    
    # scaling and modeling
    scalerX = StandardScaler()
    scalerX.fit(train_X)
    train_X = scalerX.transform(train_X)
    test_X = scalerX.transform(test_X)
    
    scalery = StandardScaler() 
    scalery.fit(train_y) 
    train_y = scalery.transform(train_y) 
    
    
    alpha = a
    l1_ratio = l
    enet = ElasticNet(alpha=a, l1_ratio=l, normalize=False,max_iter=10000)
    enet.fit(train_X,train_y)
    print('Nonzero weights: %d from %d' % (len(np.nonzero(enet.coef_)[0]), len(enet.coef_)))
    y_pred1 = enet.predict(test_X)
    y_pred1 = scalery.inverse_transform(y_pred1)

    mae1 = mean_absolute_error(test_y, y_pred1)
    #print('The mean absolute error is: ',mae1)

    rmse1 = sqrt(mean_squared_error(test_y, y_pred1))
    #print('The root mean squared error is: ',rmse1)
    
    corr_y = test_y.copy()
    corr_y['y_act'] = test_y
    corr_y['y_pred']= y_pred1
    corr = np.corrcoef(corr_y['y_act'],corr_y['y_pred'])[0,1]
    #print('The correlation is: ',corr)
    
    return rmse1, mae1,corr

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.1, 310 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train1_X0,train1_y,test1_X0,test1_y))

# %%
np
# Out:
# <module 'numpy' from '/home/yiyangsu/anaconda3/lib/python3.6/site-packages/numpy/__init__.py'>

# %%
## Fixing l1-ratio = 0.3, only tuning alpha.
para = np.arange(0.01, 2.0, 0.01)
para_l=[0.3]
rmse=100000
mae=1000000
corr=0
print('For correlation filter r>=0.2, 212 features are selected')
for a in para:
    for l in para_l:
        print('alpha:',a,' L1-ratio:',l)
        rmse0,mae0,corr0 = eNet(a,l,train1_X1,train1_y,val1_X1,val1_y)
        if rmse0< rmse:
            rmse=rmse0
            mae=mae0
            corr = corr0
            print('========================================')
            print('Best RMSE is updated! ' )
            print('The mean absolute error is: ',mae)
            print('The root mean squared error is: ',rmse)
            print('The correlation is: ',corr)
            print('----------------------------------------')
# Out:
# For correlation filter r>=0.2, 212 features are selected
# alpha: 0.01  L1-ratio: 0.3
# Nonzero weights: 122 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  18.758344355984708
# The root mean squared error is:  36.48630170603103
# The correlation is:  0.8177579535794238
# ----------------------------------------
# alpha: 0.02  L1-ratio: 0.3
# Nonzero weights: 109 from 157
# alpha: 0.03  L1-ratio: 0.3
# Nonzero weights: 87 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  18.396001477018206
# The root mean squared error is:  34.961866255421214
# The correlation is:  0.8563961712787699
# ----------------------------------------
# alpha: 0.04  L1-ratio: 0.3
# Nonzero weights: 82 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  17.23346852174038
# The root mean squared error is:  32.3694644378473
# The correlation is:  0.8629858157804526
# ----------------------------------------
# alpha: 0.05  L1-ratio: 0.3
# Nonzero weights: 75 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  16.077135554081174
# The root mean squared error is:  29.835433831134814
# The correlation is:  0.8700313415801973
# ----------------------------------------
# alpha: 0.060000000000000005  L1-ratio: 0.3
# Nonzero weights: 70 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  15.11255494499589
# The root mean squared error is:  27.6619850676387
# The correlation is:  0.8763514823203475
# ----------------------------------------
# alpha: 0.06999999999999999  L1-ratio: 0.3
# Nonzero weights: 64 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.37842331577968
# The root mean squared error is:  26.077992769675223
# The correlation is:  0.8792197813138711
# ----------------------------------------
# alpha: 0.08  L1-ratio: 0.3
# Nonzero weights: 63 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.823368762537235
# The root mean squared error is:  24.962880569892285
# The correlation is:  0.8788442759955499
# ----------------------------------------
# alpha: 0.09  L1-ratio: 0.3
# Nonzero weights: 60 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.296139766708166
# The root mean squared error is:  23.891599892420142
# The correlation is:  0.8784626941399405
# ----------------------------------------
# alpha: 0.09999999999999999  L1-ratio: 0.3
# Nonzero weights: 57 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.815485332166668
# The root mean squared error is:  22.943275254944048
# The correlation is:  0.8772961805433754
# ----------------------------------------
# alpha: 0.11  L1-ratio: 0.3
# Nonzero weights: 54 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.395123182940681
# The root mean squared error is:  22.133477562323858
# The correlation is:  0.875919407225079
# ----------------------------------------
# alpha: 0.12  L1-ratio: 0.3
# Nonzero weights: 49 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.017612723611386
# The root mean squared error is:  21.42501690286234
# The correlation is:  0.8748785711636793
# ----------------------------------------
# alpha: 0.13  L1-ratio: 0.3
# Nonzero weights: 45 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  11.68028772525156
# The root mean squared error is:  20.76730424639244
# The correlation is:  0.873813299180997
# ----------------------------------------
# alpha: 0.14  L1-ratio: 0.3
# Nonzero weights: 41 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  11.38692203476124
# The root mean squared error is:  20.18181477388651
# The correlation is:  0.8735100530118983
# ----------------------------------------
# alpha: 0.15000000000000002  L1-ratio: 0.3
# Nonzero weights: 40 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  11.032972555451018
# The root mean squared error is:  19.434641217867185
# The correlation is:  0.874910161760711
# ----------------------------------------
# alpha: 0.16  L1-ratio: 0.3
# Nonzero weights: 40 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.689587853903895
# The root mean squared error is:  18.71893593056882
# The correlation is:  0.8763054270812979
# ----------------------------------------
# alpha: 0.17  L1-ratio: 0.3
# Nonzero weights: 39 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.488973239064071
# The root mean squared error is:  18.299931960126386
# The correlation is:  0.8773443486896387
# ----------------------------------------
# alpha: 0.18000000000000002  L1-ratio: 0.3
# Nonzero weights: 38 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.396094794564979
# The root mean squared error is:  18.082926071478912
# The correlation is:  0.8785469267501911
# ----------------------------------------
# alpha: 0.19  L1-ratio: 0.3
# Nonzero weights: 35 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.311366128489746
# The root mean squared error is:  17.882417134723713
# The correlation is:  0.8795395729337551
# ----------------------------------------
# alpha: 0.2  L1-ratio: 0.3
# Nonzero weights: 35 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.229598887017056
# The root mean squared error is:  17.684872864197995
# The correlation is:  0.8803913563222804
# ----------------------------------------
# alpha: 0.21000000000000002  L1-ratio: 0.3
# Nonzero weights: 34 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.149505792804886
# The root mean squared error is:  17.48892779196403
# The correlation is:  0.8812515667700765
# ----------------------------------------
# alpha: 0.22  L1-ratio: 0.3
# Nonzero weights: 34 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.069250596532203
# The root mean squared error is:  17.2939189820085
# The correlation is:  0.8821053729517088
# ----------------------------------------
# alpha: 0.23  L1-ratio: 0.3
# Nonzero weights: 32 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.031558977093184
# The root mean squared error is:  17.18767395298847
# The correlation is:  0.8826016306517835
# ----------------------------------------
# alpha: 0.24000000000000002  L1-ratio: 0.3
# Nonzero weights: 32 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.99209841702877
# The root mean squared error is:  17.0769606899798
# The correlation is:  0.8831397232594125
# ----------------------------------------
# alpha: 0.25  L1-ratio: 0.3
# Nonzero weights: 31 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.952125373020614
# The root mean squared error is:  16.964949877580334
# The correlation is:  0.8836581013759192
# ----------------------------------------
# alpha: 0.26  L1-ratio: 0.3
# Nonzero weights: 29 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.912415319787854
# The root mean squared error is:  16.854816814838294
# The correlation is:  0.8840719814902378
# ----------------------------------------
# alpha: 0.27  L1-ratio: 0.3
# Nonzero weights: 29 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.871162423286387
# The root mean squared error is:  16.74272990747234
# The correlation is:  0.8844468623687265
# ----------------------------------------
# alpha: 0.28  L1-ratio: 0.3
# Nonzero weights: 27 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.829334826500462
# The root mean squared error is:  16.62826542232236
# The correlation is:  0.8848139941505058
# ----------------------------------------
# alpha: 0.29000000000000004  L1-ratio: 0.3
# Nonzero weights: 27 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.790467152090521
# The root mean squared error is:  16.520481820793034
# The correlation is:  0.885095100541064
# ----------------------------------------
# alpha: 0.3  L1-ratio: 0.3
# Nonzero weights: 27 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.737854559782454
# The root mean squared error is:  16.399828425904197
# The correlation is:  0.8851202597315856
# ----------------------------------------
# alpha: 0.31  L1-ratio: 0.3
# Nonzero weights: 26 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.682545510031725
# The root mean squared error is:  16.273726743256915
# The correlation is:  0.885193374120943
# ----------------------------------------
# alpha: 0.32  L1-ratio: 0.3
# Nonzero weights: 26 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.625115422156027
# The root mean squared error is:  16.143106760749962
# The correlation is:  0.8852878678802256
# ----------------------------------------
# alpha: 0.33  L1-ratio: 0.3
# Nonzero weights: 26 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.567697716684656
# The root mean squared error is:  16.013473792450352
# The correlation is:  0.8853855098086727
# ----------------------------------------
# alpha: 0.34  L1-ratio: 0.3
# Nonzero weights: 25 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.506475620488049
# The root mean squared error is:  15.87766271096325
# The correlation is:  0.8854972727976004
# ----------------------------------------
# alpha: 0.35000000000000003  L1-ratio: 0.3
# Nonzero weights: 25 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.445367001788318
# The root mean squared error is:  15.740895754842752
# The correlation is:  0.8856164022722868
# ----------------------------------------
# alpha: 0.36000000000000004  L1-ratio: 0.3
# Nonzero weights: 24 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.383644107075433
# The root mean squared error is:  15.600386639659748
# The correlation is:  0.8857475726616904
# ----------------------------------------
# alpha: 0.37  L1-ratio: 0.3
# Nonzero weights: 23 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.323933429010037
# The root mean squared error is:  15.458152034018745
# The correlation is:  0.8858865005612315
# ----------------------------------------
# alpha: 0.38  L1-ratio: 0.3
# Nonzero weights: 23 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.262628240597614
# The root mean squared error is:  15.314327928369016
# The correlation is:  0.8860290936092795
# ----------------------------------------
# alpha: 0.39  L1-ratio: 0.3
# Nonzero weights: 21 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.202911156936432
# The root mean squared error is:  15.17583033715641
# The correlation is:  0.8861666635365296
# ----------------------------------------
# alpha: 0.4  L1-ratio: 0.3
# Nonzero weights: 21 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.1590733271856
# The root mean squared error is:  15.068722128951563
# The correlation is:  0.8863531550733528
# ----------------------------------------
# alpha: 0.41000000000000003  L1-ratio: 0.3
# Nonzero weights: 21 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.114308173841941
# The root mean squared error is:  14.961150158264235
# The correlation is:  0.8865408332409955
# ----------------------------------------
# alpha: 0.42000000000000004  L1-ratio: 0.3
# Nonzero weights: 21 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.072557884920162
# The root mean squared error is:  14.856004156676773
# The correlation is:  0.8867308358410825
# ----------------------------------------
# alpha: 0.43  L1-ratio: 0.3
# Nonzero weights: 21 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.03105799417107
# The root mean squared error is:  14.751752512504325
# The correlation is:  0.8869225530069318
# ----------------------------------------
# alpha: 0.44  L1-ratio: 0.3
# Nonzero weights: 20 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.986000632742716
# The root mean squared error is:  14.641507746099625
# The correlation is:  0.8871529755484637
# ----------------------------------------
# alpha: 0.45  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.93708292013789
# The root mean squared error is:  14.523368835821401
# The correlation is:  0.8874613053410675
# ----------------------------------------
# alpha: 0.46  L1-ratio: 0.3
# Nonzero weights: 18 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.895233499818442
# The root mean squared error is:  14.42996934277441
# The correlation is:  0.887458792882184
# ----------------------------------------
# alpha: 0.47000000000000003  L1-ratio: 0.3
# Nonzero weights: 18 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.858370545209318
# The root mean squared error is:  14.352048477784104
# The correlation is:  0.8872934398567854
# ----------------------------------------
# alpha: 0.48000000000000004  L1-ratio: 0.3
# Nonzero weights: 18 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.821411766559184
# The root mean squared error is:  14.275130895663905
# The correlation is:  0.8871303272187049
# ----------------------------------------
# alpha: 0.49  L1-ratio: 0.3
# Nonzero weights: 18 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.784376678651066
# The root mean squared error is:  14.198460283196702
# The correlation is:  0.8869654187880217
# ----------------------------------------
# alpha: 0.5  L1-ratio: 0.3
# Nonzero weights: 18 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.748009940584888
# The root mean squared error is:  14.123831388662701
# The correlation is:  0.8868061610688458
# ----------------------------------------
# alpha: 0.51  L1-ratio: 0.3
# Nonzero weights: 18 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.711591493557783
# The root mean squared error is:  14.050280870650893
# The correlation is:  0.8866487285518025
# ----------------------------------------
# alpha: 0.52  L1-ratio: 0.3
# Nonzero weights: 18 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.675060332854036
# The root mean squared error is:  13.977013857105653
# The correlation is:  0.8864890428554414
# ----------------------------------------
# alpha: 0.53  L1-ratio: 0.3
# Nonzero weights: 16 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.637545730071704
# The root mean squared error is:  13.901339464814892
# The correlation is:  0.8863941359916369
# ----------------------------------------
# alpha: 0.54  L1-ratio: 0.3
# Nonzero weights: 16 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.5977108491849
# The root mean squared error is:  13.821602619026987
# The correlation is:  0.8863373500102041
# ----------------------------------------
# alpha: 0.55  L1-ratio: 0.3
# Nonzero weights: 16 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.558182504334
# The root mean squared error is:  13.743251617686676
# The correlation is:  0.8862822298386742
# ----------------------------------------
# alpha: 0.56  L1-ratio: 0.3
# Nonzero weights: 16 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.518965570523756
# The root mean squared error is:  13.665613364852268
# The correlation is:  0.8862248788584776
# ----------------------------------------
# alpha: 0.5700000000000001  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.480043686660018
# The root mean squared error is:  13.589438359487625
# The correlation is:  0.8861785884162433
# ----------------------------------------
# alpha: 0.5800000000000001  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.440753932163528
# The root mean squared error is:  13.513385984288453
# The correlation is:  0.8861433768147522
# ----------------------------------------
# alpha: 0.59  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.402396779762826
# The root mean squared error is:  13.438825786102827
# The correlation is:  0.8861102689885334
# ----------------------------------------
# alpha: 0.6  L1-ratio: 0.3
# Nonzero weights: 14 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.364794561244093
# The root mean squared error is:  13.361378884780414
# The correlation is:  0.8860874234789436
# ----------------------------------------
# alpha: 0.61  L1-ratio: 0.3
# Nonzero weights: 14 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.326437515653598
# The root mean squared error is:  13.284551097778348
# The correlation is:  0.8860745844551048
# ----------------------------------------
# alpha: 0.62  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.288125666126179
# The root mean squared error is:  13.210395828585446
# The correlation is:  0.8860522704042763
# ----------------------------------------
# alpha: 0.63  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.24948105868982
# The root mean squared error is:  13.139174665844013
# The correlation is:  0.8860164543559025
# ----------------------------------------
# alpha: 0.64  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.210741736625524
# The root mean squared error is:  13.069266614803476
# The correlation is:  0.8859782994391998
# ----------------------------------------
# alpha: 0.65  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.172774650653615
# The root mean squared error is:  13.001919871217517
# The correlation is:  0.8859455327098981
# ----------------------------------------
# alpha: 0.66  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.13505341967437
# The root mean squared error is:  12.936487606104981
# The correlation is:  0.8859142750888891
# ----------------------------------------
# alpha: 0.67  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.097532477007618
# The root mean squared error is:  12.873015516817073
# The correlation is:  0.8858844398177916
# ----------------------------------------
# alpha: 0.68  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.061994773549124
# The root mean squared error is:  12.811543216554494
# The correlation is:  0.8858559392102806
# ----------------------------------------
# alpha: 0.6900000000000001  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  8.028914797674311
# The root mean squared error is:  12.751674982431744
# The correlation is:  0.8858246808150493
# ----------------------------------------
# alpha: 0.7000000000000001  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.998855862177188
# The root mean squared error is:  12.694432712018635
# The correlation is:  0.8857985199336854
# ----------------------------------------
# alpha: 0.7100000000000001  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.972086950683125
# The root mean squared error is:  12.63929316448007
# The correlation is:  0.8857735443553757
# ----------------------------------------
# alpha: 0.72  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.9473459952142385
# The root mean squared error is:  12.586291869618227
# The correlation is:  0.8857496863811197
# ----------------------------------------
# alpha: 0.73  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.922530528692953
# The root mean squared error is:  12.535461020842444
# The correlation is:  0.8857268942599008
# ----------------------------------------
# alpha: 0.74  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.898054368548792
# The root mean squared error is:  12.48683761036373
# The correlation is:  0.885705080518656
# ----------------------------------------
# alpha: 0.75  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.875641080322744
# The root mean squared error is:  12.440454410035032
# The correlation is:  0.8856841832851331
# ----------------------------------------
# alpha: 0.76  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.853760095456437
# The root mean squared error is:  12.39615556248931
# The correlation is:  0.8856600544961407
# ----------------------------------------
# alpha: 0.77  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.8392934350630075
# The root mean squared error is:  12.354422736908205
# The correlation is:  0.885640795457604
# ----------------------------------------
# alpha: 0.78  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.827322918163548
# The root mean squared error is:  12.31500911357381
# The correlation is:  0.8856223252174976
# ----------------------------------------
# alpha: 0.79  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.815539711729722
# The root mean squared error is:  12.277942550476698
# The correlation is:  0.8856045863043521
# ----------------------------------------
# alpha: 0.8  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.8042582133320755
# The root mean squared error is:  12.243249114885181
# The correlation is:  0.8855875232978772
# ----------------------------------------
# alpha: 0.81  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.795743771113516
# The root mean squared error is:  12.210953299269624
# The correlation is:  0.8855710826770341
# ----------------------------------------
# alpha: 0.8200000000000001  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.787711930417938
# The root mean squared error is:  12.180999328233213
# The correlation is:  0.8855513222829294
# ----------------------------------------
# alpha: 0.8300000000000001  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.782608565531136
# The root mean squared error is:  12.153623066553378
# The correlation is:  0.8855359574645417
# ----------------------------------------
# alpha: 0.8400000000000001  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.778531932597112
# The root mean squared error is:  12.12869783281784
# The correlation is:  0.8855211037789177
# ----------------------------------------
# alpha: 0.85  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.774785797258633
# The root mean squared error is:  12.106241769649426
# The correlation is:  0.885506709702351
# ----------------------------------------
# alpha: 0.86  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.772286537218815
# The root mean squared error is:  12.08581579173612
# The correlation is:  0.8854989017915761
# ----------------------------------------
# alpha: 0.87  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.770424060482576
# The root mean squared error is:  12.067043875049567
# The correlation is:  0.8855041439652539
# ----------------------------------------
# alpha: 0.88  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.7699060352183755
# The root mean squared error is:  12.055404837382996
# The correlation is:  0.8854190148781534
# ----------------------------------------
# alpha: 0.89  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.770819612582008
# The root mean squared error is:  12.050865352584854
# The correlation is:  0.8852478474681669
# ----------------------------------------
# alpha: 0.9  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.771672591275639
# The root mean squared error is:  12.048894313918163
# The correlation is:  0.8850767586051318
# ----------------------------------------
# alpha: 0.91  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 0.92  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# alpha: 0.93  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# alpha: 0.9400000000000001  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# alpha: 0.9500000000000001  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 0.9600000000000001  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 0.97  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 0.98  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 0.99  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.0  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.01  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.02  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.03  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.04  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.05  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.06  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.07  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.08  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.09  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.1  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.11  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.12  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.1300000000000001  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.1400000000000001  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.1500000000000001  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.1600000000000001  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.17  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.18  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.19  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.2  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.21  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.22  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.23  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.24  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.25  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.26  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.27  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.28  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.29  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.3  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.31  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.32  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.33  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.34  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.35  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.36  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.37  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.3800000000000001  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.3900000000000001  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.4000000000000001  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.4100000000000001  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.42  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.43  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.44  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.45  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.46  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.47  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.48  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.49  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.5  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.51  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.52  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.53  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.54  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.55  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.56  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.57  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.58  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.59  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.6  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.61  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.62  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.6300000000000001  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.6400000000000001  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.6500000000000001  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.6600000000000001  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.6700000000000002  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.68  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# alpha: 1.69  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# alpha: 1.7  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# alpha: 1.71  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# alpha: 1.72  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# alpha: 1.73  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# alpha: 1.74  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# alpha: 1.75  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# alpha: 1.76  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# alpha: 1.77  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# alpha: 1.78  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# alpha: 1.79  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.8  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.81  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.82  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.83  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.84  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.85  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.86  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.87  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.8800000000000001  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.8900000000000001  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.9000000000000001  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.9100000000000001  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.9200000000000002  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.93  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.94  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.95  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.96  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.97  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.98  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# alpha: 1.99  L1-ratio: 0.3
# Nonzero weights: 6 from 157

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.3, 150 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train1_X2,train1_y,test1_X2,test1_y))

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.4, 103 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train1_X3,train1_y,test1_X3,test1_y))

# %%
## tuned alpha based on validation set, then measure the performance for test set.
## Fixing l1-ratio = 0.3
para = [0.9]
para_l=[0.3]
rmse=100000
mae=1000000
corr=0

for a in para:
    for l in para_l:
        print('alpha:',a,' L1-ratio:',l)
        rmse0,mae0,corr0 = eNet(a,l,train1_X1,train1_y,test1_X1,test1_y)
        if rmse0< rmse:
            rmse=rmse0
            mae=mae0
            corr = corr0
            print('========================================')
            print('Best RMSE is updated! ' )
            print('The mean absolute error is: ',mae)
            print('The root mean squared error is: ',rmse)
            print('The correlation is: ',corr)
            print('----------------------------------------')
# Out:
# For correlation filter r>=0.2, 212 features are selected
# alpha: 0.9  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.025636980566922
# The root mean squared error is:  4.544224744424967
# The correlation is:  0.8391743685708768
# ----------------------------------------

# %% [markdown]
# ## For the last 2 years as the testing set

# %%
train_size = 3653
corrs2 = np.zeros((X.shape[1],1))
for i in range(0,X.shape[1]):
    if X.sum(axis=1)[i] == 0:
        corrs2[i] = 0
    else:
        corrs2[i] = np.corrcoef(X.iloc[0:train_size,i],y.iloc[0:train_size,0])[0,1]
        
corrs2.shape,X.columns.shape,X.columns[0],X.columns[249]
# Out:
# ((250, 1), (250,), ('flu',), ('flu incubation',))

# %%
#train2_X0,test2_X0 = corr_filter(train2_X,test2_X,corrs2,0.1)
train2_X1,val2_X1,test2_X1 = corr_filter(train2_X,val2_X,test2_X,corrs2,0.2)
#train2_X2,test2_X2 = corr_filter(train2_X,test2_X,corrs2,0.3)
#train2_X3,test2_X3 = corr_filter(train2_X,test2_X,corrs2,0.4)

# %%
#print('For correlation filter r>0.1, we select feature number: ',train2_X0.shape[1])
print('For correlation filter r>0.2, we select feature number: ',train2_X1.shape[1])
#print('For correlation filter r>0.3, we select feature number: ',train2_X2.shape[1])
#print('For correlation filter r>0.4, we select feature number: ',train2_X3.shape[1])
# Out:
# For correlation filter r>0.2, we select feature number:  157

# %% [markdown]
# para = range(1,100)
# para_l=[0.3]
# rmse=100000
# mae=1000000
# corr=0
# print('For correlation filter r>=0.1, 303 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         rmse0,mae0,corr0 = eNet(a,l,train2_X1,train2_y,val2_X1,val2_y)
#         if rmse0< rmse:
#             rmse=rmse0
#             mae=mae0
#             corr = corr0
#             print('========================================')
#             print('Best RMSE is updated! ' )
#             print('The mean absolute error is: ',mae)
#             print('The root mean squared error is: ',rmse)
#             print('The correlation is: ',corr)
#             print('----------------------------------------')

# %%
para = np.arange(0.01, 3.0, 0.01)
para_l=[0.3]
rmse=100000
mae=1000000
corr=0
print('For correlation filter r>=0.1, 303 features are selected')
for a in para:
    for l in para_l:
        print('alpha:',a,' L1-ratio:',l)
        rmse0,mae0,corr0 = eNet(a,l,train2_X1,train2_y,val2_X1,val2_y)
        if rmse0< rmse:
            rmse=rmse0
            mae=mae0
            corr = corr0
            print('========================================')
            print('Best RMSE is updated! ' )
            print('The mean absolute error is: ',mae)
            print('The root mean squared error is: ',rmse)
            print('The correlation is: ',corr)
            print('----------------------------------------')
# Out:
# For correlation filter r>=0.1, 303 features are selected
# alpha: 0.01  L1-ratio: 0.3
# Nonzero weights: 118 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.978415541845191
# The root mean squared error is:  10.9539269209476
# The correlation is:  0.35416707307360035
# ----------------------------------------
# alpha: 0.02  L1-ratio: 0.3
# Nonzero weights: 100 from 157
# alpha: 0.03  L1-ratio: 0.3
# Nonzero weights: 85 from 157
# alpha: 0.04  L1-ratio: 0.3
# Nonzero weights: 76 from 157
# alpha: 0.05  L1-ratio: 0.3
# Nonzero weights: 74 from 157
# alpha: 0.060000000000000005  L1-ratio: 0.3
# Nonzero weights: 68 from 157
# alpha: 0.06999999999999999  L1-ratio: 0.3
# Nonzero weights: 64 from 157
# alpha: 0.08  L1-ratio: 0.3
# Nonzero weights: 63 from 157
# alpha: 0.09  L1-ratio: 0.3
# Nonzero weights: 62 from 157
# alpha: 0.09999999999999999  L1-ratio: 0.3
# Nonzero weights: 57 from 157
# alpha: 0.11  L1-ratio: 0.3
# Nonzero weights: 54 from 157
# alpha: 0.12  L1-ratio: 0.3
# Nonzero weights: 52 from 157
# alpha: 0.13  L1-ratio: 0.3
# Nonzero weights: 51 from 157
# alpha: 0.14  L1-ratio: 0.3
# Nonzero weights: 51 from 157
# alpha: 0.15000000000000002  L1-ratio: 0.3
# Nonzero weights: 51 from 157
# alpha: 0.16  L1-ratio: 0.3
# Nonzero weights: 50 from 157
# alpha: 0.17  L1-ratio: 0.3
# Nonzero weights: 48 from 157
# alpha: 0.18000000000000002  L1-ratio: 0.3
# Nonzero weights: 47 from 157
# alpha: 0.19  L1-ratio: 0.3
# Nonzero weights: 47 from 157
# alpha: 0.2  L1-ratio: 0.3
# Nonzero weights: 46 from 157
# alpha: 0.21000000000000002  L1-ratio: 0.3
# Nonzero weights: 45 from 157
# alpha: 0.22  L1-ratio: 0.3
# Nonzero weights: 43 from 157
# alpha: 0.23  L1-ratio: 0.3
# Nonzero weights: 42 from 157
# alpha: 0.24000000000000002  L1-ratio: 0.3
# Nonzero weights: 42 from 157
# alpha: 0.25  L1-ratio: 0.3
# Nonzero weights: 41 from 157
# alpha: 0.26  L1-ratio: 0.3
# Nonzero weights: 40 from 157
# alpha: 0.27  L1-ratio: 0.3
# Nonzero weights: 40 from 157
# alpha: 0.28  L1-ratio: 0.3
# Nonzero weights: 40 from 157
# alpha: 0.29000000000000004  L1-ratio: 0.3
# Nonzero weights: 37 from 157
# alpha: 0.3  L1-ratio: 0.3
# Nonzero weights: 36 from 157
# alpha: 0.31  L1-ratio: 0.3
# Nonzero weights: 33 from 157
# alpha: 0.32  L1-ratio: 0.3
# Nonzero weights: 33 from 157
# alpha: 0.33  L1-ratio: 0.3
# Nonzero weights: 33 from 157
# alpha: 0.34  L1-ratio: 0.3
# Nonzero weights: 34 from 157
# alpha: 0.35000000000000003  L1-ratio: 0.3
# Nonzero weights: 33 from 157
# alpha: 0.36000000000000004  L1-ratio: 0.3
# Nonzero weights: 33 from 157
# alpha: 0.37  L1-ratio: 0.3
# Nonzero weights: 33 from 157
# alpha: 0.38  L1-ratio: 0.3
# Nonzero weights: 33 from 157
# alpha: 0.39  L1-ratio: 0.3
# Nonzero weights: 32 from 157
# alpha: 0.4  L1-ratio: 0.3
# Nonzero weights: 32 from 157
# alpha: 0.41000000000000003  L1-ratio: 0.3
# Nonzero weights: 32 from 157
# alpha: 0.42000000000000004  L1-ratio: 0.3
# Nonzero weights: 31 from 157
# alpha: 0.43  L1-ratio: 0.3
# Nonzero weights: 31 from 157
# alpha: 0.44  L1-ratio: 0.3
# Nonzero weights: 31 from 157
# alpha: 0.45  L1-ratio: 0.3
# Nonzero weights: 30 from 157
# alpha: 0.46  L1-ratio: 0.3
# Nonzero weights: 29 from 157
# alpha: 0.47000000000000003  L1-ratio: 0.3
# Nonzero weights: 28 from 157
# alpha: 0.48000000000000004  L1-ratio: 0.3
# Nonzero weights: 28 from 157
# alpha: 0.49  L1-ratio: 0.3
# Nonzero weights: 26 from 157
# alpha: 0.5  L1-ratio: 0.3
# Nonzero weights: 26 from 157
# alpha: 0.51  L1-ratio: 0.3
# Nonzero weights: 26 from 157
# alpha: 0.52  L1-ratio: 0.3
# Nonzero weights: 26 from 157
# alpha: 0.53  L1-ratio: 0.3
# Nonzero weights: 25 from 157
# alpha: 0.54  L1-ratio: 0.3
# Nonzero weights: 25 from 157
# alpha: 0.55  L1-ratio: 0.3
# Nonzero weights: 25 from 157
# alpha: 0.56  L1-ratio: 0.3
# Nonzero weights: 25 from 157
# alpha: 0.5700000000000001  L1-ratio: 0.3
# Nonzero weights: 25 from 157
# alpha: 0.5800000000000001  L1-ratio: 0.3
# Nonzero weights: 25 from 157
# alpha: 0.59  L1-ratio: 0.3
# Nonzero weights: 26 from 157
# alpha: 0.6  L1-ratio: 0.3
# Nonzero weights: 26 from 157
# alpha: 0.61  L1-ratio: 0.3
# Nonzero weights: 26 from 157
# alpha: 0.62  L1-ratio: 0.3
# Nonzero weights: 26 from 157
# alpha: 0.63  L1-ratio: 0.3
# Nonzero weights: 25 from 157
# alpha: 0.64  L1-ratio: 0.3
# Nonzero weights: 24 from 157
# alpha: 0.65  L1-ratio: 0.3
# Nonzero weights: 24 from 157
# alpha: 0.66  L1-ratio: 0.3
# Nonzero weights: 24 from 157
# alpha: 0.67  L1-ratio: 0.3
# Nonzero weights: 24 from 157
# alpha: 0.68  L1-ratio: 0.3
# Nonzero weights: 23 from 157
# alpha: 0.6900000000000001  L1-ratio: 0.3
# Nonzero weights: 22 from 157
# alpha: 0.7000000000000001  L1-ratio: 0.3
# Nonzero weights: 22 from 157
# alpha: 0.7100000000000001  L1-ratio: 0.3
# Nonzero weights: 22 from 157
# alpha: 0.72  L1-ratio: 0.3
# Nonzero weights: 22 from 157
# alpha: 0.73  L1-ratio: 0.3
# Nonzero weights: 21 from 157
# alpha: 0.74  L1-ratio: 0.3
# Nonzero weights: 21 from 157
# alpha: 0.75  L1-ratio: 0.3
# Nonzero weights: 21 from 157
# alpha: 0.76  L1-ratio: 0.3
# Nonzero weights: 21 from 157
# alpha: 0.77  L1-ratio: 0.3
# Nonzero weights: 21 from 157
# alpha: 0.78  L1-ratio: 0.3
# Nonzero weights: 20 from 157
# alpha: 0.79  L1-ratio: 0.3
# Nonzero weights: 20 from 157
# alpha: 0.8  L1-ratio: 0.3
# Nonzero weights: 20 from 157
# alpha: 0.81  L1-ratio: 0.3
# Nonzero weights: 20 from 157
# alpha: 0.8200000000000001  L1-ratio: 0.3
# Nonzero weights: 20 from 157
# alpha: 0.8300000000000001  L1-ratio: 0.3
# Nonzero weights: 20 from 157
# alpha: 0.8400000000000001  L1-ratio: 0.3
# Nonzero weights: 20 from 157
# alpha: 0.85  L1-ratio: 0.3
# Nonzero weights: 20 from 157
# alpha: 0.86  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 0.87  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 0.88  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 0.89  L1-ratio: 0.3
# Nonzero weights: 18 from 157
# alpha: 0.9  L1-ratio: 0.3
# Nonzero weights: 18 from 157
# alpha: 0.91  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 0.92  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 0.93  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 0.9400000000000001  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 0.9500000000000001  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 0.9600000000000001  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 0.97  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 0.98  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 0.99  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 1.0  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 1.01  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 1.02  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 1.03  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 1.04  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 1.05  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 1.06  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 1.07  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 1.08  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 1.09  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 1.1  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# alpha: 1.11  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.942976602579631
# The root mean squared error is:  10.919447582392722
# The correlation is:  0.11376253017210894
# ----------------------------------------
# alpha: 1.12  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.941599904071301
# The root mean squared error is:  10.8832173974399
# The correlation is:  0.11362837205129346
# ----------------------------------------
# alpha: 1.1300000000000001  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.940266789816382
# The root mean squared error is:  10.846961960539309
# The correlation is:  0.11349891279192438
# ----------------------------------------
# alpha: 1.1400000000000001  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.938972823930644
# The root mean squared error is:  10.811005571423665
# The correlation is:  0.11336546829834236
# ----------------------------------------
# alpha: 1.1500000000000001  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.937642909053445
# The root mean squared error is:  10.775188573690405
# The correlation is:  0.11323242424061114
# ----------------------------------------
# alpha: 1.1600000000000001  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.9362200967925665
# The root mean squared error is:  10.739364606703829
# The correlation is:  0.1131038493517306
# ----------------------------------------
# alpha: 1.17  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.93482253688181
# The root mean squared error is:  10.703843202622652
# The correlation is:  0.11297121312777703
# ----------------------------------------
# alpha: 1.18  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.933335091626286
# The root mean squared error is:  10.668324460129417
# The correlation is:  0.11284305945357749
# ----------------------------------------
# alpha: 1.19  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.931870822998151
# The root mean squared error is:  10.633107341682548
# The correlation is:  0.11271075529255395
# ----------------------------------------
# alpha: 1.2  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.93032233202379
# The root mean squared error is:  10.59790946492945
# The correlation is:  0.11258273545552278
# ----------------------------------------
# alpha: 1.21  L1-ratio: 0.3
# Nonzero weights: 19 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.9287941160659
# The root mean squared error is:  10.563010188935229
# The correlation is:  0.11245054424704508
# ----------------------------------------
# alpha: 1.22  L1-ratio: 0.3
# Nonzero weights: 18 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.9269015670461105
# The root mean squared error is:  10.527083549290108
# The correlation is:  0.11238622615068126
# ----------------------------------------
# alpha: 1.23  L1-ratio: 0.3
# Nonzero weights: 18 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.9247830474141185
# The root mean squared error is:  10.4906491655136
# The correlation is:  0.11236070312030016
# ----------------------------------------
# alpha: 1.24  L1-ratio: 0.3
# Nonzero weights: 18 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.922667097871381
# The root mean squared error is:  10.454484781608476
# The correlation is:  0.11233379745106602
# ----------------------------------------
# alpha: 1.25  L1-ratio: 0.3
# Nonzero weights: 18 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.920492370442817
# The root mean squared error is:  10.418421198007241
# The correlation is:  0.11231074257707704
# ----------------------------------------
# alpha: 1.26  L1-ratio: 0.3
# Nonzero weights: 17 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.918130445906774
# The root mean squared error is:  10.382464621376261
# The correlation is:  0.11227909959078511
# ----------------------------------------
# alpha: 1.27  L1-ratio: 0.3
# Nonzero weights: 16 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.91764023290915
# The root mean squared error is:  10.352824870422983
# The correlation is:  0.11217754896676115
# ----------------------------------------
# alpha: 1.28  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.917435641146766
# The root mean squared error is:  10.32427215652948
# The correlation is:  0.1120665970262233
# ----------------------------------------
# alpha: 1.29  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.916445079170271
# The root mean squared error is:  10.294826172596217
# The correlation is:  0.11198368020021447
# ----------------------------------------
# alpha: 1.3  L1-ratio: 0.3
# Nonzero weights: 15 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.915499699765793
# The root mean squared error is:  10.265593931764982
# The correlation is:  0.11190001960689921
# ----------------------------------------
# alpha: 1.31  L1-ratio: 0.3
# Nonzero weights: 14 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.914258971510235
# The root mean squared error is:  10.236066418454051
# The correlation is:  0.11179925027229293
# ----------------------------------------
# alpha: 1.32  L1-ratio: 0.3
# Nonzero weights: 14 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.9123404064217056
# The root mean squared error is:  10.206115614804078
# The correlation is:  0.11166142292750966
# ----------------------------------------
# alpha: 1.33  L1-ratio: 0.3
# Nonzero weights: 14 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.910394758590477
# The root mean squared error is:  10.1762849450105
# The correlation is:  0.11152250561616688
# ----------------------------------------
# alpha: 1.34  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.907266409554663
# The root mean squared error is:  10.143443581070192
# The correlation is:  0.11141626078877188
# ----------------------------------------
# alpha: 1.35  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.903957630042644
# The root mean squared error is:  10.110369217075895
# The correlation is:  0.11131715286496487
# ----------------------------------------
# alpha: 1.36  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.9006635665562825
# The root mean squared error is:  10.077569981173804
# The correlation is:  0.11121514573690326
# ----------------------------------------
# alpha: 1.37  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.897275036101256
# The root mean squared error is:  10.044800773575261
# The correlation is:  0.11111893911795669
# ----------------------------------------
# alpha: 1.3800000000000001  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.8938526993156835
# The root mean squared error is:  10.012204440376077
# The correlation is:  0.11102380016813893
# ----------------------------------------
# alpha: 1.3900000000000001  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.890456633656023
# The root mean squared error is:  9.979925003672768
# The correlation is:  0.11092492773185665
# ----------------------------------------
# alpha: 1.4000000000000001  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.8869589972069765
# The root mean squared error is:  9.947657121017938
# The correlation is:  0.11083256448896081
# ----------------------------------------
# alpha: 1.4100000000000001  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.8834294248082415
# The root mean squared error is:  9.91557253970682
# The correlation is:  0.1107412236603678
# ----------------------------------------
# alpha: 1.42  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.879867481352596
# The root mean squared error is:  9.88367212705298
# The correlation is:  0.11065097189796606
# ----------------------------------------
# alpha: 1.43  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.876273801330136
# The root mean squared error is:  9.851959138900325
# The correlation is:  0.11056178758347403
# ----------------------------------------
# alpha: 1.44  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.872706421539254
# The root mean squared error is:  9.820574668911018
# The correlation is:  0.11046887806016144
# ----------------------------------------
# alpha: 1.45  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.869044997065212
# The root mean squared error is:  9.789229587923252
# The correlation is:  0.11038222197947768
# ----------------------------------------
# alpha: 1.46  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.865353398101949
# The root mean squared error is:  9.758082423809782
# The correlation is:  0.11029661349195405
# ----------------------------------------
# alpha: 1.47  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.861632065828842
# The root mean squared error is:  9.72713617820853
# The correlation is:  0.11021204717135757
# ----------------------------------------
# alpha: 1.48  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.8578817513787085
# The root mean squared error is:  9.696394722530794
# The correlation is:  0.11012849199726993
# ----------------------------------------
# alpha: 1.49  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.854103020819848
# The root mean squared error is:  9.665861407898172
# The correlation is:  0.11004593095642864
# ----------------------------------------
# alpha: 1.5  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.850350000508438
# The root mean squared error is:  9.635666886881484
# The correlation is:  0.10995967517678806
# ----------------------------------------
# alpha: 1.51  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.846511034301757
# The root mean squared error is:  9.605545176791829
# The correlation is:  0.10987943015875452
# ----------------------------------------
# alpha: 1.52  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.842645249703735
# The root mean squared error is:  9.575641781505384
# The correlation is:  0.1098001419445108
# ----------------------------------------
# alpha: 1.53  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.838753184212988
# The root mean squared error is:  9.545959961781051
# The correlation is:  0.10972179326049411
# ----------------------------------------
# alpha: 1.54  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.834835127087157
# The root mean squared error is:  9.516502417665318
# The correlation is:  0.10964438876676023
# ----------------------------------------
# alpha: 1.55  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.830945034878064
# The root mean squared error is:  9.487400935848864
# The correlation is:  0.10956308631384466
# ----------------------------------------
# alpha: 1.56  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.826972384876534
# The root mean squared error is:  9.458389086967118
# The correlation is:  0.10948782821290362
# ----------------------------------------
# alpha: 1.57  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.822975451868079
# The root mean squared error is:  9.429611904989416
# The correlation is:  0.10941345728728395
# ----------------------------------------
# alpha: 1.58  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.818954651604112
# The root mean squared error is:  9.401072353428555
# The correlation is:  0.10933996417103217
# ----------------------------------------
# alpha: 1.59  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.814965759116218
# The root mean squared error is:  9.372910188831426
# The correlation is:  0.10926223108214268
# ----------------------------------------
# alpha: 1.6  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.81089482631245
# The root mean squared error is:  9.344843213823687
# The correlation is:  0.10919072512048152
# ----------------------------------------
# alpha: 1.61  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.806801285916216
# The root mean squared error is:  9.317023294785386
# The correlation is:  0.10912007506588046
# ----------------------------------------
# alpha: 1.62  L1-ratio: 0.3
# Nonzero weights: 13 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.802729607019823
# The root mean squared error is:  9.289569373146179
# The correlation is:  0.10904621670844078
# ----------------------------------------
# alpha: 1.6300000000000001  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.798243810087645
# The root mean squared error is:  9.261164119382045
# The correlation is:  0.10900748543286767
# ----------------------------------------
# alpha: 1.6400000000000001  L1-ratio: 0.3
# Nonzero weights: 12 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.793769024656832
# The root mean squared error is:  9.233110223832742
# The correlation is:  0.10896718177251952
# ----------------------------------------
# alpha: 1.6500000000000001  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.789467148655265
# The root mean squared error is:  9.205769465451226
# The correlation is:  0.10891177107600424
# ----------------------------------------
# alpha: 1.6600000000000001  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.7851935627550475
# The root mean squared error is:  9.178793915978561
# The correlation is:  0.10885332909147055
# ----------------------------------------
# alpha: 1.6700000000000002  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.780906894713329
# The root mean squared error is:  9.152110454950929
# The correlation is:  0.10879533330945029
# ----------------------------------------
# alpha: 1.68  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.776628565193597
# The root mean squared error is:  9.12578772129075
# The correlation is:  0.10873588092084416
# ----------------------------------------
# alpha: 1.69  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.772323163864493
# The root mean squared error is:  9.099732441429135
# The correlation is:  0.10867850153532686
# ----------------------------------------
# alpha: 1.7  L1-ratio: 0.3
# Nonzero weights: 11 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.768001072349923
# The root mean squared error is:  9.073934637160281
# The correlation is:  0.10862134475574921
# ----------------------------------------
# alpha: 1.71  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.763623297032936
# The root mean squared error is:  9.048955264236122
# The correlation is:  0.10856145255785837
# ----------------------------------------
# alpha: 1.72  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.759191739514107
# The root mean squared error is:  9.024920212460769
# The correlation is:  0.10849780705942526
# ----------------------------------------
# alpha: 1.73  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.754761096808519
# The root mean squared error is:  9.001171797334742
# The correlation is:  0.10843263630274047
# ----------------------------------------
# alpha: 1.74  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.750318627955718
# The root mean squared error is:  8.97769560064825
# The correlation is:  0.10836794614482098
# ----------------------------------------
# alpha: 1.75  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.7458646351092995
# The root mean squared error is:  8.954493551522852
# The correlation is:  0.10830372022127965
# ----------------------------------------
# alpha: 1.76  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.741399413518982
# The root mean squared error is:  8.93156754616845
# The correlation is:  0.10823994206817453
# ----------------------------------------
# alpha: 1.77  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.736955396460944
# The root mean squared error is:  8.908919447751025
# The correlation is:  0.10817659510343235
# ----------------------------------------
# alpha: 1.78  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.73255892470379
# The root mean squared error is:  8.886519842003517
# The correlation is:  0.10811642778702632
# ----------------------------------------
# alpha: 1.79  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.728173978160968
# The root mean squared error is:  8.864440536483816
# The correlation is:  0.10805353263073249
# ----------------------------------------
# alpha: 1.8  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.723778531286904
# The root mean squared error is:  8.842643965539695
# The correlation is:  0.10799100987199516
# ----------------------------------------
# alpha: 1.81  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.7193721199030705
# The root mean squared error is:  8.821129616720887
# The correlation is:  0.10792889646825743
# ----------------------------------------
# alpha: 1.82  L1-ratio: 0.3
# Nonzero weights: 10 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.71493160498237
# The root mean squared error is:  8.799852437180745
# The correlation is:  0.10787028987887444
# ----------------------------------------
# alpha: 1.83  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.711190890330742
# The root mean squared error is:  8.780448703828387
# The correlation is:  0.10778080076207541
# ----------------------------------------
# alpha: 1.84  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.707423558396158
# The root mean squared error is:  8.761275865579146
# The correlation is:  0.10769505235144267
# ----------------------------------------
# alpha: 1.85  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.703673845852806
# The root mean squared error is:  8.742415188492606
# The correlation is:  0.10760530427810232
# ----------------------------------------
# alpha: 1.86  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.699915882092915
# The root mean squared error is:  8.72381620571219
# The correlation is:  0.107515198375913
# ----------------------------------------
# alpha: 1.87  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.69614921624391
# The root mean squared error is:  8.705478722542106
# The correlation is:  0.10742479075957802
# ----------------------------------------
# alpha: 1.8800000000000001  L1-ratio: 0.3
# Nonzero weights: 9 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.69235561800839
# The root mean squared error is:  8.687365860797323
# The correlation is:  0.1073365645861375
# ----------------------------------------
# alpha: 1.8900000000000001  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.689669630916225
# The root mean squared error is:  8.671721018964504
# The correlation is:  0.10713562117112421
# ----------------------------------------
# alpha: 1.9000000000000001  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.687003803736691
# The root mean squared error is:  8.656355583673744
# The correlation is:  0.10693025217263614
# ----------------------------------------
# alpha: 1.9100000000000001  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.68434735922433
# The root mean squared error is:  8.641254363749567
# The correlation is:  0.10671941871811717
# ----------------------------------------
# alpha: 1.9200000000000002  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.68169145449693
# The root mean squared error is:  8.626394283983588
# The correlation is:  0.1065044189673711
# ----------------------------------------
# alpha: 1.93  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.679036135574057
# The root mean squared error is:  8.61177518926514
# The correlation is:  0.10628508238259964
# ----------------------------------------
# alpha: 1.94  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.676381449218707
# The root mean squared error is:  8.5973969510922
# The correlation is:  0.10606124078424635
# ----------------------------------------
# alpha: 1.95  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.67372744127321
# The root mean squared error is:  8.58325942715768
# The correlation is:  0.10583271788009783
# ----------------------------------------
# alpha: 1.96  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.671074018919027
# The root mean squared error is:  8.569362108851335
# The correlation is:  0.10559934638375625
# ----------------------------------------
# alpha: 1.97  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.6684212247801815
# The root mean squared error is:  8.555704827318149
# The correlation is:  0.10536093051595193
# ----------------------------------------
# alpha: 1.98  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.665769261080072
# The root mean squared error is:  8.542287818186935
# The correlation is:  0.10511725020078293
# ----------------------------------------
# alpha: 1.99  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.663175933506547
# The root mean squared error is:  8.529090988190275
# The correlation is:  0.10486929251791804
# ----------------------------------------
# alpha: 2.0  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.660628368342289
# The root mean squared error is:  8.516156432576853
# The correlation is:  0.10461434618084559
# ----------------------------------------
# alpha: 2.01  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.658081429486818
# The root mean squared error is:  8.503461203598995
# The correlation is:  0.10435346057787181
# ----------------------------------------
# alpha: 2.02  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.655535192898184
# The root mean squared error is:  8.491005158970934
# The correlation is:  0.10408638547792202
# ----------------------------------------
# alpha: 2.03  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.65298970787719
# The root mean squared error is:  8.478788069021562
# The correlation is:  0.10381285745347157
# ----------------------------------------
# alpha: 2.04  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.650434400800773
# The root mean squared error is:  8.46678393643829
# The correlation is:  0.103533586545183
# ----------------------------------------
# alpha: 2.05  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.647891106279202
# The root mean squared error is:  8.455045693228113
# The correlation is:  0.10324629337251527
# ----------------------------------------
# alpha: 2.0599999999999996  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.645348667502827
# The root mean squared error is:  8.443545482241953
# The correlation is:  0.10295166619983777
# ----------------------------------------
# alpha: 2.07  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.642807095865877
# The root mean squared error is:  8.432282940152819
# The correlation is:  0.1026493858696241
# ----------------------------------------
# alpha: 2.0799999999999996  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.640266460178999
# The root mean squared error is:  8.421257812066665
# The correlation is:  0.10233910017423518
# ----------------------------------------
# alpha: 2.09  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.637726791834764
# The root mean squared error is:  8.410469745903182
# The correlation is:  0.10202044294743709
# ----------------------------------------
# alpha: 2.0999999999999996  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.635188115195271
# The root mean squared error is:  8.399918363121838
# The correlation is:  0.10169302842539012
# ----------------------------------------
# alpha: 2.11  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.632642562620675
# The root mean squared error is:  8.389585109570698
# The correlation is:  0.10135644401691819
# ----------------------------------------
# alpha: 2.1199999999999997  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.630106525140689
# The root mean squared error is:  8.379507561285633
# The correlation is:  0.10101027685356471
# ----------------------------------------
# alpha: 2.13  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.627571659290033
# The root mean squared error is:  8.369665663546115
# The correlation is:  0.10065403627902672
# ----------------------------------------
# alpha: 2.1399999999999997  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.625037926751987
# The root mean squared error is:  8.360058838450328
# The correlation is:  0.10028722838021886
# ----------------------------------------
# alpha: 2.15  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.622505356895283
# The root mean squared error is:  8.35068665183838
# The correlation is:  0.09990932890306024
# ----------------------------------------
# alpha: 2.1599999999999997  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.619973978675693
# The root mean squared error is:  8.341548655039023
# The correlation is:  0.09951977918432273
# ----------------------------------------
# alpha: 2.17  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.617443541735553
# The root mean squared error is:  8.332643090794756
# The correlation is:  0.09911668025230859
# ----------------------------------------
# alpha: 2.1799999999999997  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.614914429246609
# The root mean squared error is:  8.323971871026698
# The correlation is:  0.09870221794889471
# ----------------------------------------
# alpha: 2.19  L1-ratio: 0.3
# Nonzero weights: 8 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.612386568761153
# The root mean squared error is:  8.315533363553904
# The correlation is:  0.09827424233249174
# ----------------------------------------
# alpha: 2.1999999999999997  L1-ratio: 0.3
# Nonzero weights: 7 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.609697423135435
# The root mean squared error is:  8.307115012795114
# The correlation is:  0.09786279784824634
# ----------------------------------------
# alpha: 2.21  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.60651190811178
# The root mean squared error is:  8.297997592690315
# The correlation is:  0.09764314664621297
# ----------------------------------------
# alpha: 2.2199999999999998  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.603251382729281
# The root mean squared error is:  8.288947216373327
# The correlation is:  0.09746668589477682
# ----------------------------------------
# alpha: 2.23  L1-ratio: 0.3
# Nonzero weights: 6 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.600025873808633
# The root mean squared error is:  8.280155764934195
# The correlation is:  0.09728406962987977
# ----------------------------------------
# alpha: 2.2399999999999998  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.596808969864215
# The root mean squared error is:  8.271621794018271
# The correlation is:  0.09709522614785046
# ----------------------------------------
# alpha: 2.25  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.5916128393986275
# The root mean squared error is:  8.26132184526623
# The correlation is:  0.09726499198139521
# ----------------------------------------
# alpha: 2.26  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.5866351410025725
# The root mean squared error is:  8.251325226945804
# The correlation is:  0.0974426376381228
# ----------------------------------------
# alpha: 2.27  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.5817311493511435
# The root mean squared error is:  8.241631808727421
# The correlation is:  0.09762875849522568
# ----------------------------------------
# alpha: 2.28  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.57683901932232
# The root mean squared error is:  8.232240397539169
# The correlation is:  0.0978239364684254
# ----------------------------------------
# alpha: 2.29  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.571958701575948
# The root mean squared error is:  8.22314978049691
# The correlation is:  0.09802880857947699
# ----------------------------------------
# alpha: 2.3  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.567091754740112
# The root mean squared error is:  8.214362077013055
# The correlation is:  0.0982447089588343
# ----------------------------------------
# alpha: 2.31  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.562234840722876
# The root mean squared error is:  8.205868999871326
# The correlation is:  0.09847110449791785
# ----------------------------------------
# alpha: 2.32  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.5573896003106205
# The root mean squared error is:  8.197672991348407
# The correlation is:  0.09870950884462275
# ----------------------------------------
# alpha: 2.3299999999999996  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.552555985126252
# The root mean squared error is:  8.18977275811252
# The correlation is:  0.0989608568875444
# ----------------------------------------
# alpha: 2.34  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.547733947152832
# The root mean squared error is:  8.182166987815286
# The correlation is:  0.09922618380825096
# ----------------------------------------
# alpha: 2.3499999999999996  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.542923393559648
# The root mean squared error is:  8.174854260550191
# The correlation is:  0.09950660786198079
# ----------------------------------------
# alpha: 2.36  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.538124305383277
# The root mean squared error is:  8.16783329402322
# The correlation is:  0.09980342442315103
# ----------------------------------------
# alpha: 2.3699999999999997  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.53333665906622
# The root mean squared error is:  8.161102767015214
# The correlation is:  0.10011807767492842
# ----------------------------------------
# alpha: 2.38  L1-ratio: 0.3
# Nonzero weights: 5 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.528563196523521
# The root mean squared error is:  8.154664150334272
# The correlation is:  0.10045259893763964
# ----------------------------------------
# alpha: 2.3899999999999997  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.524057350807146
# The root mean squared error is:  8.148829508280427
# The correlation is:  0.10069192775533078
# ----------------------------------------
# alpha: 2.4  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.51978293932188
# The root mean squared error is:  8.143533918805872
# The correlation is:  0.10084785052183866
# ----------------------------------------
# alpha: 2.4099999999999997  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.5155203398621095
# The root mean squared error is:  8.138500778524302
# The correlation is:  0.1010137744163923
# ----------------------------------------
# alpha: 2.42  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.511269498379542
# The root mean squared error is:  8.133728444595574
# The correlation is:  0.101190668654499
# ----------------------------------------
# alpha: 2.4299999999999997  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.507030361226956
# The root mean squared error is:  8.129215263618514
# The correlation is:  0.10137963224201915
# ----------------------------------------
# alpha: 2.44  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.502802875153346
# The root mean squared error is:  8.124959571926789
# The correlation is:  0.10158191644225209
# ----------------------------------------
# alpha: 2.4499999999999997  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.498586987299147
# The root mean squared error is:  8.120959695890292
# The correlation is:  0.10179895207675195
# ----------------------------------------
# alpha: 2.46  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.494382645191545
# The root mean squared error is:  8.117213952221702
# The correlation is:  0.10203238291807255
# ----------------------------------------
# alpha: 2.4699999999999998  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.490189778904222
# The root mean squared error is:  8.113720636723512
# The correlation is:  0.1022841039671036
# ----------------------------------------
# alpha: 2.48  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.486010253566951
# The root mean squared error is:  8.110479265633852
# The correlation is:  0.10255629285220988
# ----------------------------------------
# alpha: 2.4899999999999998  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.481839903110415
# The root mean squared error is:  8.107485466146235
# The correlation is:  0.1028515618190439
# ----------------------------------------
# alpha: 2.5  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.477680905025751
# The root mean squared error is:  8.104739013076255
# The correlation is:  0.10317292011795348
# ----------------------------------------
# alpha: 2.51  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.473533208385079
# The root mean squared error is:  8.102238177867768
# The correlation is:  0.10352394173998436
# ----------------------------------------
# alpha: 2.52  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.469396762624934
# The root mean squared error is:  8.099981224275627
# The correlation is:  0.10390888519204737
# ----------------------------------------
# alpha: 2.53  L1-ratio: 0.3
# Nonzero weights: 4 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.4652709346957185
# The root mean squared error is:  8.097966136650724
# The correlation is:  0.10433289998173126
# ----------------------------------------
# alpha: 2.54  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.461353640721364
# The root mean squared error is:  8.09649540805289
# The correlation is:  0.10440634775051864
# ----------------------------------------
# alpha: 2.55  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.4574646220357685
# The root mean squared error is:  8.095280796079857
# The correlation is:  0.10445445503315429
# ----------------------------------------
# alpha: 2.56  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.453587637750577
# The root mean squared error is:  8.094295731096377
# The correlation is:  0.10450763455473659
# ----------------------------------------
# alpha: 2.57  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.449722631317971
# The root mean squared error is:  8.093538194563488
# The correlation is:  0.10456671966224881
# ----------------------------------------
# alpha: 2.5799999999999996  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.445869546551519
# The root mean squared error is:  8.093006167318924
# The correlation is:  0.10463273309179405
# ----------------------------------------
# alpha: 2.59  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.442028327623267
# The root mean squared error is:  8.092697629940645
# The correlation is:  0.10470694230611743
# ----------------------------------------
# alpha: 2.5999999999999996  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.4381989190608655
# The root mean squared error is:  8.092610563107916
# The correlation is:  0.10479093441010326
# ----------------------------------------
# alpha: 2.61  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 2.6199999999999997  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 2.63  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 2.6399999999999997  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 2.65  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# alpha: 2.6599999999999997  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 2.67  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 2.6799999999999997  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 2.69  L1-ratio: 0.3
# Nonzero weights: 2 from 157
# alpha: 2.6999999999999997  L1-ratio: 0.3
# Nonzero weights: 1 from 157
# alpha: 2.71  L1-ratio: 0.3
# Nonzero weights: 1 from 157
# alpha: 2.7199999999999998  L1-ratio: 0.3
# Nonzero weights: 1 from 157
# alpha: 2.73  L1-ratio: 0.3
# Nonzero weights: 1 from 157
# alpha: 2.7399999999999998  L1-ratio: 0.3
# Nonzero weights: 1 from 157
# alpha: 2.75  L1-ratio: 0.3
# Nonzero weights: 1 from 157
# alpha: 2.76  L1-ratio: 0.3
# Nonzero weights: 1 from 157
# alpha: 2.77  L1-ratio: 0.3
# Nonzero weights: 1 from 157
# alpha: 2.78  L1-ratio: 0.3
# Nonzero weights: 1 from 157
# alpha: 2.79  L1-ratio: 0.3
# Nonzero weights: 1 from 157
# alpha: 2.8  L1-ratio: 0.3
# Nonzero weights: 1 from 157
# alpha: 2.81  L1-ratio: 0.3
# Nonzero weights: 1 from 157
# alpha: 2.82  L1-ratio: 0.3
# Nonzero weights: 1 from 157
# alpha: 2.8299999999999996  L1-ratio: 0.3
# Nonzero weights: 0 from 157
# alpha: 2.84  L1-ratio: 0.3
# Nonzero weights: 0 from 157
# alpha: 2.8499999999999996  L1-ratio: 0.3
# Nonzero weights: 0 from 157
# alpha: 2.86  L1-ratio: 0.3
# Nonzero weights: 0 from 157
# alpha: 2.8699999999999997  L1-ratio: 0.3
# Nonzero weights: 0 from 157
# alpha: 2.88  L1-ratio: 0.3
# Nonzero weights: 0 from 157
# alpha: 2.8899999999999997  L1-ratio: 0.3
# Nonzero weights: 0 from 157
# alpha: 2.9  L1-ratio: 0.3
# Nonzero weights: 0 from 157
# alpha: 2.9099999999999997  L1-ratio: 0.3
# Nonzero weights: 0 from 157
# alpha: 2.92  L1-ratio: 0.3
# Nonzero weights: 0 from 157
# alpha: 2.9299999999999997  L1-ratio: 0.3
# Nonzero weights: 0 from 157
# alpha: 2.94  L1-ratio: 0.3
# Nonzero weights: 0 from 157
# alpha: 2.9499999999999997  L1-ratio: 0.3
# Nonzero weights: 0 from 157
# alpha: 2.96  L1-ratio: 0.3
# Nonzero weights: 0 from 157
# alpha: 2.9699999999999998  L1-ratio: 0.3
# Nonzero weights: 0 from 157
# alpha: 2.98  L1-ratio: 0.3
# Nonzero weights: 0 from 157
# alpha: 2.9899999999999998  L1-ratio: 0.3
# Nonzero weights: 0 from 157

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.3, 154 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train2_X2,train2_y,test2_X2,test2_y))

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.4, 105 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train2_X3,train2_y,test2_X3,test2_y))

# %%
## tuned alpha based on validation set, then measure the performance for test set.
## Fixing l1-ratio = 0.3
para = [2.60]
para_l=[0.3]
rmse=100000
mae=1000000
corr=0
print('For correlation filter r>=0.2, 212 features are selected')
for a in para:
    for l in para_l:
        print('alpha:',a,' L1-ratio:',l)
        rmse0,mae0,corr0 = eNet(a,l,train2_X1,train2_y,test2_X1,test2_y)
        if rmse0< rmse:
            rmse=rmse0
            mae=mae0
            corr = corr0
            print('========================================')
            print('Best RMSE is updated! ' )
            print('The mean absolute error is: ',mae)
            print('The root mean squared error is: ',rmse)
            print('The correlation is: ',corr)
            print('----------------------------------------')
# Out:
# For correlation filter r>=0.2, 212 features are selected
# alpha: 2.6  L1-ratio: 0.3
# Nonzero weights: 3 from 157
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  5.806283856375737
# The root mean squared error is:  6.670485083096372
# The correlation is:  0.7505757759942205
# ----------------------------------------
