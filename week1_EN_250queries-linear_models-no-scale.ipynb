# %% [markdown]
# ## tasks
# ### 1: Form training and testing periods as discussed (2 test periods, last 2*365 days). Be careful tp scale data only based on data from the training set. You may use (from Python) MinMaxScaler, standardisation (StandardScaler) or the default scaler in Python's elastic net.
# ### 2:Estimate the current flu rates by training an elastic net model. Use a Pearson correlation filter (r > 0.3) on the training data to reduce the amount of queries prior to training an elastic net (reminder: not all 1000 queries I provided are related to flu!). Report performance on the two test sets using three metrics: mean absolute error, root mean squared error and Pearson's correlation.
# ### 3: If there is time, begin work on traditional forecasting models (you've identified seasonal ARIMA and Hult-Winters).

# %%
# import libraries
import numpy as np
import pandas as pd
import random
import csv
import scipy.stats as stats
import seaborn as sns
from collections import Counter
from collections import defaultdict
import math
from sklearn.linear_model import ElasticNet
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from random import randint
from sklearn.linear_model import Ridge
from sklearn import linear_model

import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm
from statsmodels.nonparametric.kde import KDEUnivariate
from statsmodels.nonparametric import smoothers_lowess
from pandas import Series, DataFrame
from patsy import dmatrices
from sklearn import datasets, svm

# initialize the plotting sizes
# set size
plt.rc('figure', figsize=(10, 5))
# subplots size
fizsize_with_subplots = (10, 10)
# histogram size
bin_size = 10

# %%
# Loading data
dates = pd.read_csv('data/dates.csv',header=None)
queries = pd.read_csv('data/queries.csv',header=None)
X = pd.read_csv('data/X.csv',header=None)
y = pd.read_csv('data/y.csv',header=None)

X.columns = queries

# %%
# data preprocessing and train-test split
# this data is well formed with no missing value and other symbols or labels that are non numerical.
# splitting the data into train and test

# Here we want the first 500 queries
X = X.iloc[:, 0: 250]

# first with the last year as test
# for convinience, pick the two validation set starting from 1/3 and 2/3 of the training set,
# 10% of training set as validation, here use 400 data points, two 200 periods.
test_size =365
length = X.shape[0]
l =(X.shape[0]-test_size)//3

train1_X = pd.concat([X[0:l],X[l+200:2*l],X[2*l+200:length-test_size]])
val1_X = pd.concat([X[l:l+200],X[2*l:2*l+200]])
train1_y = pd.concat([y[0:l],y[l+200:2*l],y[2*l+200:length-test_size]])
val1_y = pd.concat([y[l:l+200],y[2*l:2*l+200]])
test1_X = X[length-test_size:]
test1_y = y[length-test_size:]

# second with the last 2 year as test
test_size2 =365*2
l2 =(X.shape[0]-test_size2)//3

train2_X = pd.concat([X[0:l2],X[l2+180:2*l2],X[2*l2+180:length-test_size2]])
val2_X = pd.concat([X[l2:l2+180],X[2*l2:2*l2+180]])
train2_y = pd.concat([y[0:l2],y[l2+180:2*l2],y[2*l2+180:length-test_size2]])
val2_y = pd.concat([y[l2:l2+180],y[2*l2:2*l2+180]])
test2_X = X[length-test_size2:length-test_size]
test2_y = y[length-test_size2:length-test_size]

print('X shape: ',X.shape,'  y shape: ',y.shape)
print('train1 X:',train1_X.shape,' train1 y:',train1_y.shape,' Test1 X shape:',test1_X.shape, ' Test1 y shape:',test1_y.shape)
print('validation1 X:',val1_X.shape,' validation1 y:',val1_y.shape)
print('train2 X:',train2_X.shape,' train2 y:',train2_y.shape,' Test2 X:',test2_X.shape,' Test2 y:',test2_y.shape)
print('validation2 X:',val2_X.shape,' validation2 y:',val2_y.shape)
# Out:
# X shape:  (4383, 250)   y shape:  (4383, 1)
# train1 X: (3618, 250)  train1 y: (3618, 1)  Test1 X shape: (365, 250)  Test1 y shape: (365, 1)
# validation1 X: (400, 250)  validation1 y: (400, 1)
# train2 X: (3293, 250)  train2 y: (3293, 1)  Test2 X: (730, 250)  Test2 y: (730, 1)
# validation2 X: (360, 250)  validation2 y: (360, 1)

# %%
train_size = train1_X.shape[0]
corrs = np.zeros((X.shape[1],1))
for i in range(0,X.shape[1]):
    if X.sum(axis=1)[i] == 0:
        corrs[i] = 0
    else:
        corrs[i] = np.corrcoef(X.iloc[0:train_size,i],y.iloc[0:train_size,0])[0,1]
        
corrs.shape,X.columns.shape,X.columns[0],X.columns[249]
# Out:
# ((250, 1), (250,), ('flu',), ('flu incubation',))

# %%
def corr_filter(df_X,df_Xval,df_Xtest,corrs,threshold):
    X = df_X.copy()
    X_test = df_Xtest.copy()
    X_val = df_Xval.copy()
    col_corr = set() # Set of all the names of deleted columns
    for i in range(0,250):
            if corrs[i,0] < threshold: 
                #print(X.columns[i])
                colname = df_X.columns[i]
                del X[colname] # deleting the column from the dataset
                del X_test[colname] 
                del X_val[colname]

    return X,X_val,X_test

# %% [markdown]
# ## Fixing pearson correlation filter r>=0.2

# %%
#train1_X0,test1_X0 = corr_filter(train1_X,test1_X,corrs,0.1)
train1_X1,val1_X1,test1_X1 = corr_filter(train1_X,val1_X,test1_X,corrs,0.2)
#train1_X2,test1_X2 = corr_filter(train1_X,test1_X,corrs,0.3)
#train1_X3,test1_X3 = corr_filter(train1_X,test1_X,corrs,0.4)

# %%
#print('For correlation filter r>=0.1, we select feature number: ',train1_X0.shape[1])
print('For correlation filter r>=0.2, we select feature number: ',train1_X1.shape[1])
#print('For correlation filter r>=0.3, we select feature number: ',train1_X2.shape[1])
#print('For correlation filter r>=0.4, we select feature number: ',train1_X3.shape[1])
# Out:
# For correlation filter r>=0.2, we select feature number:  157

# %%
# Defien the mearure matrics, MAE, RMSE, CORR
# define three metrics: mean absolute error, root mean squared error and Pearson's correlation.
from sklearn.metrics import mean_absolute_error
# mae = mean_absolute_error(y_actual, y_pred)

from sklearn.metrics import mean_squared_error
from math import sqrt
# rmse = sqrt(mean_squared_error(y_actual, y_pred))

# np.correcoef returns Pearson product-moment correlation coefficients
def pearson_r(x,y):   
    corr_mat = np.corrcoef(x,y)
    return corr_mat[0,1]
# r = pearson_r(y_actual,y_pred)


# Generalise the function for convinient tuning
def ridge(a,train_X,train_y,test_X,test_y):
    alpha=a
    ri = Ridge(alpha, copy_X=True, fit_intercept=True, max_iter=None,
      normalize=False, random_state=None, solver='auto', tol=0.001)
  
    ri.fit(train_X,train_y)

    y_pred1 = ri.predict(test_X)

    mae1 = mean_absolute_error(test_y, y_pred1)
    #print('The mean absolute error is: ',mae1)

    rmse1 = sqrt(mean_squared_error(test_y, y_pred1))
    #print('The root mean squared error is: ',rmse1)
    
    corr_y = test_y.copy()
    corr_y['y_act'] = test_y
    corr_y['y_pred']= y_pred1
    corr = np.corrcoef(corr_y['y_act'],corr_y['y_pred'])[0,1]
    #print('The correlation is: ',corr)
    
    return rmse1, mae1,corr

# %% [markdown]
# # scaling and modeling
# scaler = MinMaxScaler()
# train1_X0_scaled = scaler.fit_transform(train1_X0)
# test1_X0_scaled = scaler.transform(test1_x0)
#
# train1_X1_scaled = scaler.fit_transform(train1_X1)
# test1_X1_scaled = scaler.transform(test1_x1)
#
# train1_X2_scaled = scaler.fit_transform(train1_X2)
# test1_X2_scaled = scaler.transform(test1_x2)
#
# train1_X3_scaled = scaler.fit_transform(train1_X3)
# test1_X3_scaled = scaler.transform(test1_x3)

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.1, 310 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train1_X0,train1_y,test1_X0,test1_y))

# %%
para = np.arange(0.01, 100000000, 100000)
rmse=100000
mae=1000000
corr=0
for a in para:
    print('alpha:',a)
    rmse0,mae0,corr0 = ridge(a,train1_X1,train1_y,val1_X1,val1_y)
    if rmse0< rmse:
        rmse=rmse0
        mae=mae0
        corr = corr0
        print('========================================')
        print('Best RMSE is updated! ' )
        print('The mean absolute error is: ',mae)
        print('The root mean squared error is: ',rmse)
        print('The correlation is: ',corr)
        print('----------------------------------------')
# Out:
# alpha: 0.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.738477450973598
# The root mean squared error is:  45.958052947675554
# The correlation is:  0.7576646305034048
# ----------------------------------------
# alpha: 100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.835767393873052
# The root mean squared error is:  45.7247377041174
# The correlation is:  0.7828578465778442
# ----------------------------------------
# alpha: 200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.740940801233837
# The root mean squared error is:  45.112747716741495
# The correlation is:  0.7995459431814701
# ----------------------------------------
# alpha: 300000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.660687654051323
# The root mean squared error is:  44.62687212114223
# The correlation is:  0.8116760346728115
# ----------------------------------------
# alpha: 400000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.596325688054016
# The root mean squared error is:  44.2453271321119
# The correlation is:  0.82097602231974
# ----------------------------------------
# alpha: 500000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.543744488651566
# The root mean squared error is:  43.936741582265036
# The correlation is:  0.8283770276627062
# ----------------------------------------
# alpha: 600000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.498949143988966
# The root mean squared error is:  43.679258778161305
# The correlation is:  0.8344333993276838
# ----------------------------------------
# alpha: 700000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.45961135141653
# The root mean squared error is:  43.45845541592506
# The correlation is:  0.8394983681782404
# ----------------------------------------
# alpha: 800000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.423805278318433
# The root mean squared error is:  43.26470785988015
# The correlation is:  0.8438087588367952
# ----------------------------------------
# alpha: 900000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.39047967116033
# The root mean squared error is:  43.09144210070412
# The correlation is:  0.8475298429432245
# ----------------------------------------
# alpha: 1000000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.35913726952364
# The root mean squared error is:  42.93405387767027
# The correlation is:  0.8507807779807322
# ----------------------------------------
# alpha: 1100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.3292688754627
# The root mean squared error is:  42.789241796082855
# The correlation is:  0.8536498336324462
# ----------------------------------------
# alpha: 1200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.300702227706875
# The root mean squared error is:  42.65458753885903
# The correlation is:  0.8562039142451621
# ----------------------------------------
# alpha: 1300000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.272901376492342
# The root mean squared error is:  42.52828529262377
# The correlation is:  0.8584947364829519
# ----------------------------------------
# alpha: 1400000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.245715000677436
# The root mean squared error is:  42.40896313580708
# The correlation is:  0.8605629640604928
# ----------------------------------------
# alpha: 1500000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.21903633637227
# The root mean squared error is:  42.295562434616244
# The correlation is:  0.8624410506722481
# ----------------------------------------
# alpha: 1600000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.192789842754774
# The root mean squared error is:  42.18725468629127
# The correlation is:  0.8641552411974635
# ----------------------------------------
# alpha: 1700000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.166924068234444
# The root mean squared error is:  42.08338307475157
# The correlation is:  0.8657270098646707
# ----------------------------------------
# alpha: 1800000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.141470180714805
# The root mean squared error is:  41.98342067276469
# The correlation is:  0.8671741129608244
# ----------------------------------------
# alpha: 1900000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.116329626366877
# The root mean squared error is:  41.88694007188493
# The correlation is:  0.8685113721598644
# ----------------------------------------
# alpha: 2000000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.09148419505953
# The root mean squared error is:  41.79359099542978
# The correlation is:  0.8697512660792764
# ----------------------------------------
# alpha: 2100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.066921570327022
# The root mean squared error is:  41.70308357809141
# The correlation is:  0.8709043830208371
# ----------------------------------------
# alpha: 2200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.042633674763252
# The root mean squared error is:  41.61517572746641
# The correlation is:  0.871979771700201
# ----------------------------------------
# alpha: 2300000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.01861546228901
# The root mean squared error is:  41.52966346586246
# The correlation is:  0.8729852159751175
# ----------------------------------------
# alpha: 2400000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.994864031847055
# The root mean squared error is:  41.44637347528573
# The correlation is:  0.8739274522346828
# ----------------------------------------
# alpha: 2500000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.971377974485886
# The root mean squared error is:  41.365157289776114
# The correlation is:  0.8748123430283903
# ----------------------------------------
# alpha: 2600000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.94815689137562
# The root mean squared error is:  41.28588673259335
# The correlation is:  0.8756450169417587
# ----------------------------------------
# alpha: 2700000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.925256258291608
# The root mean squared error is:  41.2084503032143
# The correlation is:  0.8764299821809828
# ----------------------------------------
# alpha: 2800000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.90262957506697
# The root mean squared error is:  41.13275029564614
# The correlation is:  0.8771712194921957
# ----------------------------------------
# alpha: 2900000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.880299636194476
# The root mean squared error is:  41.05870048447981
# The correlation is:  0.8778722586998732
# ----------------------------------------
# alpha: 3000000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.858349795451982
# The root mean squared error is:  40.98622425511275
# The correlation is:  0.8785362421582201
# ----------------------------------------
# alpha: 3100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.836665218475808
# The root mean squared error is:  40.91525308402417
# The correlation is:  0.8791659776699075
# ----------------------------------------
# alpha: 3200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.815246722868224
# The root mean squared error is:  40.84572529669929
# The correlation is:  0.8797639828698594
# ----------------------------------------
# alpha: 3300000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.794094967467927
# The root mean squared error is:  40.777585047219254
# The correlation is:  0.8803325226480336
# ----------------------------------------
# alpha: 3400000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.773248673917468
# The root mean squared error is:  40.71078147584099
# The correlation is:  0.8808736408604451
# ----------------------------------------
# alpha: 3500000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.752687203948106
# The root mean squared error is:  40.645268010226296
# The correlation is:  0.8813891873269455
# ----------------------------------------
# alpha: 3600000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.73239160870872
# The root mean squared error is:  40.58100178329514
# The correlation is:  0.8818808409183985
# ----------------------------------------
# alpha: 3700000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.712361745085058
# The root mean squared error is:  40.51794314613864
# The correlation is:  0.8823501293829935
# ----------------------------------------
# alpha: 3800000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.692597244804787
# The root mean squared error is:  40.45605525880568
# The correlation is:  0.882798446440248
# ----------------------------------------
# alpha: 3900000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.673097520191273
# The root mean squared error is:  40.39530374514677
# The correlation is:  0.8832270665751455
# ----------------------------------------
# alpha: 4000000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.653861772608142
# The root mean squared error is:  40.33565640057121
# The correlation is:  0.8836371578880237
# ----------------------------------------
# alpha: 4100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.634889002751237
# The root mean squared error is:  40.27708294368795
# The correlation is:  0.884029793294025
# ----------------------------------------
# alpha: 4200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.616178022129343
# The root mean squared error is:  40.21955480444265
# The correlation is:  0.8844059603161389
# ----------------------------------------
# alpha: 4300000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.597764602881117
# The root mean squared error is:  40.163044942755576
# The correlation is:  0.8847665696751589
# ----------------------------------------
# alpha: 4400000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.579649949243393
# The root mean squared error is:  40.10752769271444
# The correlation is:  0.8851124628468852
# ----------------------------------------
# alpha: 4500000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.561791683253094
# The root mean squared error is:  40.05297862823588
# The correlation is:  0.8854444187297867
# ----------------------------------------
# alpha: 4600000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.544188018855298
# The root mean squared error is:  39.99937444685101
# The correlation is:  0.8857631595438921
# ----------------------------------------
# alpha: 4700000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.526837039994813
# The root mean squared error is:  39.946692868807354
# The correlation is:  0.8860693560632824
# ----------------------------------------
# alpha: 4800000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.50973671255723
# The root mean squared error is:  39.89491254915726
# The correlation is:  0.8863636322692029
# ----------------------------------------
# alpha: 4900000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.492884895798834
# The root mean squared error is:  39.84401300090955
# The correlation is:  0.8866465694978882
# ----------------------------------------
# alpha: 5000000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.476279353216782
# The root mean squared error is:  39.7939745276102
# The correlation is:  0.8869187101466413
# ----------------------------------------
# alpha: 5100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.459917762829946
# The root mean squared error is:  39.744778163977784
# The correlation is:  0.8871805609926305
# ----------------------------------------
# alpha: 5200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.4437977268663
# The root mean squared error is:  39.69640562345873
# The correlation is:  0.8874325961712579
# ----------------------------------------
# alpha: 5300000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.427916780858254
# The root mean squared error is:  39.648839251734316
# The correlation is:  0.8876752598545812
# ----------------------------------------
# alpha: 5400000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.41227240214648
# The root mean squared error is:  39.60206198533996
# The correlation is:  0.8879089686648672
# ----------------------------------------
# alpha: 5500000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.39686201781946
# The root mean squared error is:  39.5560573147283
# The correlation is:  0.8881341138535999
# ----------------------------------------
# alpha: 5600000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.381683012093834
# The root mean squared error is:  39.51080925115214
# The correlation is:  0.888351063272529
# ----------------------------------------
# alpha: 5700000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.366732733174032
# The root mean squared error is:  39.46630229689936
# The correlation is:  0.8885601631596804
# ----------------------------------------
# alpha: 5800000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.352008499601087
# The root mean squared error is:  39.42252141841712
# The correlation is:  0.8887617397606536
# ----------------------------------------
# alpha: 5900000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.33750760612384
# The root mean squared error is:  39.37945202197445
# The correlation is:  0.8889561008028175
# ----------------------------------------
# alpha: 6000000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.323227329116953
# The root mean squared error is:  39.33707993154423
# The correlation is:  0.8891435368379454
# ----------------------------------------
# alpha: 6100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.309164931571157
# The root mean squared error is:  39.295391368631826
# The correlation is:  0.8893243224669798
# ----------------------------------------
# alpha: 6200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.295317667679797
# The root mean squared error is:  39.254372933814004
# The correlation is:  0.8894987174589923
# ----------------------------------------
# alpha: 6300000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.281682787049963
# The root mean squared error is:  39.214011589792854
# The correlation is:  0.88966696777497
# ----------------------------------------
# alpha: 6400000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.268257538558927
# The root mean squared error is:  39.17429464578443
# The correlation is:  0.8898293065059109
# ----------------------------------------
# alpha: 6500000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.255039173879894
# The root mean squared error is:  39.13520974309177
# The correlation is:  0.8899859547335834
# ----------------------------------------
# alpha: 6600000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.242024950701758
# The root mean squared error is:  39.09674484173707
# The correlation is:  0.8901371223213804
# ----------------------------------------
# alpha: 6700000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.22921213565829
# The root mean squared error is:  39.05888820802739
# The correlation is:  0.8902830086419526
# ----------------------------------------
# alpha: 6800000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.21662647483755
# The root mean squared error is:  39.021628402971096
# The correlation is:  0.8904238032474668
# ----------------------------------------
# alpha: 6900000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.204249449545244
# The root mean squared error is:  38.98495427144176
# The correlation is:  0.8905596864878343
# ----------------------------------------
# alpha: 7000000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.1920652853687
# The root mean squared error is:  38.94885493202447
# The correlation is:  0.8906908300816127
# ----------------------------------------
# alpha: 7100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.180071317465057
# The root mean squared error is:  38.91331976746778
# The correlation is:  0.8908173976438405
# ----------------------------------------
# alpha: 7200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.16826490074036
# The root mean squared error is:  38.87833841570617
# The correlation is:  0.8909395451745661
# ----------------------------------------
# alpha: 7300000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.156643411440747
# The root mean squared error is:  38.84390076136512
# The correlation is:  0.8910574215115696
# ----------------------------------------
# alpha: 7400000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.145204248578793
# The root mean squared error is:  38.80999692773438
# The correlation is:  0.8911711687503174
# ----------------------------------------
# alpha: 7500000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.133944835204876
# The root mean squared error is:  38.7766172691622
# The correlation is:  0.8912809226339042
# ----------------------------------------
# alpha: 7600000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.122862619530803
# The root mean squared error is:  38.74375236382562
# The correlation is:  0.8913868129155494
# ----------------------------------------
# alpha: 7700000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.11195507591755
# The root mean squared error is:  38.71139300684637
# The correlation is:  0.8914889636959256
# ----------------------------------------
# alpha: 7800000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.10121970574625
# The root mean squared error is:  38.679530203743866
# The correlation is:  0.8915874937372875
# ----------------------------------------
# alpha: 7900000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.09065403817163
# The root mean squared error is:  38.648155164177346
# The correlation is:  0.8916825167563545
# ----------------------------------------
# alpha: 8000000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.080255630768523
# The root mean squared error is:  38.61725929595845
# The correlation is:  0.8917741416976425
# ----------------------------------------
# alpha: 8100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.070022070087617
# The root mean squared error is:  38.586834199331875
# The correlation is:  0.8918624729886971
# ----------------------------------------
# alpha: 8200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.059950972120596
# The root mean squared error is:  38.55687166148878
# The correlation is:  0.8919476107787159
# ----------------------------------------
# alpha: 8300000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.05003998268071
# The root mean squared error is:  38.52736365129507
# The correlation is:  0.8920296511618155
# ----------------------------------------
# alpha: 8400000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.040286777714286
# The root mean squared error is:  38.49830231423905
# The correlation is:  0.8921086863860703
# ----------------------------------------
# alpha: 8500000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.030689333626206
# The root mean squared error is:  38.46967996756498
# The correlation is:  0.8921848050494372
# ----------------------------------------
# alpha: 8600000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.021284572280006
# The root mean squared error is:  38.44148909559186
# The correlation is:  0.8922580922835006
# ----------------------------------------
# alpha: 8700000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.01203038948036
# The root mean squared error is:  38.41372234520282
# The correlation is:  0.8923286299259576
# ----------------------------------------
# alpha: 8800000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.00292459200685
# The root mean squared error is:  38.38637252150371
# The correlation is:  0.8923964966826002
# ----------------------------------------
# alpha: 8900000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.993965017143168
# The root mean squared error is:  38.359432583619274
# The correlation is:  0.8924617682796568
# ----------------------------------------
# alpha: 9000000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.985149532667904
# The root mean squared error is:  38.33289564065117
# The correlation is:  0.8925245176070316
# ----------------------------------------
# alpha: 9100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.97647603679866
# The root mean squared error is:  38.306754947759046
# The correlation is:  0.8925848148532057
# ----------------------------------------
# alpha: 9200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.96794245810526
# The root mean squared error is:  38.281003902383844
# The correlation is:  0.892642727632281
# ----------------------------------------
# alpha: 9300000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.95954675538667
# The root mean squared error is:  38.25563604058828
# The correlation is:  0.8926983211037611
# ----------------------------------------
# alpha: 9400000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.95129950768009
# The root mean squared error is:  38.23064503351445
# The correlation is:  0.8927516580855461
# ----------------------------------------
# alpha: 9500000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.943250042578185
# The root mean squared error is:  38.20602468395964
# The correlation is:  0.8928027991605801
# ----------------------------------------
# alpha: 9600000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.93538670685968
# The root mean squared error is:  38.18176892305548
# The correlation is:  0.8928518027775861
# ----------------------------------------
# alpha: 9700000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.92771401216517
# The root mean squared error is:  38.15787180705259
# The correlation is:  0.8928987253462711
# ----------------------------------------
# alpha: 9800000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.920168494899695
# The root mean squared error is:  38.13432751420296
# The correlation is:  0.8929436213273582
# ----------------------------------------
# alpha: 9900000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.912748302427033
# The root mean squared error is:  38.11113034173144
# The correlation is:  0.8929865433177926
# ----------------------------------------
# alpha: 10000000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.905451610587598
# The root mean squared error is:  38.08827470291312
# The correlation is:  0.893027542131375
# ----------------------------------------
# alpha: 10100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.898276623406527
# The root mean squared error is:  38.06575512421854
# The correlation is:  0.8930666668752024
# ----------------------------------------
# alpha: 10200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.891221572795413
# The root mean squared error is:  38.04356624255511
# The correlation is:  0.893103965022082
# ----------------------------------------
# alpha: 10300000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.88428471824253
# The root mean squared error is:  38.021702802587406
# The correlation is:  0.893139482479213
# ----------------------------------------
# alpha: 10400000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.87746434649234
# The root mean squared error is:  38.00015965413192
# The correlation is:  0.8931732636533716
# ----------------------------------------
# alpha: 10500000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.87075877121565
# The root mean squared error is:  37.97893174962382
# The correlation is:  0.8932053515127983
# ----------------------------------------
# alpha: 10600000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.86416633267878
# The root mean squared error is:  37.95801414166831
# The correlation is:  0.8932357876459448
# ----------------------------------------
# alpha: 10700000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.857685397398537
# The root mean squared error is:  37.937401980643195
# The correlation is:  0.8932646123173594
# ----------------------------------------
# alpha: 10800000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.85131435780042
# The root mean squared error is:  37.91709051238601
# The correlation is:  0.8932918645207697
# ----------------------------------------
# alpha: 10900000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.845051631866813
# The root mean squared error is:  37.89707507593219
# The correlation is:  0.8933175820296221
# ----------------------------------------
# alpha: 11000000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.838895662785426
# The root mean squared error is:  37.87735110132341
# The correlation is:  0.8933418014451506
# ----------------------------------------
# alpha: 11100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.83284491859469
# The root mean squared error is:  37.85791410747422
# The correlation is:  0.8933645582421618
# ----------------------------------------
# alpha: 11200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.82689789182773
# The root mean squared error is:  37.83875970009754
# The correlation is:  0.8933858868126366
# ----------------------------------------
# alpha: 11300000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.82105309915387
# The root mean squared error is:  37.81988356968346
# The correlation is:  0.8934058205073047
# ----------------------------------------
# alpha: 11400000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.81530908102272
# The root mean squared error is:  37.80128148953891
# The correlation is:  0.8934243916752544
# ----------------------------------------
# alpha: 11500000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.80966440130572
# The root mean squared error is:  37.78294931387453
# The correlation is:  0.8934416317017353
# ----------------------------------------
# alpha: 11600000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.80411764693983
# The root mean squared error is:  37.76488297594563
# The correlation is:  0.8934575710442199
# ----------------------------------------
# alpha: 11700000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.798667427570717
# The root mean squared error is:  37.74707848623972
# The correlation is:  0.893472239266847
# ----------------------------------------
# alpha: 11800000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.793312375200326
# The root mean squared error is:  37.729531930718025
# The correlation is:  0.8934856650732836
# ----------------------------------------
# alpha: 11900000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.788051143834306
# The root mean squared error is:  37.7122394690994
# The correlation is:  0.8934978763381426
# ----------------------------------------
# alpha: 12000000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.782882409129975
# The root mean squared error is:  37.69519733318567
# The correlation is:  0.893508900137028
# ----------------------------------------
# alpha: 12100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.777804868050808
# The root mean squared error is:  37.67840182523968
# The correlation is:  0.8935187627752192
# ----------------------------------------
# alpha: 12200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.77281723852147
# The root mean squared error is:  37.66184931640082
# The correlation is:  0.8935274898151387
# ----------------------------------------
# alpha: 12300000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.767918259084226
# The root mean squared error is:  37.64553624513843
# The correlation is:  0.893535106102635
# ----------------------------------------
# alpha: 12400000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.76310668856291
# The root mean squared error is:  37.62945911575434
# The correlation is:  0.8935416357921124
# ----------------------------------------
# alpha: 12500000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.758381305724143
# The root mean squared error is:  37.61361449691111
# The correlation is:  0.8935471023706428
# ----------------------------------------
# alpha: 12600000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.753740908949617
# The root mean squared error is:  37.59799902021413
# The correlation is:  0.8935515286810032
# ----------------------------------------
# alpha: 12700000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.749184315904653
# The root mean squared error is:  37.582609378813906
# The correlation is:  0.8935549369438024
# ----------------------------------------
# alpha: 12800000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.74471036321685
# The root mean squared error is:  37.56744232605759
# The correlation is:  0.8935573487786536
# ----------------------------------------
# alpha: 12900000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.74031790615378
# The root mean squared error is:  37.5524946741643
# The correlation is:  0.8935587852244935
# ----------------------------------------
# alpha: 13000000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.73600581830765
# The root mean squared error is:  37.53776329294012
# The correlation is:  0.893559266759078
# ----------------------------------------
# alpha: 13100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.73177299128343
# The root mean squared error is:  37.52324510852413
# The correlation is:  0.8935588133176645
# ----------------------------------------
# alpha: 13200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.7276183343912
# The root mean squared error is:  37.508937102166136
# The correlation is:  0.89355744431096
# ----------------------------------------
# alpha: 13300000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.723540774342005
# The root mean squared error is:  37.494836309033396
# The correlation is:  0.893555178642354
# ----------------------------------------
# alpha: 13400000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.719539254948618
# The root mean squared error is:  37.48093981704837
# The correlation is:  0.8935520347244589
# ----------------------------------------
# alpha: 13500000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.715612736831776
# The root mean squared error is:  37.467244765758025
# The correlation is:  0.8935480304950028
# ----------------------------------------
# alpha: 13600000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.71176019712746
# The root mean squared error is:  37.45374834522393
# The correlation is:  0.893543183432108
# ----------------------------------------
# alpha: 13700000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.707980629203025
# The root mean squared error is:  37.44044779494946
# The correlation is:  0.8935375105689679
# ----------------------------------------
# alpha: 13800000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.7042730423742
# The root mean squared error is:  37.427340402826054
# The correlation is:  0.8935310285079617
# ----------------------------------------
# alpha: 13900000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.700636461627752
# The root mean squared error is:  37.414423504107766
# The correlation is:  0.8935237534342336
# ----------------------------------------
# alpha: 14000000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.697069927348576
# The root mean squared error is:  37.401694480411486
# The correlation is:  0.8935157011287533
# ----------------------------------------
# alpha: 14100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.693572495051416
# The root mean squared error is:  37.389150758741664
# The correlation is:  0.8935068869808819
# ----------------------------------------
# alpha: 14200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.690143235116437
# The root mean squared error is:  37.376789810538014
# The correlation is:  0.8934973260004675
# ----------------------------------------
# alpha: 14300000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.68678123252874
# The root mean squared error is:  37.364609150745395
# The correlation is:  0.8934870328295029
# ----------------------------------------
# alpha: 14400000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.68348558662405
# The root mean squared error is:  37.35260633691012
# The correlation is:  0.8934760217533296
# ----------------------------------------
# alpha: 14500000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.68025541083512
# The root mean squared error is:  37.34077896829038
# The correlation is:  0.8934643067114615
# ----------------------------------------
# alpha: 14600000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.67708983244883
# The root mean squared error is:  37.329124685002036
# The correlation is:  0.8934519013079681
# ----------------------------------------
# alpha: 14700000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.673987992358274
# The root mean squared error is:  37.317641167165036
# The correlation is:  0.893438818821542
# ----------------------------------------
# alpha: 14800000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.670949044827445
# The root mean squared error is:  37.30632613408809
# The correlation is:  0.893425072215159
# ----------------------------------------
# alpha: 14900000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.667972157256678
# The root mean squared error is:  37.295177343465774
# The correlation is:  0.8934106741453943
# ----------------------------------------
# alpha: 15000000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.665056509950418
# The root mean squared error is:  37.284192590590855
# The correlation is:  0.8933956369714423
# ----------------------------------------
# alpha: 15100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.662201295892864
# The root mean squared error is:  37.273369707593346
# The correlation is:  0.8933799727637807
# ----------------------------------------
# alpha: 15200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.659405720523946
# The root mean squared error is:  37.262706562689786
# The correlation is:  0.8933636933125534
# ----------------------------------------
# alpha: 15300000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.656669001522346
# The root mean squared error is:  37.25220105945683
# The correlation is:  0.8933468101356496
# ----------------------------------------
# alpha: 15400000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.65399036858937
# The root mean squared error is:  37.241851136115145
# The correlation is:  0.8933293344865153
# ----------------------------------------
# alpha: 15500000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.65136906324116
# The root mean squared error is:  37.23165476483994
# The correlation is:  0.8933112773616738
# ----------------------------------------
# alpha: 15600000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.648804338598335
# The root mean squared error is:  37.221609951073866
# The correlation is:  0.8932926495080223
# ----------------------------------------
# alpha: 15700000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.646295459186195
# The root mean squared error is:  37.21171473287029
# The correlation is:  0.8932734614298428
# ----------------------------------------
# alpha: 15800000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.643841700732764
# The root mean squared error is:  37.201967180239556
# The correlation is:  0.893253723395614
# ----------------------------------------
# alpha: 15900000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.641442349974064
# The root mean squared error is:  37.19236539451786
# The correlation is:  0.8932334454445643
# ----------------------------------------
# alpha: 16000000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.63909670446299
# The root mean squared error is:  37.18290750775071
# The correlation is:  0.8932126373930179
# ----------------------------------------
# alpha: 16100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.636804072378794
# The root mean squared error is:  37.17359168208447
# The correlation is:  0.8931913088405345
# ----------------------------------------
# alpha: 16200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.634563772343718
# The root mean squared error is:  37.16441610917955
# The correlation is:  0.8931694691758343
# ----------------------------------------
# alpha: 16300000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.632375133239602
# The root mean squared error is:  37.155379009629705
# The correlation is:  0.8931471275825492
# ----------------------------------------
# alpha: 16400000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.63023749403104
# The root mean squared error is:  37.146478632401234
# The correlation is:  0.8931242930447597
# ----------------------------------------
# alpha: 16500000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.62815020358913
# The root mean squared error is:  37.13771325427949
# The correlation is:  0.8931009743523758
# ----------------------------------------
# alpha: 16600000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.626112620521116
# The root mean squared error is:  37.12908117933309
# The correlation is:  0.8930771801063232
# ----------------------------------------
# alpha: 16700000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.62412411299928
# The root mean squared error is:  37.12058073838211
# The correlation is:  0.8930529187235972
# ----------------------------------------
# alpha: 16800000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.622184058598403
# The root mean squared error is:  37.112210288489734
# The correlation is:  0.8930281984421058
# ----------------------------------------
# alpha: 16900000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.620291844131955
# The root mean squared error is:  37.10396821245598
# The correlation is:  0.8930030273254013
# ----------------------------------------
# alpha: 17000000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.618446865492
# The root mean squared error is:  37.09585291832428
# The correlation is:  0.892977413267252
# ----------------------------------------
# alpha: 17100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.616648527494693
# The root mean squared error is:  37.087862838904584
# The correlation is:  0.8929513639960541
# ----------------------------------------
# alpha: 17200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.61489624372506
# The root mean squared error is:  37.07999643129933
# The correlation is:  0.892924887079132
# ----------------------------------------
# alpha: 17300000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.613189436387902
# The root mean squared error is:  37.07225217644676
# The correlation is:  0.8928979899268795
# ----------------------------------------
# alpha: 17400000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.611527536158402
# The root mean squared error is:  37.06462857866794
# The correlation is:  0.892870679796796
# ----------------------------------------
# alpha: 17500000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.609909982039724
# The root mean squared error is:  37.0571241652324
# The correlation is:  0.8928429637973783
# ----------------------------------------
# alpha: 17600000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.608336221217684
# The root mean squared error is:  37.049737485921554
# The correlation is:  0.8928148488919134
# ----------------------------------------
# alpha: 17700000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.606805708922998
# The root mean squared error is:  37.04246711261207
# The correlation is:  0.8927863419021489
# ----------------------------------------
# alpha: 17800000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.605317908294957
# The root mean squared error is:  37.035311638865785
# The correlation is:  0.8927574495118299
# ----------------------------------------
# alpha: 17900000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.603872290244876
# The root mean squared error is:  37.028269679522595
# The correlation is:  0.8927281782701791
# ----------------------------------------
# alpha: 18000000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.60246833332628
# The root mean squared error is:  37.02133987031117
# The correlation is:  0.8926985345952191
# ----------------------------------------
# alpha: 18100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.60110552360442
# The root mean squared error is:  37.014520867461435
# The correlation is:  0.8926685247770345
# ----------------------------------------
# alpha: 18200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.599783354529553
# The root mean squared error is:  37.007811347328165
# The correlation is:  0.892638154980924
# ----------------------------------------
# alpha: 18300000.01
# ...
# ----------------------------------------
# alpha: 27700000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.610267802121633
# The root mean squared error is:  36.72749799151692
# The correlation is:  0.8887195796614221
# ----------------------------------------
# alpha: 27800000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.611422813065804
# The root mean squared error is:  36.727216564622786
# The correlation is:  0.8886717357630246
# ----------------------------------------
# alpha: 27900000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.61259478343288
# The root mean squared error is:  36.72697422080414
# The correlation is:  0.8886238141401424
# ----------------------------------------
# alpha: 28000000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.613779738277717
# The root mean squared error is:  36.726770588069435
# The correlation is:  0.8885758160266675
# ----------------------------------------
# alpha: 28100000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.61497753555126
# The root mean squared error is:  36.72660529856556
# The correlation is:  0.8885277426397248
# ----------------------------------------
# alpha: 28200000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.616188034811103
# The root mean squared error is:  36.726477988518425
# The correlation is:  0.8884795951799677
# ----------------------------------------
# alpha: 28300000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.617411097201334
# The root mean squared error is:  36.726388298180204
# The correlation is:  0.8884313748318339
# ----------------------------------------
# alpha: 28400000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.618646585430106
# The root mean squared error is:  36.72633587177185
# The correlation is:  0.8883830827638237
# ----------------------------------------
# alpha: 28500000.01
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.61989436374936
# The root mean squared error is:  36.72632035743047
# The correlation is:  0.8883347201287579
# ----------------------------------------
# alpha: 28600000.01
# alpha: 28700000.01
# alpha: 28800000.01
# alpha: 28900000.01
# alpha: 29000000.01
# alpha: 29100000.01
# alpha: 29200000.01
# alpha: 29300000.01
# alpha: 29400000.01
# alpha: 29500000.01
# alpha: 29600000.01
# alpha: 29700000.01
# alpha: 29800000.01
# alpha: 29900000.01
# alpha: 30000000.01
# alpha: 30100000.01
# alpha: 30200000.01
# alpha: 30300000.01
# alpha: 30400000.01
# alpha: 30500000.01
# alpha: 30600000.01
# alpha: 30700000.01
# alpha: 30800000.01
# alpha: 30900000.01
# alpha: 31000000.01
# alpha: 31100000.01
# alpha: 31200000.01
# alpha: 31300000.01
# alpha: 31400000.01
# alpha: 31500000.01
# alpha: 31600000.01
# alpha: 31700000.01
# alpha: 31800000.01
# alpha: 31900000.01
# alpha: 32000000.01
# alpha: 32100000.01
# alpha: 32200000.01
# alpha: 32300000.01
# alpha: 32400000.01
# alpha: 32500000.01
# alpha: 32600000.01
# alpha: 32700000.01
# alpha: 32800000.01
# alpha: 32900000.01
# alpha: 33000000.01
# alpha: 33100000.01
# alpha: 33200000.01
# alpha: 33300000.01
# alpha: 33400000.01
# alpha: 33500000.01
# alpha: 33600000.01
# alpha: 33700000.01
# alpha: 33800000.01
# alpha: 33900000.01
# alpha: 34000000.01
# alpha: 34100000.01
# alpha: 34200000.01
# alpha: 34300000.01
# alpha: 34400000.01
# alpha: 34500000.01
# alpha: 34600000.01
# alpha: 34700000.01
# alpha: 34800000.01
# alpha: 34900000.01
# alpha: 35000000.01
# alpha: 35100000.01
# alpha: 35200000.01
# alpha: 35300000.01
# alpha: 35400000.01
# alpha: 35500000.01
# alpha: 35600000.01
# alpha: 35700000.01
# alpha: 35800000.01
# alpha: 35900000.01
# alpha: 36000000.01
# alpha: 36100000.01
# alpha: 36200000.01
# alpha: 36300000.01
# alpha: 36400000.01
# alpha: 36500000.01
# alpha: 36600000.01
# alpha: 36700000.01
# alpha: 36800000.01
# alpha: 36900000.01
# alpha: 37000000.01
# alpha: 37100000.01
# alpha: 37200000.01
# alpha: 37300000.01
# alpha: 37400000.01
# alpha: 37500000.01
# alpha: 37600000.01
# alpha: 37700000.01
# alpha: 37800000.01
# alpha: 37900000.01
# alpha: 38000000.01
# alpha: 38100000.01
# alpha: 38200000.01
# alpha: 38300000.01
# alpha: 38400000.01
# alpha: 38500000.01
# alpha: 38600000.01
# alpha: 38700000.01
# alpha: 38800000.01
# alpha: 38900000.01
# alpha: 39000000.01
# alpha: 39100000.01
# alpha: 39200000.01
# alpha: 39300000.01
# alpha: 39400000.01
# alpha: 39500000.01
# alpha: 39600000.01
# alpha: 39700000.01
# alpha: 39800000.01
# alpha: 39900000.01
# alpha: 40000000.01
# alpha: 40100000.01
# alpha: 40200000.01
# alpha: 40300000.01
# alpha: 40400000.01
# alpha: 40500000.01
# alpha: 40600000.01
# alpha: 40700000.01
# alpha: 40800000.01
# alpha: 40900000.01
# alpha: 41000000.01
# alpha: 41100000.01
# alpha: 41200000.01
# alpha: 41300000.01
# alpha: 41400000.01
# alpha: 41500000.01
# alpha: 41600000.01
# alpha: 41700000.01
# alpha: 41800000.01
# alpha: 41900000.01
# alpha: 42000000.01
# alpha: 42100000.01
# alpha: 42200000.01
# alpha: 42300000.01
# alpha: 42400000.01
# alpha: 42500000.01
# alpha: 42600000.01
# alpha: 42700000.01
# alpha: 42800000.01
# alpha: 42900000.01
# alpha: 43000000.01
# alpha: 43100000.01
# alpha: 43200000.01
# alpha: 43300000.01
# alpha: 43400000.01
# alpha: 43500000.01
# alpha: 43600000.01
# alpha: 43700000.01
# alpha: 43800000.01
# alpha: 43900000.01
# alpha: 44000000.01
# alpha: 44100000.01
# alpha: 44200000.01
# alpha: 44300000.01
# alpha: 44400000.01
# alpha: 44500000.01
# alpha: 44600000.01
# alpha: 44700000.01
# alpha: 44800000.01
# alpha: 44900000.01
# alpha: 45000000.01
# alpha: 45100000.01
# alpha: 45200000.01
# alpha: 45300000.01
# alpha: 45400000.01
# alpha: 45500000.01
# alpha: 45600000.01
# alpha: 45700000.01
# alpha: 45800000.01
# alpha: 45900000.01
# alpha: 46000000.01
# alpha: 46100000.01
# alpha: 46200000.01
# alpha: 46300000.01
# alpha: 46400000.01
# alpha: 46500000.01
# alpha: 46600000.01
# alpha: 46700000.01
# alpha: 46800000.01
# alpha: 46900000.01
# alpha: 47000000.01
# alpha: 47100000.01
# alpha: 47200000.01
# alpha: 47300000.01
# alpha: 47400000.01
# alpha: 47500000.01
# alpha: 47600000.01
# alpha: 47700000.01
# alpha: 47800000.01
# alpha: 47900000.01
# alpha: 48000000.01
# alpha: 48100000.01
# alpha: 48200000.01
# alpha: 48300000.01
# alpha: 48400000.01
# alpha: 48500000.01
# alpha: 48600000.01
# alpha: 48700000.01
# alpha: 48800000.01
# alpha: 48900000.01
# alpha: 49000000.01
# alpha: 49100000.01
# alpha: 49200000.01
# alpha: 49300000.01
# alpha: 49400000.01
# alpha: 49500000.01
# alpha: 49600000.01
# alpha: 49700000.01
# alpha: 49800000.01
# alpha: 49900000.01
# alpha: 50000000.01
# alpha: 50100000.01
# alpha: 50200000.01
# alpha: 50300000.01
# alpha: 50400000.01
# alpha: 50500000.01
# alpha: 50600000.01
# alpha: 50700000.01
# alpha: 50800000.01
# alpha: 50900000.01
# alpha: 51000000.01
# alpha: 51100000.01
# alpha: 51200000.01
# alpha: 51300000.01
# alpha: 51400000.01
# alpha: 51500000.01
# alpha: 51600000.01
# alpha: 51700000.01
# alpha: 51800000.01
# alpha: 51900000.01
# alpha: 52000000.01
# alpha: 52100000.01
# alpha: 52200000.01
# alpha: 52300000.01
# alpha: 52400000.01
# alpha: 52500000.01
# alpha: 52600000.01
# alpha: 52700000.01
# alpha: 52800000.01
# alpha: 52900000.01
# alpha: 53000000.01
# alpha: 53100000.01
# alpha: 53200000.01
# alpha: 53300000.01
# alpha: 53400000.01
# alpha: 53500000.01
# alpha: 53600000.01
# alpha: 53700000.01
# alpha: 53800000.01
# alpha: 53900000.01
# alpha: 54000000.01
# alpha: 54100000.01
# alpha: 54200000.01
# alpha: 54300000.01
# alpha: 54400000.01
# alpha: 54500000.01
# alpha: 54600000.01
# alpha: 54700000.01
# alpha: 54800000.01
# alpha: 54900000.01
# alpha: 55000000.01
# alpha: 55100000.01
# alpha: 55200000.01
# alpha: 55300000.01
# alpha: 55400000.01
# alpha: 55500000.01
# alpha: 55600000.01
# alpha: 55700000.01
# alpha: 55800000.01
# alpha: 55900000.01
# alpha: 56000000.01
# alpha: 56100000.01
# alpha: 56200000.01
# alpha: 56300000.01
# alpha: 56400000.01
# alpha: 56500000.01
# alpha: 56600000.01
# alpha: 56700000.01
# alpha: 56800000.01
# alpha: 56900000.01
# alpha: 57000000.01
# alpha: 57100000.01
# alpha: 57200000.01
# alpha: 57300000.01
# alpha: 57400000.01
# alpha: 57500000.01
# alpha: 57600000.01
# alpha: 57700000.01
# alpha: 57800000.01
# alpha: 57900000.01
# alpha: 58000000.01
# alpha: 58100000.01
# alpha: 58200000.01
# alpha: 58300000.01
# alpha: 58400000.01
# alpha: 58500000.01
# alpha: 58600000.01
# alpha: 58700000.01
# alpha: 58800000.01
# alpha: 58900000.01
# alpha: 59000000.01
# alpha: 59100000.01
# alpha: 59200000.01
# alpha: 59300000.01
# alpha: 59400000.01
# alpha: 59500000.01
# alpha: 59600000.01
# alpha: 59700000.01
# alpha: 59800000.01
# alpha: 59900000.01
# alpha: 60000000.01
# alpha: 60100000.01
# alpha: 60200000.01
# alpha: 60300000.01
# alpha: 60400000.01
# alpha: 60500000.01
# alpha: 60600000.01
# alpha: 60700000.01
# alpha: 60800000.01
# alpha: 60900000.01
# alpha: 61000000.01
# alpha: 61100000.01
# alpha: 61200000.01
# alpha: 61300000.01
# alpha: 61400000.01
# alpha: 61500000.01
# alpha: 61600000.01
# alpha: 61700000.01
# alpha: 61800000.01
# alpha: 61900000.01
# alpha: 62000000.01
# alpha: 62100000.01
# alpha: 62200000.01
# alpha: 62300000.01
# alpha: 62400000.01
# alpha: 62500000.01
# alpha: 62600000.01
# alpha: 62700000.01
# alpha: 62800000.01
# alpha: 62900000.01
# alpha: 63000000.01
# alpha: 63100000.01
# alpha: 63200000.01
# alpha: 63300000.01
# alpha: 63400000.01
# alpha: 63500000.01
# alpha: 63600000.01
# alpha: 63700000.01
# alpha: 63800000.01
# alpha: 63900000.01
# alpha: 64000000.01
# alpha: 64100000.01
# alpha: 64200000.01
# alpha: 64300000.01
# alpha: 64400000.01
# alpha: 64500000.01
# alpha: 64600000.01
# alpha: 64700000.01
# alpha: 64800000.01
# alpha: 64900000.01
# alpha: 65000000.01
# alpha: 65100000.01
# alpha: 65200000.01
# alpha: 65300000.01
# alpha: 65400000.01
# alpha: 65500000.01
# alpha: 65600000.01
# alpha: 65700000.01
# alpha: 65800000.01
# alpha: 65900000.01
# alpha: 66000000.01
# alpha: 66100000.01
# alpha: 66200000.01
# alpha: 66300000.01
# alpha: 66400000.01
# alpha: 66500000.01
# alpha: 66600000.01
# alpha: 66700000.01
# alpha: 66800000.01
# alpha: 66900000.01
# alpha: 67000000.01
# alpha: 67100000.01
# alpha: 67200000.01
# alpha: 67300000.01
# alpha: 67400000.01
# alpha: 67500000.01
# alpha: 67600000.01
# alpha: 67700000.01
# alpha: 67800000.01
# alpha: 67900000.01
# alpha: 68000000.01
# alpha: 68100000.01
# alpha: 68200000.01
# alpha: 68300000.01
# alpha: 68400000.01
# alpha: 68500000.01
# alpha: 68600000.01
# alpha: 68700000.01
# alpha: 68800000.01
# alpha: 68900000.01
# alpha: 69000000.01
# alpha: 69100000.01
# alpha: 69200000.01
# alpha: 69300000.01
# alpha: 69400000.01
# alpha: 69500000.01
# alpha: 69600000.01
# alpha: 69700000.01
# alpha: 69800000.01
# alpha: 69900000.01
# alpha: 70000000.01
# alpha: 70100000.01
# alpha: 70200000.01
# alpha: 70300000.01
# alpha: 70400000.01
# alpha: 70500000.01
# alpha: 70600000.01
# alpha: 70700000.01
# alpha: 70800000.01
# alpha: 70900000.01
# alpha: 71000000.01
# alpha: 71100000.01
# alpha: 71200000.01
# alpha: 71300000.01
# alpha: 71400000.01
# alpha: 71500000.01
# alpha: 71600000.01
# alpha: 71700000.01
# alpha: 71800000.01
# alpha: 71900000.01
# alpha: 72000000.01
# alpha: 72100000.01
# alpha: 72200000.01
# alpha: 72300000.01
# alpha: 72400000.01
# alpha: 72500000.01
# alpha: 72600000.01
# alpha: 72700000.01
# alpha: 72800000.01
# alpha: 72900000.01
# alpha: 73000000.01
# alpha: 73100000.01
# alpha: 73200000.01
# alpha: 73300000.01
# alpha: 73400000.01
# alpha: 73500000.01
# alpha: 73600000.01
# alpha: 73700000.01
# alpha: 73800000.01
# alpha: 73900000.01
# alpha: 74000000.01
# alpha: 74100000.01
# alpha: 74200000.01
# alpha: 74300000.01
# alpha: 74400000.01
# alpha: 74500000.01
# alpha: 74600000.01
# alpha: 74700000.01
# alpha: 74800000.01
# alpha: 74900000.01
# alpha: 75000000.01
# alpha: 75100000.01
# alpha: 75200000.01
# alpha: 75300000.01
# alpha: 75400000.01
# alpha: 75500000.01
# alpha: 75600000.01
# alpha: 75700000.01
# alpha: 75800000.01
# alpha: 75900000.01
# alpha: 76000000.01
# alpha: 76100000.01
# alpha: 76200000.01
# alpha: 76300000.01
# alpha: 76400000.01
# alpha: 76500000.01
# alpha: 76600000.01
# alpha: 76700000.01
# alpha: 76800000.01
# alpha: 76900000.01
# alpha: 77000000.01
# alpha: 77100000.01
# alpha: 77200000.01
# alpha: 77300000.01
# alpha: 77400000.01
# alpha: 77500000.01
# alpha: 77600000.01
# alpha: 77700000.01
# alpha: 77800000.01
# alpha: 77900000.01
# alpha: 78000000.01
# alpha: 78100000.01
# alpha: 78200000.01
# alpha: 78300000.01
# alpha: 78400000.01
# alpha: 78500000.01
# alpha: 78600000.01
# alpha: 78700000.01
# alpha: 78800000.01
# alpha: 78900000.01
# alpha: 79000000.01
# alpha: 79100000.01
# alpha: 79200000.01
# alpha: 79300000.01
# alpha: 79400000.01
# alpha: 79500000.01
# alpha: 79600000.01
# alpha: 79700000.01
# alpha: 79800000.01
# alpha: 79900000.01
# alpha: 80000000.01
# alpha: 80100000.01
# alpha: 80200000.01
# alpha: 80300000.01
# alpha: 80400000.01
# alpha: 80500000.01
# alpha: 80600000.01
# alpha: 80700000.01
# alpha: 80800000.01
# alpha: 80900000.01
# alpha: 81000000.01
# alpha: 81100000.01
# alpha: 81200000.01
# alpha: 81300000.01
# alpha: 81400000.01
# alpha: 81500000.01
# alpha: 81600000.01
# alpha: 81700000.01
# alpha: 81800000.01
# alpha: 81900000.01
# alpha: 82000000.01
# alpha: 82100000.01
# alpha: 82200000.01
# alpha: 82300000.01
# alpha: 82400000.01
# alpha: 82500000.01
# alpha: 82600000.01
# alpha: 82700000.01
# alpha: 82800000.01
# alpha: 82900000.01
# alpha: 83000000.01
# alpha: 83100000.01
# alpha: 83200000.01
# alpha: 83300000.01
# alpha: 83400000.01
# alpha: 83500000.01
# alpha: 83600000.01
# alpha: 83700000.01
# alpha: 83800000.01
# alpha: 83900000.01
# alpha: 84000000.01
# alpha: 84100000.01
# alpha: 84200000.01
# alpha: 84300000.01
# alpha: 84400000.01
# alpha: 84500000.01
# alpha: 84600000.01
# alpha: 84700000.01
# alpha: 84800000.01
# alpha: 84900000.01
# alpha: 85000000.01
# alpha: 85100000.01
# alpha: 85200000.01
# alpha: 85300000.01
# alpha: 85400000.01
# alpha: 85500000.01
# alpha: 85600000.01
# alpha: 85700000.01
# alpha: 85800000.01
# alpha: 85900000.01
# alpha: 86000000.01
# alpha: 86100000.01
# alpha: 86200000.01
# alpha: 86300000.01
# alpha: 86400000.01
# alpha: 86500000.01
# alpha: 86600000.01
# alpha: 86700000.01
# alpha: 86800000.01
# alpha: 86900000.01
# alpha: 87000000.01
# alpha: 87100000.01
# alpha: 87200000.01
# alpha: 87300000.01
# alpha: 87400000.01
# alpha: 87500000.01
# alpha: 87600000.01
# alpha: 87700000.01
# alpha: 87800000.01
# alpha: 87900000.01
# alpha: 88000000.01
# alpha: 88100000.01
# alpha: 88200000.01
# alpha: 88300000.01
# alpha: 88400000.01
# alpha: 88500000.01
# alpha: 88600000.01
# alpha: 88700000.01
# alpha: 88800000.01
# alpha: 88900000.01
# alpha: 89000000.01
# alpha: 89100000.01
# alpha: 89200000.01
# alpha: 89300000.01
# alpha: 89400000.01
# alpha: 89500000.01
# alpha: 89600000.01
# alpha: 89700000.01
# alpha: 89800000.01
# alpha: 89900000.01
# alpha: 90000000.01
# alpha: 90100000.01
# alpha: 90200000.01
# alpha: 90300000.01
# alpha: 90400000.01
# alpha: 90500000.01
# alpha: 90600000.01
# alpha: 90700000.01
# alpha: 90800000.01
# alpha: 90900000.01
# alpha: 91000000.01
# alpha: 91100000.01
# alpha: 91200000.01
# alpha: 91300000.01
# alpha: 91400000.01
# alpha: 91500000.01
# alpha: 91600000.01
# alpha: 91700000.01
# alpha: 91800000.01
# alpha: 91900000.01
# alpha: 92000000.01
# alpha: 92100000.01
# alpha: 92200000.01
# alpha: 92300000.01
# alpha: 92400000.01
# alpha: 92500000.01
# alpha: 92600000.01
# alpha: 92700000.01
# alpha: 92800000.01
# alpha: 92900000.01
# alpha: 93000000.01
# alpha: 93100000.01
# alpha: 93200000.01
# alpha: 93300000.01
# alpha: 93400000.01
# alpha: 93500000.01
# alpha: 93600000.01
# alpha: 93700000.01
# alpha: 93800000.01
# alpha: 93900000.01
# alpha: 94000000.01
# alpha: 94100000.01
# alpha: 94200000.01
# alpha: 94300000.01
# alpha: 94400000.01
# alpha: 94500000.01
# alpha: 94600000.01
# alpha: 94700000.01
# alpha: 94800000.01
# alpha: 94900000.01
# alpha: 95000000.01
# alpha: 95100000.01
# alpha: 95200000.01
# alpha: 95300000.01
# alpha: 95400000.01
# alpha: 95500000.01
# alpha: 95600000.01
# alpha: 95700000.01
# alpha: 95800000.01
# alpha: 95900000.01
# alpha: 96000000.01
# alpha: 96100000.01
# alpha: 96200000.01
# alpha: 96300000.01
# alpha: 96400000.01
# alpha: 96500000.01
# alpha: 96600000.01
# alpha: 96700000.01
# alpha: 96800000.01
# alpha: 96900000.01
# alpha: 97000000.01
# alpha: 97100000.01
# alpha: 97200000.01
# alpha: 97300000.01
# alpha: 97400000.01
# alpha: 97500000.01
# alpha: 97600000.01
# alpha: 97700000.01
# alpha: 97800000.01
# alpha: 97900000.01
# alpha: 98000000.01
# alpha: 98100000.01
# alpha: 98200000.01
# alpha: 98300000.01
# alpha: 98400000.01
# alpha: 98500000.01
# alpha: 98600000.01
# alpha: 98700000.01
# alpha: 98800000.01
# alpha: 98900000.01
# alpha: 99000000.01
# alpha: 99100000.01
# alpha: 99200000.01
# alpha: 99300000.01
# alpha: 99400000.01
# alpha: 99500000.01
# alpha: 99600000.01
# alpha: 99700000.01
# alpha: 99800000.01
# alpha: 99900000.01

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.3, 150 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train1_X2,train1_y,test1_X2,test1_y))

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.4, 103 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train1_X3,train1_y,test1_X3,test1_y))

# %%
para =[0,28500000]
rmse=100000
mae=1000000
corr=0
for a in para:
    print('alpha:',a)
    rmse0,mae0,corr0 = ridge(a,train1_X1,train1_y,val1_X1,val1_y)
    if rmse0< rmse:
        rmse=rmse0
        mae=mae0
        corr = corr0
        print('========================================')
        print('Best RMSE is updated! ' )
        print('The mean absolute error is: ',mae)
        print('The root mean squared error is: ',rmse)
        print('The correlation is: ',corr)
        print('----------------------------------------')
# Out:
# alpha: 0
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.73847737393675
# The root mean squared error is:  45.95805279347588
# The correlation is:  0.7576646272128535
# ----------------------------------------
# alpha: 28500000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  20.619894363623906
# The root mean squared error is:  36.72632035743006
# The correlation is:  0.8883347201335979
# ----------------------------------------

# %% [markdown]
# ## For the last 2 years as the testing set

# %%
train_size = 3653
corrs2 = np.zeros((X.shape[1],1))
for i in range(0,X.shape[1]):
    if X.sum(axis=1)[i] == 0:
        corrs2[i] = 0
    else:
        corrs2[i] = np.corrcoef(X.iloc[0:train_size,i],y.iloc[0:train_size,0])[0,1]
        
corrs2.shape,X.columns.shape,X.columns[0],X.columns[249]
# Out:
# ((250, 1), (250,), ('flu',), ('flu incubation',))

# %%
#train2_X0,test2_X0 = corr_filter(train2_X,test2_X,corrs2,0.1)
train2_X1,val2_X1,test2_X1 = corr_filter(train2_X,val2_X,test2_X,corrs2,0.2)
#train2_X2,test2_X2 = corr_filter(train2_X,test2_X,corrs2,0.3)
#train2_X3,test2_X3 = corr_filter(train2_X,test2_X,corrs2,0.4)

# %%
#print('For correlation filter r>0.1, we select feature number: ',train2_X0.shape[1])
print('For correlation filter r>0.2, we select feature number: ',train2_X1.shape[1])
#print('For correlation filter r>0.3, we select feature number: ',train2_X2.shape[1])
#print('For correlation filter r>0.4, we select feature number: ',train2_X3.shape[1])
# Out:
# For correlation filter r>0.2, we select feature number:  157

# %% [markdown]
# # scaling and modeling
# scaler = MinMaxScaler()
# train2_X0_scaled = scaler.fit_transform(train2_X0)
# test2_X0_scaled = scaler.transform(test2_X0)
#
# train2_X1_scaled = scaler.fit_transform(train2_X1)
# test2_X1_scaled = scaler.transform(test2_X1)
#
# train2_X2_scaled = scaler.fit_transform(train2_X2)
# test2_X2_scaled = scaler.transform(test2_X2)
#
# train2_X3_scaled = scaler.fit_transform(train2_X3)
# test2_X3_scaled = scaler.transform(test2_X3)

# %% [markdown]
# para = range(1,100)
# para = np.arange(0.01, 10.0, 0.01)
# rmse=100000
# mae=1000000
# corr=0
# for a in para:
#     print('alpha:',a)
#     rmse0,mae0,corr0 = ridge(a,train1_X1,train1_y,val1_X1,val1_y)
#     if rmse0< rmse:
#         rmse=rmse0
#         mae=mae0
#         corr = corr0
#         print('========================================')
#         print('Best RMSE is updated! ' )
#         print('The mean absolute error is: ',mae)
#         print('The root mean squared error is: ',rmse)
#         print('The correlation is: ',corr)
#         print('----------------------------------------')

# %%
para =np.arange(0, 10000000, 10000)
rmse=100000
mae=1000000
corr=0
for a in para:
    print('alpha:',a)
    rmse0,mae0,corr0 = ridge(a,train2_X1,train2_y,val2_X1,val2_y)
    if rmse0< rmse:
        rmse=rmse0
        mae=mae0
        corr = corr0
        print('========================================')
        print('Best RMSE is updated! ' )
        print('The mean absolute error is: ',mae)
        print('The root mean squared error is: ',rmse)
        print('The correlation is: ',corr)
        print('----------------------------------------')
# Out:
# alpha: 0
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.824141181729265
# The root mean squared error is:  10.31516320934834
# The correlation is:  0.38850181146733165
# ----------------------------------------
# alpha: 10000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.805691092591468
# The root mean squared error is:  10.249416705583524
# The correlation is:  0.39021113735396473
# ----------------------------------------
# alpha: 20000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.787762372771287
# The root mean squared error is:  10.184086394066915
# The correlation is:  0.39197029246842957
# ----------------------------------------
# alpha: 30000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.7702625304282105
# The root mean squared error is:  10.119651214469608
# The correlation is:  0.39375502509385285
# ----------------------------------------
# alpha: 40000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.753262350705389
# The root mean squared error is:  10.056373408476652
# The correlation is:  0.3955499513398582
# ----------------------------------------
# alpha: 50000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.736719119331545
# The root mean squared error is:  9.994391807903382
# The correlation is:  0.39734502945811634
# ----------------------------------------
# alpha: 60000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.720628098513923
# The root mean squared error is:  9.933772746406037
# The correlation is:  0.39913356846744336
# ----------------------------------------
# alpha: 70000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.705244584683493
# The root mean squared error is:  9.87453905817393
# The correlation is:  0.40091104937299565
# ----------------------------------------
# alpha: 80000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.69036852735364
# The root mean squared error is:  9.816687170671425
# The correlation is:  0.4026743998669875
# ----------------------------------------
# alpha: 90000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.676007854336955
# The root mean squared error is:  9.760197460706083
# The correlation is:  0.40442153331887254
# ----------------------------------------
# alpha: 100000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.6619729011662105
# The root mean squared error is:  9.705040667964152
# The correlation is:  0.40615104752937325
# ----------------------------------------
# alpha: 110000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.648285596506802
# The root mean squared error is:  9.651181934955728
# The correlation is:  0.40786202313119685
# ----------------------------------------
# alpha: 120000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.635008397930052
# The root mean squared error is:  9.598583383338516
# The correlation is:  0.4095538858484383
# ----------------------------------------
# alpha: 130000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.622022639325358
# The root mean squared error is:  9.547205769332507
# The correlation is:  0.41122631066083476
# ----------------------------------------
# alpha: 140000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.609319592272369
# The root mean squared error is:  9.497009549754692
# The correlation is:  0.4128791540489599
# ----------------------------------------
# alpha: 150000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.596936240477305
# The root mean squared error is:  9.447955565509536
# The correlation is:  0.41451240541026974
# ----------------------------------------
# alpha: 160000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.584847331432127
# The root mean squared error is:  9.400005473938673
# The correlation is:  0.41612615178351386
# ----------------------------------------
# alpha: 170000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.573012936184576
# The root mean squared error is:  9.353122014867628
# The correlation is:  0.41772055195154867
# ----------------------------------------
# alpha: 180000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.561434591107221
# The root mean squared error is:  9.3072691659006
# The correlation is:  0.41929581724275367
# ----------------------------------------
# alpha: 190000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.55026814617282
# The root mean squared error is:  9.262412223729342
# The correlation is:  0.4208521971776619
# ----------------------------------------
# alpha: 200000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.539356263418723
# The root mean squared error is:  9.218517836108136
# The correlation is:  0.4223899686581626
# ----------------------------------------
# alpha: 210000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.52878193966262
# The root mean squared error is:  9.175554001090765
# The correlation is:  0.42390942777503443
# ----------------------------------------
# alpha: 220000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.518430595766092
# The root mean squared error is:  9.133490044851586
# The correlation is:  0.42541088356716966
# ----------------------------------------
# alpha: 230000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.5082868850990865
# The root mean squared error is:  9.092296585779444
# The correlation is:  0.4268946532495729
# ----------------------------------------
# alpha: 240000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.498343947766718
# The root mean squared error is:  9.0519454901334
# The correlation is:  0.4283610585544515
# ----------------------------------------
# alpha: 250000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.488621159671682
# The root mean squared error is:  9.012409822892057
# The correlation is:  0.42981042292145094
# ----------------------------------------
# alpha: 260000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.479135971045881
# The root mean squared error is:  8.973663796239482
# The correlation is:  0.43124306934124285
# ----------------------------------------
# alpha: 270000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.469819222464488
# The root mean squared error is:  8.935682717393368
# The correlation is:  0.4326593187030464
# ----------------------------------------
# alpha: 280000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.460665919026799
# The root mean squared error is:  8.89844293689246
# The correlation is:  0.4340594885337426
# ----------------------------------------
# alpha: 290000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.451671257029678
# The root mean squared error is:  8.861921798076333
# The correlation is:  0.4354438920428752
# ----------------------------------------
# alpha: 300000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.442830617030795
# The root mean squared error is:  8.82609758824548
# The correlation is:  0.436812837406639
# ----------------------------------------
# alpha: 310000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.434139556742365
# The root mean squared error is:  8.790949491781435
# The correlation is:  0.43816662723982386
# ----------------------------------------
# alpha: 320000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.425593803893665
# The root mean squared error is:  8.756457545378955
# The correlation is:  0.43950555821595705
# ----------------------------------------
# alpha: 330000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.417189249163411
# The root mean squared error is:  8.722602595459373
# The correlation is:  0.4408299208042472
# ----------------------------------------
# alpha: 340000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.408921939253014
# The root mean squared error is:  8.689366257775896
# The correlation is:  0.44213999909847795
# ----------------------------------------
# alpha: 350000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.400788070145499
# The root mean squared error is:  8.656730879157148
# The correlation is:  0.44343607071920954
# ----------------------------------------
# alpha: 360000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.39278398058461
# The root mean squared error is:  8.62467950133655
# The correlation is:  0.4447184067733504
# ----------------------------------------
# alpha: 370000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.3849061457941865
# The root mean squared error is:  8.593195826786003
# The correlation is:  0.44598727185890424
# ----------------------------------------
# alpha: 380000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.3771511714472275
# The root mean squared error is:  8.562264186453943
# The correlation is:  0.44724292410550615
# ----------------------------------------
# alpha: 390000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.3695157878919195
# The root mean squared error is:  8.53186950932263
# The correlation is:  0.4484856152424164
# ----------------------------------------
# alpha: 400000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.362004646232067
# The root mean squared error is:  8.501997293670664
# The correlation is:  0.44971559068848965
# ----------------------------------------
# alpha: 410000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.354771608544994
# The root mean squared error is:  8.472633579963171
# The correlation is:  0.4509330896581256
# ----------------------------------------
# alpha: 420000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.347729085139553
# The root mean squared error is:  8.443764925259968
# The correlation is:  0.4521383452799181
# ----------------------------------------
# alpha: 430000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.340789749095442
# The root mean squared error is:  8.41537837905193
# The correlation is:  0.4533315847246262
# ----------------------------------------
# alpha: 440000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.333951033706127
# The root mean squared error is:  8.387461460450066
# The correlation is:  0.4545130293393648
# ----------------------------------------
# alpha: 450000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.3272211833551975
# The root mean squared error is:  8.360002136632742
# The correlation is:  0.4556828947863744
# ----------------------------------------
# alpha: 460000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.320605824257607
# The root mean squared error is:  8.332988802471501
# The correlation is:  0.456841391184828
# ----------------------------------------
# alpha: 470000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.3141214600363025
# The root mean squared error is:  8.306410261279767
# The correlation is:  0.4579887232534191
# ----------------------------------------
# alpha: 480000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.307846224874983
# The root mean squared error is:  8.280255706592872
# The correlation is:  0.4591250904537386
# ----------------------------------------
# alpha: 490000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.30168492186743
# The root mean squared error is:  8.254514704931275
# The correlation is:  0.4602506871327607
# ----------------------------------------
# alpha: 500000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.295606670127988
# The root mean squared error is:  8.229177179480727
# The correlation is:  0.46136570266405214
# ----------------------------------------
# alpha: 510000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.289609570136613
# The root mean squared error is:  8.204233394628172
# The correlation is:  0.4624703215873956
# ----------------------------------------
# alpha: 520000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.283715057597803
# The root mean squared error is:  8.179673941312164
# The correlation is:  0.4635647237458155
# ----------------------------------------
# alpha: 530000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.277906342981061
# The root mean squared error is:  8.155489723131236
# The correlation is:  0.46464908442007563
# ----------------------------------------
# alpha: 540000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.272173224125161
# The root mean squared error is:  8.131671943162644
# The correlation is:  0.4657235744604618
# ----------------------------------------
# alpha: 550000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.266514028128511
# The root mean squared error is:  8.108212091457933
# The correlation is:  0.4667883604152389
# ----------------------------------------
# alpha: 560000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.260927132355789
# The root mean squared error is:  8.085101933158528
# The correlation is:  0.4678436046564755
# ----------------------------------------
# alpha: 570000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.255410962629465
# The root mean squared error is:  8.062333497220505
# The correlation is:  0.468889465501826
# ----------------------------------------
# alpha: 580000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.249963991487482
# The root mean squared error is:  8.039899065682174
# The correlation is:  0.46992609733385166
# ----------------------------------------
# alpha: 590000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.244584736512522
# The root mean squared error is:  8.01779116347198
# The correlation is:  0.4709536507152921
# ----------------------------------------
# alpha: 600000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.23927175872379
# The root mean squared error is:  7.9960025487037765
# The correlation is:  0.47197227250147317
# ----------------------------------------
# alpha: 610000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.234023661033268
# The root mean squared error is:  7.974526203442011
# The correlation is:  0.47298210594933554
# ----------------------------------------
# alpha: 620000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.228839086763557
# The root mean squared error is:  7.953355324913474
# The correlation is:  0.4739832908228939
# ----------------------------------------
# alpha: 630000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.223716718222836
# The root mean squared error is:  7.932483317128569
# The correlation is:  0.4749759634958948
# ----------------------------------------
# alpha: 640000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.218655275336297
# The root mean squared error is:  7.911903782898683
# The correlation is:  0.47596025705117906
# ----------------------------------------
# alpha: 650000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.213653514333512
# The root mean squared error is:  7.891610516230443
# The correlation is:  0.4769363013766625
# ----------------------------------------
# alpha: 660000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.208710226484964
# The root mean squared error is:  7.871597495062635
# The correlation is:  0.47790422325879
# ----------------------------------------
# alpha: 670000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.203824236890895
# The root mean squared error is:  7.851858874344338
# The correlation is:  0.47886414647257103
# ----------------------------------------
# alpha: 680000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.198994403316464
# The root mean squared error is:  7.832388979421789
# The correlation is:  0.4798161918690662
# ----------------------------------------
# alpha: 690000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.194219615073104
# The root mean squared error is:  7.813182299725649
# The correlation is:  0.4807604774599308
# ----------------------------------------
# alpha: 700000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.189498791943719
# The root mean squared error is:  7.794233482738602
# The correlation is:  0.4816971184993783
# ----------------------------------------
# alpha: 710000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.184830883151358
# The root mean squared error is:  7.775537328237077
# The correlation is:  0.48262622756311285
# ----------------------------------------
# alpha: 720000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.180224324983067
# The root mean squared error is:  7.757088782775972
# The correlation is:  0.4835479146253023
# ----------------------------------------
# alpha: 730000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.175687587292412
# The root mean squared error is:  7.738882934417771
# The correlation is:  0.48446228713287925
# ----------------------------------------
# alpha: 740000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.171200519974564
# The root mean squared error is:  7.720915007700424
# The correlation is:  0.4853694500768057
# ----------------------------------------
# alpha: 750000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.166762184326737
# The root mean squared error is:  7.703180358800723
# The correlation is:  0.4862695060622855
# ----------------------------------------
# alpha: 760000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.162371666427251
# The root mean squared error is:  7.6856744709252105
# The correlation is:  0.4871625553754264
# ----------------------------------------
# alpha: 770000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.1580280763198925
# The root mean squared error is:  7.668392949879609
# The correlation is:  0.48804869604874357
# ----------------------------------------
# alpha: 780000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.1537305472324375
# The root mean squared error is:  7.651331519834939
# The correlation is:  0.488928023923943
# ----------------------------------------
# alpha: 790000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.149482965264321
# The root mean squared error is:  7.634486019266397
# The correlation is:  0.4898006327128905
# ----------------------------------------
# alpha: 800000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.145281537227361
# The root mean squared error is:  7.617852397055898
# The correlation is:  0.4906666140568845
# ----------------------------------------
# alpha: 810000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.141123608460443
# The root mean squared error is:  7.6014267087647065
# The correlation is:  0.4915260575834669
# ----------------------------------------
# alpha: 820000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.137008399612225
# The root mean squared error is:  7.585205113046565
# The correlation is:  0.49237905096207174
# ----------------------------------------
# alpha: 830000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.132935150965822
# The root mean squared error is:  7.569183868216219
# The correlation is:  0.4932256799573258
# ----------------------------------------
# alpha: 840000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.1289031218199534
# The root mean squared error is:  7.553359328949744
# The correlation is:  0.49406602848100073
# ----------------------------------------
# alpha: 850000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.124911589892648
# The root mean squared error is:  7.5377279431159
# The correlation is:  0.49490017864237873
# ----------------------------------------
# alpha: 860000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.121203499715384
# The root mean squared error is:  7.522286248738536
# The correlation is:  0.4957282107967064
# ----------------------------------------
# alpha: 870000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.117594847288855
# The root mean squared error is:  7.5070308710719695
# The correlation is:  0.49655020359249735
# ----------------------------------------
# alpha: 880000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.114022562668419
# The root mean squared error is:  7.491958519796743
# The correlation is:  0.4973662340170262
# ----------------------------------------
# alpha: 890000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.110486013367935
# The root mean squared error is:  7.477065986320785
# The correlation is:  0.49817637744056426
# ----------------------------------------
# alpha: 900000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.106984582386619
# The root mean squared error is:  7.462350141181916
# The correlation is:  0.49898070765945257
# ----------------------------------------
# alpha: 910000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.103517667733886
# The root mean squared error is:  7.447807931556316
# The correlation is:  0.49977929693741735
# ----------------------------------------
# alpha: 920000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.100084681970339
# The root mean squared error is:  7.433436378857881
# The correlation is:  0.500572216045853
# ----------------------------------------
# alpha: 930000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.096685051765713
# The root mean squared error is:  7.419232576427985
# The correlation is:  0.5013595343028948
# ----------------------------------------
# alpha: 940000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.093318217472299
# The root mean squared error is:  7.4051936873116295
# The correlation is:  0.5021413196113073
# ----------------------------------------
# alpha: 950000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.089983632715403
# The root mean squared error is:  7.391316942121662
# The correlation is:  0.5029176384948977
# ----------------------------------------
# alpha: 960000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.086680763995734
# The root mean squared error is:  7.37759963697282
# The correlation is:  0.5036885561344194
# ----------------------------------------
# alpha: 970000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.083409090308166
# The root mean squared error is:  7.364039131499598
# The correlation is:  0.5044541364018916
# ----------------------------------------
# alpha: 980000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.080168102773401
# The root mean squared error is:  7.350632846945337
# The correlation is:  0.5052144418939487
# ----------------------------------------
# alpha: 990000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.07695730428169
# The root mean squared error is:  7.337378264316217
# The correlation is:  0.5059695339645222
# ----------------------------------------
# alpha: 1000000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.073776209150233
# The root mean squared error is:  7.324272922607655
# The correlation is:  0.506719472756135
# ----------------------------------------
# alpha: 1010000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.070624342791673
# The root mean squared error is:  7.311314417090318
# The correlation is:  0.507464317230549
# ----------------------------------------
# alpha: 1020000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.067501241394239
# The root mean squared error is:  7.298500397658974
# The correlation is:  0.5082041251983968
# ----------------------------------------
# alpha: 1030000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.064406451612961
# The root mean squared error is:  7.2858285672390695
# The correlation is:  0.5089389533479718
# ----------------------------------------
# alpha: 1040000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.061339530271757
# The root mean squared error is:  7.273296680251152
# The correlation is:  0.5096688572730842
# ----------------------------------------
# alpha: 1050000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.058300044075287
# The root mean squared error is:  7.260902541127774
# The correlation is:  0.5103938915001636
# ----------------------------------------
# alpha: 1060000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.055287569329766
# The root mean squared error is:  7.248644002878699
# The correlation is:  0.511114109514822
# ----------------------------------------
# alpha: 1070000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.052301691675
# The root mean squared error is:  7.236518965712773
# The correlation is:  0.5118295637871396
# ----------------------------------------
# alpha: 1080000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.049342005824118
# The root mean squared error is:  7.224525375702226
# The correlation is:  0.5125403057965907
# ----------------------------------------
# alpha: 1090000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.046408115311838
# The root mean squared error is:  7.2126612234923995
# The correlation is:  0.5132463860562431
# ----------------------------------------
# alpha: 1100000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.043501511428125
# The root mean squared error is:  7.200924543060313
# The correlation is:  0.5139478541359325
# ----------------------------------------
# alpha: 1110000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.040622752745375
# The root mean squared error is:  7.189313410505609
# The correlation is:  0.5146447586854282
# ----------------------------------------
# alpha: 1120000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.037768586903852
# The root mean squared error is:  7.177825942892327
# The correlation is:  0.5153371474562585
# ----------------------------------------
# alpha: 1130000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.0349386518551125
# The root mean squared error is:  7.166460297125031
# The correlation is:  0.5160250673231712
# ----------------------------------------
# alpha: 1140000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.03214239293475
# The root mean squared error is:  7.155214668859004
# The correlation is:  0.5167085643052696
# ----------------------------------------
# alpha: 1150000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.0293709739923145
# The root mean squared error is:  7.144087291452988
# The correlation is:  0.5173876835860547
# ----------------------------------------
# alpha: 1160000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.026622689532598
# The root mean squared error is:  7.133076434950699
# The correlation is:  0.5180624695333226
# ----------------------------------------
# alpha: 1170000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.023897207724061
# The root mean squared error is:  7.122180405097829
# The correlation is:  0.5187329657183491
# ----------------------------------------
# alpha: 1180000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.021194203575036
# The root mean squared error is:  7.111397542391702
# The correlation is:  0.5193992149344767
# ----------------------------------------
# alpha: 1190000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.018513358754294
# The root mean squared error is:  7.1007262211590945
# The correlation is:  0.5200612592153759
# ----------------------------------------
# alpha: 1200000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.0158543614185245
# The root mean squared error is:  7.090164848667668
# The correlation is:  0.5207191398525303
# ----------------------------------------
# alpha: 1210000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.013216906043544
# The root mean squared error is:  7.079711864260446
# The correlation is:  0.5213728974125991
# ----------------------------------------
# alpha: 1220000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.010600693262226
# The root mean squared error is:  7.0693657385227295
# The correlation is:  0.5220225717539622
# ----------------------------------------
# alpha: 1230000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.0080054297062375
# The root mean squared error is:  7.059124972470947
# The correlation is:  0.522668202043142
# ----------------------------------------
# alpha: 1240000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.005430827854096
# The root mean squared error is:  7.048988096772193
# The correlation is:  0.5233098267703806
# ----------------------------------------
# alpha: 1250000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.002876605882007
# The root mean squared error is:  7.03895367098168
# The correlation is:  0.5239474837652908
# ----------------------------------------
# alpha: 1260000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.000342487520533
# The root mean squared error is:  7.0290202828084185
# The correlation is:  0.5245812102117315
# ----------------------------------------
# alpha: 1270000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9978282019156115
# The root mean squared error is:  7.01918654740337
# The correlation is:  0.5252110426623258
# ----------------------------------------
# alpha: 1280000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9953334834933805
# The root mean squared error is:  7.009451106668246
# The correlation is:  0.5258370170526713
# ----------------------------------------
# alpha: 1290000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9928580718283913
# The root mean squared error is:  6.999812628583343
# The correlation is:  0.5264591687153161
# ----------------------------------------
# alpha: 1300000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9904017115175106
# The root mean squared error is:  6.990269806561492
# The correlation is:  0.5270775323929795
# ----------------------------------------
# alpha: 1310000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9879641520552527
# The root mean squared error is:  6.980821358813986
# The correlation is:  0.5276921422519523
# ----------------------------------------
# alpha: 1320000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9855451477155452
# The root mean squared error is:  6.971466027744584
# The correlation is:  0.5283030318944915
# ----------------------------------------
# alpha: 1330000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9831444574339083
# The root mean squared error is:  6.962202579351623
# The correlation is:  0.528910234371643
# ----------------------------------------
# alpha: 1340000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9807618446956523
# The root mean squared error is:  6.953029802656373
# The correlation is:  0.5295137821951005
# ----------------------------------------
# alpha: 1350000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9783970774264517
# The root mean squared error is:  6.943946509145433
# The correlation is:  0.5301137073489653
# ----------------------------------------
# alpha: 1360000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9760499278847723
# The root mean squared error is:  6.934951532225081
# The correlation is:  0.5307100413015426
# ----------------------------------------
# alpha: 1370000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9737201725595117
# The root mean squared error is:  6.926043726698807
# The correlation is:  0.5313028150163036
# ----------------------------------------
# alpha: 1380000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.971407592069578
# The root mean squared error is:  6.917221968256703
# The correlation is:  0.5318920589628188
# ----------------------------------------
# alpha: 1390000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9691119710661913
# The root mean squared error is:  6.908485152978986
# The correlation is:  0.5324778031274523
# ----------------------------------------
# alpha: 1400000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.966833098138102
# The root mean squared error is:  6.899832196854812
# The correlation is:  0.5330600770237337
# ----------------------------------------
# alpha: 1410000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.964570765719639
# The root mean squared error is:  6.891262035314627
# The correlation is:  0.5336389097024681
# ----------------------------------------
# alpha: 1420000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.962324770000862
# The root mean squared error is:  6.8827736227751535
# The correlation is:  0.5342143297616783
# ----------------------------------------
# alpha: 1430000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.960094910841491
# The root mean squared error is:  6.874365932200827
# The correlation is:  0.5347863653559852
# ----------------------------------------
# alpha: 1440000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9578809916855864
# The root mean squared error is:  6.8660379546725405
# The correlation is:  0.5353550442061892
# ----------------------------------------
# alpha: 1450000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9556828194792293
# The root mean squared error is:  6.857788698970406
# The correlation is:  0.5359203936084506
# ----------------------------------------
# alpha: 1460000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.953500204591369
# The root mean squared error is:  6.849617191171287
# The correlation is:  0.5364824404429979
# ----------------------------------------
# alpha: 1470000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9513329607355754
# The root mean squared error is:  6.84152247425336
# The correlation is:  0.5370412111829599
# ----------------------------------------
# alpha: 1480000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9491809048941255
# The root mean squared error is:  6.833503607712187
# The correlation is:  0.5375967319029326
# ----------------------------------------
# alpha: 1490000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9470438572456596
# The root mean squared error is:  6.8255596671923175
# The correlation is:  0.5381490282869514
# ----------------------------------------
# alpha: 1500000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9449216410918377
# The root mean squared error is:  6.817689744119621
# The correlation is:  0.5386981256370132
# ----------------------------------------
# alpha: 1510000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.942814082789518
# The root mean squared error is:  6.809892945354695
# The correlation is:  0.5392440488805069
# ----------------------------------------
# alpha: 1520000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.940721011681578
# The root mean squared error is:  6.802168392845558
# The correlation is:  0.5397868225782902
# ----------------------------------------
# alpha: 1530000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9386422600317825
# The root mean squared error is:  6.794515223297668
# The correlation is:  0.5403264709319171
# ----------------------------------------
# alpha: 1540000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.936577662960487
# The root mean squared error is:  6.786932587848274
# The correlation is:  0.5408630177910827
# ----------------------------------------
# alpha: 1550000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9345270583820575
# The root mean squared error is:  6.77941965175113
# The correlation is:  0.5413964866607333
# ----------------------------------------
# alpha: 1560000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.932490286943623
# The root mean squared error is:  6.771975594067722
# The correlation is:  0.5419269007081817
# ----------------------------------------
# alpha: 1570000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9304671919667507
# The root mean squared error is:  6.764599607371239
# The correlation is:  0.5424542827696758
# ----------------------------------------
# alpha: 1580000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.928457619388849
# The root mean squared error is:  6.7572908974524575
# The correlation is:  0.5429786553572972
# ----------------------------------------
# alpha: 1590000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.926461417707689
# The root mean squared error is:  6.750048683038685
# The correlation is:  0.5435000406652511
# ----------------------------------------
# alpha: 1600000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.924485137312322
# The root mean squared error is:  6.742872195515488
# The correlation is:  0.5440184605764087
# ----------------------------------------
# alpha: 1610000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9225288536364613
# The root mean squared error is:  6.735760678658117
# The correlation is:  0.5445339366684792
# ----------------------------------------
# alpha: 1620000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9205854585159186
# The root mean squared error is:  6.728713388373845
# The correlation is:  0.5450464902196995
# ----------------------------------------
# alpha: 1630000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9186548103917778
# The root mean squared error is:  6.721729592439428
# The correlation is:  0.5455561422153832
# ----------------------------------------
# alpha: 1640000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9167367700045563
# The root mean squared error is:  6.714808570259438
# The correlation is:  0.5460629133531112
# ----------------------------------------
# alpha: 1650000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.914831200344579
# The root mean squared error is:  6.707949612619324
# The correlation is:  0.5465668240487764
# ----------------------------------------
# alpha: 1660000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.912937966606041
# The root mean squared error is:  6.701152021452328
# The correlation is:  0.5470678944418566
# ----------------------------------------
# alpha: 1670000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9110569361409295
# The root mean squared error is:  6.694415109608181
# The correlation is:  0.5475661444008941
# ----------------------------------------
# alpha: 1680000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9091879784146624
# The root mean squared error is:  6.687738200629638
# The correlation is:  0.5480615935287184
# ----------------------------------------
# alpha: 1690000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.907330964962313
# The root mean squared error is:  6.681120628532679
# The correlation is:  0.5485542611676771
# ----------------------------------------
# alpha: 1700000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9054857693467535
# The root mean squared error is:  6.674561737595084
# The correlation is:  0.5490441664045281
# ----------------------------------------
# alpha: 1710000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.903652267116802
# The root mean squared error is:  6.6680608821469765
# The correlation is:  0.5495313280755025
# ----------------------------------------
# alpha: 1720000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9018303357672215
# The root mean squared error is:  6.661617426369059
# The correlation is:  0.5500157647710258
# ----------------------------------------
# alpha: 1730000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.9000198546993854
# The root mean squared error is:  6.655230744094981
# The correlation is:  0.5504974948404153
# ----------------------------------------
# alpha: 1740000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.8982207051834052
# The root mean squared error is:  6.648900218620152
# The correlation is:  0.5509765363963387
# ----------------------------------------
# alpha: 1750000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.8964784144504203
# The root mean squared error is:  6.642625242509916
# The correlation is:  0.5514529073196296
# ----------------------------------------
# alpha: 1760000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.894751893921602
# The root mean squared error is:  6.636405217418752
# The correlation is:  0.551926625263445
# ----------------------------------------
# alpha: 1770000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.893035944636178
# The root mean squared error is:  6.630239553911748
# The correlation is:  0.552397707657518
# ----------------------------------------
# alpha: 1780000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.891330459287423
# The root mean squared error is:  6.62412767128873
# The correlation is:  0.5528661717124519
# ----------------------------------------
# alpha: 1790000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.8896353321996746
# The root mean squared error is:  6.6180689974144356
# The correlation is:  0.5533320344237772
# ----------------------------------------
# alpha: 1800000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.887950459295617
# The root mean squared error is:  6.612062968549937
# The correlation is:  0.5537953125761574
# ----------------------------------------
# alpha: 1810000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.8862786902358883
# The root mean squared error is:  6.606109029196187
# The correlation is:  0.5542560227467778
# ----------------------------------------
# alpha: 1820000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.8846205723094562
# The root mean squared error is:  6.600206631926715
# The correlation is:  0.5547141813099834
# ----------------------------------------
# alpha: 1830000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.8829723867053834
# The root mean squared error is:  6.594355237241454
# The correlation is:  0.5551698044402503
# ----------------------------------------
# alpha: 1840000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.8813340355636594
# The root mean squared error is:  6.588554313409283
# The correlation is:  0.5556229081164327
# ----------------------------------------
# alpha: 1850000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.879705422472841
# The root mean squared error is:  6.582803336324401
# The correlation is:  0.5560735081250011
# ----------------------------------------
# alpha: 1860000
# ...
# The correlation is:  0.6207790218388837
# ----------------------------------------
# alpha: 5400000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.640329913464064
# The root mean squared error is:  5.942095564072901
# The correlation is:  0.6208001132307763
# ----------------------------------------
# alpha: 5410000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6401503816750456
# The root mean squared error is:  5.941980829170538
# The correlation is:  0.620820689858148
# ----------------------------------------
# alpha: 5420000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6399717759695993
# The root mean squared error is:  5.941869715751324
# The correlation is:  0.6208407540216674
# ----------------------------------------
# alpha: 5430000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6397940930468033
# The root mean squared error is:  5.941762201098397
# The correlation is:  0.6208603080135352
# ----------------------------------------
# alpha: 5440000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6396173296225696
# The root mean squared error is:  5.941658262637792
# The correlation is:  0.6208793541176014
# ----------------------------------------
# alpha: 5450000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6394414824294694
# The root mean squared error is:  5.94155787793736
# The correlation is:  0.6208978946093976
# ----------------------------------------
# alpha: 5460000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.639266548216902
# The root mean squared error is:  5.941461024706113
# The correlation is:  0.6209159317561003
# ----------------------------------------
# alpha: 5470000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6390925237508847
# The root mean squared error is:  5.941367680793109
# The correlation is:  0.6209334678165795
# ----------------------------------------
# alpha: 5480000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.638919405813977
# The root mean squared error is:  5.941277824186555
# The correlation is:  0.6209505050414036
# ----------------------------------------
# alpha: 5490000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.63874719120492
# The root mean squared error is:  5.941191433012437
# The correlation is:  0.6209670456729327
# ----------------------------------------
# alpha: 5500000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.638575876738958
# The root mean squared error is:  5.941108485534168
# The correlation is:  0.6209830919452347
# ----------------------------------------
# alpha: 5510000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6384054592468966
# The root mean squared error is:  5.941028960150551
# The correlation is:  0.6209986460842946
# ----------------------------------------
# alpha: 5520000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.638235935576347
# The root mean squared error is:  5.940952835396516
# The correlation is:  0.6210137103077475
# ----------------------------------------
# alpha: 5530000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6380673025901755
# The root mean squared error is:  5.940880089940371
# The correlation is:  0.62102828682521
# ----------------------------------------
# alpha: 5540000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6378995571674806
# The root mean squared error is:  5.9408107025842485
# The correlation is:  0.6210423778380677
# ----------------------------------------
# alpha: 5550000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6377326962026597
# The root mean squared error is:  5.940744652262089
# The correlation is:  0.6210559855396862
# ----------------------------------------
# alpha: 5560000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6375667166056185
# The root mean squared error is:  5.940681918039156
# The correlation is:  0.621069112115357
# ----------------------------------------
# alpha: 5570000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.637401615302227
# The root mean squared error is:  5.940622479111813
# The correlation is:  0.6210817597422025
# ----------------------------------------
# alpha: 5580000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.63723738923328
# The root mean squared error is:  5.940566314805421
# The correlation is:  0.6210939305894022
# ----------------------------------------
# alpha: 5590000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.637074035355035
# The root mean squared error is:  5.94051340457428
# The correlation is:  0.6211056268180795
# ----------------------------------------
# alpha: 5600000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6369115506386396
# The root mean squared error is:  5.940463728000107
# The correlation is:  0.6211168505814192
# ----------------------------------------
# alpha: 5610000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6367499320702814
# The root mean squared error is:  5.940417264791478
# The correlation is:  0.6211276040246495
# ----------------------------------------
# alpha: 5620000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6365891766514205
# The root mean squared error is:  5.940373994783387
# The correlation is:  0.621137889284977
# ----------------------------------------
# alpha: 5630000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.636429281397806
# The root mean squared error is:  5.940333897935249
# The correlation is:  0.6211477084918107
# ----------------------------------------
# alpha: 5640000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6362702433404896
# The root mean squared error is:  5.94029695433141
# The correlation is:  0.6211570637665458
# ----------------------------------------
# alpha: 5650000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6361120595246614
# The root mean squared error is:  5.9402631441789815
# The correlation is:  0.621165957222813
# ----------------------------------------
# alpha: 5660000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6359547270100663
# The root mean squared error is:  5.9402324478076345
# The correlation is:  0.6211743909663874
# ----------------------------------------
# alpha: 5670000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.635798242871206
# The root mean squared error is:  5.940204845669118
# The correlation is:  0.621182367095154
# ----------------------------------------
# alpha: 5680000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6356426041965153
# The root mean squared error is:  5.940180318335487
# The correlation is:  0.6211898876992872
# ----------------------------------------
# alpha: 5690000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6354878080888193
# The root mean squared error is:  5.940158846499019
# The correlation is:  0.621196954861145
# ----------------------------------------
# alpha: 5700000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6353338516648566
# The root mean squared error is:  5.9401404109708675
# The correlation is:  0.621203570655384
# ----------------------------------------
# alpha: 5710000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6351807320559564
# The root mean squared error is:  5.940124992681199
# The correlation is:  0.6212097371488167
# ----------------------------------------
# alpha: 5720000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6350284464066003
# The root mean squared error is:  5.940112572676759
# The correlation is:  0.6212154564007143
# ----------------------------------------
# alpha: 5730000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6348769918755415
# The root mean squared error is:  5.9401031321215045
# The correlation is:  0.6212207304625794
# ----------------------------------------
# alpha: 5740000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6347263656352817
# The root mean squared error is:  5.940096652295326
# The correlation is:  0.6212255613782539
# ----------------------------------------
# alpha: 5750000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.634576564871731
# The root mean squared error is:  5.940093114592926
# The correlation is:  0.6212299511839968
# ----------------------------------------
# alpha: 5760000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  3.6344275867846867
# The root mean squared error is:  5.9400925005237015
# The correlation is:  0.6212339019083936
# ----------------------------------------
# alpha: 5770000
# alpha: 5780000
# alpha: 5790000
# alpha: 5800000
# alpha: 5810000
# alpha: 5820000
# alpha: 5830000
# alpha: 5840000
# alpha: 5850000
# alpha: 5860000
# alpha: 5870000
# alpha: 5880000
# alpha: 5890000
# alpha: 5900000
# alpha: 5910000
# alpha: 5920000
# alpha: 5930000
# alpha: 5940000
# alpha: 5950000
# alpha: 5960000
# alpha: 5970000
# alpha: 5980000
# alpha: 5990000
# alpha: 6000000
# alpha: 6010000
# alpha: 6020000
# alpha: 6030000
# alpha: 6040000
# alpha: 6050000
# alpha: 6060000
# alpha: 6070000
# alpha: 6080000
# alpha: 6090000
# alpha: 6100000
# alpha: 6110000
# alpha: 6120000
# alpha: 6130000
# alpha: 6140000
# alpha: 6150000
# alpha: 6160000
# alpha: 6170000
# alpha: 6180000
# alpha: 6190000
# alpha: 6200000
# alpha: 6210000
# alpha: 6220000
# alpha: 6230000
# alpha: 6240000
# alpha: 6250000
# alpha: 6260000
# alpha: 6270000
# alpha: 6280000
# alpha: 6290000
# alpha: 6300000
# alpha: 6310000
# alpha: 6320000
# alpha: 6330000
# alpha: 6340000
# alpha: 6350000
# alpha: 6360000
# alpha: 6370000
# alpha: 6380000
# alpha: 6390000
# alpha: 6400000
# alpha: 6410000
# alpha: 6420000
# alpha: 6430000
# alpha: 6440000
# alpha: 6450000
# alpha: 6460000
# alpha: 6470000
# alpha: 6480000
# alpha: 6490000
# alpha: 6500000
# alpha: 6510000
# alpha: 6520000
# alpha: 6530000
# alpha: 6540000
# alpha: 6550000
# alpha: 6560000
# alpha: 6570000
# alpha: 6580000
# alpha: 6590000
# alpha: 6600000
# alpha: 6610000
# alpha: 6620000
# alpha: 6630000
# alpha: 6640000
# alpha: 6650000
# alpha: 6660000
# alpha: 6670000
# alpha: 6680000
# alpha: 6690000
# alpha: 6700000
# alpha: 6710000
# alpha: 6720000
# alpha: 6730000
# alpha: 6740000
# alpha: 6750000
# alpha: 6760000
# alpha: 6770000
# alpha: 6780000
# alpha: 6790000
# alpha: 6800000
# alpha: 6810000
# alpha: 6820000
# alpha: 6830000
# alpha: 6840000
# alpha: 6850000
# alpha: 6860000
# alpha: 6870000
# alpha: 6880000
# alpha: 6890000
# alpha: 6900000
# alpha: 6910000
# alpha: 6920000
# alpha: 6930000
# alpha: 6940000
# alpha: 6950000
# alpha: 6960000
# alpha: 6970000
# alpha: 6980000
# alpha: 6990000
# alpha: 7000000
# alpha: 7010000
# alpha: 7020000
# alpha: 7030000
# alpha: 7040000
# alpha: 7050000
# alpha: 7060000
# alpha: 7070000
# alpha: 7080000
# alpha: 7090000
# alpha: 7100000
# alpha: 7110000
# alpha: 7120000
# alpha: 7130000
# alpha: 7140000
# alpha: 7150000
# alpha: 7160000
# alpha: 7170000
# alpha: 7180000
# alpha: 7190000
# alpha: 7200000
# alpha: 7210000
# alpha: 7220000
# alpha: 7230000
# alpha: 7240000
# alpha: 7250000
# alpha: 7260000
# alpha: 7270000
# alpha: 7280000
# alpha: 7290000
# alpha: 7300000
# alpha: 7310000
# alpha: 7320000
# alpha: 7330000
# alpha: 7340000
# alpha: 7350000
# alpha: 7360000
# alpha: 7370000
# alpha: 7380000
# alpha: 7390000
# alpha: 7400000
# alpha: 7410000
# alpha: 7420000
# alpha: 7430000
# alpha: 7440000
# alpha: 7450000
# alpha: 7460000
# alpha: 7470000
# alpha: 7480000
# alpha: 7490000
# alpha: 7500000
# alpha: 7510000
# alpha: 7520000
# alpha: 7530000
# alpha: 7540000
# alpha: 7550000
# alpha: 7560000
# alpha: 7570000
# alpha: 7580000
# alpha: 7590000
# alpha: 7600000
# alpha: 7610000
# alpha: 7620000
# alpha: 7630000
# alpha: 7640000
# alpha: 7650000
# alpha: 7660000
# alpha: 7670000
# alpha: 7680000
# alpha: 7690000
# alpha: 7700000
# alpha: 7710000
# alpha: 7720000
# alpha: 7730000
# alpha: 7740000
# alpha: 7750000
# alpha: 7760000
# alpha: 7770000
# alpha: 7780000
# alpha: 7790000
# alpha: 7800000
# alpha: 7810000
# alpha: 7820000
# alpha: 7830000
# alpha: 7840000
# alpha: 7850000
# alpha: 7860000
# alpha: 7870000
# alpha: 7880000
# alpha: 7890000
# alpha: 7900000
# alpha: 7910000
# alpha: 7920000
# alpha: 7930000
# alpha: 7940000
# alpha: 7950000
# alpha: 7960000
# alpha: 7970000
# alpha: 7980000
# alpha: 7990000
# alpha: 8000000
# alpha: 8010000
# alpha: 8020000
# alpha: 8030000
# alpha: 8040000
# alpha: 8050000
# alpha: 8060000
# alpha: 8070000
# alpha: 8080000
# alpha: 8090000
# alpha: 8100000
# alpha: 8110000
# alpha: 8120000
# alpha: 8130000
# alpha: 8140000
# alpha: 8150000
# alpha: 8160000
# alpha: 8170000
# alpha: 8180000
# alpha: 8190000
# alpha: 8200000
# alpha: 8210000
# alpha: 8220000
# alpha: 8230000
# alpha: 8240000
# alpha: 8250000
# alpha: 8260000
# alpha: 8270000
# alpha: 8280000
# alpha: 8290000
# alpha: 8300000
# alpha: 8310000
# alpha: 8320000
# alpha: 8330000
# alpha: 8340000
# alpha: 8350000
# alpha: 8360000
# alpha: 8370000
# alpha: 8380000
# alpha: 8390000
# alpha: 8400000
# alpha: 8410000
# alpha: 8420000
# alpha: 8430000
# alpha: 8440000
# alpha: 8450000
# alpha: 8460000
# alpha: 8470000
# alpha: 8480000
# alpha: 8490000
# alpha: 8500000
# alpha: 8510000
# alpha: 8520000
# alpha: 8530000
# alpha: 8540000
# alpha: 8550000
# alpha: 8560000
# alpha: 8570000
# alpha: 8580000
# alpha: 8590000
# alpha: 8600000
# alpha: 8610000
# alpha: 8620000
# alpha: 8630000
# alpha: 8640000
# alpha: 8650000
# alpha: 8660000
# alpha: 8670000
# alpha: 8680000
# alpha: 8690000
# alpha: 8700000
# alpha: 8710000
# alpha: 8720000
# alpha: 8730000
# alpha: 8740000
# alpha: 8750000
# alpha: 8760000
# alpha: 8770000
# alpha: 8780000
# alpha: 8790000
# alpha: 8800000
# alpha: 8810000
# alpha: 8820000
# alpha: 8830000
# alpha: 8840000
# alpha: 8850000
# alpha: 8860000
# alpha: 8870000
# alpha: 8880000
# alpha: 8890000
# alpha: 8900000
# alpha: 8910000
# alpha: 8920000
# alpha: 8930000
# alpha: 8940000
# alpha: 8950000
# alpha: 8960000
# alpha: 8970000
# alpha: 8980000
# alpha: 8990000
# alpha: 9000000
# alpha: 9010000
# alpha: 9020000
# alpha: 9030000
# alpha: 9040000
# alpha: 9050000
# alpha: 9060000
# alpha: 9070000
# alpha: 9080000
# alpha: 9090000
# alpha: 9100000
# alpha: 9110000
# alpha: 9120000
# alpha: 9130000
# alpha: 9140000
# alpha: 9150000
# alpha: 9160000
# alpha: 9170000
# alpha: 9180000
# alpha: 9190000
# alpha: 9200000
# alpha: 9210000
# alpha: 9220000
# alpha: 9230000
# alpha: 9240000
# alpha: 9250000
# alpha: 9260000
# alpha: 9270000
# alpha: 9280000
# alpha: 9290000
# alpha: 9300000
# alpha: 9310000
# alpha: 9320000
# alpha: 9330000
# alpha: 9340000
# alpha: 9350000
# alpha: 9360000
# alpha: 9370000
# alpha: 9380000
# alpha: 9390000
# alpha: 9400000
# alpha: 9410000
# alpha: 9420000
# alpha: 9430000
# alpha: 9440000
# alpha: 9450000
# alpha: 9460000
# alpha: 9470000
# alpha: 9480000
# alpha: 9490000
# alpha: 9500000
# alpha: 9510000
# alpha: 9520000
# alpha: 9530000
# alpha: 9540000
# alpha: 9550000
# alpha: 9560000
# alpha: 9570000
# alpha: 9580000
# alpha: 9590000
# alpha: 9600000
# alpha: 9610000
# alpha: 9620000
# alpha: 9630000
# alpha: 9640000
# alpha: 9650000
# alpha: 9660000
# alpha: 9670000
# alpha: 9680000
# alpha: 9690000
# alpha: 9700000
# alpha: 9710000
# alpha: 9720000
# alpha: 9730000
# alpha: 9740000
# alpha: 9750000
# alpha: 9760000
# alpha: 9770000
# alpha: 9780000
# alpha: 9790000
# alpha: 9800000
# alpha: 9810000
# alpha: 9820000
# alpha: 9830000
# alpha: 9840000
# alpha: 9850000
# alpha: 9860000
# alpha: 9870000
# alpha: 9880000
# alpha: 9890000
# alpha: 9900000
# alpha: 9910000
# alpha: 9920000
# alpha: 9930000
# alpha: 9940000
# alpha: 9950000
# alpha: 9960000
# alpha: 9970000
# alpha: 9980000
# alpha: 9990000

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.3, 154 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train2_X2,train2_y,test2_X2,test2_y))

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.4, 105 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train2_X3,train2_y,test2_X3,test2_y))

# %%
## tuned alpha based on validation set, then measure the performance for test set.
## Fixing l1-ratio = 0.3
para = [0,5760000]
rmse=100000
mae=1000000
corr=0
for a in para:
    print('alpha:',a)
    rmse0,mae0,corr0 = ridge(a,train1_X1,train1_y,val1_X1,val1_y)
    if rmse0< rmse:
        rmse=rmse0
        mae=mae0
        corr = corr0
        print('========================================')
        print('Best RMSE is updated! ' )
        print('The mean absolute error is: ',mae)
        print('The root mean squared error is: ',rmse)
        print('The correlation is: ',corr)
        print('----------------------------------------')
# Out:
# alpha: 0
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.73847737393675
# The root mean squared error is:  45.95805279347588
# The correlation is:  0.7576646272128535
# ----------------------------------------
# alpha: 5760000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  21.35787124172689
# The root mean squared error is:  39.43994758867146
# The correlation is:  0.8886819918013812
# ----------------------------------------
