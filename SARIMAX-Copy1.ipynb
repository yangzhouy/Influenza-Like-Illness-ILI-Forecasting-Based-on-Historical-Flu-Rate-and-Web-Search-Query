# %% [markdown]
# ## The Process
# ### 1. visualize the data
# ### 2. stationarize the time series
# ### 3. plot ACF/PACF
# ### 4. build the ARIMA
# ### 5. make the prediction
#
# ### reference: http://www.seanabu.com/2016/03/22/time-series-seasonal-ARIMA-model-in-python/

# %%
# import libraries
import numpy as np
import pandas as pd
import random
import csv
import scipy.stats as stats
import seaborn as sns
from collections import Counter
from collections import defaultdict
import math
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from random import randint

import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm
from statsmodels.nonparametric.kde import KDEUnivariate
from statsmodels.nonparametric import smoothers_lowess
from pandas import Series, DataFrame
from patsy import dmatrices
from sklearn import datasets, svm

# initialize the plotting sizes
# set size
plt.rc('figure', figsize=(15, 8))
# subplots size
fizsize_with_subplots = (15, 8)
# histogram size
bin_size = 10

# %%
dates = pd.read_csv('data/dates.csv',header=None)
queries = pd.read_csv('data/queries.csv',header=None)
X = pd.read_csv('data/X.csv',header=None)
y = pd.read_csv('data/y.csv',header=None)

# %%
dates['Date'] = pd.to_datetime(dates[0])
y.set_index(dates['Date'],inplace=True)
X.set_index(dates['Date'],inplace=True)

# %%
# data preprocessing and train-test split
# this data is well formed with no missing value and other symbols or labels that are non numerical.
# splitting the data into train and test

# Here we want the first 500 queries
X = X.iloc[:, 0: 500]

# first with the last year as test
# for convinience, pick the two validation set starting from 1/3 and 2/3 of the training set,
# 10% of training set as validation, here use 400 data points, two 200 periods.
test_size =365
length = X.shape[0]
l =(X.shape[0]-test_size)//3

train1_X = pd.concat([X[0:l],X[l+200:2*l],X[2*l+200:length-test_size]])
val1_X = pd.concat([X[l:l+200],X[2*l:2*l+200]])
train1_y = pd.concat([y[0:l],y[l+200:2*l],y[2*l+200:length-test_size]])
val1_y = pd.concat([y[l:l+200],y[2*l:2*l+200]])
test1_X = X[length-test_size:]
test1_y = y[length-test_size:]

#without validation set
train1_X2 = X[0:length-test_size]
train1_y2 = y[0:length-test_size]


# second with the last 2 year as test
test_size2 =365*2
l2 =(X.shape[0]-test_size2)//3

train2_X = pd.concat([X[0:l2],X[l2+180:2*l2],X[2*l2+180:length-test_size2]])
val2_X = pd.concat([X[l2:l2+180],X[2*l2:2*l2+180]])
train2_y = pd.concat([y[0:l2],y[l2+180:2*l2],y[2*l2+180:length-test_size2]])
val2_y = pd.concat([y[l2:l2+180],y[2*l2:2*l2+180]])
test2_X = X[length-test_size2:length-test_size]
test2_y = y[length-test_size2:length-test_size]

#without validation set
train2_X2 = X[0:length-test_size2]
train2_y2 = y[0:length-test_size2]

print('X shape: ',X.shape,'  y shape: ',y.shape)
print('train1 X:',train1_X.shape,' train1 y:',train1_y.shape,' Test1 X shape:',test1_X.shape, ' Test1 y shape:',test1_y.shape)
print('validation1 X:',val1_X.shape,' validation1 y:',val1_y.shape)
print('train2 X:',train2_X.shape,' train2 y:',train2_y.shape,' Test2 X:',test2_X.shape,' Test2 y:',test2_y.shape)
print('validation2 X:',val2_X.shape,' validation2 y:',val2_y.shape)
# Out:
# X shape:  (4383, 500)   y shape:  (4383, 1)
# train1 X: (3618, 500)  train1 y: (3618, 1)  Test1 X shape: (365, 500)  Test1 y shape: (365, 1)
# validation1 X: (400, 500)  validation1 y: (400, 1)
# train2 X: (3293, 500)  train2 y: (3293, 1)  Test2 X: (365, 500)  Test2 y: (365, 1)
# validation2 X: (360, 500)  validation2 y: (360, 1)

# %% [markdown]
# ## First use the last 365 days as test set

# %%
from statsmodels.tsa.stattools import adfuller
df = y.copy()
df['y']=y.values
def test_stationarity(timeseries):

    #Determing rolling statistics
    rolmean = timeseries.rolling(window=30,center=False).mean()
    rolstd = timeseries.rolling(window=30,center=False).std()

    #Plot rolling statistics:
    fig = plt.figure(figsize=(12, 8))
    orig = plt.plot(timeseries, color='blue',label='Original')
    mean = plt.plot(rolmean, color='red', label='Rolling Mean')
    std = plt.plot(rolstd, color='black', label = 'Rolling Std')
    plt.legend(loc='best')
    plt.title('Rolling Mean & Standard Deviation')
    plt.show()
    
    #Perform Dickey-Fuller test:
    print ('Results of Dickey-Fuller Test:')
    dftest = adfuller(timeseries, autolag='AIC')
    dfoutput = pd.Series(dftest[0:4], index=['Test Statistic','p-value','#Lags Used','Number of Observations Used'])
    for key,value in dftest[4].items():
        dfoutput['Critical Value (%s)'%key] = value
    print(dfoutput)

# %%
test_stationarity(df.y)
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -7.356968e+00
# p-value                        9.722981e-11
# #Lags Used                     3.100000e+01
# Number of Observations Used    4.351000e+03
# Critical Value (1%)           -3.431854e+00
# Critical Value (5%)           -2.862205e+00
# Critical Value (10%)          -2.567124e+00
# dtype: float64

# %%
# take a first difference of the data, remove the overall trend
df['first_dif'] = df.y-df.y.shift(1)
test_stationarity(df.first_dif.dropna(inplace=False))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.294262e+01
# p-value                        3.508763e-24
# #Lags Used                     3.100000e+01
# Number of Observations Used    4.350000e+03
# Critical Value (1%)           -3.431854e+00
# Critical Value (5%)           -2.862205e+00
# Critical Value (10%)          -2.567124e+00
# dtype: float64

# %%
# remove the seasonality
df['seasonal_dif'] = df.y-df.y.shift(12)
test_stationarity(df.seasonal_dif.dropna(inplace=False))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.161143e+01
# p-value                        2.507599e-21
# #Lags Used                     3.100000e+01
# Number of Observations Used    4.339000e+03
# Critical Value (1%)           -3.431858e+00
# Critical Value (5%)           -2.862206e+00
# Critical Value (10%)          -2.567125e+00
# dtype: float64

# %%
# take a first difference of seasonal difference
df['seasonal_first_dif'] = df.first_dif - df.first_dif.shift(12)
test_stationarity(df.seasonal_first_dif.dropna(inplace=False))
# Out:
# Results of Dickey-Fuller Test:
# Test Statistic                -1.765380e+01
# p-value                        3.709482e-30
# #Lags Used                     3.000000e+01
# Number of Observations Used    4.339000e+03
# Critical Value (1%)           -3.431858e+00
# Critical Value (5%)           -2.862206e+00
# Critical Value (10%)          -2.567125e+00
# dtype: float64

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(211)
fig = sm.graphics.tsa.plot_acf(df.seasonal_first_dif.iloc[13:], lags=50, ax=ax1)
ax2 = fig.add_subplot(212)
fig = sm.graphics.tsa.plot_pacf(df.seasonal_first_dif.iloc[13:], lags=50, ax=ax2)

# %%
# the 3 queries 
df3 = train1_X2.iloc[:, 0: 3].copy()
df4 = test1_X.iloc[:,0:3].copy()

# %%
p_values = [0,1]
d_values = [1,2]
q_values = [13,14]
P_v=[0,1]
D_v=[0,1]
Q_v=[0,1]
s_v=[0,7,12]
train_X=df3
test_X=df4
best_score=1000000000
p0=0
d0=0
q0=0
P0=0
D0=0
Q0=0
s0=0
param_best=list()
for p in p_values:
    for d in d_values:
        for q in q_values:
            for P in P_v:
                for D in D_v:
                    for Q in Q_v:
                        for s in s_v:
                            try:
                                model = sm.tsa.statespace.SARIMAX(endog =train1_y2.values,
                                                                  exog=train_X,
                                                                  trend='n', order=(p,d,q),
                                                                  seasonal_order=(P,D,Q,s),
                                                                  enforce_stationarity=False,
                                                                  enforce_invertibility=False)
                                model_fit = model.fit()
                                aic = model_fit.aic
                                print('(',p,',',d,',',q,'),(',P,',',D,',',Q,',',s,') AIC:',aic)
                                
                                if aic < best_score:
                                    best_score = aic
                                    param_best = model_fit().params
                                    p0=p
                                    d0=d
                                    q0=q
                                    P0=P
                                    D0=D
                                    Q0=Q
                                    s0=s
                                
                            except:
                                continue
print('Best SARIMA (',p0,',',d0,',',q0,'),(',P0,',',D0,',',Q0,',',s0,') AIC:', best_score)
print(param_best)
# Out:
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 1 , 13 ),( 0 , 0 , 0 , 0 ) AIC: 4049.936667301583
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 1 , 13 ),( 0 , 0 , 0 , 7 ) AIC: 4049.936667301583
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 1 , 13 ),( 0 , 0 , 0 , 12 ) AIC: 4049.936667301583
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 13 ),( 0 , 0 , 1 , 0 ) AIC: 5930.060845632885
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 1 , 13 ),( 0 , 0 , 1 , 7 ) AIC: 4379.669166103715
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 13 ),( 0 , 0 , 1 , 12 ) AIC: 4616.665815384689
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 13 ),( 0 , 1 , 0 , 7 ) AIC: 6266.52422495958
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 13 ),( 0 , 1 , 0 , 12 ) AIC: 7606.224873741564
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 13 ),( 0 , 1 , 1 , 7 ) AIC: 5683.509223560736
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 13 ),( 0 , 1 , 1 , 12 ) AIC: 6726.616772879761
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 13 ),( 1 , 0 , 0 , 0 ) AIC: 6078.9398698093555
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 13 ),( 1 , 0 , 0 , 7 ) AIC: 4383.175515849488
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 13 ),( 1 , 0 , 0 , 12 ) AIC: 4615.360918909719
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 13 ),( 1 , 0 , 1 , 0 ) AIC: 5435.686616337505
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 13 ),( 1 , 0 , 1 , 7 ) AIC: 4274.370945731536
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 13 ),( 1 , 0 , 1 , 12 ) AIC: 4620.950824014963
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 1 , 13 ),( 1 , 1 , 0 , 7 ) AIC: 5338.521017566549
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 13 ),( 1 , 1 , 0 , 12 ) AIC: 6706.7015175665965
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 1 , 13 ),( 1 , 1 , 1 , 7 ) AIC: 5345.41442123786
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 13 ),( 1 , 1 , 1 , 12 ) AIC: 8518.901009332512
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 14 ),( 0 , 0 , 0 , 0 ) AIC: 4530.022607385947
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 14 ),( 0 , 0 , 0 , 7 ) AIC: 4530.022607385947
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 14 ),( 0 , 0 , 0 , 12 ) AIC: 4530.022607385947
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 1 , 14 ),( 0 , 0 , 1 , 0 ) AIC: 4710.115572752973
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 14 ),( 0 , 0 , 1 , 7 ) AIC: 4453.463417826533
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 14 ),( 0 , 0 , 1 , 12 ) AIC: 4085.3716460353967
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 14 ),( 0 , 1 , 0 , 7 ) AIC: 7102.7282486068325
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 1 , 14 ),( 0 , 1 , 0 , 12 ) AIC: 6626.180520225468
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 14 ),( 0 , 1 , 1 , 7 ) AIC: 6873.4493780585
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 1 , 14 ),( 0 , 1 , 1 , 12 ) AIC: 5822.456404265395
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 1 , 14 ),( 1 , 0 , 0 , 0 ) AIC: 6110.2367865780925
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 14 ),( 1 , 0 , 0 , 7 ) AIC: 4926.803322779242
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 14 ),( 1 , 0 , 0 , 12 ) AIC: 4106.276743425063
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 14 ),( 1 , 0 , 1 , 0 ) AIC: 6179.750266481433
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 1 , 14 ),( 1 , 0 , 1 , 7 ) AIC: 4420.377941683559
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 1 , 14 ),( 1 , 0 , 1 , 12 ) AIC: 4084.9861231586183
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 14 ),( 1 , 1 , 0 , 7 ) AIC: 6995.807562975044
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 1 , 14 ),( 1 , 1 , 0 , 12 ) AIC: 6400.330011450356
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 14 ),( 1 , 1 , 1 , 7 ) AIC: 6947.984668041585
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 14 ),( 1 , 1 , 1 , 12 ) AIC: 6174.334708999948
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 13 ),( 0 , 0 , 0 , 0 ) AIC: 4429.4200936204115
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 13 ),( 0 , 0 , 0 , 7 ) AIC: 4429.4200936204115
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 13 ),( 0 , 0 , 0 , 12 ) AIC: 4429.4200936204115
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 13 ),( 0 , 0 , 1 , 0 ) AIC: 4431.818683173394
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 13 ),( 0 , 0 , 1 , 7 ) AIC: 4479.977800624981
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 13 ),( 0 , 0 , 1 , 12 ) AIC: 4435.064469372081
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 13 ),( 0 , 1 , 0 , 7 ) AIC: 5263.974098257878
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 2 , 13 ),( 0 , 1 , 0 , 12 ) AIC: 5652.92214360332
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 13 ),( 0 , 1 , 1 , 7 ) AIC: 4523.883689622318
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 2 , 13 ),( 0 , 1 , 1 , 12 ) AIC: 5931.348876076582
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 13 ),( 1 , 0 , 0 , 0 ) AIC: 4431.958515130926
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 2 , 13 ),( 1 , 0 , 0 , 7 ) AIC: 4453.884515696154
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 13 ),( 1 , 0 , 0 , 12 ) AIC: 4434.482949951081
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 13 ),( 1 , 0 , 1 , 0 ) AIC: 4433.820613989528
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 13 ),( 1 , 0 , 1 , 7 ) AIC: 3751.9643564184144
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 13 ),( 1 , 0 , 1 , 12 ) AIC: 4437.266479426518
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 13 ),( 1 , 1 , 0 , 7 ) AIC: 5185.795580296638
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 13 ),( 1 , 1 , 0 , 12 ) AIC: 6202.149139786363
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 13 ),( 1 , 1 , 1 , 7 ) AIC: 4419.766890024339
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 13 ),( 1 , 1 , 1 , 12 ) AIC: 6042.403200716231
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 14 ),( 0 , 0 , 0 , 0 ) AIC: 3545.5745378754473
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 14 ),( 0 , 0 , 0 , 7 ) AIC: 3545.5745378754473
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 14 ),( 0 , 0 , 0 , 12 ) AIC: 3545.5745378754473
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 2 , 14 ),( 0 , 0 , 1 , 0 ) AIC: 3442.11119240007
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 14 ),( 0 , 0 , 1 , 7 ) AIC: 3551.0928787942885
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 14 ),( 0 , 0 , 1 , 12 ) AIC: 3464.122404267203
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 2 , 14 ),( 0 , 1 , 0 , 7 ) AIC: 6044.1078573995765
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 2 , 14 ),( 0 , 1 , 0 , 12 ) AIC: 5853.548806181783
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 2 , 14 ),( 0 , 1 , 1 , 7 ) AIC: 4085.1419511115737
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 14 ),( 0 , 1 , 1 , 12 ) AIC: 5986.4804366575545
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 14 ),( 1 , 0 , 0 , 0 ) AIC: 3442.6126623406512
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 14 ),( 1 , 0 , 0 , 7 ) AIC: 3527.1968113045036
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 14 ),( 1 , 0 , 0 , 12 ) AIC: 3435.835509302441
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 14 ),( 1 , 0 , 1 , 0 ) AIC: 3445.3121678792904
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 14 ),( 1 , 0 , 1 , 7 ) AIC: 3447.37945840057
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 14 ),( 1 , 0 , 1 , 12 ) AIC: 3462.354250983144
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 14 ),( 1 , 1 , 0 , 7 ) AIC: 5808.1620296039955
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 14 ),( 1 , 1 , 0 , 12 ) AIC: 6242.731575355721
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 2 , 14 ),( 1 , 1 , 1 , 7 ) AIC: 3924.383767191532
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 2 , 14 ),( 1 , 1 , 1 , 12 ) AIC: 6384.075243554542
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 13 ),( 0 , 0 , 0 , 0 ) AIC: 4493.456889113037
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 13 ),( 0 , 0 , 0 , 7 ) AIC: 4493.456889113037
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 13 ),( 0 , 0 , 0 , 12 ) AIC: 4493.456889113037
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 1 , 13 ),( 0 , 0 , 1 , 0 ) AIC: 5776.121183414044
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 13 ),( 0 , 0 , 1 , 7 ) AIC: 4282.016623195106
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 13 ),( 0 , 0 , 1 , 12 ) AIC: 4495.760003226495
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 13 ),( 0 , 1 , 0 , 7 ) AIC: 5418.559227314313
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 1 , 13 ),( 0 , 1 , 0 , 12 ) AIC: 5458.562723928158
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 13 ),( 0 , 1 , 1 , 7 ) AIC: 5102.017556139324
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 13 ),( 0 , 1 , 1 , 12 ) AIC: 5209.1146287387255
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 13 ),( 1 , 0 , 0 , 0 ) AIC: 6778.879582868184
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 1 , 13 ),( 1 , 0 , 0 , 7 ) AIC: 4342.367358675947
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 13 ),( 1 , 0 , 0 , 12 ) AIC: 4503.771225216656
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 1 , 13 ),( 1 , 0 , 1 , 0 ) AIC: 5555.0822339269
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 13 ),( 1 , 0 , 1 , 7 ) AIC: 4251.659796770437
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 13 ),( 1 , 0 , 1 , 12 ) AIC: 4493.642172553839
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 13 ),( 1 , 1 , 0 , 7 ) AIC: 5298.370526791534
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 13 ),( 1 , 1 , 0 , 12 ) AIC: 5590.8078381163705
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 13 ),( 1 , 1 , 1 , 7 ) AIC: 5237.067086491149
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 13 ),( 1 , 1 , 1 , 12 ) AIC: 5303.781084741534
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 14 ),( 0 , 0 , 0 , 0 ) AIC: 4099.166393826734
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 14 ),( 0 , 0 , 0 , 7 ) AIC: 4099.166393826734
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 14 ),( 0 , 0 , 0 , 12 ) AIC: 4099.166393826734
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 14 ),( 0 , 0 , 1 , 0 ) AIC: 5471.652512609649
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 14 ),( 0 , 0 , 1 , 7 ) AIC: 3694.1694541950847
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 1 , 14 ),( 0 , 0 , 1 , 12 ) AIC: 4092.9505082763894
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ...
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 13 ),( 0 , 0 , 0 , 12 ) AIC: 4430.802285678875
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 13 ),( 0 , 0 , 1 , 0 ) AIC: 4433.222277865535
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 13 ),( 0 , 0 , 1 , 7 ) AIC: 4481.812462897882
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 13 ),( 0 , 0 , 1 , 12 ) AIC: 4436.429053904436
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 13 ),( 0 , 1 , 0 , 7 ) AIC: 5265.961536103602
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 13 ),( 0 , 1 , 0 , 12 ) AIC: 5768.768325845419
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 13 ),( 0 , 1 , 1 , 7 ) AIC: 4525.860294794398
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 2 , 13 ),( 0 , 1 , 1 , 12 ) AIC: 5980.505051345848
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 13 ),( 1 , 0 , 0 , 0 ) AIC: 4433.385785251251
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 13 ),( 1 , 0 , 0 , 7 ) AIC: 4455.048301980355
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 13 ),( 1 , 0 , 0 , 12 ) AIC: 4435.890751782185
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 13 ),( 1 , 0 , 1 , 0 ) AIC: 4435.224160299553
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 2 , 13 ),( 1 , 0 , 1 , 7 ) AIC: 3769.41610283496
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 13 ),( 1 , 0 , 1 , 12 ) AIC: 4438.630590463898
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 13 ),( 1 , 1 , 0 , 7 ) AIC: 5187.778158694286
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 13 ),( 1 , 1 , 0 , 12 ) AIC: 6205.522551688744
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 13 ),( 1 , 1 , 1 , 7 ) AIC: 4421.6669682763795
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 2 , 13 ),( 1 , 1 , 1 , 12 ) AIC: 5749.312162593275
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ),( 0 , 0 , 0 , 0 ) AIC: 3550.74956784021
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ),( 0 , 0 , 0 , 7 ) AIC: 3550.74956784021
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ),( 0 , 0 , 0 , 12 ) AIC: 3550.74956784021
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 2 , 14 ),( 0 , 0 , 1 , 0 ) AIC: 3550.1025604305746
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ),( 0 , 0 , 1 , 7 ) AIC: 3552.998511397171
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ),( 0 , 0 , 1 , 12 ) AIC: 3431.964793251319
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ),( 0 , 1 , 0 , 7 ) AIC: 6045.976976241528
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ),( 0 , 1 , 0 , 12 ) AIC: 5875.540598593351
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ),( 0 , 1 , 1 , 7 ) AIC: 4084.01099021467
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ),( 0 , 1 , 1 , 12 ) AIC: 6012.542434764624
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ),( 1 , 0 , 0 , 0 ) AIC: 3550.0862842786382
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ),( 1 , 0 , 0 , 7 ) AIC: 3529.1093900155383
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ),( 1 , 0 , 0 , 12 ) AIC: 3552.9008563248535
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ),( 1 , 0 , 1 , 0 ) AIC: 3552.0651105859706
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ),( 1 , 0 , 1 , 7 ) AIC: 3449.3076721361654
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ),( 1 , 0 , 1 , 12 ) AIC: 3432.896525945602
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ),( 1 , 1 , 0 , 7 ) AIC: 5810.0615719988
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ),( 1 , 1 , 0 , 12 ) AIC: 6277.611350194521
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ),( 1 , 1 , 1 , 7 ) AIC: 3918.317365175065
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ),( 1 , 1 , 1 , 12 ) AIC: 6418.576574157205
# Best SARIMA ( 0 , 0 , 0 ),( 0 , 0 , 0 , 0 ) AIC: 3431.964793251319
# []

# %% [markdown]
# ### above did not print the correct final result, but I come back and find for AIC=3431.96 is (1,2,14)(0,0,1,12)

# %%
## first try without seasonal term, it is faster
p_values = [1,2,3]
d_values = [1,2,3]
q_values = [13,14,15]


train_X = train1_X2.iloc[:, 0: 3].copy()
test_X = test1_X.iloc[:,0:3].copy()


best_score=1000000000
p0=0
d0=0
q0=0

param=list()
for p in p_values:
    for d in d_values:
        for q in q_values:
            try:
                model = sm.tsa.statespace.SARIMAX(endog =train1_y2.values,
                                                  exog=train_X,
                                                  trend='n', order=(p,d,q),

                                                  enforce_stationarity=False,
                                                  enforce_invertibility=False)
                model_fit = model.fit()
                aic = model_fit.aic
                print('(',p,',',d,',',q,'), AIC:',aic)
                if (aic < best_score):
                    best_score = aic
                    param = model_fit().params
                    p0=p
                    d0=d
                    q0=q
            except:
                continue
print('Best SARIMA (',p0,',',d0,',',q0,'), AIC:', best_score)
print(param)
# Out:
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 13 ), AIC: 4493.456889113037
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 14 ), AIC: 4099.166393826734
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 15 ), AIC: 4104.057430812287
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 13 ), AIC: 4430.802285678875
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 14 ), AIC: 3550.74956784021
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 2 , 15 ), AIC: 3431.5878915480216
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 3 , 13 ), AIC: 4708.874778859626
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 3 , 14 ), AIC: 4683.5981023678005
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 3 , 15 ), AIC: 3887.3565498830103
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 2 , 1 , 13 ), AIC: 4462.575401394584
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 2 , 1 , 14 ), AIC: 4102.215509998072
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 2 , 1 , 15 ), AIC: 4102.208609300833
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 2 , 2 , 13 ), AIC: 4425.627732540665
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 2 , 2 , 14 ), AIC: 3554.7171492601683
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 2 , 2 , 15 ), AIC: 3553.9996567824537
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 2 , 3 , 13 ), AIC: 4590.82544596098
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 2 , 3 , 14 ), AIC: 4508.887785209855
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 2 , 3 , 15 ), AIC: 4062.3382771369334
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 3 , 1 , 13 ), AIC: 4331.279492823772
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 3 , 1 , 14 ), AIC: 4102.298469941792
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 3 , 1 , 15 ), AIC: 4289.593715183839
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 3 , 2 , 13 ), AIC: 4417.996149940799
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 3 , 2 , 14 ), AIC: 3557.0764678093765
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 3 , 2 , 15 ), AIC: 3556.0230917718295
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 3 , 3 , 13 ), AIC: 4574.977669201416
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 3 , 3 , 14 ), AIC: 4291.739272492246
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 3 , 3 , 15 ), AIC: 3881.810616392258
# Best SARIMA ( 0 , 0 , 0 ), AIC: 3431.5878915480216
# []

# %%
## the above (1,2,15) gives best for X= 3 columns, AIC=3431.59
p_values = [1]
d_values = [2]
q_values = [15]
P_v=[0,1]
D_v=[0,1]
Q_v=[0,1]
s_v=[0,7,12]
train_X=df3
test_X=df4
best_score=1000000000
p0=0
d0=0
q0=0
P0=0
D0=0
Q0=0
s0=0
param_best=list()
for p in p_values:
    for d in d_values:
        for q in q_values:
            for P in P_v:
                for D in D_v:
                    for Q in Q_v:
                        for s in s_v:
                            try:
                                model = sm.tsa.statespace.SARIMAX(endog =train1_y2.values,
                                                                  exog=train_X,
                                                                  trend='n', order=(p,d,q),
                                                                  seasonal_order=(P,D,Q,s),
                                                                  enforce_stationarity=False,
                                                                  enforce_invertibility=False)
                                model_fit = model.fit()
                                aic = model_fit.aic
                                print('(',p,',',d,',',q,'),(',P,',',D,',',Q,',',s,') AIC:',aic)
                                
                                if aic < best_score:
                                    best_score = aic
                                    param_best = model_fit().params
                                    p0=p
                                    d0=d
                                    q0=q
                                    P0=P
                                    D0=D
                                    Q0=Q
                                    s0=s
                                
                            except:
                                continue
print('Best SARIMA (',p0,',',d0,',',q0,'),(',P0,',',D0,',',Q0,',',s0,') AIC:', best_score)
print(param_best)
# Out:
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 2 , 15 ),( 0 , 0 , 0 , 0 ) AIC: 3431.5878915480216
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 2 , 15 ),( 0 , 0 , 0 , 7 ) AIC: 3431.5878915480216
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 2 , 15 ),( 0 , 0 , 0 , 12 ) AIC: 3431.5878915480216
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 15 ),( 0 , 0 , 1 , 0 ) AIC: 3552.903356610051
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 15 ),( 0 , 0 , 1 , 7 ) AIC: 3553.2818095312027
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 15 ),( 0 , 0 , 1 , 12 ) AIC: 3557.371763298016
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 15 ),( 0 , 1 , 0 , 7 ) AIC: 6046.253019286218
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 2 , 15 ),( 0 , 1 , 0 , 12 ) AIC: 6160.082309919112
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 15 ),( 0 , 1 , 1 , 7 ) AIC: 4126.061238939082
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 15 ),( 0 , 1 , 1 , 12 ) AIC: 6519.069722745369
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 15 ),( 1 , 0 , 0 , 0 ) AIC: 3552.9109429172418
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 15 ),( 1 , 0 , 0 , 7 ) AIC: 3528.9950094123096
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 15 ),( 1 , 0 , 0 , 12 ) AIC: 3553.4864377938843
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 15 ),( 1 , 0 , 1 , 0 ) AIC: 3554.915158782993
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 15 ),( 1 , 0 , 1 , 7 ) AIC: 3450.097748643014
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 15 ),( 1 , 0 , 1 , 12 ) AIC: 3559.502046930978
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 15 ),( 1 , 1 , 0 , 7 ) AIC: 5811.0878928408365
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 15 ),( 1 , 1 , 0 , 12 ) AIC: 6826.455615484582
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 15 ),( 1 , 1 , 1 , 7 ) AIC: 3937.2904922045786
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 15 ),( 1 , 1 , 1 , 12 ) AIC: 7058.141379082339
# Best SARIMA ( 0 , 0 , 0 ),( 0 , 0 , 0 , 0 ) AIC: 3431.5878915480216
# []

# %%
## X with first 20 queries
## first try without seasonal term, it is faster
p_values = [0,1,2]
d_values = [0,1,2]
q_values = [5,7,9,11,13,15]


train_X = train1_X2.iloc[:, 0: 20].copy()
test_X = test1_X.iloc[:,0:20].copy()


best_score=1000000000
p0=0
d0=0
q0=0

param=list()
for p in p_values:
    for d in d_values:
        for q in q_values:
            try:
                model = sm.tsa.statespace.SARIMAX(endog =train1_y2.values,
                                                  exog=train_X,
                                                  trend='n', order=(p,d,q),

                                                  enforce_stationarity=False,
                                                  enforce_invertibility=False)
                model_fit = model.fit()
                aic = model_fit.aic
                print('(',p,',',d,',',q,'), AIC:',aic)
                if (aic < best_score):
                    best_score = aic
                    param = model_fit().params
                    p0=p
                    d0=d
                    q0=q
            except:
                continue
print('Best SARIMA (',p0,',',d0,',',q0,'), AIC:', best_score)
print(param)
# Out:
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 0 , 5 ), AIC: 22471.12642180542
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 0 , 7 ), AIC: 21511.13733923487
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 0 , 9 ), AIC: 19183.151439947487
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 0 , 11 ), AIC: 18400.162442416866
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 0 , 13 ), AIC: 16759.378217245525
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 0 , 15 ), AIC: 14574.151720301981
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 5 ), AIC: 6080.829212010436
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 7 ), AIC: 5330.38745424341
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 1 , 9 ), AIC: 5039.545425801618
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 11 ), AIC: 4835.91566039617
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 13 ), AIC: 4692.973201388802
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 1 , 15 ), AIC: 4634.6238131878745
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 2 , 5 ), AIC: 4905.7476696662125
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 7 ), AIC: 4455.615828381755
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 9 ), AIC: 4455.462758523808
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 2 , 11 ), AIC: 4433.635213095164
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 13 ), AIC: 4423.736820678228
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 15 ), AIC: 3604.0478616482196
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 0 , 5 ), AIC: 18772.297461322552
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 0 , 7 ), AIC: 15587.945246707135
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 0 , 9 ), AIC: 14652.142579822543
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 0 , 11 ), AIC: 15196.61796020819
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 0 , 13 ), AIC: 13903.350096373182
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 0 , 15 ), AIC: 14718.442002350608
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 5 ), AIC: 4783.194273261026
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 7 ), AIC: 4542.558456476436
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 9 ), AIC: 4708.891060003489
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 11 ), AIC: 4593.693367253125
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 1 , 13 ), AIC: 4648.92498814049
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 1 , 15 ), AIC: 4178.532734673239
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 2 , 5 ), AIC: 4907.730307491268
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 7 ), AIC: 4456.7421775971725
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 9 ), AIC: 4457.388375450958
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 11 ), AIC: 4436.307495304065
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 1 , 2 , 13 ), AIC: 4422.891848785981
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 1 , 2 , 15 ), AIC: 3606.524116997361
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 2 , 0 , 5 ), AIC: 18829.48186126703
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 2 , 0 , 7 ), AIC: 15857.560091231298
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 2 , 0 , 9 ), AIC: 16098.417718647383
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 2 , 0 , 11 ), AIC: 15538.928098432256
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 2 , 0 , 13 ), AIC: 16283.336452300173
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 2 , 0 , 15 ), AIC: 16286.765210877496
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 2 , 1 , 5 ), AIC: 4780.780655216606
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 2 , 1 , 7 ), AIC: 4568.741767021483
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 2 , 1 , 9 ), AIC: 4722.485595734929
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 2 , 1 , 11 ), AIC: 4563.502972780542
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 2 , 1 , 13 ), AIC: 4613.418479264739
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 2 , 1 , 15 ), AIC: 4198.212760557953
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 2 , 2 , 5 ), AIC: 4908.683586943051
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 2 , 2 , 7 ), AIC: 4456.309859099047
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 2 , 2 , 9 ), AIC: 4459.2877903006965
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 2 , 2 , 11 ), AIC: 4438.893248070732
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 2 , 2 , 13 ), AIC: 4417.461561432593
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 2 , 2 , 15 ), AIC: 3610.4896920663286
# Best SARIMA ( 0 , 0 , 0 ), AIC: 3604.0478616482196
# []

# %% [markdown]
# ### above have (0,2,15) AIC=3604.05 for X select first 20 queries

# %%
## X with first 20 queries
p_values = [0]
d_values = [2]
q_values = [15]
P_v=[0,1]
D_v=[0,1]
Q_v=[0,1]
s_v=[0,7,12]
train_X=df3
test_X=df4
best_score=1000000000
p0=0
d0=0
q0=0
P0=0
D0=0
Q0=0
s0=0
param_best=list()
for p in p_values:
    for d in d_values:
        for q in q_values:
            for P in P_v:
                for D in D_v:
                    for Q in Q_v:
                        for s in s_v:
                            try:
                                model = sm.tsa.statespace.SARIMAX(endog =train1_y2.values,
                                                                  exog=train_X,
                                                                  trend='n', order=(p,d,q),
                                                                  seasonal_order=(P,D,Q,s),
                                                                  enforce_stationarity=False,
                                                                  enforce_invertibility=False)
                                model_fit = model.fit()
                                aic = model_fit.aic
                                print('(',p,',',d,',',q,'),(',P,',',D,',',Q,',',s,') AIC:',aic)
                                
                                if aic < best_score:
                                    best_score = aic
                                    param_best = model_fit().params
                                    p0=p
                                    d0=d
                                    q0=q
                                    P0=P
                                    D0=D
                                    Q0=Q
                                    s0=s
                                
                            except:
                                continue
print('Best SARIMA (',p0,',',d0,',',q0,'),(',P0,',',D0,',',Q0,',',s0,') AIC:', best_score)
print(param_best)
# Out:
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 15 ),( 0 , 0 , 0 , 0 ) AIC: 3548.489046293617
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 15 ),( 0 , 0 , 0 , 7 ) AIC: 3548.489046293617
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 15 ),( 0 , 0 , 0 , 12 ) AIC: 3548.489046293617
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 15 ),( 0 , 0 , 1 , 0 ) AIC: 3440.8439420006744
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 2 , 15 ),( 0 , 0 , 1 , 7 ) AIC: 3550.403422149644
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 2 , 15 ),( 0 , 0 , 1 , 12 ) AIC: 3558.8829062478108
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 2 , 15 ),( 0 , 1 , 0 , 7 ) AIC: 6044.284717222074
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 15 ),( 0 , 1 , 0 , 12 ) AIC: 6144.59016767738
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 15 ),( 0 , 1 , 1 , 7 ) AIC: 4061.600504938101
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 2 , 15 ),( 0 , 1 , 1 , 12 ) AIC: 6484.301071180863
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 15 ),( 1 , 0 , 0 , 0 ) AIC: 3437.7620101315483
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 15 ),( 1 , 0 , 0 , 7 ) AIC: 3526.9542131647027
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# ( 0 , 2 , 15 ),( 1 , 0 , 0 , 12 ) AIC: 3442.524194201552
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 15 ),( 1 , 0 , 1 , 0 ) AIC: 3440.1513294962383
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 15 ),( 1 , 0 , 1 , 7 ) AIC: 3448.153004714251
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 15 ),( 1 , 0 , 1 , 12 ) AIC: 3558.1293321149283
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ( 0 , 2 , 15 ),( 1 , 1 , 0 , 7 ) AIC: 5808.902476660628
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
# Defien the mearure matrics, MAE, RMSE, CORR
# define three metrics: mean absolute error, root mean squared error and Pearson's correlation.
from sklearn.metrics import mean_absolute_error
# mae = mean_absolute_error(y_actual, y_pred)

from sklearn.metrics import mean_squared_error
from math import sqrt
# rmse = sqrt(mean_squared_error(y_actual, y_pred))

# np.correcoef returns Pearson product-moment correlation coefficients
def pearson_r(x,y):   
    corr_mat = np.corrcoef(x,y)
    return corr_mat[0,1]
# r = pearson_r(y_actual,y_pred)

train1 = train1_y2.values
test1 = test1_y.values
df3 = train1_X2.iloc[:, 0: 20].copy()
df4 = test1_X.iloc[:,0:20].copy()

history = [x for x in train1]
predict = list()
training_mod = sm.tsa.statespace.SARIMAX(endog =train1,
                                  exog=df3,
                                  trend='n', order=(0,2,15),
                                  seasonal_order=(1,0,10,0),
                                  enforce_stationarity=False,
                                  enforce_invertibility=False)
training_res = training_mod.fit()
# Out:
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
df4.iloc[[1]].shape
model = sm.tsa.statespace.SARIMAX(endog =train1,
                              exog=df3,
                              trend='n', order=(0,2,15),
                              seasonal_order=(1,0,0,0),
                              enforce_stationarity=False,
                              enforce_invertibility=False)
model_fit = model.filter(training_res.params)
output = model_fit.forecast(steps=1,exog=df4.iloc[[100]])
output
# Out:
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 4018    1.185308
# dtype: float64

# %%
output.values[0]
# Out:
# 1.1853080438502241

# %%
train1 = train1_y2.values
test1 = test1_y.values
df = X.iloc[:,0:20].copy()
df3 = train1_X2.iloc[:, 0: 20].copy()
df4 = test1_X.iloc[:,0:20].copy()

history = [x for x in train1]
predict = list()
count=0

for t in range(len(test1)):
    exog_train= df[0:4018+t]
    model = sm.tsa.statespace.SARIMAX(endog =history,
                                      exog=exog_train,
                                      trend='n', order=(0,2,15),
                                      seasonal_order=(1,0,0,0),
                                      enforce_stationarity=False,
                                      enforce_invertibility=False)
    model_fit = model.filter(training_res.params)
    exog_test =df4.iloc[[t]]
    output = model_fit.forecast(steps=1,exog=exog_test)
    yhat = output.values[0]
    print(yhat)
    predict.append(yhat)
    obs = test1[t]
    history.append(obs)
    count=count+1
    print(count)

mae1 = mean_absolute_error(test1, predict)
rmse1 = sqrt(mean_squared_error(test1, predict))

print(mae1,rmse1)
# Out:
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 1.1581190939980917
# 1
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.085441690265404
# 2
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.0306790685543137
# 3
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 1.1828795367412237
# 4
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.1825030760240032
# 5
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 1.2328571377546491
# 6
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.2635324823957643
# 7
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 1.2941772156782552
# 8
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 1.3160064892049272
# 9
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.3303658601265111
# 10
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.496250995811286
# 11
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.5775537473281556
# 12
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.660031216236149
# 13
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 1.7381921831498817
# 14
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.8113300677839321
# 15
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.8835085454186373
# 16
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.9313456719071809
# 17
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.9315021546995754
# 18
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 1.9529993143686206
# 19
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 1.9835768204839337
# 20
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 1.9917012440949877
# 21
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 2.0088643210768766
# 22
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2.0131268253097634
# 23
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2.0182184918960697
# 24
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2.4281599066728794
# 25
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2.5988745665087105
# 26
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 2.8180568014086678
# 27
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 2.990591570251484
# 28
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 3.1741788680372744
# 29
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3.3868604638289193
# 30
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 3.467233375478604
# 31
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 3.914797321047427
# 32
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 4.139636483629702
# 33
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 4.437203755855603
# 34
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 4.676678881108248
# 35
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 4.904719742119467
# 36
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 5.182861763654718
# 37
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 5.289954414039122
# 38
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 5.902335997301398
# 39
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 6.174377240323878
# 40
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 6.563708093372334
# 41
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 6.903600729955962
# 42
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 7.179712328153327
# 43
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 7.564351919689462
# 44
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 7.750165910500569
# 45
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 7.543267423856355
# 46
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 7.590161305710079
# 47
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 7.663731814634786
# 48
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 7.618332668339309
# 49
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 7.630323583008044
# 50
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 7.592652599854088
# 51
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 7.665579174907278
# 52
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 7.383072759759384
# 53
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 7.256373102519346
# 54
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 7.221332326152775
# 55
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 7.0029231333554725
# 56
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 6.900040586478743
# 57
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 6.757498656569104
# 58
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 6.763228693396872
# 59
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 6.78080655378736
# 60
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 6.777600324855408
# 61
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 6.845076893644547
# 62
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 6.757394612102724
# 63
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 6.784915736440659
# 64
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 6.7662251615014855
# 65
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 6.818515918743959
# 66
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 7.240135848052934
# 67
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 7.425429327923019
# 68
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 7.697760144169783
# 69
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 7.87266949926353
# 70
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 8.063985252948791
# 71
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 8.276364829959217
# 72
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 8.415581426064898
# 73
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 7.809362957547135
# 74
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 7.5730138448737385
# 75
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 7.3718330679211395
# 76
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 7.052005091933732
# 77
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 6.829496030370803
# 78
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 6.569622681060445
# 79
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 6.403095372381759
# 80
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 6.988502594674664
# 81
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 7.139766420598913
# 82
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 7.382309612460314
# 83
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 7.456737832628646
# 84
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 7.698341806750799
# 85
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 7.857738558178127
# 86
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 8.035855225543253
# 87
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 8.119992430221197
# 88
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# 8.234467131477576
# 89
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# ...
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.7348098988550618
# 335
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.714786430762634
# 336
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.6445295523674768
# 337
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.612687524578444
# 338
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.584551245606102
# 339
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.6294752070470306
# 340
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.6429362141216712
# 341
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.6527355830338426
# 342
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.6624524396650484
# 343
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.6394579049136717
# 344
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.6797326031864135
# 345
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.6769657125065944
# 346
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.630859919274318
# 347
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.6095915319746654
# 348
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.6032111381106045
# 349
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.5799363135754156
# 350
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.5434377715043213
# 351
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.5544621408890136
# 352
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.4888102214255987
# 353
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.6671009047957692
# 354
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.701038824279645
# 355
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.7696324925181068
# 356
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.822848981785421
# 357
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.8531627941888944
# 358
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.9489803952629177
# 359
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.9493482781973026
# 360
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.8756699175802953
# 361
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.849144008181328
# 362
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.8182185417597723
# 363
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# 1.7974962072057807
# 364
# 1.7611800043941626
# 365
# 0.043813329161501775 0.11859459286195011
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
# visualize
date = pd.date_range('20050824',periods=4383)
import matplotlib.dates as mdates
df = y.copy()
df['y'] = y.values
fig, ax = plt.subplots()
ax.plot(date[4018:],df.y[4018:],label='real flu rate')
ax.plot(date[4018:],predict,label='predicted flu rate')
# Now add the legend with some customizations.
legend = ax.legend(loc='upper right', shadow=True)

plt.title("Figure 11: SARIMA forecast the test_set1 based on all the data since the day before(lag=1),passing parameter to the model")
plt.ylabel('flu rate')
plt.xlabel('Date')

plt.show()

# %%
## lag=5
train1 = train1_y2.values
test = test1_y.values
test1 = test1_y[4:].values

history = [x for x in train1]
predict2 = list()

count =0

for t in range(len(test1)):
    model = sm.tsa.SARIMAX(history, order=(1,1,14),seasonal_order=(1,0,1,7),enforce_stationarity=False,
                              enforce_invertibility=False)
    model_fit = model.filter(training_res.params)
    output = model_fit.forecast(steps=5)
    yhat = output[4]
    print(yhat)
    predict2.append(yhat)
    obs = test[t]
    history.append(obs)
    count=count+1
    print(count)

mae1 = mean_absolute_error(test1, predict2)
rmse1 = sqrt(mean_squared_error(test1, predict2))

print(mae1,rmse1)
# Out:
# 1.6411105539117279
# 1
# 1.744361284287232
# 2
# 1.954604395151228
# 3
# 1.4109833465669688
# 4
# 1.371370556223658
# 5
# 1.5865010842423848
# 6
# 1.7303187742274069
# 7
# 1.9354926907761234
# 8
# 2.056690189304985
# 9
# 2.283005738271227
# 10
# 1.935672002775689
# 11
# 1.9415865512227342
# 12
# 2.150173013115591
# 13
# 2.286747206919652
# 14
# 2.4848548527174503
# 15
# 2.599970138606801
# 16
# 2.819043394038617
# 17
# 2.131151938321902
# 18
# 2.073199716206102
# 19
# 2.2481016720501747
# 20
# 2.349489913581443
# 21
# 2.511897402117628
# 22
# 2.5925383071999786
# 23
# 2.774666107370625
# 24
# 3.304900887519575
# 25
# 3.4199795684498637
# 26
# 3.651472219917462
# 27
# 3.8106637740171467
# 28
# 4.0316545104960175
# 29
# 4.17040647417743
# 30
# 4.4131449924476165
# 31
# 5.0449809309437
# 32
# 5.227607468857153
# 33
# 5.397832064773805
# 34
# 5.496597396479603
# 35
# 5.656589802341581
# 36
# 5.7329892471049435
# 37
# 5.915281725370663
# 38
# 7.328463393948507
# 39
# 7.59200669231431
# 40
# 7.747923949712925
# 41
# 7.835178159017416
# 42
# 7.9842131994936505
# 43
# 8.047413264211293
# 44
# 8.221890881742132
# 45
# 7.744284695844667
# 46
# 7.6840563424588595
# 47
# 7.678106741280161
# 48
# 7.601852572614094
# 49
# 7.58595171363633
# 50
# 7.484090791838204
# 51
# 7.49140835016512
# 52
# 7.014345389154139
# 53
# 6.814259599712015
# 54
# 6.85214822948038
# 55
# 6.8196049810007215
# 56
# 6.847879654113525
# 57
# 6.79158307331574
# 58
# 6.843768774563955
# 59
# 6.897396466976463
# 60
# 6.823395463572312
# 61
# 6.902328386540937
# 62
# 6.910914695203705
# 63
# 6.980204694487888
# 64
# 6.96441506620871
# 65
# 7.057844697892168
# 66
# 8.187857981610446
# 67
# 8.328837536379156
# 68
# 8.440856181539212
# 69
# 8.485126533907616
# 70
# 8.590448325922369
# 71
# 8.60899779570423
# 72
# 8.74125906444136
# 73
# 6.943858507135465
# 74
# 6.625681865736366
# 75
# 6.548547873110756
# 76
# 6.399531119262065
# 77
# 6.309465533682437
# 78
# 6.1347248728229085
# 79
# 6.0666813242753
# 80
# 7.791689580236899
# 81
# 7.897105553451961
# 82
# 8.08686065853048
# 83
# 8.209685474410849
# 84
# 8.394213795227815
# 85
# 8.492516701931127
# 86
# 8.706037467659945
# 87
# 8.681976470667312
# 88
# 8.729007039650636
# 89
# 8.719935597858784
# 90
# 8.642601556939866
# 91
# 8.624196390013463
# 92
# 8.517831008761858
# 93
# 8.525183337406753
# 94
# 8.630762713091077
# 95
# 8.527244803410765
# 96
# 8.5514731784822
# 97
# 8.508540332381278
# 98
# 8.525935844998905
# 99
# 8.456060831662816
# 100
# 8.501662266528708
# 101
# 9.504687911722002
# 102
# 9.583907582900173
# 103
# 9.644100625549012
# 104
# 9.638988743699144
# 105
# 9.693824883267919
# 106
# 9.659021752720585
# 107
# 9.74349350283385
# 108
# 14.264734892325075
# 109
# 14.968537283396122
# 110
# 15.129316596905593
# 111
# 15.234502095930575
# 112
# 15.4017489490174
# 113
# 15.472513870457371
# 114
# 15.678549211722434
# 115
# 16.6647634698012
# 116
# 16.878039324798536
# 117
# 16.6650533069236
# 118
# 16.395409101063386
# 119
# 16.18594580964027
# 120
# 15.8747882810657
# 121
# 15.701923361811005
# 122
# 13.853097219035968
# 123
# 13.274218168933736
# 124
# 12.981073055795486
# 125
# 12.628413912066039
# 126
# 12.336617394496313
# 127
# 11.946675075021462
# 128
# 11.688859936905905
# 129
# 19.118104790131422
# 130
# 20.02625486422845
# 131
# 20.283552151309852
# 132
# 20.49722865559147
# 133
# 20.776819895811588
# 134
# 20.94585139931953
# 135
# 21.278201107991862
# 136
# 20.518617092987736
# 137
# 20.545754713695437
# 138
# 20.049532280576948
# 139
# 19.503249408050735
# 140
# 19.017238622355155
# 141
# 18.416263770129824
# 142
# 17.971970406213572
# 143
# 17.74543999212516
# 144
# 17.213540709573852
# 145
# 16.942712732574186
# 146
# 16.623797336201115
# 147
# 16.370174778629956
# 148
# 16.00414716787988
# 149
# 15.79802180762136
# 150
# 17.242510821595477
# 151
# 17.190501319456136
# 152
# 17.046152804961697
# 153
# 16.85670726217915
# 154
# 16.730513531202416
# 155
# 16.488116579863945
# 156
# 16.410230228087702
# 157
# 18.76499972763633
# 158
# 18.973117813433635
# 159
# 18.83130329827653
# 160
# 18.649186775770595
# 161
# 18.531397665262908
# 162
# 18.29313327018995
# 163
# 18.22932316965683
# 164
# 15.319614789803474
# 165
# 14.656376564697709
# 166
# 14.225398780534846
# 167
# 13.747494078478688
# 168
# 13.330827646925796
# 169
# 12.797212528842053
# 170
# 12.425277114023675
# 171
# 13.135142360837758
# 172
# 12.820886800864804
# 173
# 12.785782834797972
# 174
# 12.706845615666989
# 175
# 12.692855419316684
# 176
# 12.561845741762948
# 177
# 12.600015061111732
# 178
# 9.574890163844644
# 179
# 8.974132222960947
# 180
# 8.730908247298844
# 181
# 8.436004142225583
# 182
# 8.2018907035404
# 183
# 7.853465589482034
# 184
# 7.661460498951503
# 185
# 8.298755748421536
# 186
# 8.11918924860155
# 187
# 8.23174443165136
# 188
# 8.296142480735407
# 189
# 8.425319027760223
# 190
# 8.441621184135744
# 191
# 8.619933406603224
# 192
# 8.304052176737276
# 193
# 8.272954702400268
# 194
# 8.27206021295183
# 195
# 8.220451243530228
# 196
# 8.231075675303073
# 197
# 8.12730222008683
# 198
# 8.182721055797751
# 199
# 5.793745603281389
# 200
# 5.310745814743006
# 201
# 5.248823564157978
# 202
# 5.131924261638418
# 203
# 5.0773527832910315
# 204
# 4.9135519830787615
# 205
# 4.900879342582294
# 206
# 5.821762023862009
# 207
# 5.836606125027679
# 208
# 6.041054842663912
# 209
# 6.192968323559981
# 210
# 6.408791715963457
# 211
# 6.514563319580607
# 212
# 6.775936411927292
# 213
# 5.268558723676725
# 214
# 5.103564455465759
# 215
# 5.107312900969893
# 216
# 5.054001509817269
# 217
# 5.062436727646639
# 218
# 4.962299304244553
# 219
# 5.010957389208128
# 220
# 4.141735667319611
# 221
# 3.905104594372215
# 222
# 4.02125964966993
# 223
# 4.079527706746587
# 224
# 4.200847190529419
# 225
# 4.216583765229929
# 226
# 4.379079953654884
# 227
# 2.9902032951986746
# 228
# 2.760250622528596
# 229
# 2.8647045458709455
# 230
# 2.9079000593129547
# 231
# 3.01288387538624
# 232
# 3.0143210462991337
# 233
# 3.1568916973174894
# 234
# 2.966438350594684
# 235
# 2.919741027338176
# 236
# 3.11969646189843
# 237
# 3.2583647350375857
# 238
# 3.459938307747913
# 239
# 3.559306188562625
# 240
# 3.7999039998935156
# 241
# 3.060555833532119
# 242
# 3.002724436921957
# 243
# 3.1454638774744876
# 244
# 3.224661939650248
# 245
# 3.365809709493595
# 246
# 3.4057165788135664
# 247
# 3.5833698444808295
# 248
# 2.7260145160110163
# 249
# 2.5948160530967646
# 250
# 2.745992701400674
# 251
# 2.831964799103646
# 252
# 2.9802833224437566
# 253
# 3.029538216045455
# 254
# 3.213686534738214
# 255
# 3.1566914822198466
# 256
# 3.1644898223571825
# 257
# 3.3619356360055535
# 258
# 3.4938642540602176
# 259
# 3.6883455456736787
# 260
# 3.784107121139237
# 261
# 4.014553288701563
# 262
# 3.7963667369738006
# 263
# 3.8150383278662963
# 264
# 3.9712167982639928
# 265
# 4.061002462711604
# 266
# 4.213050070476911
# 267
# 4.266811311863201
# 268
# 4.454259835939706
# 269
# 2.876371488327847
# 270
# 2.63000261840947
# 271
# 2.716658590816603
# 272
# 2.7334821624617898
# 273
# 2.811852540068583
# 274
# 2.7947869600947928
# 275
# 2.9053908754530777
# 276
# 1.7698492554785645
# 277
# 1.532288244022881
# 278
# 1.7008185062768613
# 279
# 1.797580303254637
# 280
# 1.9562948273862308
# 281
# 2.0221944602592723
# 282
# 2.2124004538859645
# 283
# 2.007965848151784
# 284
# 1.9921522108196368
# 285
# 2.215597017527165
# 286
# 2.3669007137452964
# 287
# 2.580126392135
# 288
# 2.7012752777325626
# 289
# 2.945933012056567
# 290
# 2.1370721145699316
# 291
# 2.064411229235918
# 292
# 2.2289404214088733
# 293
# 2.3192847410697506
# 294
# 2.4710394889904803
# 295
# 2.532151881895121
# 296
# 2.7135684295723133
# 297
# 1.322258647988791
# 298
# 1.0980115559149923
# 299
# 1.2520364654164609
# 300
# 1.3291188851706064
# 301
# 1.467446198795877
# 302
# 1.517966493116814
# 303
# 1.6838101699551329
# 304
# 1.9205254324886807
# 305
# 1.955649272508487
# 306
# 2.2166794457619083
# 307
# 2.401530900540426
# 308
# 2.6483828673839476
# 309
# 2.807609678663005
# 310
# 3.0837253450572035
# 311
# 2.003886808330836
# 312
# 1.9092351536782655
# 313
# 2.0513897178280502
# 314
# 2.1144583995718165
# 315
# 2.2381935259502415
# 316
# 2.275729521594375
# 317
# 2.4255079893086275
# 318
# 1.718329597469367
# 319
# 1.57978751582258
# 320
# 1.773920914004261
# 321
# 1.8880336222078098
# 322
# 2.063492954829815
# 323
# 2.154801324444921
# 324
# 2.356614392026337
# 325
# 1.9805576354985113
# 326
# 1.9402512430055128
# 327
# 2.1448162606000793
# 328
# 2.2683564340131483
# 329
# 2.452925604234245
# 330
# 2.5538844174636544
# 331
# 2.7639106455556495
# 332
# 1.7961515504492678
# 333
# 1.6624841431550235
# 334
# 1.8251749081423803
# 335
# 1.9048585422151554
# 336
# 2.045195549393161
# 337
# 2.1038344706617873
# 338
# 2.268095688814997
# 339
# 1.8011983355394385
# 340
# 1.712654314525712
# 341
# 1.9185160591322696
# 342
# 2.0407061832064777
# 343
# 2.223800896889753
# 344
# 2.3264456863342096
# 345
# 2.5333746597816376
# 346
# 1.6998416577552835
# 347
# 1.5845633701564108
# 348
# 1.7598192369304486
# 349
# 1.8495038698583581
# 350
# 1.9996289962013067
# 351
# 2.0706629487992787
# 352
# 2.2429423995208717
# 353
# 2.0167950755690582
# 354
# 1.9738780211185931
# 355
# 2.1879607832680272
# 356
# 2.316461634387458
# 357
# 2.505671435429474
# 358
# 2.6167817348467977
# 359
# 2.8287152535251203
# 360
# 1.9125624874935365
# 361
# 0.4693265178219825 0.8199890363372884

# %%
## lag=5
# visualize
date = pd.date_range('20050824',periods=4383)
import matplotlib.dates as mdates
df = y.copy()
df['y'] = y.values
fig, ax = plt.subplots()
ax.plot(date[4018+4:],df.y[4018+4:],label='real flu rate')
ax.plot(date[4018+4:],predict2,label='predicted flu rate')
# Now add the legend with some customizations.
legend = ax.legend(loc='upper right', shadow=True)

plt.title("Figure 12: SARIMA forecast the last 361 days based on all the data since 5 days before(lag=5),passing parameter to the model")
plt.ylabel('flu rate')
plt.xlabel('Date')

plt.show()

# %%
## lag=10
train1 = train1_y2.values
test = test1_y.values
test1 = test1_y[9:].values
history = [x for x in train1]
predict3 = list()

count =0

for t in range(len(test1)):
    model = sm.tsa.SARIMAX(history, order=(1,1,14),seasonal_order=(1,0,1,7),enforce_stationarity=False,
                              enforce_invertibility=False)
    model_fit = model.filter(training_res.params)
    output = model_fit.forecast(steps=10)
    yhat = output[9]
    print(yhat)
    predict3.append(yhat)
    obs = test[t]
    history.append(obs)
    count=count+1
    print(count)

mae1 = mean_absolute_error(test1, predict3)
rmse1 = sqrt(mean_squared_error(test1, predict3))

print(mae1,rmse1)
# Out:
# 2.639997597273907
# 1
# 2.7688371171494577
# 2
# 3.0573131353920715
# 3
# 2.316671467824092
# 4
# 2.3880263192310958
# 5
# 2.6341398496240083
# 6
# 2.75481056773951
# 7
# 2.9934474086632723
# 8
# 3.107896544686674
# 9
# 3.37931642519433
# 10
# 2.8626937225735936
# 11
# 2.924766938032793
# 12
# 3.1647681922560857
# 13
# 3.2781727140390573
# 14
# 3.4966193137465926
# 15
# 3.592208413317395
# 16
# 3.84297352996874
# 17
# 2.860988499285931
# 18
# 2.8862251411415176
# 19
# 3.093303887858049
# 20
# 3.170914836494807
# 21
# 3.390632731628644
# 22
# 3.48915977376794
# 23
# 3.739327372886667
# 24
# 4.432543102194261
# 25
# 4.514409622257173
# 26
# 4.7777278290116145
# 27
# 4.914098601701077
# 28
# 5.07205035780076
# 29
# 5.108247406877869
# 30
# 5.2993777273622085
# 31
# 5.9873959462596575
# 32
# 6.010972211312871
# 33
# 6.212719318104181
# 34
# 6.28865024739294
# 35
# 6.396919753949822
# 36
# 6.3816426083445315
# 37
# 6.52419441317441
# 38
# 8.286879305522307
# 39
# 8.300560274093673
# 40
# 8.486916964305044
# 41
# 8.552628597407415
# 42
# 8.582004056039645
# 43
# 8.484911555795392
# 44
# 8.553208038817157
# 45
# 7.727017974832644
# 46
# 7.578891920905573
# 47
# 7.604043599061278
# 48
# 7.504848691527511
# 49
# 7.569231571042983
# 50
# 7.506949218608641
# 51
# 7.607452957276293
# 52
# 7.038301704283308
# 53
# 6.930581326957183
# 54
# 6.999846336540538
# 55
# 6.944867860994225
# 56
# 7.029033542218787
# 57
# 6.988482258377923
# 58
# 7.109369275229636
# 59
# 7.208862920770422
# 60
# 7.142699483066404
# 61
# 7.253005357175888
# 62
# 7.239111071309438
# 63
# 7.312386972772801
# 64
# 7.260278567586646
# 65
# 7.3706951792026
# 66
# 8.84121591031068
# 67
# 8.811943597126806
# 68
# 8.954365404955963
# 69
# 8.977347046799624
# 70
# 8.990241418571495
# 71
# 8.875566524918142
# 72
# 8.929705807759222
# 73
# 6.383697393868329
# 74
# 6.160946423035846
# 75
# 6.115918905743258
# 76
# 5.9430968055510025
# 77
# 6.059585196468905
# 78
# 6.051273507267077
# 79
# 6.202203786196551
# 80
# 8.723945005185936
# 81
# 8.77005523082241
# 82
# 8.99016088247904
# 83
# 9.092706285012955
# 84
# 9.101823496842181
# 85
# 8.984265832759286
# 86
# 9.037211680900667
# 87
# 8.747674035432347
# 88
# 8.599806539425018
# 89
# 8.621471073678274
# 90
# 8.52165311866897
# 91
# 8.54801534915807
# 92
# 8.445307033072252
# 93
# 8.511849048349092
# 94
# 8.685443324552713
# 95
# 8.568308384143476
# 96
# 8.62301473958886
# 97
# 8.558970745423307
# 98
# 8.585686082564234
# 99
# 8.484364405421854
# 100
# 8.554247842369744
# 101
# 9.876973932445594
# 102
# 9.80111521099795
# 103
# 9.890988145558484
# 104
# 9.865088401677534
# 105
# 9.84610773939362
# 106
# 9.695925608160943
# 107
# 9.722584047909207
# 108
# 15.64516455569273
# 109
# 15.687203542095249
# 110
# 15.873508716522823
# 111
# 15.962078265639807
# 112
# 15.733804712495814
# 113
# 15.365245849659939
# 114
# 15.19616183394433
# 115
# 16.038226340955426
# 116
# 15.714834318058955
# 117
# 15.527260971391756
# 118
# 15.238691863326848
# 119
# 15.03603076036378
# 120
# 14.685872966713927
# 121
# 14.54068238760892
# 122
# 12.129147381307108
# 123
# 11.718318455271625
# 124
# 11.451825324632237
# 125
# 11.079373462437358
# 126
# 11.024611042453094
# 127
# 10.826896640626353
# 128
# 10.825250155134896
# 129
# 21.055051632239874
# 130
# 21.217470682297527
# 131
# 21.494934031218047
# 132
# 21.69695249647524
# 133
# 21.279299873665444
# 134
# 20.702363728278495
# 135
# 20.36507385680298
# 136
# 18.5333196787315
# 137
# 17.951686773718894
# 138
# 17.477398666702776
# 139
# 16.91239740877665
# 140
# 16.65957952110256
# 141
# 16.24100324087546
# 142
# 16.055178295546398
# 143
# 16.12717360244256
# 144
# 15.762003033845433
# 145
# 15.512603561637635
# 146
# 15.178502280211179
# 147
# 14.994428997501936
# 148
# 14.648004654201312
# 149
# 14.53753522864744
# 150
# 16.59484421835161
# 151
# 16.36743746385497
# 152
# 16.243123114415507
# 153
# 16.038283181942035
# 154
# 15.8248456369346
# 155
# 15.443946346245209
# 156
# 15.306306223722565
# 157
# 18.379681994335808
# 158
# 18.162357565018304
# 159
# 18.03855590678641
# 160
# 17.843285612343855
# 161
# 17.571074515765975
# 162
# 17.125892738003
# 163
# 16.93787810564311
# 164
# 12.913129531530528
# 165
# 12.401948820721968
# 166
# 11.99141239562045
# 167
# 11.495891702068754
# 168
# 11.444546223296857
# 169
# 11.224683366697121
# 170
# 11.244721510782666
# 171
# 12.674356705414802
# 172
# 12.553469238129088
# 173
# 12.537920560949923
# 174
# 12.445069021613554
# 175
# 12.365891636153764
# 176
# 12.118378452074438
# 177
# 12.120122417085076
# 178
# 7.996083621366436
# 179
# 7.661188917786792
# 180
# 7.4406717350698335
# 181
# 7.1265202012253575
# 182
# 7.22943924308979
# 183
# 7.167435957737073
# 184
# 7.337643301878213
# 185
# 8.581784926002685
# 186
# 8.596924964925563
# 187
# 8.731182754310492
# 188
# 8.780277860406592
# 189
# 8.829510667562909
# 190
# 8.715974833633492
# 191
# 8.841178543736609
# 192
# 8.271007031147276
# 193
# 8.175990970640225
# 194
# 8.19758595517717
# 195
# 8.127911511017269
# 196
# 8.197039195132948
# 197
# 8.10118684223351
# 198
# 8.241036122901347
# 199
# 5.084377307450684
# 200
# 4.915825343500987
# 201
# 4.878439225009994
# 202
# 4.7425041116137505
# 203
# 4.9294838640839584
# 204
# 4.958450389164592
# 205
# 5.211169881357091
# 206
# 6.677483612622553
# 207
# 6.775857067451247
# 208
# 7.003994094337775
# 209
# 7.13869407530897
# 210
# 7.242550391590484
# 211
# 7.187385156328118
# 212
# 7.361867157177994
# 213
# 5.141633911688856
# 214
# 5.035491245769978
# 215
# 5.064704466647041
# 216
# 4.9912835183586095
# 217
# 5.166933772929556
# 218
# 5.185427625917217
# 219
# 5.42446577340726
# 220
# 4.406847023936877
# 221
# 4.405179152146594
# 222
# 4.547486788914006
# 223
# 4.586518019317531
# 224
# 4.776435905956216
# 225
# 4.813311252976349
# 226
# 5.0671230469085184
# 227
# 3.218587622677861
# 228
# 3.200418270184083
# 229
# 3.332471084002775
# 230
# 3.35464759030052
# 231
# 3.584603844961072
# 232
# 3.664212723925892
# 233
# 3.952948326775422
# 234
# 3.767153394337161
# 235
# 3.8399425543572514
# 236
# 4.0677477056555
# 237
# 4.1862747766903095
# 238
# 4.386583525518493
# 239
# 4.438431256008127
# 240
# 4.699034200687631
# 241
# 3.6211877101905325
# 242
# 3.6342823816489447
# 243
# 3.8058279684116587
# 244
# 3.8635420555185642
# 245
# 4.072399242636334
# 246
# 4.134033191749434
# 247
# 4.399695060453329
# 248
# 3.254575955501249
# 249
# 3.270174863376917
# 250
# 3.451031352587478
# 251
# 3.515381294077934
# 252
# 3.735055703431033
# 253
# 3.8104510632194177
# 254
# 4.085512517662911
# 255
# 4.009810717798188
# 256
# 4.070148583774903
# 257
# 4.297501913251892
# 258
# 4.40785675503125
# 259
# 4.59480543771846
# 260
# 4.637938496923719
# 261
# 4.88034985584355
# 262
# 4.4950474365643265
# 263
# 4.512313049713794
# 264
# 4.698856590554789
# 265
# 4.766691204236787
# 266
# 4.939335029972859
# 267
# 4.968754939993136
# 268
# 5.196042705939156
# 269
# 3.0385610806312133
# 270
# 2.9794787964792286
# 271
# 3.098063491826616
# 272
# 3.09152406499383
# 273
# 3.3203648939027746
# 274
# 3.4097840598611504
# 275
# 3.6884882258625735
# 276
# 2.276950395526194
# 277
# 2.2926335619741476
# 278
# 2.4941445440536203
# 279
# 2.5674206424610406
# 280
# 2.813017661539332
# 281
# 2.922761100823152
# 282
# 3.2166187141014957
# 283
# 2.957252670167
# 284
# 3.0260002525599154
# 285
# 3.282732710469027
# 286
# 3.410562941779756
# 287
# 3.6246621074259053
# 288
# 3.7039332757653547
# 289
# 3.9660679516279935
# 290
# 2.7956968019892248
# 291
# 2.801640679071414
# 292
# 3.000404106595343
# 293
# 3.066416701250558
# 294
# 3.2901083055354623
# 295
# 3.3809006834147026
# 296
# 3.6500002233745605
# 297
# 1.794531949977915
# 298
# 1.783064381776375
# 299
# 1.9726513930627345
# 300
# 2.0245788950559787
# 301
# 2.282431956270716
# 302
# 2.41118762550417
# 303
# 2.7109823898566763
# 304
# 3.0810077607508632
# 305
# 3.175049558630679
# 306
# 3.471528193650184
# 307
# 3.632119282717061
# 308
# 3.832541103736576
# 309
# 3.904185949129071
# 310
# 4.1487720048374
# 311
# 2.558553658154175
# 312
# 2.530269610266053
# 313
# 2.7091395272277
# 314
# 2.746267795988133
# 315
# 2.974399658973421
# 316
# 3.075631808179608
# 317
# 3.3434489115895225
# 318
# 2.443975869399081
# 319
# 2.461965508388134
# 320
# 2.6934725978926384
# 321
# 2.782028103811691
# 322
# 3.0076931367813384
# 323
# 3.109282475367757
# 324
# 3.374539334283396
# 325
# 2.8450416874433553
# 326
# 2.871815179785026
# 327
# 3.1142555875016864
# 328
# 3.2117544317991764
# 329
# 3.4201011879730716
# 330
# 3.5050868672533646
# 331
# 3.7517356584943804
# 332
# 2.40338479319887
# 333
# 2.383491634586637
# 334
# 2.5850498217625524
# 335
# 2.6380357945563766
# 336
# 2.8641890390915665
# 337
# 2.96956732691375
# 338
# 3.2316082989406145
# 339
# 2.629056417051605
# 340
# 2.649144354429891
# 341
# 2.894320484148153
# 342
# 2.989907170726583
# 343
# 3.202085820328463
# 344
# 3.295201786427959
# 345
# 3.5428568752672107
# 346
# 2.3797885776549013
# 347
# 2.3657123216488665
# 348
# 2.581168580101898
# 349
# 2.6434498910157025
# 350
# 2.8653111098320028
# 351
# 2.96992343703742
# 352
# 3.22476648334444
# 353
# 2.9266490038969017
# 354
# 2.9490234142357403
# 355
# 3.203518218348007
# 356
# 1.406868131519935 1.9318300324981599

# %%
# visualize lag=10
date = pd.date_range('20050824',periods=4383)
import matplotlib.dates as mdates
df = y.copy()
df['y'] = y.values
fig, ax = plt.subplots()
ax.plot(date[4018+9:],df.y[4018+9:],label='real flu rate')
ax.plot(date[4018+9:],predict3,label='predicted flu rate')
# Now add the legend with some customizations.
legend = ax.legend(loc='upper right', shadow=True)

plt.title("Figure 13: SARIMA forecast the last 356 days based on all the data since 10 days before(lag=10),passing parameter to the model")
plt.ylabel('flu rate')
plt.xlabel('Date')

plt.show()

# %%
## lag=14
train1 = train1_y2.values
test = test1_y.values
test1 = test1_y[13:].values

history = [x for x in train1]
predict4 = list()

count =0

for t in range(len(test1)):
    model = sm.tsa.SARIMAX(history, order=(1,1,14),seasonal_order=(1,0,1,7),enforce_stationarity=False,
                              enforce_invertibility=False)
    model_fit = model.filter(training_res.params)
    output = model_fit.forecast(steps=14)
    yhat = output[13]
    print(yhat)
    predict4.append(yhat)
    obs = test[t]
    history.append(obs)
    count=count+1
    print(count)

mae1 = mean_absolute_error(test1, predict4)
rmse1 = sqrt(mean_squared_error(test1, predict4))

print(mae1,rmse1)
# Out:
# 3.6186206249812916
# 1
# 3.7373311022717965
# 2
# 4.036020423053088
# 3
# 3.18957910475666
# 4
# 3.2674345305418364
# 5
# 3.5371405619806944
# 6
# 3.6705165382285054
# 7
# 3.916085379325838
# 8
# 4.020448526120094
# 9
# 4.301976826143493
# 10
# 3.696595953587851
# 11
# 3.7517248480605203
# 12
# 4.002202808263554
# 13
# 4.114932353022223
# 14
# 4.340417270014165
# 15
# 4.426005104861673
# 16
# 4.686738375110321
# 17
# 3.596763567634565
# 18
# 3.6520104724901756
# 19
# 3.9071063715995322
# 20
# 4.021270178320451
# 21
# 4.2478922731537905
# 22
# 4.336483875310753
# 23
# 4.5964584484107345
# 24
# 5.272830932640066
# 25
# 5.263914966850867
# 26
# 5.454154826450371
# 27
# 5.50602139302478
# 28
# 5.6712538356039115
# 29
# 5.697537049799554
# 30
# 5.8985790618086416
# 31
# 6.588524267685866
# 32
# 6.533090672680125
# 33
# 6.673211407114727
# 34
# 6.6764477193481575
# 35
# 6.791880548402746
# 36
# 6.766611379362975
# 37
# 6.9193844251521455
# 38
# 8.758150756232164
# 39
# 8.624858269184417
# 40
# 8.680719283625907
# 41
# 8.605378021657927
# 42
# 8.642249453316431
# 43
# 8.53507691748258
# 44
# 8.614025817130116
# 45
# 7.7468089609517135
# 46
# 7.65240112956822
# 47
# 7.748198706722324
# 48
# 7.709131316224693
# 49
# 7.780476844019789
# 50
# 7.708047566305193
# 51
# 7.81929529165265
# 52
# 7.212446080480827
# 53
# 7.133451210592665
# 54
# 7.248620389141908
# 55
# 7.228698580479785
# 56
# 7.320107600491846
# 57
# 7.2695247230539115
# 58
# 7.400928557975767
# 59
# 7.4930274991256125
# 60
# 7.403782848294443
# 61
# 7.5081559480062205
# 62
# 7.477558430451775
# 63
# 7.558052378368645
# 64
# 7.495880035529782
# 65
# 7.616933315182379
# 66
# 9.158397348042332
# 67
# 9.00961618051121
# 68
# 9.048877194787236
# 69
# 8.958380002607667
# 70
# 8.97877965426567
# 71
# 8.853980796699384
# 72
# 8.919097145769983
# 73
# 6.243125389147977
# 74
# 6.20061930349765
# 75
# 6.353518204989353
# 76
# 6.367856719026802
# 77
# 6.491023939538357
# 78
# 6.472623281016511
# 79
# 6.634234021771746
# 80
# 9.271040869186281
# 81
# 9.114007184597325
# 82
# 9.147304903905992
# 83
# 9.052536738733096
# 84
# 9.06957409342381
# 85
# 8.941960939663643
# 86
# 9.005824861386378
# 87
# 8.710677000636787
# 88
# 8.581631572163095
# 89
# 8.638617095500457
# 90
# 8.564171543513798
# 91
# 8.597427110828445
# 92
# 8.484457298871606
# 93
# 8.562340482290022
# 94
# 8.750519621197888
# 95
# 8.615783139765629
# 96
# 8.6692488426068
# 97
# 8.593773650980808
# 98
# 8.627983753899786
# 99
# 8.516497318917711
# 100
# 8.597576906581864
# 101
# 9.997438176370649
# 102
# 9.821391774037007
# 103
# 9.826731148374252
# 104
# 9.706712882515307
# 105
# 9.695152449514879
# 106
# 9.534657180020837
# 107
# 9.57297581512353
# 108
# 15.838307171405505
# 109
# 15.458522807866457
# 110
# 15.235355311288828
# 111
# 14.906739322565874
# 112
# 14.686875648735269
# 113
# 14.307772374400718
# 114
# 14.151563754290375
# 115
# 15.123429333558645
# 116
# 14.782530444000646
# 117
# 14.589548079500286
# 118
# 14.288730565982393
# 119
# 14.093439327072632
# 120
# 13.732239029660331
# 121
# 13.600867915490664
# 122
# 11.133884141150142
# 123
# 10.934990671146693
# 124
# 10.89351846218715
# 125
# 10.738517808676937
# 126
# 10.69117277962908
# 127
# 10.482647263621178
# 128
# 10.494137651916851
# 129
# 21.3136839762379
# 130
# 20.752713812779202
# 131
# 20.314635601634805
# 132
# 19.79605142090079
# 133
# 19.388068082795378
# 134
# 18.79972919953574
# 135
# 18.47768440204732
# 136
# 16.688573896504728
# 137
# 16.318174295292145
# 138
# 16.06392976621544
# 139
# 15.714977064932635
# 140
# 15.46908820174828
# 141
# 15.038520663299643
# 142
# 14.868806492242506
# 143
# 15.037417732429844
# 144
# 14.716658967132023
# 145
# 14.520280997029031
# 146
# 14.234269544279396
# 147
# 14.058880811856316
# 148
# 13.700746302055556
# 149
# 13.605733641465719
# 150
# 15.846622166962348
# 151
# 15.508536188624122
# 152
# 15.280977659106274
# 153
# 14.969190080120502
# 154
# 14.763843811911473
# 155
# 14.370949974338613
# 156
# 14.24953767096352
# 157
# 17.57122057421908
# 158
# 17.175990955710233
# 159
# 16.88016505722987
# 160
# 16.50999259336711
# 161
# 16.246394467288077
# 162
# 15.788954772088202
# 163
# 15.617887760972913
# 164
# 11.471627608137787
# 165
# 11.30368353767938
# 166
# 11.244203286802419
# 167
# 11.096340761394814
# 168
# 11.052135819065796
# 169
# 10.820098633867316
# 170
# 10.856493665122642
# 171
# 12.394650562729229
# 172
# 12.184107205680144
# 173
# 12.086202016491162
# 174
# 11.907020245716083
# 175
# 11.836501369321635
# 176
# 11.57682993840327
# 177
# 11.594812777343604
# 178
# 7.284006306105644
# 179
# 7.263502679547611
# 180
# 7.366928007473083
# 181
# 7.3722173570274405
# 182
# 7.4820165317569565
# 183
# 7.407773382166252
# 184
# 7.593803281424548
# 185
# 8.888537392880972
# 186
# 8.798444072447625
# 187
# 8.836414399053357
# 188
# 8.784128853504196
# 189
# 8.841899387248368
# 190
# 8.716340829193102
# 191
# 8.856993492525433
# 192
# 8.254427767322072
# 193
# 8.194326069049216
# 194
# 8.260258119650983
# 195
# 8.230211950686492
# 196
# 8.306754148364746
# 197
# 8.198641397720008
# 198
# 8.354263391865622
# 199
# 5.017973162150804
# 200
# 5.066348319783353
# 201
# 5.2570686878792
# 202
# 5.343213837639162
# 203
# 5.537635531737817
# 204
# 5.554614204739698
# 205
# 5.822171190859877
# 206
# 7.324855370143922
# 207
# 7.285801301536458
# 208
# 7.387041804370364
# 209
# 7.388911727187016
# 210
# 7.500872606192739
# 211
# 7.4337190966609334
# 212
# 7.623142815143061
# 213
# 5.263369733976102
# 214
# 5.299915437883934
# 215
# 5.483706769284108
# 216
# 5.558539155925709
# 217
# 5.741348983118414
# 218
# 5.747816154350165
# 219
# 6.001586570365632
# 220
# 4.888086798057257
# 221
# 4.929119925303667
# 222
# 5.126651778113088
# 223
# 5.213775182613732
# 224
# 5.411425015950777
# 225
# 5.4364864404250826
# 226
# 5.704467215832991
# 227
# 3.7099730984738755
# 228
# 3.791184251021925
# 229
# 4.036278556343337
# 230
# 4.163868689117711
# 231
# 4.401040283439982
# 232
# 4.46889112198787
# 233
# 4.771475861298533
# 234
# 4.518229511282619
# 235
# 4.563193098749498
# 236
# 4.777080232567255
# 237
# 4.873609046215155
# 238
# 5.081615159632796
# 239
# 5.121815531957672
# 240
# 5.3960119141543075
# 241
# 4.210967416052326
# 242
# 4.265547565342337
# 243
# 4.493197153920037
# 244
# 4.598696562852217
# 245
# 4.814848334851779
# 246
# 4.864847758377209
# 247
# 5.143972000364798
# 248
# 3.8853841445075012
# 249
# 3.9454516907085337
# 250
# 4.186131158576375
# 251
# 4.301373236741769
# 252
# 4.528500667630324
# 253
# 4.592397859506166
# 254
# 4.880538350057088
# 255
# 4.746367813476078
# 256
# 4.772059242411652
# 257
# 4.980282822765426
# 258
# 5.062439303012602
# 259
# 5.256930607482345
# 260
# 5.288595400120208
# 261
# 5.54404039208001
# 262
# 5.093447952556072
# 263
# 5.104195448771708
# 264
# 5.300073978371857
# 265
# 5.3680127501268835
# 266
# 5.548119831200466
# 267
# 5.56608095536735
# 268
# 5.806359720153532
# 269
# 3.491145744178894
# 270
# 3.555278606853394
# 271
# 3.8141754799834664
# 272
# 3.938011807211615
# 273
# 4.17402327797713
# 274
# 4.252120790891815
# 275
# 4.543345392940276
# 276
# 2.997433510462803
# 277
# 3.071961924134627
# 278
# 3.350288461507718
# 279
# 3.4897098947762064
# 280
# 3.7426700356643843
# 281
# 3.841257721271758
# 282
# 4.147180910663491
# 283
# 3.8111021135978627
# 284
# 3.852497329236544
# 285
# 4.100072440387208
# 286
# 4.207910506755373
# 287
# 4.429435571054412
# 288
# 4.497615499205281
# 289
# 4.771723738485097
# 290
# 3.484538054589619
# 291
# 3.5341672343491815
# 292
# 3.7955576191946507
# 293
# 3.9129639416081123
# 294
# 4.143896039234473
# 295
# 4.223665121658374
# 296
# 4.504526472907131
# 297
# 2.491826253749377
# 298
# 2.5711887284207067
# 299
# 2.871617692146362
# 300
# 3.0224379520933073
# 301
# 3.2874706849972672
# 302
# 3.405373016641134
# 303
# 3.7164564109537594
# 304
# 4.040251216621333
# 305
# 4.058597491949969
# 306
# 4.299296896281766
# 307
# 4.392032955330608
# 308
# 4.600020340926333
# 309
# 4.6608660255455
# 310
# 4.916729107006559
# 311
# 3.1908165732049594
# 312
# 3.2381016380052166
# 313
# 3.5134025339197934
# 314
# 3.6345469984954546
# 315
# 3.869737583804814
# 316
# 3.960209862655338
# 317
# 4.239122045399034
# 318
# 3.233194859507587
# 319
# 3.2717174367543955
# 320
# 3.5451690540103935
# 321
# 3.6626784458536736
# 322
# 3.895738853615
# 323
# 3.9867264683013346
# 324
# 4.262730512594195
# 325
# 3.6476272322022774
# 326
# 3.668542680947671
# 327
# 3.926890950422511
# 328
# 4.0271577438842305
# 329
# 4.242796808001419
# 330
# 4.317217404260341
# 331
# 4.574562876374149
# 332
# 3.1012318981096834
# 333
# 3.1373128502891445
# 334
# 3.417399348706348
# 335
# 3.5352872681568246
# 336
# 3.7686426249379643
# 337
# 3.863567616183004
# 338
# 4.136016172679366
# 339
# 3.4436893641298187
# 340
# 3.4626036614234916
# 341
# 3.7295189512922113
# 342
# 3.8329017251405593
# 343
# 4.0524347521156905
# 344
# 4.135206450332886
# 345
# 4.39307977481633
# 346
# 3.113862994389527
# 347
# 3.141241775889635
# 348
# 3.421755927468463
# 349
# 3.534788186429509
# 350
# 3.76383815382754
# 351
# 3.858181617246279
# 352
# 2.0437271015486123 2.6227193696644755

# %%
# visualize lag=14
date = pd.date_range('20050824',periods=4383)
import matplotlib.dates as mdates
df = y.copy()
df['y'] = y.values
fig, ax = plt.subplots()
ax.plot(date[4018+13:],df.y[4018+13:],label='real flu rate')
ax.plot(date[4018+13:],predict4,label='predicted flu rate')
# Now add the legend with some customizations.
legend = ax.legend(loc='upper right', shadow=True)

plt.title("Figure 14: SARIMA forecast the last 352 days based on all the data since 14 days before(lag=14),passing parameter to the model")
plt.ylabel('flu rate')
plt.xlabel('Date')

plt.show()

# %%
## lag=28
train1 = train1_y2.values
test = test1_y.values
test1 = test1_y[27:].values

history = [x for x in train1]
predict5 = list()

count =0

for t in range(len(test1)):
    model = sm.tsa.SARIMAX(history, order=(1,1,14),seasonal_order=(1,0,1,7),enforce_stationarity=False,
                              enforce_invertibility=False)
    model_fit = model.filter(training_res.params)
    output = model_fit.forecast(steps=28)
    yhat = output[27]
    print(yhat)
    predict5.append(yhat)
    obs = test[t]
    history.append(obs)
    count=count+1
    print(count)

mae1 = mean_absolute_error(test1, predict5)
rmse1 = sqrt(mean_squared_error(test1, predict5))

print(mae1,rmse1)
# Out:
# 6.061705102339913
# 1
# 6.126466717086989
# 2
# 6.290539123575452
# 3
# 5.822736210425406
# 4
# 5.864785682519872
# 5
# 6.012693308111205
# 6
# 6.085411088904557
# 7
# 6.220042931941495
# 8
# 6.276790809779436
# 9
# 6.431297073166172
# 10
# 6.09638081921275
# 11
# 6.12580791583246
# 12
# 6.263022540363318
# 13
# 6.3242649827552455
# 14
# 6.447731270102172
# 15
# 6.494035656396209
# 16
# 6.636983552860139
# 17
# 6.034712292891313
# 18
# 6.064152150611292
# 19
# 6.203862297311155
# 20
# 6.2658449892890795
# 21
# 6.389888035099749
# 22
# 6.43780006861011
# 23
# 6.5802802053619445
# 24
# 6.952244724125284
# 25
# 6.946202853867221
# 26
# 7.050045717144058
# 27
# 7.077570364323011
# 28
# 7.167653144057769
# 29
# 7.181095588001653
# 30
# 7.29096552179306
# 31
# 7.670386708523735
# 32
# 7.638654776226346
# 33
# 7.7148177957208866
# 34
# 7.715481740490159
# 35
# 7.778056139043505
# 36
# 7.76302105726631
# 37
# 7.84622217167965
# 38
# 8.85931883089483
# 39
# 8.784626610637517
# 40
# 8.814293204196419
# 41
# 8.77159104324921
# 42
# 8.790803646552055
# 43
# 8.730558675701692
# 44
# 8.773002301951173
# 45
# 8.293601181895097
# 46
# 8.240471850589776
# 47
# 8.292282053432183
# 48
# 8.269704113491665
# 49
# 8.308048718342377
# 50
# 8.267085589355194
# 51
# 8.327463026566596
# 52
# 7.991749218045668
# 53
# 7.947190374344434
# 54
# 8.009754720188257
# 55
# 7.997806762463633
# 56
# 8.047287592309193
# 57
# 8.018444699305341
# 58
# 8.09000963903172
# 59
# 8.13986274937841
# 60
# 8.089681418106263
# 61
# 8.146320456253875
# 62
# 8.128512893655763
# 63
# 8.172000846608974
# 64
# 8.136792343735681
# 65
# 8.202673809691428
# 66
# 9.051988008250898
# 67
# 8.968971632285681
# 68
# 8.98969572206404
# 69
# 8.938845203295621
# 70
# 8.9491790889436
# 71
# 8.879416020881147
# 72
# 8.914429491178065
# 73
# 7.437605586405987
# 74
# 7.413360002670851
# 75
# 7.496920757388518
# 76
# 7.5040560471411215
# 77
# 7.571239008829402
# 78
# 7.560333055524549
# 79
# 7.648744054592542
# 80
# 9.102307118500244
# 81
# 9.014819033424773
# 82
# 9.032332109512739
# 83
# 8.979203375929597
# 84
# 8.98775843902109
# 85
# 8.9165179782521
# 86
# 8.950913523649271
# 87
# 8.787349427923603
# 88
# 8.715392999625792
# 89
# 8.746065229022143
# 90
# 8.704239765476792
# 91
# 8.721834165644065
# 92
# 8.65876508026444
# 93
# 8.700987821959517
# 94
# 8.804077047118454
# 95
# 8.729040187221363
# 96
# 8.757828454243972
# 97
# 8.715492121960903
# 98
# 8.733668972665777
# 99
# 8.67147328236315
# 100
# 8.715513058577574
# 101
# 9.486969075890366
# 102
# 9.389173352532772
# 103
# 9.391439133390366
# 104
# 9.324554257647264
# 105
# 9.317502464244203
# 106
# 9.22828898564681
# 107
# 9.248754555278323
# 108
# 12.70384688271597
# 109
# 12.493624224279749
# 110
# 12.369787144413547
# 111
# 12.187770157540418
# 112
# 12.065737090801932
# 113
# 11.85584536301797
# 114
# 11.768905381250512
# 115
# 12.304498236002717
# 116
# 12.115978113657103
# 117
# 12.00904238625677
# 118
# 11.842609338019285
# 119
# 11.734379504335317
# 120
# 11.534611410703883
# 121
# 11.46161909811129
# 122
# 10.100720861350583
# 123
# 9.990818509097982
# 124
# 9.967748756028946
# 125
# 9.882046487313247
# 126
# 9.855726647372862
# 127
# 9.740482565991316
# 128
# 9.746605247588569
# 129
# 15.714023294327635
# 130
# 15.404245032627808
# 131
# 15.162231017678097
# 132
# 14.875780743695971
# 133
# 14.650318229455017
# 134
# 14.325332870405017
# 135
# 14.147223872221305
# 136
# 13.160527005515325
# 137
# 12.95631392473366
# 138
# 12.816153750306563
# 139
# 12.623728438829886
# 140
# 12.488138578397036
# 141
# 12.250647588549398
# 142
# 12.157036698740695
# 143
# 12.250383719742072
# 144
# 12.073779324298021
# 145
# 11.965765956937119
# 146
# 11.808287699850338
# 147
# 11.71181467369673
# 148
# 11.514507274435024
# 149
# 11.462331180678586
# 150
# 12.698783501973097
# 151
# 12.512730322423876
# 152
# 12.387623303268365
# 153
# 12.2160298042083
# 154
# 12.103132535171817
# 155
# 11.886749486769114
# 156
# 11.820106580987497
# 157
# 13.652781627230205
# 158
# 13.435308244186649
# 159
# 13.272639769238461
# 160
# 13.068931548531975
# 161
# 12.923988308791584
# 162
# 12.672082535069855
# 163
# 12.578126420068624
# 164
# 10.292077926769657
# 165
# 10.200284822381585
# 166
# 10.168304171215214
# 167
# 10.087551228170579
# 168
# 10.063963594317842
# 169
# 9.93673892174462
# 170
# 9.957576323476603
# 171
# 10.806799385827116
# 172
# 10.69148093644804
# 173
# 10.638275419415315
# 174
# 10.540215682550537
# 175
# 10.502080137481443
# 176
# 10.359577355192434
# 177
# 10.37022114361616
# 178
# 7.993533911155889
# 179
# 7.983172580216712
# 180
# 8.041161960834588
# 181
# 8.045007087910463
# 182
# 8.106494808285195
# 183
# 8.06644495164448
# 184
# 8.169962566689751
# 185
# 8.88488919041585
# 186
# 8.835983557150934
# 187
# 8.857707437904729
# 188
# 8.82963225345703
# 189
# 8.862256860130397
# 190
# 8.793735284094863
# 191
# 8.872054328723163
# 192
# 8.540459508771091
# 193
# 8.50804104446157
# 194
# 8.545134357687605
# 195
# 8.529274500949416
# 196
# 8.57220378027222
# 197
# 8.513258420412125
# 198
# 8.599789507357814
# 199
# 6.76039566075455
# 200
# 6.787804591700429
# 201
# 6.8937298363164885
# 202
# 6.941966915303377
# 203
# 7.049930696022862
# 204
# 7.0600055171157186
# 205
# 7.208305301225044
# 206
# 8.03763749633976
# 207
# 8.016606165679258
# 208
# 8.072957216766062
# 209
# 8.074488714570236
# 210
# 8.136745088692594
# 211
# 8.10018807064261
# 212
# 8.205162281589281
# 213
# 6.90411977594569
# 214
# 6.924748745136672
# 215
# 7.026599168894362
# 216
# 7.068346261341939
# 217
# 7.169657098736814
# 218
# 7.173689217575756
# 219
# 7.31414120825722
# 220
# 6.700352557865781
# 221
# 6.723330435778833
# 222
# 6.832635827683928
# 223
# 6.8810407120339665
# 224
# 6.990417065765506
# 225
# 7.004587929517226
# 226
# 7.152761819825339
# 227
# 6.052958981204969
# 228
# 6.097991096566381
# 229
# 6.2334276217067455
# 230
# 6.304053649768509
# 231
# 6.43513336492097
# 232
# 6.472814435759615
# 233
# 6.639986488630613
# 234
# 6.500385327940965
# 235
# 6.525250635534475
# 236
# 6.643300556173527
# 237
# 6.696620848649326
# 238
# 6.811440403702239
# 239
# 6.833697368362701
# 240
# 6.985037877084606
# 241
# 6.331398478960523
# 242
# 6.361455272134246
# 243
# 6.4869852936200125
# 244
# 6.54514472136329
# 245
# 6.664350096908785
# 246
# 6.691907380868207
# 247
# 6.845862707843877
# 248
# 6.151552019970936
# 249
# 6.1845253977145225
# 250
# 6.317134087418001
# 251
# 6.380561112728883
# 252
# 6.505715698083255
# 253
# 6.540836267178072
# 254
# 6.699663444970564
# 255
# 6.625376132208896
# 256
# 6.6392518045664115
# 257
# 6.753821361174487
# 258
# 6.798861824992105
# 259
# 6.905877222319079
# 260
# 6.923081261406072
# 261
# 7.0637357451678175
# 262
# 6.814838863706152
# 263
# 6.820380635747134
# 264
# 6.928049787139723
# 265
# 6.965157409625733
# 266
# 7.064148171629277
# 267
# 7.073703592672372
# 268
# 7.205902556163354
# 269
# 5.928574050333809
# 270
# 5.963532816854411
# 271
# 6.105935974292805
# 272
# 6.173853823324937
# 273
# 6.303661900952226
# 274
# 6.346373250445454
# 275
# 6.506661665865192
# 276
# 5.653538806171203
# 277
# 5.694138924038653
# 278
# 5.8471683276115245
# 279
# 5.923594087042311
# 280
# 6.062663795094653
# 281
# 6.116592602752616
# 282
# 6.284905184160772
# 283
# 6.098916927427229
# 284
# 6.1211139168220745
# 285
# 6.2570532925660265
# 286
# 6.315930022787099
# 287
# 6.437531918736919
# 288
# 6.474559488225584
# 289
# 6.625193921885117
# 290
# 5.914573079259974
# 291
# 5.941242282837149
# 292
# 6.0847335938501255
# 293
# 6.148821373364738
# 294
# 6.275546531797427
# 295
# 6.31890287247132
# 296
# 6.473199485789003
# 297
# 5.362383201996942
# 298
# 5.405396702865806
# 299
# 5.57036740234045
# 300
# 5.652835060168192
# 301
# 5.798321121941569
# 302
# 5.8626658172324175
# 303
# 6.033589054949565
# 304
# 6.211277695798059
# 305
# 6.220501076760371
# 306
# 6.352389061769237
# 307
# 6.402679923817348
# 308
# 6.516560093567554
# 309
# 6.549290903570687
# 310
# 6.689610961762771
# 311
# 5.736807183281071
# 312
# 5.761963921657391
# 313
# 5.912910520455644
# 314
# 5.9788463993388765
# 315
# 6.107708667063747
# 316
# 6.156760939977365
# 317
# 6.309776046338
# 318
# 5.753995189067196
# 319
# 5.774251208137654
# 320
# 5.924110496425354
# 321
# 5.987974875542589
# 322
# 6.115595875495176
# 323
# 6.164866864325103
# 324
# 6.316212345671101
# 325
# 5.975911033445269
# 326
# 5.986385976684419
# 327
# 6.1278446919458
# 328
# 6.182128641363747
# 329
# 6.300070223694636
# 330
# 6.340133182759959
# 331
# 6.4811164859361545
# 332
# 5.667456743541897
# 333
# 5.686266518967697
# 334
# 5.839686531129813
# 335
# 5.903662576977805
# 336
# 6.031349843079001
# 337
# 6.082698138360579
# 338
# 3.609639708366726 4.164295439828905

# %%
# visualize
date = pd.date_range('20050824',periods=4383)
import matplotlib.dates as mdates
df = y.copy()
df['y'] = y.values
fig, ax = plt.subplots()
ax.plot(date[4018+27:],df.y[4018+27:],label='real flu rate')
ax.plot(date[4018+27:],predict5,label='predicted flu rate')
# Now add the legend with some customizations.
legend = ax.legend(loc='upper right', shadow=True)

plt.title("Figure 15:SARIMA forecast the last 338 days based on all the data since 28 days before(lag=28),passing parameter to the model")
plt.ylabel('flu rate')
plt.xlabel('Date')

plt.show()

# %%
model = sm.tsa.SARIMAX(train1_y2.values, order=(1,1,14),seasonal_order=(1,0,1,7),enforce_stationarity=False,
                              enforce_invertibility=False)
model_fit = model.fit()
model_fit.summary()
# Out:
# /home/yiyangsu/anaconda3/lib/python3.6/site-packages/statsmodels/base/model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  Statespace Model Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                 4018
# Model:             SARIMAX(1, 1, 14)x(1, 0, 1, 7)   Log Likelihood               -1339.072
# Date:                            Sun, 15 Jul 2018   AIC                           2714.144
# Time:                                    07:23:08   BIC                           2827.414
# Sample:                                         0   HQIC                          2754.297
#                                            - 4018
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9866      0.056     17.768      0.000       0.878       1.095
# ma.L1          0.0105      0.143      0.073      0.942      -0.269       0.290
# ma.L2          0.0156      0.250      0.062      0.950      -0.474       0.505
# ma.L3          0.0105      0.151      0.070      0.945      -0.286       0.307
# ma.L4          0.0103      0.156      0.066      0.947      -0.296       0.317
# ma.L5          0.0140      0.258      0.054      0.957      -0.491       0.519
# ma.L6          0.0085      0.123      0.069      0.945      -0.232       0.249
# ma.L7         -0.4705      0.280     -1.681      0.093      -1.019       0.078
# ma.L8          0.0036      0.114      0.031      0.975      -0.221       0.228
# ma.L9          0.0073      0.186      0.039      0.969      -0.357       0.372
# ma.L10         0.0054      0.129      0.042      0.967      -0.248       0.258
# ma.L11         0.0061      0.142      0.043      0.966      -0.273       0.285
# ma.L12         0.0085      0.181      0.047      0.963      -0.346       0.363
# ma.L13         0.0058      0.110      0.053      0.958      -0.209       0.220
# ma.L14        -0.5051      0.144     -3.512      0.000      -0.787      -0.223
# ar.S.L7        0.7460      0.006    120.921      0.000       0.734       0.758
# ma.S.L7       -1.0035      0.045    -22.322      0.000      -1.092      -0.915
# sigma2         0.1102      0.031      3.578      0.000       0.050       0.171
# ===================================================================================
# Ljung-Box (Q):                       31.29   Jarque-Bera (JB):          53003555.61
# Prob(Q):                              0.84   Prob(JB):                         0.00
# Heteroskedasticity (H):               0.52   Skew:                            10.33
# Prob(H) (two-sided):                  0.00   Kurtosis:                       566.91
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """
