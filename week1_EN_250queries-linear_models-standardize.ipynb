# %% [markdown]
# ## tasks
# ### 1: Form training and testing periods as discussed (2 test periods, last 2*365 days). Be careful tp scale data only based on data from the training set. You may use (from Python) MinMaxScaler, standardisation (StandardScaler) or the default scaler in Python's elastic net.
# ### 2:Estimate the current flu rates by training an elastic net model. Use a Pearson correlation filter (r > 0.3) on the training data to reduce the amount of queries prior to training an elastic net (reminder: not all 1000 queries I provided are related to flu!). Report performance on the two test sets using three metrics: mean absolute error, root mean squared error and Pearson's correlation.
# ### 3: If there is time, begin work on traditional forecasting models (you've identified seasonal ARIMA and Hult-Winters).

# %%
# import libraries
import numpy as np
import pandas as pd
import random
import csv
import scipy.stats as stats
import seaborn as sns
from collections import Counter
from collections import defaultdict
import math
from sklearn.linear_model import ElasticNet
from sklearn.feature_extraction import DictVectorizer
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from random import randint
from sklearn.linear_model import Ridge
from sklearn import linear_model

import matplotlib.pyplot as plt
# %matplotlib inline
import statsmodels.api as sm
from statsmodels.nonparametric.kde import KDEUnivariate
from statsmodels.nonparametric import smoothers_lowess
from pandas import Series, DataFrame
from patsy import dmatrices
from sklearn import datasets, svm

# initialize the plotting sizes
# set size
plt.rc('figure', figsize=(10, 5))
# subplots size
fizsize_with_subplots = (10, 10)
# histogram size
bin_size = 10

# %%
# Loading data
dates = pd.read_csv('data/dates.csv',header=None)
queries = pd.read_csv('data/queries.csv',header=None)
X = pd.read_csv('data/X.csv',header=None)
y = pd.read_csv('data/y.csv',header=None)

X.columns = queries

# %%
# data preprocessing and train-test split
# this data is well formed with no missing value and other symbols or labels that are non numerical.
# splitting the data into train and test

# Here we want the first 500 queries
X = X.iloc[:, 0: 250]

# first with the last year as test
# for convinience, pick the two validation set starting from 1/3 and 2/3 of the training set,
# 10% of training set as validation, here use 400 data points, two 200 periods.
test_size =365
length = X.shape[0]
l =(X.shape[0]-test_size)//3

train1_X = pd.concat([X[0:l],X[l+200:2*l],X[2*l+200:length-test_size]])
val1_X = pd.concat([X[l:l+200],X[2*l:2*l+200]])
train1_y = pd.concat([y[0:l],y[l+200:2*l],y[2*l+200:length-test_size]])
val1_y = pd.concat([y[l:l+200],y[2*l:2*l+200]])
test1_X = X[length-test_size:]
test1_y = y[length-test_size:]

# second with the last 2 year as test
test_size2 =365*2
l2 =(X.shape[0]-test_size2)//3

train2_X = pd.concat([X[0:l2],X[l2+180:2*l2],X[2*l2+180:length-test_size2]])
val2_X = pd.concat([X[l2:l2+180],X[2*l2:2*l2+180]])
train2_y = pd.concat([y[0:l2],y[l2+180:2*l2],y[2*l2+180:length-test_size2]])
val2_y = pd.concat([y[l2:l2+180],y[2*l2:2*l2+180]])
test2_X = X[length-test_size2:]
test2_y = y[length-test_size2:]

print('X shape: ',X.shape,'  y shape: ',y.shape)
print('train1 X:',train1_X.shape,' train1 y:',train1_y.shape,' Test1 X shape:',test1_X.shape, ' Test1 y shape:',test1_y.shape)
print('validation1 X:',val1_X.shape,' validation1 y:',val1_y.shape)
print('train2 X:',train2_X.shape,' train2 y:',train2_y.shape,' Test2 X:',test2_X.shape,' Test2 y:',test2_y.shape)
print('validation2 X:',val2_X.shape,' validation2 y:',val2_y.shape)
# Out:
# X shape:  (4383, 250)   y shape:  (4383, 1)
# train1 X: (3618, 250)  train1 y: (3618, 1)  Test1 X shape: (365, 250)  Test1 y shape: (365, 1)
# validation1 X: (400, 250)  validation1 y: (400, 1)
# train2 X: (3293, 250)  train2 y: (3293, 1)  Test2 X: (730, 250)  Test2 y: (730, 1)
# validation2 X: (360, 250)  validation2 y: (360, 1)

# %%
train_size = train1_X.shape[0]
corrs = np.zeros((X.shape[1],1))
for i in range(0,X.shape[1]):
    if X.sum(axis=1)[i] == 0:
        corrs[i] = 0
    else:
        corrs[i] = np.corrcoef(X.iloc[0:train_size,i],y.iloc[0:train_size,0])[0,1]
        
corrs.shape,X.columns.shape,X.columns[0],X.columns[249]
# Out:
# ((250, 1), (250,), ('flu',), ('flu incubation',))

# %%
def corr_filter(df_X,df_Xval,df_Xtest,corrs,threshold):
    X = df_X.copy()
    X_test = df_Xtest.copy()
    X_val = df_Xval.copy()
    col_corr = set() # Set of all the names of deleted columns
    for i in range(0,250):
            if corrs[i,0] < threshold: 
                #print(X.columns[i])
                colname = df_X.columns[i]
                del X[colname] # deleting the column from the dataset
                del X_test[colname] 
                del X_val[colname]

    return X,X_val,X_test

# %% [markdown]
# ## Fixing pearson correlation filter r>=0.2

# %%
#train1_X0,test1_X0 = corr_filter(train1_X,test1_X,corrs,0.1)
train1_X1,val1_X1,test1_X1 = corr_filter(train1_X,val1_X,test1_X,corrs,0.2)
#train1_X2,test1_X2 = corr_filter(train1_X,test1_X,corrs,0.3)
#train1_X3,test1_X3 = corr_filter(train1_X,test1_X,corrs,0.4)

# %%
#print('For correlation filter r>=0.1, we select feature number: ',train1_X0.shape[1])
print('For correlation filter r>=0.2, we select feature number: ',train1_X1.shape[1])
#print('For correlation filter r>=0.3, we select feature number: ',train1_X2.shape[1])
#print('For correlation filter r>=0.4, we select feature number: ',train1_X3.shape[1])
# Out:
# For correlation filter r>=0.2, we select feature number:  157

# %%
# Defien the mearure matrics, MAE, RMSE, CORR
# define three metrics: mean absolute error, root mean squared error and Pearson's correlation.
from sklearn.metrics import mean_absolute_error
# mae = mean_absolute_error(y_actual, y_pred)

from sklearn.metrics import mean_squared_error
from math import sqrt
# rmse = sqrt(mean_squared_error(y_actual, y_pred))

# np.correcoef returns Pearson product-moment correlation coefficients
def pearson_r(x,y):   
    corr_mat = np.corrcoef(x,y)
    return corr_mat[0,1]
# r = pearson_r(y_actual,y_pred)


# Generalise the function for convinient tuning
def ridge(a,train_X,train_y,test_X,test_y):
    # scaling and modeling
    scalerX = StandardScaler()
    scalerX.fit(train_X)
    train_X = scalerX.transform(train_X)
    test_X = scalerX.transform(test_X)
    
    scalery = StandardScaler() 
    scalery.fit(train_y) 
    train_y = scalery.transform(train_y) 
    
    
    alpha=a
    ri = Ridge(alpha, copy_X=True, fit_intercept=True, max_iter=None,
      normalize=False, random_state=None, solver='auto', tol=0.001)
  
    ri.fit(train_X,train_y)

    y_pred1 = ri.predict(test_X)
    y_pred1 = scalery.inverse_transform(y_pred1)

    mae1 = mean_absolute_error(test_y, y_pred1)
    #print('The mean absolute error is: ',mae1)

    rmse1 = sqrt(mean_squared_error(test_y, y_pred1))
    #print('The root mean squared error is: ',rmse1)
    
    corr_y = test_y.copy()
    corr_y['y_act'] = test_y
    corr_y['y_pred']= y_pred1
    corr = np.corrcoef(corr_y['y_act'],corr_y['y_pred'])[0,1]
    #print('The correlation is: ',corr)
    
    return rmse1, mae1,corr

# %% [markdown]
# # scaling and modeling
# scaler = MinMaxScaler()
# train1_X0_scaled = scaler.fit_transform(train1_X0)
# test1_X0_scaled = scaler.transform(test1_x0)
#
# train1_X1_scaled = scaler.fit_transform(train1_X1)
# test1_X1_scaled = scaler.transform(test1_x1)
#
# train1_X2_scaled = scaler.fit_transform(train1_X2)
# test1_X2_scaled = scaler.transform(test1_x2)
#
# train1_X3_scaled = scaler.fit_transform(train1_X3)
# test1_X3_scaled = scaler.transform(test1_x3)

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.1, 310 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train1_X0,train1_y,test1_X0,test1_y))

# %%
para = np.arange(0, 10000000, 10000)
rmse=100000
mae=1000000
corr=0
for a in para:
    print('alpha:',a)
    rmse0,mae0,corr0 = ridge(a,train1_X1,train1_y,val1_X1,val1_y)
    if rmse0< rmse:
        rmse=rmse0
        mae=mae0
        corr = corr0
        print('========================================')
        print('Best RMSE is updated! ' )
        print('The mean absolute error is: ',mae)
        print('The root mean squared error is: ',rmse)
        print('The correlation is: ',corr)
        print('----------------------------------------')
# Out:
# alpha: 0
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.738477373935684
# The root mean squared error is:  45.95805279347314
# The correlation is:  0.7576646272128614
# ----------------------------------------
# alpha: 10000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  16.711505749513822
# The root mean squared error is:  31.749734057273503
# The correlation is:  0.8031339020365239
# ----------------------------------------
# alpha: 20000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  14.715536414461608
# The root mean squared error is:  27.80398238959264
# The correlation is:  0.7935808781893313
# ----------------------------------------
# alpha: 30000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.400096739561404
# The root mean squared error is:  25.21790854319866
# The correlation is:  0.7875531686540677
# ----------------------------------------
# alpha: 40000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  12.377312840804953
# The root mean squared error is:  23.287918384884467
# The correlation is:  0.783437580905504
# ----------------------------------------
# alpha: 50000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  11.56753424208431
# The root mean squared error is:  21.771295841645497
# The correlation is:  0.7804518356531714
# ----------------------------------------
# alpha: 60000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.921033211130684
# The root mean squared error is:  20.554715236060847
# The correlation is:  0.7781877072994899
# ----------------------------------------
# alpha: 70000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.398717581960096
# The root mean squared error is:  19.572933415131228
# The correlation is:  0.776412208273758
# ----------------------------------------
# alpha: 80000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  10.01206591539365
# The root mean squared error is:  18.78234730515729
# The correlation is:  0.7749827933504845
# ----------------------------------------
# alpha: 90000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.746123385036714
# The root mean squared error is:  18.150688528377284
# The correlation is:  0.7738073925070645
# ----------------------------------------
# alpha: 100000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.573398003335637
# The root mean squared error is:  17.652445890454594
# The correlation is:  0.7728239025919448
# ----------------------------------------
# alpha: 110000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.463263241875422
# The root mean squared error is:  17.266618933016954
# The correlation is:  0.7719889212806288
# ----------------------------------------
# alpha: 120000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.400964134906364
# The root mean squared error is:  16.97551929010858
# The correlation is:  0.7712712055400319
# ----------------------------------------
# alpha: 130000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.370479956833432
# The root mean squared error is:  16.76407550773469
# The correlation is:  0.7706476950231202
# ----------------------------------------
# alpha: 140000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.369725123555417
# The root mean squared error is:  16.61938953745456
# The correlation is:  0.7701009994930301
# ----------------------------------------
# alpha: 150000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.407722328485065
# The root mean squared error is:  16.530422107424993
# The correlation is:  0.7696177580430112
# ----------------------------------------
# alpha: 160000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.474834149644122
# The root mean squared error is:  16.487746102882483
# The correlation is:  0.7691875366358614
# ----------------------------------------
# alpha: 170000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.551547496559987
# The root mean squared error is:  16.48333838435159
# The correlation is:  0.7688020686719569
# ----------------------------------------
# alpha: 180000
# alpha: 190000
# alpha: 200000
# alpha: 210000
# alpha: 220000
# alpha: 230000
# alpha: 240000
# alpha: 250000
# alpha: 260000
# alpha: 270000
# alpha: 280000
# alpha: 290000
# alpha: 300000
# alpha: 310000
# alpha: 320000
# alpha: 330000
# alpha: 340000
# alpha: 350000
# alpha: 360000
# alpha: 370000
# alpha: 380000
# alpha: 390000
# alpha: 400000
# alpha: 410000
# alpha: 420000
# alpha: 430000
# alpha: 440000
# alpha: 450000
# alpha: 460000
# alpha: 470000
# alpha: 480000
# alpha: 490000
# alpha: 500000
# alpha: 510000
# alpha: 520000
# alpha: 530000
# alpha: 540000
# alpha: 550000
# alpha: 560000
# alpha: 570000
# alpha: 580000
# alpha: 590000
# alpha: 600000
# alpha: 610000
# alpha: 620000
# alpha: 630000
# alpha: 640000
# alpha: 650000
# alpha: 660000
# alpha: 670000
# alpha: 680000
# alpha: 690000
# alpha: 700000
# alpha: 710000
# alpha: 720000
# alpha: 730000
# alpha: 740000
# alpha: 750000
# alpha: 760000
# alpha: 770000
# alpha: 780000
# alpha: 790000
# alpha: 800000
# alpha: 810000
# alpha: 820000
# alpha: 830000
# alpha: 840000
# alpha: 850000
# alpha: 860000
# alpha: 870000
# alpha: 880000
# alpha: 890000
# alpha: 900000
# alpha: 910000
# alpha: 920000
# alpha: 930000
# alpha: 940000
# alpha: 950000
# alpha: 960000
# alpha: 970000
# alpha: 980000
# alpha: 990000
# alpha: 1000000
# alpha: 1010000
# alpha: 1020000
# alpha: 1030000
# alpha: 1040000
# alpha: 1050000
# alpha: 1060000
# alpha: 1070000
# alpha: 1080000
# alpha: 1090000
# alpha: 1100000
# alpha: 1110000
# alpha: 1120000
# alpha: 1130000
# alpha: 1140000
# alpha: 1150000
# alpha: 1160000
# alpha: 1170000
# alpha: 1180000
# alpha: 1190000
# alpha: 1200000
# alpha: 1210000
# alpha: 1220000
# alpha: 1230000
# alpha: 1240000
# alpha: 1250000
# alpha: 1260000
# alpha: 1270000
# alpha: 1280000
# alpha: 1290000
# alpha: 1300000
# alpha: 1310000
# alpha: 1320000
# alpha: 1330000
# alpha: 1340000
# alpha: 1350000
# alpha: 1360000
# alpha: 1370000
# alpha: 1380000
# alpha: 1390000
# alpha: 1400000
# alpha: 1410000
# alpha: 1420000
# alpha: 1430000
# alpha: 1440000
# alpha: 1450000
# alpha: 1460000
# alpha: 1470000
# alpha: 1480000
# alpha: 1490000
# alpha: 1500000
# alpha: 1510000
# alpha: 1520000
# alpha: 1530000
# alpha: 1540000
# alpha: 1550000
# alpha: 1560000
# alpha: 1570000
# alpha: 1580000
# alpha: 1590000
# alpha: 1600000
# alpha: 1610000
# alpha: 1620000
# alpha: 1630000
# alpha: 1640000
# alpha: 1650000
# alpha: 1660000
# alpha: 1670000
# alpha: 1680000
# alpha: 1690000
# alpha: 1700000
# alpha: 1710000
# alpha: 1720000
# alpha: 1730000
# alpha: 1740000
# alpha: 1750000
# alpha: 1760000
# alpha: 1770000
# alpha: 1780000
# alpha: 1790000
# alpha: 1800000
# alpha: 1810000
# alpha: 1820000
# alpha: 1830000
# alpha: 1840000
# alpha: 1850000
# alpha: 1860000
# alpha: 1870000
# alpha: 1880000
# alpha: 1890000
# alpha: 1900000
# alpha: 1910000
# alpha: 1920000
# alpha: 1930000
# alpha: 1940000
# alpha: 1950000
# alpha: 1960000
# alpha: 1970000
# alpha: 1980000
# alpha: 1990000
# alpha: 2000000
# alpha: 2010000
# alpha: 2020000
# alpha: 2030000
# alpha: 2040000
# alpha: 2050000
# alpha: 2060000
# alpha: 2070000
# alpha: 2080000
# alpha: 2090000
# alpha: 2100000
# alpha: 2110000
# alpha: 2120000
# alpha: 2130000
# alpha: 2140000
# alpha: 2150000
# alpha: 2160000
# alpha: 2170000
# alpha: 2180000
# alpha: 2190000
# alpha: 2200000
# alpha: 2210000
# alpha: 2220000
# alpha: 2230000
# alpha: 2240000
# alpha: 2250000
# alpha: 2260000
# alpha: 2270000
# alpha: 2280000
# alpha: 2290000
# alpha: 2300000
# alpha: 2310000
# alpha: 2320000
# alpha: 2330000
# alpha: 2340000
# alpha: 2350000
# alpha: 2360000
# alpha: 2370000
# alpha: 2380000
# alpha: 2390000
# alpha: 2400000
# alpha: 2410000
# alpha: 2420000
# alpha: 2430000
# alpha: 2440000
# alpha: 2450000
# alpha: 2460000
# alpha: 2470000
# alpha: 2480000
# alpha: 2490000
# alpha: 2500000
# alpha: 2510000
# alpha: 2520000
# alpha: 2530000
# alpha: 2540000
# alpha: 2550000
# alpha: 2560000
# alpha: 2570000
# alpha: 2580000
# alpha: 2590000
# alpha: 2600000
# alpha: 2610000
# alpha: 2620000
# alpha: 2630000
# alpha: 2640000
# alpha: 2650000
# alpha: 2660000
# alpha: 2670000
# alpha: 2680000
# alpha: 2690000
# alpha: 2700000
# alpha: 2710000
# alpha: 2720000
# alpha: 2730000
# alpha: 2740000
# alpha: 2750000
# alpha: 2760000
# alpha: 2770000
# alpha: 2780000
# alpha: 2790000
# alpha: 2800000
# alpha: 2810000
# alpha: 2820000
# alpha: 2830000
# alpha: 2840000
# alpha: 2850000
# alpha: 2860000
# alpha: 2870000
# alpha: 2880000
# alpha: 2890000
# alpha: 2900000
# alpha: 2910000
# alpha: 2920000
# alpha: 2930000
# alpha: 2940000
# alpha: 2950000
# alpha: 2960000
# alpha: 2970000
# alpha: 2980000
# alpha: 2990000
# alpha: 3000000
# alpha: 3010000
# alpha: 3020000
# alpha: 3030000
# alpha: 3040000
# alpha: 3050000
# alpha: 3060000
# alpha: 3070000
# alpha: 3080000
# alpha: 3090000
# alpha: 3100000
# alpha: 3110000
# alpha: 3120000
# alpha: 3130000
# alpha: 3140000
# alpha: 3150000
# alpha: 3160000
# alpha: 3170000
# alpha: 3180000
# alpha: 3190000
# alpha: 3200000
# alpha: 3210000
# alpha: 3220000
# alpha: 3230000
# alpha: 3240000
# alpha: 3250000
# alpha: 3260000
# alpha: 3270000
# alpha: 3280000
# alpha: 3290000
# alpha: 3300000
# alpha: 3310000
# alpha: 3320000
# alpha: 3330000
# alpha: 3340000
# alpha: 3350000
# alpha: 3360000
# alpha: 3370000
# alpha: 3380000
# alpha: 3390000
# alpha: 3400000
# alpha: 3410000
# alpha: 3420000
# alpha: 3430000
# alpha: 3440000
# alpha: 3450000
# alpha: 3460000
# alpha: 3470000
# alpha: 3480000
# alpha: 3490000
# alpha: 3500000
# alpha: 3510000
# alpha: 3520000
# alpha: 3530000
# alpha: 3540000
# alpha: 3550000
# alpha: 3560000
# alpha: 3570000
# alpha: 3580000
# alpha: 3590000
# alpha: 3600000
# alpha: 3610000
# alpha: 3620000
# alpha: 3630000
# alpha: 3640000
# alpha: 3650000
# alpha: 3660000
# alpha: 3670000
# alpha: 3680000
# alpha: 3690000
# alpha: 3700000
# alpha: 3710000
# alpha: 3720000
# alpha: 3730000
# alpha: 3740000
# alpha: 3750000
# alpha: 3760000
# alpha: 3770000
# alpha: 3780000
# alpha: 3790000
# alpha: 3800000
# alpha: 3810000
# alpha: 3820000
# alpha: 3830000
# alpha: 3840000
# alpha: 3850000
# alpha: 3860000
# alpha: 3870000
# alpha: 3880000
# alpha: 3890000
# alpha: 3900000
# alpha: 3910000
# alpha: 3920000
# alpha: 3930000
# alpha: 3940000
# alpha: 3950000
# alpha: 3960000
# alpha: 3970000
# alpha: 3980000
# alpha: 3990000
# alpha: 4000000
# alpha: 4010000
# alpha: 4020000
# alpha: 4030000
# alpha: 4040000
# alpha: 4050000
# alpha: 4060000
# alpha: 4070000
# alpha: 4080000
# alpha: 4090000
# alpha: 4100000
# alpha: 4110000
# alpha: 4120000
# alpha: 4130000
# alpha: 4140000
# alpha: 4150000
# alpha: 4160000
# alpha: 4170000
# alpha: 4180000
# alpha: 4190000
# alpha: 4200000
# alpha: 4210000
# alpha: 4220000
# alpha: 4230000
# alpha: 4240000
# alpha: 4250000
# alpha: 4260000
# alpha: 4270000
# alpha: 4280000
# alpha: 4290000
# alpha: 4300000
# alpha: 4310000
# alpha: 4320000
# alpha: 4330000
# alpha: 4340000
# alpha: 4350000
# alpha: 4360000
# alpha: 4370000
# alpha: 4380000
# alpha: 4390000
# alpha: 4400000
# alpha: 4410000
# alpha: 4420000
# alpha: 4430000
# alpha: 4440000
# alpha: 4450000
# alpha: 4460000
# alpha: 4470000
# alpha: 4480000
# alpha: 4490000
# alpha: 4500000
# alpha: 4510000
# alpha: 4520000
# alpha: 4530000
# alpha: 4540000
# alpha: 4550000
# alpha: 4560000
# alpha: 4570000
# alpha: 4580000
# alpha: 4590000
# alpha: 4600000
# alpha: 4610000
# alpha: 4620000
# alpha: 4630000
# alpha: 4640000
# alpha: 4650000
# alpha: 4660000
# alpha: 4670000
# alpha: 4680000
# alpha: 4690000
# alpha: 4700000
# alpha: 4710000
# alpha: 4720000
# alpha: 4730000
# alpha: 4740000
# alpha: 4750000
# alpha: 4760000
# alpha: 4770000
# alpha: 4780000
# alpha: 4790000
# alpha: 4800000
# alpha: 4810000
# alpha: 4820000
# alpha: 4830000
# alpha: 4840000
# alpha: 4850000
# alpha: 4860000
# alpha: 4870000
# alpha: 4880000
# alpha: 4890000
# alpha: 4900000
# alpha: 4910000
# alpha: 4920000
# alpha: 4930000
# alpha: 4940000
# alpha: 4950000
# alpha: 4960000
# alpha: 4970000
# alpha: 4980000
# alpha: 4990000
# alpha: 5000000
# alpha: 5010000
# alpha: 5020000
# alpha: 5030000
# alpha: 5040000
# alpha: 5050000
# alpha: 5060000
# alpha: 5070000
# alpha: 5080000
# alpha: 5090000
# alpha: 5100000
# alpha: 5110000
# alpha: 5120000
# alpha: 5130000
# alpha: 5140000
# alpha: 5150000
# alpha: 5160000
# alpha: 5170000
# alpha: 5180000
# alpha: 5190000
# alpha: 5200000
# alpha: 5210000
# alpha: 5220000
# alpha: 5230000
# alpha: 5240000
# alpha: 5250000
# alpha: 5260000
# alpha: 5270000
# alpha: 5280000
# alpha: 5290000
# alpha: 5300000
# alpha: 5310000
# alpha: 5320000
# alpha: 5330000
# alpha: 5340000
# alpha: 5350000
# alpha: 5360000
# alpha: 5370000
# alpha: 5380000
# alpha: 5390000
# alpha: 5400000
# alpha: 5410000
# alpha: 5420000
# alpha: 5430000
# alpha: 5440000
# alpha: 5450000
# alpha: 5460000
# alpha: 5470000
# alpha: 5480000
# alpha: 5490000
# alpha: 5500000
# alpha: 5510000
# alpha: 5520000
# alpha: 5530000
# alpha: 5540000
# alpha: 5550000
# alpha: 5560000
# alpha: 5570000
# alpha: 5580000
# alpha: 5590000
# alpha: 5600000
# alpha: 5610000
# alpha: 5620000
# alpha: 5630000
# alpha: 5640000
# alpha: 5650000
# alpha: 5660000
# alpha: 5670000
# alpha: 5680000
# alpha: 5690000
# alpha: 5700000
# alpha: 5710000
# alpha: 5720000
# alpha: 5730000
# alpha: 5740000
# alpha: 5750000
# alpha: 5760000
# alpha: 5770000
# alpha: 5780000
# alpha: 5790000
# alpha: 5800000
# alpha: 5810000
# alpha: 5820000
# alpha: 5830000
# alpha: 5840000
# alpha: 5850000
# alpha: 5860000
# alpha: 5870000
# alpha: 5880000
# alpha: 5890000
# alpha: 5900000
# alpha: 5910000
# alpha: 5920000
# alpha: 5930000
# alpha: 5940000
# alpha: 5950000
# alpha: 5960000
# alpha: 5970000
# alpha: 5980000
# alpha: 5990000
# alpha: 6000000
# alpha: 6010000
# alpha: 6020000
# alpha: 6030000
# alpha: 6040000
# alpha: 6050000
# alpha: 6060000
# alpha: 6070000
# alpha: 6080000
# alpha: 6090000
# alpha: 6100000
# alpha: 6110000
# alpha: 6120000
# alpha: 6130000
# alpha: 6140000
# alpha: 6150000
# alpha: 6160000
# alpha: 6170000
# alpha: 6180000
# alpha: 6190000
# alpha: 6200000
# alpha: 6210000
# alpha: 6220000
# alpha: 6230000
# alpha: 6240000
# alpha: 6250000
# alpha: 6260000
# alpha: 6270000
# alpha: 6280000
# alpha: 6290000
# alpha: 6300000
# alpha: 6310000
# alpha: 6320000
# alpha: 6330000
# alpha: 6340000
# alpha: 6350000
# alpha: 6360000
# alpha: 6370000
# alpha: 6380000
# alpha: 6390000
# alpha: 6400000
# alpha: 6410000
# alpha: 6420000
# alpha: 6430000
# alpha: 6440000
# alpha: 6450000
# alpha: 6460000
# alpha: 6470000
# alpha: 6480000
# alpha: 6490000
# alpha: 6500000
# alpha: 6510000
# alpha: 6520000
# alpha: 6530000
# alpha: 6540000
# alpha: 6550000
# alpha: 6560000
# alpha: 6570000
# alpha: 6580000
# alpha: 6590000
# alpha: 6600000
# alpha: 6610000
# alpha: 6620000
# alpha: 6630000
# alpha: 6640000
# alpha: 6650000
# alpha: 6660000
# alpha: 6670000
# alpha: 6680000
# alpha: 6690000
# alpha: 6700000
# alpha: 6710000
# alpha: 6720000
# alpha: 6730000
# alpha: 6740000
# alpha: 6750000
# alpha: 6760000
# alpha: 6770000
# alpha: 6780000
# alpha: 6790000
# alpha: 6800000
# alpha: 6810000
# alpha: 6820000
# alpha: 6830000
# alpha: 6840000
# alpha: 6850000
# alpha: 6860000
# alpha: 6870000
# alpha: 6880000
# alpha: 6890000
# alpha: 6900000
# alpha: 6910000
# alpha: 6920000
# alpha: 6930000
# alpha: 6940000
# alpha: 6950000
# alpha: 6960000
# alpha: 6970000
# alpha: 6980000
# alpha: 6990000
# alpha: 7000000
# alpha: 7010000
# alpha: 7020000
# alpha: 7030000
# alpha: 7040000
# alpha: 7050000
# alpha: 7060000
# alpha: 7070000
# alpha: 7080000
# alpha: 7090000
# alpha: 7100000
# alpha: 7110000
# alpha: 7120000
# alpha: 7130000
# alpha: 7140000
# alpha: 7150000
# alpha: 7160000
# alpha: 7170000
# alpha: 7180000
# alpha: 7190000
# alpha: 7200000
# alpha: 7210000
# alpha: 7220000
# alpha: 7230000
# alpha: 7240000
# alpha: 7250000
# alpha: 7260000
# alpha: 7270000
# alpha: 7280000
# alpha: 7290000
# alpha: 7300000
# alpha: 7310000
# alpha: 7320000
# alpha: 7330000
# alpha: 7340000
# alpha: 7350000
# alpha: 7360000
# alpha: 7370000
# alpha: 7380000
# alpha: 7390000
# alpha: 7400000
# alpha: 7410000
# alpha: 7420000
# alpha: 7430000
# alpha: 7440000
# alpha: 7450000
# alpha: 7460000
# alpha: 7470000
# alpha: 7480000
# alpha: 7490000
# alpha: 7500000
# alpha: 7510000
# alpha: 7520000
# alpha: 7530000
# alpha: 7540000
# alpha: 7550000
# alpha: 7560000
# alpha: 7570000
# alpha: 7580000
# alpha: 7590000
# alpha: 7600000
# alpha: 7610000
# alpha: 7620000
# alpha: 7630000
# alpha: 7640000
# alpha: 7650000
# alpha: 7660000
# alpha: 7670000
# alpha: 7680000
# alpha: 7690000
# alpha: 7700000
# alpha: 7710000
# alpha: 7720000
# alpha: 7730000
# alpha: 7740000
# alpha: 7750000
# alpha: 7760000
# alpha: 7770000
# alpha: 7780000
# alpha: 7790000
# alpha: 7800000
# alpha: 7810000
# alpha: 7820000
# alpha: 7830000
# alpha: 7840000
# alpha: 7850000
# alpha: 7860000
# alpha: 7870000
# alpha: 7880000
# alpha: 7890000
# alpha: 7900000
# alpha: 7910000
# alpha: 7920000
# alpha: 7930000
# alpha: 7940000
# alpha: 7950000
# alpha: 7960000
# alpha: 7970000
# alpha: 7980000
# alpha: 7990000
# alpha: 8000000
# alpha: 8010000
# alpha: 8020000
# alpha: 8030000
# alpha: 8040000
# alpha: 8050000
# alpha: 8060000
# alpha: 8070000
# alpha: 8080000
# alpha: 8090000
# alpha: 8100000
# alpha: 8110000
# alpha: 8120000
# alpha: 8130000
# alpha: 8140000
# alpha: 8150000
# alpha: 8160000
# alpha: 8170000
# alpha: 8180000
# alpha: 8190000
# alpha: 8200000
# alpha: 8210000
# alpha: 8220000
# alpha: 8230000
# alpha: 8240000
# alpha: 8250000
# alpha: 8260000
# alpha: 8270000
# alpha: 8280000
# alpha: 8290000
# alpha: 8300000
# alpha: 8310000
# alpha: 8320000
# alpha: 8330000
# alpha: 8340000
# alpha: 8350000
# alpha: 8360000
# alpha: 8370000
# alpha: 8380000
# alpha: 8390000
# alpha: 8400000
# alpha: 8410000
# alpha: 8420000
# alpha: 8430000
# alpha: 8440000
# alpha: 8450000
# alpha: 8460000
# alpha: 8470000
# alpha: 8480000
# alpha: 8490000
# alpha: 8500000
# alpha: 8510000
# alpha: 8520000
# alpha: 8530000
# alpha: 8540000
# alpha: 8550000
# alpha: 8560000
# alpha: 8570000
# alpha: 8580000
# alpha: 8590000
# alpha: 8600000
# alpha: 8610000
# alpha: 8620000
# alpha: 8630000
# alpha: 8640000
# alpha: 8650000
# alpha: 8660000
# alpha: 8670000
# alpha: 8680000
# alpha: 8690000
# alpha: 8700000
# alpha: 8710000
# alpha: 8720000
# alpha: 8730000
# alpha: 8740000
# alpha: 8750000
# alpha: 8760000
# alpha: 8770000
# alpha: 8780000
# alpha: 8790000
# alpha: 8800000
# alpha: 8810000
# alpha: 8820000
# alpha: 8830000
# alpha: 8840000
# alpha: 8850000
# alpha: 8860000
# alpha: 8870000
# alpha: 8880000
# alpha: 8890000
# alpha: 8900000
# alpha: 8910000
# alpha: 8920000
# alpha: 8930000
# alpha: 8940000
# alpha: 8950000
# alpha: 8960000
# alpha: 8970000
# alpha: 8980000
# alpha: 8990000
# alpha: 9000000
# alpha: 9010000
# alpha: 9020000
# alpha: 9030000
# alpha: 9040000
# alpha: 9050000
# alpha: 9060000
# alpha: 9070000
# alpha: 9080000
# alpha: 9090000
# alpha: 9100000
# alpha: 9110000
# alpha: 9120000
# alpha: 9130000
# alpha: 9140000
# alpha: 9150000
# alpha: 9160000
# alpha: 9170000
# alpha: 9180000
# alpha: 9190000
# alpha: 9200000
# alpha: 9210000
# alpha: 9220000
# alpha: 9230000
# alpha: 9240000
# alpha: 9250000
# alpha: 9260000
# alpha: 9270000
# alpha: 9280000
# alpha: 9290000
# alpha: 9300000
# alpha: 9310000
# alpha: 9320000
# alpha: 9330000
# alpha: 9340000
# alpha: 9350000
# alpha: 9360000
# alpha: 9370000
# alpha: 9380000
# alpha: 9390000
# alpha: 9400000
# alpha: 9410000
# alpha: 9420000
# alpha: 9430000
# alpha: 9440000
# alpha: 9450000
# alpha: 9460000
# alpha: 9470000
# alpha: 9480000
# alpha: 9490000
# alpha: 9500000
# alpha: 9510000
# alpha: 9520000
# alpha: 9530000
# alpha: 9540000
# alpha: 9550000
# alpha: 9560000
# alpha: 9570000
# alpha: 9580000
# alpha: 9590000
# alpha: 9600000
# alpha: 9610000
# alpha: 9620000
# alpha: 9630000
# alpha: 9640000
# alpha: 9650000
# alpha: 9660000
# alpha: 9670000
# alpha: 9680000
# alpha: 9690000
# alpha: 9700000
# alpha: 9710000
# alpha: 9720000
# alpha: 9730000
# alpha: 9740000
# alpha: 9750000
# alpha: 9760000
# alpha: 9770000
# alpha: 9780000
# alpha: 9790000
# alpha: 9800000
# alpha: 9810000
# alpha: 9820000
# alpha: 9830000
# alpha: 9840000
# alpha: 9850000
# alpha: 9860000
# alpha: 9870000
# alpha: 9880000
# alpha: 9890000
# alpha: 9900000
# alpha: 9910000
# alpha: 9920000
# alpha: 9930000
# alpha: 9940000
# alpha: 9950000
# alpha: 9960000
# alpha: 9970000
# alpha: 9980000
# alpha: 9990000

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.3, 150 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train1_X2,train1_y,test1_X2,test1_y))

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.4, 103 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train1_X3,train1_y,test1_X3,test1_y))

# %%
para =[0,170000]
rmse=100000
mae=1000000
corr=0
for a in para:
    print('alpha:',a)
    rmse0,mae0,corr0 = ridge(a,train1_X1,train1_y,val1_X1,val1_y)
    if rmse0< rmse:
        rmse=rmse0
        mae=mae0
        corr = corr0
        print('========================================')
        print('Best RMSE is updated! ' )
        print('The mean absolute error is: ',mae)
        print('The root mean squared error is: ',rmse)
        print('The correlation is: ',corr)
        print('----------------------------------------')
# Out:
# alpha: 0
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.738477373935684
# The root mean squared error is:  45.95805279347314
# The correlation is:  0.7576646272128614
# ----------------------------------------
# alpha: 170000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  9.551547496559987
# The root mean squared error is:  16.48333838435159
# The correlation is:  0.7688020686719569
# ----------------------------------------

# %% [markdown]
# ## For the last 2 years as the testing set

# %%
train_size = 3653
corrs2 = np.zeros((X.shape[1],1))
for i in range(0,X.shape[1]):
    if X.sum(axis=1)[i] == 0:
        corrs2[i] = 0
    else:
        corrs2[i] = np.corrcoef(X.iloc[0:train_size,i],y.iloc[0:train_size,0])[0,1]
        
corrs2.shape,X.columns.shape,X.columns[0],X.columns[249]
# Out:
# ((250, 1), (250,), ('flu',), ('flu incubation',))

# %%
#train2_X0,test2_X0 = corr_filter(train2_X,test2_X,corrs2,0.1)
train2_X1,val2_X1,test2_X1 = corr_filter(train2_X,val2_X,test2_X,corrs2,0.2)
#train2_X2,test2_X2 = corr_filter(train2_X,test2_X,corrs2,0.3)
#train2_X3,test2_X3 = corr_filter(train2_X,test2_X,corrs2,0.4)

# %%
#print('For correlation filter r>0.1, we select feature number: ',train2_X0.shape[1])
print('For correlation filter r>0.2, we select feature number: ',train2_X1.shape[1])
#print('For correlation filter r>0.3, we select feature number: ',train2_X2.shape[1])
#print('For correlation filter r>0.4, we select feature number: ',train2_X3.shape[1])
# Out:
# For correlation filter r>0.2, we select feature number:  157

# %% [markdown]
# # scaling and modeling
# scaler = MinMaxScaler()
# train2_X0_scaled = scaler.fit_transform(train2_X0)
# test2_X0_scaled = scaler.transform(test2_X0)
#
# train2_X1_scaled = scaler.fit_transform(train2_X1)
# test2_X1_scaled = scaler.transform(test2_X1)
#
# train2_X2_scaled = scaler.fit_transform(train2_X2)
# test2_X2_scaled = scaler.transform(test2_X2)
#
# train2_X3_scaled = scaler.fit_transform(train2_X3)
# test2_X3_scaled = scaler.transform(test2_X3)

# %% [markdown]
# para = range(1,100)
# para = np.arange(0.01, 10.0, 0.01)
# rmse=100000
# mae=1000000
# corr=0
# for a in para:
#     print('alpha:',a)
#     rmse0,mae0,corr0 = ridge(a,train1_X1,train1_y,val1_X1,val1_y)
#     if rmse0< rmse:
#         rmse=rmse0
#         mae=mae0
#         corr = corr0
#         print('========================================')
#         print('Best RMSE is updated! ' )
#         print('The mean absolute error is: ',mae)
#         print('The root mean squared error is: ',rmse)
#         print('The correlation is: ',corr)
#         print('----------------------------------------')

# %%
para =np.arange(0, 10000000, 10000)
rmse=100000
mae=1000000
corr=0
for a in para:
    print('alpha:',a)
    rmse0,mae0,corr0 = ridge(a,train2_X1,train2_y,val2_X1,val2_y)
    if rmse0< rmse:
        rmse=rmse0
        mae=mae0
        corr = corr0
        print('========================================')
        print('Best RMSE is updated! ' )
        print('The mean absolute error is: ',mae)
        print('The root mean squared error is: ',rmse)
        print('The correlation is: ',corr)
        print('----------------------------------------')
# Out:
# alpha: 0
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  4.82414118172931
# The root mean squared error is:  10.315163209348514
# The correlation is:  0.38850181146732626
# ----------------------------------------
# alpha: 10000
# alpha: 20000
# alpha: 30000
# alpha: 40000
# alpha: 50000
# alpha: 60000
# alpha: 70000
# alpha: 80000
# alpha: 90000
# alpha: 100000
# alpha: 110000
# alpha: 120000
# alpha: 130000
# alpha: 140000
# alpha: 150000
# alpha: 160000
# alpha: 170000
# alpha: 180000
# alpha: 190000
# alpha: 200000
# alpha: 210000
# alpha: 220000
# alpha: 230000
# alpha: 240000
# alpha: 250000
# alpha: 260000
# alpha: 270000
# alpha: 280000
# alpha: 290000
# alpha: 300000
# alpha: 310000
# alpha: 320000
# alpha: 330000
# alpha: 340000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.088104967771647
# The root mean squared error is:  10.244669138668918
# The correlation is:  0.11774946173914073
# ----------------------------------------
# alpha: 350000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.074819950359034
# The root mean squared error is:  10.166457611835487
# The correlation is:  0.11763945875371186
# ----------------------------------------
# alpha: 360000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.062179902161571
# The root mean squared error is:  10.092070035362404
# The correlation is:  0.11753534343438093
# ----------------------------------------
# alpha: 370000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.049960189539116
# The root mean squared error is:  10.021271390960631
# The correlation is:  0.11743665516443563
# ----------------------------------------
# alpha: 380000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.038137900409029
# The root mean squared error is:  9.953843939418869
# The correlation is:  0.11734298017767422
# ----------------------------------------
# alpha: 390000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.026695010521921
# The root mean squared error is:  9.889585753997947
# The correlation is:  0.11725394574676554
# ----------------------------------------
# alpha: 400000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.015614461633893
# The root mean squared error is:  9.82830939324525
# The correlation is:  0.11716921521613441
# ----------------------------------------
# alpha: 410000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  7.004880111870217
# The root mean squared error is:  9.769840698876225
# The correlation is:  0.11708848373952317
# ----------------------------------------
# alpha: 420000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.9944766866701835
# The root mean squared error is:  9.714017705890388
# The correlation is:  0.11701147460824617
# ----------------------------------------
# alpha: 430000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.984389730924853
# The root mean squared error is:  9.660689653461832
# The correlation is:  0.11693793607675435
# ----------------------------------------
# alpha: 440000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.974718837719189
# The root mean squared error is:  9.609716086376617
# The correlation is:  0.11686763860863517
# ----------------------------------------
# alpha: 450000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.965355433929867
# The root mean squared error is:  9.560966037891502
# The correlation is:  0.1168003724794625
# ----------------------------------------
# alpha: 460000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.9562654301681395
# The root mean squared error is:  9.514317285871398
# The correlation is:  0.1167359456836752
# ----------------------------------------
# alpha: 470000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.9474374025870755
# The root mean squared error is:  9.469655674937808
# The correlation is:  0.11667418210141371
# ----------------------------------------
# alpha: 480000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.938860523340313
# The root mean squared error is:  9.426874498138362
# The correlation is:  0.11661491988840109
# ----------------------------------------
# alpha: 490000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.930524525579466
# The root mean squared error is:  9.38587393233862
# The correlation is:  0.11655801005782644
# ----------------------------------------
# alpha: 500000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.922419670447243
# The root mean squared error is:  9.346560522150964
# The correlation is:  0.11650331522803355
# ----------------------------------------
# alpha: 510000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.914536716007711
# The root mean squared error is:  9.308846707760459
# The correlation is:  0.11645070851382132
# ----------------------------------------
# alpha: 520000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.907063975336346
# The root mean squared error is:  9.27265039249168
# The correlation is:  0.11640007254250019
# ----------------------------------------
# alpha: 530000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.899855735514373
# The root mean squared error is:  9.237894546390658
# The correlation is:  0.1163512985786229
# ----------------------------------------
# alpha: 540000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.89283727118844
# The root mean squared error is:  9.204506842478608
# The correlation is:  0.11630428574363523
# ----------------------------------------
# alpha: 550000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.886001342812637
# The root mean squared error is:  9.172419322674363
# The correlation is:  0.11625894031864879
# ----------------------------------------
# alpha: 560000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.879341063203448
# The root mean squared error is:  9.141568090685418
# The correlation is:  0.11621517512018323
# ----------------------------------------
# alpha: 570000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.8728498773674875
# The root mean squared error is:  9.111893029437418
# The correlation is:  0.11617290894012042
# ----------------------------------------
# alpha: 580000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.866521543589439
# The root mean squared error is:  9.083337540852739
# The correlation is:  0.11613206604228994
# ----------------------------------------
# alpha: 590000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.8603501157036995
# The root mean squared error is:  9.055848306003696
# The correlation is:  0.11609257570911867
# ----------------------------------------
# alpha: 600000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.854329926476252
# The root mean squared error is:  9.029375063857957
# The correlation is:  0.1160543718326253
# ----------------------------------------
# alpha: 610000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.8484555720265154
# The root mean squared error is:  9.003870407005483
# The correlation is:  0.11601739254478197
# ----------------------------------------
# alpha: 620000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.8427218972224715
# The root mean squared error is:  8.979289592910098
# The correlation is:  0.11598157988289023
# ----------------------------------------
# alpha: 630000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.837123981985979
# The root mean squared error is:  8.955590369366567
# The correlation is:  0.1159468794861617
# ----------------------------------------
# alpha: 640000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.831657128448766
# The root mean squared error is:  8.932732812967615
# The correlation is:  0.11591324032015886
# ----------------------------------------
# alpha: 650000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.826316848903189
# The root mean squared error is:  8.910679179496402
# The correlation is:  0.11588061442615752
# ----------------------------------------
# alpha: 660000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.82109885449531
# The root mean squared error is:  8.8893937652596
# The correlation is:  0.11584895669283876
# ----------------------------------------
# alpha: 670000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.815999044611132
# The root mean squared error is:  8.86884277846605
# The correlation is:  0.11581822464802352
# ----------------------------------------
# alpha: 680000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.811013496910155
# The root mean squared error is:  8.848994219836788
# The correlation is:  0.11578837826842543
# ----------------------------------------
# alpha: 690000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.806138457963281
# The root mean squared error is:  8.829817771705004
# The correlation is:  0.11575937980563132
# ----------------------------------------
# alpha: 700000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.801370334455151
# The root mean squared error is:  8.811284694930363
# The correlation is:  0.1157311936267127
# ----------------------------------------
# alpha: 710000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.796705684913553
# The root mean squared error is:  8.793367733011378
# The correlation is:  0.11570378606805828
# ----------------------------------------
# alpha: 720000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.7921412119312174
# The root mean squared error is:  8.776041022833283
# The correlation is:  0.11567712530115846
# ----------------------------------------
# alpha: 730000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.787673754847601
# The root mean squared error is:  8.759280011537346
# The correlation is:  0.11565118120922405
# ----------------------------------------
# alpha: 740000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.783300282860559
# The root mean squared error is:  8.743061379041603
# The correlation is:  0.11562592527362647
# ----------------------------------------
# alpha: 750000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.779017888539852
# The root mean squared error is:  8.727362965782852
# The correlation is:  0.11560133046926213
# ----------------------------------------
# alpha: 760000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.774823781716421
# The root mean squared error is:  8.7121637052859
# The correlation is:  0.11557737116803332
# ----------------------------------------
# alpha: 770000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.770715283723096
# The root mean squared error is:  8.697443561198922
# The correlation is:  0.11555402304971797
# ----------------------------------------
# alpha: 780000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.766689821964183
# The root mean squared error is:  8.683183468463664
# The correlation is:  0.11553126301958005
# ----------------------------------------
# alpha: 790000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.7627449247928855
# The root mean squared error is:  8.669365278316322
# The correlation is:  0.11550906913212922
# ----------------------------------------
# alpha: 800000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.758878216676927
# The root mean squared error is:  8.655971706839722
# The correlation is:  0.11548742052050583
# ----------------------------------------
# alpha: 810000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.755087413634217
# The root mean squared error is:  8.642986286809897
# The correlation is:  0.1154662973310073
# ----------------------------------------
# alpha: 820000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.751370318921537
# The root mean squared error is:  8.630393322600728
# The correlation is:  0.11544568066232806
# ----------------------------------------
# alpha: 830000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.74772481896042
# The root mean squared error is:  8.618177847929015
# The correlation is:  0.11542555250912202
# ----------------------------------------
# alpha: 840000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.744148879485538
# The root mean squared error is:  8.606325586239548
# The correlation is:  0.11540589570952862
# ----------------------------------------
# alpha: 850000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.740640541901816
# The root mean squared error is:  8.594822913545265
# The correlation is:  0.11538669389634827
# ----------------------------------------
# alpha: 860000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.737197919837488
# The root mean squared error is:  8.583656823552031
# The correlation is:  0.11536793145156783
# ----------------------------------------
# alpha: 870000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.733844719614495
# The root mean squared error is:  8.57281489491055
# The correlation is:  0.11534959346397512
# ----------------------------------------
# alpha: 880000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.730581611097426
# The root mean squared error is:  8.56228526044999
# The correlation is:  0.11533166568961897
# ----------------------------------------
# alpha: 890000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.727377949629004
# The root mean squared error is:  8.552056578258894
# The correlation is:  0.11531413451489421
# ----------------------------------------
# alpha: 900000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.724232135211529
# The root mean squared error is:  8.542118004488978
# The correlation is:  0.11529698692205116
# ----------------------------------------
# alpha: 910000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.721142624326361
# The root mean squared error is:  8.53245916776678
# The correlation is:  0.1152802104569452
# ----------------------------------------
# alpha: 920000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.718107927486818
# The root mean squared error is:  8.523070145106477
# The correlation is:  0.11526379319885886
# ----------------------------------------
# alpha: 930000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.715126606915698
# The root mean squared error is:  8.513941439225206
# The correlation is:  0.11524772373224208
# ----------------------------------------
# alpha: 940000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.712197274340227
# The root mean squared error is:  8.505063957169195
# The correlation is:  0.11523199112023186
# ----------------------------------------
# alpha: 950000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.709318588897622
# The root mean squared error is:  8.496428990165807
# The correlation is:  0.11521658487981837
# ----------------------------------------
# alpha: 960000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.706489255145003
# The root mean squared error is:  8.488028194622576
# The correlation is:  0.11520149495854277
# ----------------------------------------
# alpha: 970000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.703708021167642
# The root mean squared error is:  8.479853574200012
# The correlation is:  0.11518671171261607
# ----------------------------------------
# alpha: 980000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.700973676780077
# The root mean squared error is:  8.471897462890043
# The correlation is:  0.115172225886359
# ----------------------------------------
# alpha: 990000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.698285051814839
# The root mean squared error is:  8.464152509036849
# The correlation is:  0.11515802859286987
# ----------------------------------------
# alpha: 1000000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.69564101449391
# The root mean squared error is:  8.45661166024112
# The correlation is:  0.1151441112958388
# ----------------------------------------
# alpha: 1010000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.693040469878374
# The root mean squared error is:  8.449268149092987
# The correlation is:  0.11513046579242571
# ----------------------------------------
# alpha: 1020000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.690482358391927
# The root mean squared error is:  8.442115479682514
# The correlation is:  0.11511708419713308
# ----------------------------------------
# alpha: 1030000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.68796565441425
# The root mean squared error is:  8.435147414840207
# The correlation is:  0.11510395892660547
# ----------------------------------------
# alpha: 1040000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.685489364940418
# The root mean squared error is:  8.428357964063181
# The correlation is:  0.11509108268529447
# ----------------------------------------
# alpha: 1050000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.683052528302849
# The root mean squared error is:  8.421741372085597
# The correlation is:  0.11507844845193274
# ----------------------------------------
# alpha: 1060000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.680654212952402
# The root mean squared error is:  8.415292108054803
# The correlation is:  0.11506604946676303
# ----------------------------------------
# alpha: 1070000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.678293516295501
# The root mean squared error is:  8.409004855277102
# The correlation is:  0.1150538792194745
# ----------------------------------------
# alpha: 1080000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.675969563584335
# The root mean squared error is:  8.402874501499472
# The correlation is:  0.11504193143780127
# ----------------------------------------
# alpha: 1090000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.673681506857368
# The root mean squared error is:  8.396896129695818
# The correlation is:  0.11503020007673984
# ----------------------------------------
# alpha: 1100000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.671428523927488
# The root mean squared error is:  8.391065009328289
# The correlation is:  0.11501867930834803
# ----------------------------------------
# alpha: 1110000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.669209817415415
# The root mean squared error is:  8.38537658805615
# The correlation is:  0.11500736351208835
# ----------------------------------------
# alpha: 1120000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.667024613825964
# The root mean squared error is:  8.379826483866491
# The correlation is:  0.11499624726568271
# ----------------------------------------
# alpha: 1130000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.664872162665053
# The root mean squared error is:  8.374410477602614
# The correlation is:  0.11498532533644566
# ----------------------------------------
# alpha: 1140000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.6627517355953145
# The root mean squared error is:  8.36912450586754
# The correlation is:  0.1149745926730702
# ----------------------------------------
# alpha: 1150000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.660662625628448
# The root mean squared error is:  8.36396465428146
# The correlation is:  0.11496404439783489
# ----------------------------------------
# alpha: 1160000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.658604146352412
# The root mean squared error is:  8.358927151073313
# The correlation is:  0.11495367579921174
# ----------------------------------------
# alpha: 1170000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.656575631191763
# The root mean squared error is:  8.354008360987843
# The correlation is:  0.11494348232484626
# ----------------------------------------
# alpha: 1180000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.654576432699499
# The root mean squared error is:  8.349204779490702
# The correlation is:  0.11493345957489218
# ----------------------------------------
# alpha: 1190000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.652605921878854
# The root mean squared error is:  8.344513027255214
# The correlation is:  0.11492360329567713
# ----------------------------------------
# alpha: 1200000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.65066348753359
# The root mean squared error is:  8.3399298449154
# The correlation is:  0.1149139093736828
# ----------------------------------------
# alpha: 1210000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.648748535645423
# The root mean squared error is:  8.33545208807078
# The correlation is:  0.1149043738298184
# ----------------------------------------
# alpha: 1220000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.646860488777251
# The root mean squared error is:  8.331076722529435
# The correlation is:  0.11489499281397435
# ----------------------------------------
# alpha: 1230000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.644998785500973
# The root mean squared error is:  8.326800819776466
# The correlation is:  0.11488576259983721
# ----------------------------------------
# alpha: 1240000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.643162879848726
# The root mean squared error is:  8.32262155265591
# The correlation is:  0.11487667957995415
# ----------------------------------------
# alpha: 1250000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.641352240786435
# The root mean squared error is:  8.318536191254756
# The correlation is:  0.1148677402610306
# ----------------------------------------
# alpha: 1260000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.6395663517086225
# The root mean squared error is:  8.314542098978448
# The correlation is:  0.11485894125944969
# ----------------------------------------
# alpha: 1270000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.637804709953519
# The root mean squared error is:  8.310636728807847
# The correlation is:  0.11485027929700133
# ----------------------------------------
# alpha: 1280000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.636066826337479
# The root mean squared error is:  8.306817619728207
# The correlation is:  0.114841751196809
# ----------------------------------------
# alpha: 1290000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.634352224707876
# The root mean squared error is:  8.303082393321283
# The correlation is:  0.11483335387944457
# ----------------------------------------
# alpha: 1300000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.632660441513592
# The root mean squared error is:  8.29942875051218
# The correlation is:  0.11482508435921952
# ----------------------------------------
# alpha: 1310000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.630991025392317
# The root mean squared error is:  8.29585446846303
# The correlation is:  0.11481693974064529
# ----------------------------------------
# alpha: 1320000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.6293435367738915
# The root mean squared error is:  8.292357397606057
# The correlation is:  0.11480891721505228
# ----------------------------------------
# alpha: 1330000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.6277175474989845
# The root mean squared error is:  8.28893545880898
# The correlation is:  0.11480101405735955
# ----------------------------------------
# alpha: 1340000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.62611264045242
# The root mean squared error is:  8.285586640666098
# The correlation is:  0.11479322762298891
# ----------------------------------------
# alpha: 1350000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.624528409210485
# The root mean squared error is:  8.28230899690883
# The correlation is:  0.11478555534491282
# ----------------------------------------
# alpha: 1360000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.622964457701634
# The root mean squared error is:  8.279100643929711
# The correlation is:  0.11477799473083315
# ----------------------------------------
# alpha: 1370000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.62147368374526
# The root mean squared error is:  8.27595975841432
# The correlation is:  0.11477054336048079
# ----------------------------------------
# alpha: 1380000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.6200188095060994
# The root mean squared error is:  8.272884575075796
# The correlation is:  0.11476319888303249
# ----------------------------------------
# alpha: 1390000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.618582201458409
# The root mean squared error is:  8.269873384486957
# The correlation is:  0.1147559590146376
# ----------------------------------------
# alpha: 1400000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.617163518509761
# The root mean squared error is:  8.266924531005277
# The correlation is:  0.11474882153604955
# ----------------------------------------
# alpha: 1410000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.615762427986194
# The root mean squared error is:  8.264036410786264
# The correlation is:  0.1147417842903579
# ----------------------------------------
# alpha: 1420000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.614378605374855
# The root mean squared error is:  8.261207469880974
# The correlation is:  0.1147348451808145
# ----------------------------------------
# alpha: 1430000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.613011734075955
# The root mean squared error is:  8.258436202413652
# The correlation is:  0.1147280021687508
# ----------------------------------------
# alpha: 1440000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.611661505163728
# The root mean squared error is:  8.25572114883573
# The correlation is:  0.11472125327157964
# ----------------------------------------
# alpha: 1450000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.6103276171559475
# The root mean squared error is:  8.253060894252531
# The correlation is:  0.11471459656088098
# ----------------------------------------
# alpha: 1460000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.609009775791686
# The root mean squared error is:  8.250454066819298
# The correlation is:  0.11470803016056375
# ----------------------------------------
# alpha: 1470000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.607707693816954
# The root mean squared error is:  8.24789933620332
# The correlation is:  0.11470155224510338
# ----------------------------------------
# alpha: 1480000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.606421090777929
# The root mean squared error is:  8.245395412109064
# The correlation is:  0.11469516103784877
# ----------------------------------------
# alpha: 1490000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.605149692821414
# The root mean squared error is:  8.242941042863412
# The correlation is:  0.11468885480939824
# ----------------------------------------
# alpha: 1500000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.603893232502282
# The root mean squared error is:  8.240535014058267
# The correlation is:  0.11468263187603836
# ----------------------------------------
# alpha: 1510000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.6026514485975945
# The root mean squared error is:  8.238176147247858
# The correlation is:  0.11467649059824603
# ----------------------------------------
# alpha: 1520000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.6014240859271345
# The root mean squared error is:  8.235863298698325
# The correlation is:  0.11467042937924701
# ----------------------------------------
# alpha: 1530000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.6002108951800995
# The root mean squared error is:  8.233595358187156
# The correlation is:  0.11466444666363239
# ----------------------------------------
# alpha: 1540000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.599011632747712
# The root mean squared error is:  8.231371247850278
# The correlation is:  0.11465854093602747
# ----------------------------------------
# alpha: 1550000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.5978260605615
# The root mean squared error is:  8.22918992107467
# The correlation is:  0.11465271071981158
# ----------------------------------------
# alpha: 1560000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.596653945937057
# The root mean squared error is:  8.22705036143443
# The correlation is:  0.11464695457588771
# ----------------------------------------
# alpha: 1570000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.595495061423017
# The root mean squared error is:  8.22495158166844
# The correlation is:  0.11464127110149756
# ----------------------------------------
# alpha: 1580000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.594349184655102
# The root mean squared error is:  8.222892622697742
# The correlation is:  0.11463565892908134
# ----------------------------------------
# alpha: 1590000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.593216098214992
# The root mean squared error is:  8.220872552680905
# The correlation is:  0.11463011672518177
# ----------------------------------------
# alpha: 1600000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.5920955894938675
# The root mean squared error is:  8.218890466105744
# The correlation is:  0.11462464318938675
# ----------------------------------------
# alpha: 1610000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.590987450560432
# The root mean squared error is:  8.216945482915776
# The correlation is:  0.11461923705331209
# ----------------------------------------
# alpha: 1620000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.5898914780332465
# The root mean squared error is:  8.215036747669952
# The correlation is:  0.11461389707962139
# ----------------------------------------
# alpha: 1630000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.588807472957208
# The root mean squared error is:  8.213163428734234
# The correlation is:  0.11460862206108219
# ----------------------------------------
# alpha: 1640000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.587735240684029
# The root mean squared error is:  8.211324717503611
# The correlation is:  0.11460341081965601
# ----------------------------------------
# alpha: 1650000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.586674590756558
# The root mean squared error is:  8.209519827653336
# The correlation is:  0.11459826220562039
# ----------------------------------------
# alpha: 1660000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.58564079604325
# The root mean squared error is:  8.207747994418067
# The correlation is:  0.11459317509672398
# ----------------------------------------
# alpha: 1670000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.584619135617426
# The root mean squared error is:  8.206008473897814
# The correlation is:  0.11458814839737055
# ----------------------------------------
# alpha: 1680000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.5836083336663
# The root mean squared error is:  8.204300542389504
# The correlation is:  0.11458318103783226
# ----------------------------------------
# alpha: 1690000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.582608218251222
# The root mean squared error is:  8.202623495743149
# The correlation is:  0.11457827197349073
# ----------------------------------------
# alpha: 1700000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.5816186210385945
# The root mean squared error is:  8.200976648741564
# The correlation is:  0.11457342018410446
# ----------------------------------------
# alpha: 1710000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.580639377206045
# The root mean squared error is:  8.19935933450267
# The correlation is:  0.11456862467310201
# ----------------------------------------
# alpha: 1720000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.579670325351514
# The root mean squared error is:  8.19777090390346
# The correlation is:  0.11456388446689943
# ----------------------------------------
# alpha: 1730000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.578711307405164
# The root mean squared error is:  8.196210725024754
# The correlation is:  0.11455919861424106
# ----------------------------------------
# alpha: 1740000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.577762168543968
# The root mean squared error is:  8.19467818261586
# The correlation is:  0.11455456618556377
# ----------------------------------------
# alpha: 1750000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.576822757108915
# The root mean squared error is:  8.193172677578378
# The correlation is:  0.11454998627238089
# ----------------------------------------
# alpha: 1760000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.575892924524743
# The root mean squared error is:  8.19169362646835
# The correlation is:  0.11454545798668934
# ----------------------------------------
# alpha: 1770000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.574972525222076
# The root mean squared error is:  8.190240461016032
# The correlation is:  0.11454098046039493
# ----------------------------------------
# alpha: 1780000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.574061416561933
# The root mean squared error is:  8.188812627662564
# The correlation is:  0.11453655284475785
# ----------------------------------------
# alpha: 1790000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.573159458762459
# The root mean squared error is:  8.187409587112912
# The correlation is:  0.11453217430985585
# ----------------------------------------
# alpha: 1800000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.572266514827882
# The root mean squared error is:  8.186030813904377
# The correlation is:  0.11452784404406605
# ----------------------------------------
# alpha: 1810000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.571382450479539
# The root mean squared error is:  8.184675795990112
# The correlation is:  0.1145235612535628
# ----------------------------------------
# alpha: 1820000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.570507134088955
# The root mean squared error is:  8.183344034337031
# The correlation is:  0.11451932516183339
# ----------------------------------------
# alpha: 1830000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.569640436612892
# The root mean squared error is:  8.182035042537553
# The correlation is:  0.11451513500920751
# ----------------------------------------
# alpha: 1840000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.568782231530275
# The root mean squared error is:  8.18074834643465
# The correlation is:  0.11451099005240371
# ----------------------------------------
# alpha: 1850000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.567932394780978
# The root mean squared error is:  8.17948348375968
# The correlation is:  0.11450688956409005
# ----------------------------------------
# alpha: 1860000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.567090804706355
# The root mean squared error is:  8.178240003782507
# The correlation is:  0.1145028328324575
# ----------------------------------------
# alpha: 1870000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.566257341991512
# The root mean squared error is:  8.177017466973462
# The correlation is:  0.11449881916080973
# ----------------------------------------
# alpha: 1880000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.565431889609206
# The root mean squared error is:  8.175815444676655
# The correlation is:  0.11449484786716184
# ----------------------------------------
# alpha: 1890000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.564614332765369
# The root mean squared error is:  8.174633518794238
# The correlation is:  0.11449091828385649
# ----------------------------------------
# alpha: 1900000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.563804558846159
# The root mean squared error is:  8.173471281481207
# The correlation is:  0.1144870297571879
# ----------------------------------------
# alpha: 1910000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.563002457366523
# The root mean squared error is:  8.172328334850317
# The correlation is:  0.11448318164704013
# ----------------------------------------
# alpha: 1920000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.562207919920202
# The root mean squared error is:  8.171204290686743
# The correlation is:  0.11447937332653518
# ----------------------------------------
# alpha: 1930000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.561420840131132
# The root mean squared error is:  8.170098770172169
# The correlation is:  0.11447560418169339
# ----------------------------------------
# alpha: 1940000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.560641113606203
# The root mean squared error is:  8.169011403617867
# The correlation is:  0.11447187361110248
# ----------------------------------------
# alpha: 1950000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.559868637889334
# The root mean squared error is:  8.167941830206514
# The correlation is:  0.11446818102559798
# ----------------------------------------
# alpha: 1960000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.559103312416814
# The root mean squared error is:  8.166889697742382
# The correlation is:  0.11446452584795333
# ----------------------------------------
# alpha: 1970000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.558345038473856
# The root mean squared error is:  8.165854662409616
# The correlation is:  0.11446090751257865
# ----------------------------------------
# alpha: 1980000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.557593719152371
# The root mean squared error is:  8.164836388538271
# The correlation is:  0.11445732546522905
# ----------------------------------------
# alpha: 1990000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.556849259309866
# The root mean squared error is:  8.16383454837788
# The correlation is:  0.11445377916272158
# ----------------------------------------
# alpha: 2000000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.556111565529467
# The root mean squared error is:  8.162848821878232
# The correlation is:  0.1144502680726606
# ----------------------------------------
# alpha: 2010000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.555380546081025
# The root mean squared error is:  8.161878896477116
# The correlation is:  0.11444679167317165
# ----------------------------------------
# alpha: 2020000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.554656110883265
# The root mean squared error is:  8.160924466894805
# The correlation is:  0.11444334945264233
# ----------------------------------------
# alpha: 2030000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.553938171466936
# The root mean squared error is:  8.159985234934986
# The correlation is:  0.11443994090947138
# ----------------------------------------
# alpha: 2040000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.55322664093898
# The root mean squared error is:  8.159060909291972
# The correlation is:  0.11443656555182542
# ----------------------------------------
# alpha: 2050000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.552521433947602
# The root mean squared error is:  8.158151205363914
# The correlation is:  0.1144332228974017
# ----------------------------------------
# alpha: 2060000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.551822466648294
# The root mean squared error is:  8.157255845071834
# The correlation is:  0.11442991247319889
# ----------------------------------------
# alpha: 2070000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.551129656670763
# The root mean squared error is:  8.156374556684288
# The correlation is:  0.11442663381529372
# ----------------------------------------
# alpha: 2080000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.5504429230866865
# The root mean squared error is:  8.155507074647401
# The correlation is:  0.1144233864686241
# ----------------------------------------
# alpha: 2090000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.549762186378345
# The root mean squared error is:  8.154653139420175
# The correlation is:  0.11442016998677862
# ----------------------------------------
# alpha: 2100000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.5490873684080535
# The root mean squared error is:  8.1538124973148
# The correlation is:  0.11441698393179228
# ----------------------------------------
# alpha: 2110000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.548418392388384
# The root mean squared error is:  8.152984900341856
# The correlation is:  0.11441382787394708
# ----------------------------------------
# alpha: 2120000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.5477551828531535
# The root mean squared error is:  8.152170106060213
# The correlation is:  0.11441070139157958
# ----------------------------------------
# alpha: 2130000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.547097665629168
# The root mean squared error is:  8.15136787743147
# The correlation is:  0.11440760407089196
# ----------------------------------------
# alpha: 2140000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.546445767808668
# The root mean squared error is:  8.150577982678778
# The correlation is:  0.11440453550577052
# ----------------------------------------
# alpha: 2150000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.545799417722489
# The root mean squared error is:  8.149800195149895
# The correlation is:  0.11440149529760785
# ----------------------------------------
# alpha: 2160000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.545158544913907
# The root mean squared error is:  8.149034293184352
# The correlation is:  0.11439848305512963
# ----------------------------------------
# alpha: 2170000
# ...
# The correlation is:  0.11399993231000483
# ----------------------------------------
# alpha: 5590000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.456062622042778
# The root mean squared error is:  8.093874225237586
# The correlation is:  0.11399948018917126
# ----------------------------------------
# alpha: 5600000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.455962630599571
# The root mean squared error is:  8.093869295094647
# The correlation is:  0.11399902967893766
# ----------------------------------------
# alpha: 5610000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.455862983492865
# The root mean squared error is:  8.093864523677286
# The correlation is:  0.11399858077071327
# ----------------------------------------
# alpha: 5620000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.455763678947266
# The root mean squared error is:  8.09385990943316
# The correlation is:  0.1139981334559679
# ----------------------------------------
# alpha: 5630000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.455664715199557
# The root mean squared error is:  8.093855450825634
# The correlation is:  0.11399768772623224
# ----------------------------------------
# alpha: 5640000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.455566090498607
# The root mean squared error is:  8.0938511463336
# The correlation is:  0.11399724357309661
# ----------------------------------------
# alpha: 5650000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.455467803105258
# The root mean squared error is:  8.093846994451296
# The correlation is:  0.11399680098821098
# ----------------------------------------
# alpha: 5660000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.45536985129222
# The root mean squared error is:  8.093842993688138
# The correlation is:  0.11399635996328367
# ----------------------------------------
# alpha: 5670000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.455272233343981
# The root mean squared error is:  8.093839142568557
# The correlation is:  0.1139959204900819
# ----------------------------------------
# alpha: 5680000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.455174947556699
# The root mean squared error is:  8.09383543963181
# The correlation is:  0.11399548256043074
# ----------------------------------------
# alpha: 5690000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.455077992238105
# The root mean squared error is:  8.093831883431834
# The correlation is:  0.11399504616621214
# ----------------------------------------
# alpha: 5700000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.454981365707402
# The root mean squared error is:  8.093828472537067
# The correlation is:  0.11399461129936503
# ----------------------------------------
# alpha: 5710000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.454885066295174
# The root mean squared error is:  8.093825205530294
# The correlation is:  0.11399417795188473
# ----------------------------------------
# alpha: 5720000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.454789092343284
# The root mean squared error is:  8.093822081008478
# The correlation is:  0.11399374611582273
# ----------------------------------------
# alpha: 5730000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.454693442204785
# The root mean squared error is:  8.093819097582612
# The correlation is:  0.11399331578328524
# ----------------------------------------
# alpha: 5740000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.454598114243817
# The root mean squared error is:  8.093816253877552
# The correlation is:  0.11399288694643356
# ----------------------------------------
# alpha: 5750000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.4545031068355225
# The root mean squared error is:  8.093813548531877
# The correlation is:  0.11399245959748389
# ----------------------------------------
# alpha: 5760000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.454408418365951
# The root mean squared error is:  8.093810980197711
# The correlation is:  0.11399203372870571
# ----------------------------------------
# alpha: 5770000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.454314047231964
# The root mean squared error is:  8.093808547540602
# The correlation is:  0.11399160933242189
# ----------------------------------------
# alpha: 5780000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.4542199918411525
# The root mean squared error is:  8.093806249239357
# The correlation is:  0.11399118640100904
# ----------------------------------------
# alpha: 5790000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.454126250611739
# The root mean squared error is:  8.09380408398589
# The correlation is:  0.11399076492689567
# ----------------------------------------
# alpha: 5800000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.454032821972493
# The root mean squared error is:  8.093802050485095
# The correlation is:  0.11399034490256242
# ----------------------------------------
# alpha: 5810000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.453939704362647
# The root mean squared error is:  8.093800147454681
# The correlation is:  0.11398992632054213
# ----------------------------------------
# alpha: 5820000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.453846896231805
# The root mean squared error is:  8.09379837362505
# The correlation is:  0.11398950917341807
# ----------------------------------------
# alpha: 5830000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.453754396039849
# The root mean squared error is:  8.093796727739145
# The correlation is:  0.11398909345382467
# ----------------------------------------
# alpha: 5840000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.453662202256872
# The root mean squared error is:  8.093795208552317
# The correlation is:  0.11398867915444669
# ----------------------------------------
# alpha: 5850000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.45357031336308
# The root mean squared error is:  8.093793814832182
# The correlation is:  0.11398826626801858
# ----------------------------------------
# alpha: 5860000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.45347872784871
# The root mean squared error is:  8.093792545358504
# The correlation is:  0.11398785478732476
# ----------------------------------------
# alpha: 5870000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.453387444213954
# The root mean squared error is:  8.093791398923036
# The correlation is:  0.11398744470519834
# ----------------------------------------
# alpha: 5880000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.453296460968868
# The root mean squared error is:  8.09379037432941
# The correlation is:  0.11398703601452051
# ----------------------------------------
# alpha: 5890000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.4532057766333
# The root mean squared error is:  8.093789470392998
# The correlation is:  0.11398662870822197
# ----------------------------------------
# alpha: 5900000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.453115389736802
# The root mean squared error is:  8.093788685940783
# The correlation is:  0.11398622277928012
# ----------------------------------------
# alpha: 5910000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.453025298818557
# The root mean squared error is:  8.09378801981124
# The correlation is:  0.11398581822072035
# ----------------------------------------
# alpha: 5920000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.452935502427292
# The root mean squared error is:  8.093787470854203
# The correlation is:  0.11398541502561481
# ----------------------------------------
# alpha: 5930000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.452845999121215
# The root mean squared error is:  8.09378703793074
# The correlation is:  0.1139850131870824
# ----------------------------------------
# alpha: 5940000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.452756787467918
# The root mean squared error is:  8.093786719913044
# The correlation is:  0.11398461269828819
# ----------------------------------------
# alpha: 5950000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.452667866044318
# The root mean squared error is:  8.093786515684299
# The correlation is:  0.11398421355244305
# ----------------------------------------
# alpha: 5960000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  6.452579233436571
# The root mean squared error is:  8.093786424138564
# The correlation is:  0.11398381574280343
# ----------------------------------------
# alpha: 5970000
# alpha: 5980000
# alpha: 5990000
# alpha: 6000000
# alpha: 6010000
# alpha: 6020000
# alpha: 6030000
# alpha: 6040000
# alpha: 6050000
# alpha: 6060000
# alpha: 6070000
# alpha: 6080000
# alpha: 6090000
# alpha: 6100000
# alpha: 6110000
# alpha: 6120000
# alpha: 6130000
# alpha: 6140000
# alpha: 6150000
# alpha: 6160000
# alpha: 6170000
# alpha: 6180000
# alpha: 6190000
# alpha: 6200000
# alpha: 6210000
# alpha: 6220000
# alpha: 6230000
# alpha: 6240000
# alpha: 6250000
# alpha: 6260000
# alpha: 6270000
# alpha: 6280000
# alpha: 6290000
# alpha: 6300000
# alpha: 6310000
# alpha: 6320000
# alpha: 6330000
# alpha: 6340000
# alpha: 6350000
# alpha: 6360000
# alpha: 6370000
# alpha: 6380000
# alpha: 6390000
# alpha: 6400000
# alpha: 6410000
# alpha: 6420000
# alpha: 6430000
# alpha: 6440000
# alpha: 6450000
# alpha: 6460000
# alpha: 6470000
# alpha: 6480000
# alpha: 6490000
# alpha: 6500000
# alpha: 6510000
# alpha: 6520000
# alpha: 6530000
# alpha: 6540000
# alpha: 6550000
# alpha: 6560000
# alpha: 6570000
# alpha: 6580000
# alpha: 6590000
# alpha: 6600000
# alpha: 6610000
# alpha: 6620000
# alpha: 6630000
# alpha: 6640000
# alpha: 6650000
# alpha: 6660000
# alpha: 6670000
# alpha: 6680000
# alpha: 6690000
# alpha: 6700000
# alpha: 6710000
# alpha: 6720000
# alpha: 6730000
# alpha: 6740000
# alpha: 6750000
# alpha: 6760000
# alpha: 6770000
# alpha: 6780000
# alpha: 6790000
# alpha: 6800000
# alpha: 6810000
# alpha: 6820000
# alpha: 6830000
# alpha: 6840000
# alpha: 6850000
# alpha: 6860000
# alpha: 6870000
# alpha: 6880000
# alpha: 6890000
# alpha: 6900000
# alpha: 6910000
# alpha: 6920000
# alpha: 6930000
# alpha: 6940000
# alpha: 6950000
# alpha: 6960000
# alpha: 6970000
# alpha: 6980000
# alpha: 6990000
# alpha: 7000000
# alpha: 7010000
# alpha: 7020000
# alpha: 7030000
# alpha: 7040000
# alpha: 7050000
# alpha: 7060000
# alpha: 7070000
# alpha: 7080000
# alpha: 7090000
# alpha: 7100000
# alpha: 7110000
# alpha: 7120000
# alpha: 7130000
# alpha: 7140000
# alpha: 7150000
# alpha: 7160000
# alpha: 7170000
# alpha: 7180000
# alpha: 7190000
# alpha: 7200000
# alpha: 7210000
# alpha: 7220000
# alpha: 7230000
# alpha: 7240000
# alpha: 7250000
# alpha: 7260000
# alpha: 7270000
# alpha: 7280000
# alpha: 7290000
# alpha: 7300000
# alpha: 7310000
# alpha: 7320000
# alpha: 7330000
# alpha: 7340000
# alpha: 7350000
# alpha: 7360000
# alpha: 7370000
# alpha: 7380000
# alpha: 7390000
# alpha: 7400000
# alpha: 7410000
# alpha: 7420000
# alpha: 7430000
# alpha: 7440000
# alpha: 7450000
# alpha: 7460000
# alpha: 7470000
# alpha: 7480000
# alpha: 7490000
# alpha: 7500000
# alpha: 7510000
# alpha: 7520000
# alpha: 7530000
# alpha: 7540000
# alpha: 7550000
# alpha: 7560000
# alpha: 7570000
# alpha: 7580000
# alpha: 7590000
# alpha: 7600000
# alpha: 7610000
# alpha: 7620000
# alpha: 7630000
# alpha: 7640000
# alpha: 7650000
# alpha: 7660000
# alpha: 7670000
# alpha: 7680000
# alpha: 7690000
# alpha: 7700000
# alpha: 7710000
# alpha: 7720000
# alpha: 7730000
# alpha: 7740000
# alpha: 7750000
# alpha: 7760000
# alpha: 7770000
# alpha: 7780000
# alpha: 7790000
# alpha: 7800000
# alpha: 7810000
# alpha: 7820000
# alpha: 7830000
# alpha: 7840000
# alpha: 7850000
# alpha: 7860000
# alpha: 7870000
# alpha: 7880000
# alpha: 7890000
# alpha: 7900000
# alpha: 7910000
# alpha: 7920000
# alpha: 7930000
# alpha: 7940000
# alpha: 7950000
# alpha: 7960000
# alpha: 7970000
# alpha: 7980000
# alpha: 7990000
# alpha: 8000000
# alpha: 8010000
# alpha: 8020000
# alpha: 8030000
# alpha: 8040000
# alpha: 8050000
# alpha: 8060000
# alpha: 8070000
# alpha: 8080000
# alpha: 8090000
# alpha: 8100000
# alpha: 8110000
# alpha: 8120000
# alpha: 8130000
# alpha: 8140000
# alpha: 8150000
# alpha: 8160000
# alpha: 8170000
# alpha: 8180000
# alpha: 8190000
# alpha: 8200000
# alpha: 8210000
# alpha: 8220000
# alpha: 8230000
# alpha: 8240000
# alpha: 8250000
# alpha: 8260000
# alpha: 8270000
# alpha: 8280000
# alpha: 8290000
# alpha: 8300000
# alpha: 8310000
# alpha: 8320000
# alpha: 8330000
# alpha: 8340000
# alpha: 8350000
# alpha: 8360000
# alpha: 8370000
# alpha: 8380000
# alpha: 8390000
# alpha: 8400000
# alpha: 8410000
# alpha: 8420000
# alpha: 8430000
# alpha: 8440000
# alpha: 8450000
# alpha: 8460000
# alpha: 8470000
# alpha: 8480000
# alpha: 8490000
# alpha: 8500000
# alpha: 8510000
# alpha: 8520000
# alpha: 8530000
# alpha: 8540000
# alpha: 8550000
# alpha: 8560000
# alpha: 8570000
# alpha: 8580000
# alpha: 8590000
# alpha: 8600000
# alpha: 8610000
# alpha: 8620000
# alpha: 8630000
# alpha: 8640000
# alpha: 8650000
# alpha: 8660000
# alpha: 8670000
# alpha: 8680000
# alpha: 8690000
# alpha: 8700000
# alpha: 8710000
# alpha: 8720000
# alpha: 8730000
# alpha: 8740000
# alpha: 8750000
# alpha: 8760000
# alpha: 8770000
# alpha: 8780000
# alpha: 8790000
# alpha: 8800000
# alpha: 8810000
# alpha: 8820000
# alpha: 8830000
# alpha: 8840000
# alpha: 8850000
# alpha: 8860000
# alpha: 8870000
# alpha: 8880000
# alpha: 8890000
# alpha: 8900000
# alpha: 8910000
# alpha: 8920000
# alpha: 8930000
# alpha: 8940000
# alpha: 8950000
# alpha: 8960000
# alpha: 8970000
# alpha: 8980000
# alpha: 8990000
# alpha: 9000000
# alpha: 9010000
# alpha: 9020000
# alpha: 9030000
# alpha: 9040000
# alpha: 9050000
# alpha: 9060000
# alpha: 9070000
# alpha: 9080000
# alpha: 9090000
# alpha: 9100000
# alpha: 9110000
# alpha: 9120000
# alpha: 9130000
# alpha: 9140000
# alpha: 9150000
# alpha: 9160000
# alpha: 9170000
# alpha: 9180000
# alpha: 9190000
# alpha: 9200000
# alpha: 9210000
# alpha: 9220000
# alpha: 9230000
# alpha: 9240000
# alpha: 9250000
# alpha: 9260000
# alpha: 9270000
# alpha: 9280000
# alpha: 9290000
# alpha: 9300000
# alpha: 9310000
# alpha: 9320000
# alpha: 9330000
# alpha: 9340000
# alpha: 9350000
# alpha: 9360000
# alpha: 9370000
# alpha: 9380000
# alpha: 9390000
# alpha: 9400000
# alpha: 9410000
# alpha: 9420000
# alpha: 9430000
# alpha: 9440000
# alpha: 9450000
# alpha: 9460000
# alpha: 9470000
# alpha: 9480000
# alpha: 9490000
# alpha: 9500000
# alpha: 9510000
# alpha: 9520000
# alpha: 9530000
# alpha: 9540000
# alpha: 9550000
# alpha: 9560000
# alpha: 9570000
# alpha: 9580000
# alpha: 9590000
# alpha: 9600000
# alpha: 9610000
# alpha: 9620000
# alpha: 9630000
# alpha: 9640000
# alpha: 9650000
# alpha: 9660000
# alpha: 9670000
# alpha: 9680000
# alpha: 9690000
# alpha: 9700000
# alpha: 9710000
# alpha: 9720000
# alpha: 9730000
# alpha: 9740000
# alpha: 9750000
# alpha: 9760000
# alpha: 9770000
# alpha: 9780000
# alpha: 9790000
# alpha: 9800000
# alpha: 9810000
# alpha: 9820000
# alpha: 9830000
# alpha: 9840000
# alpha: 9850000
# alpha: 9860000
# alpha: 9870000
# alpha: 9880000
# alpha: 9890000
# alpha: 9900000
# alpha: 9910000
# alpha: 9920000
# alpha: 9930000
# alpha: 9940000
# alpha: 9950000
# alpha: 9960000
# alpha: 9970000
# alpha: 9980000
# alpha: 9990000

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.3, 154 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train2_X2,train2_y,test2_X2,test2_y))

# %% [markdown]
# para = [10]
# para_l=[0.3]
# print('For correlation filter r>=0.4, 105 features are selected')
# for a in para:
#     for l in para_l:
#         print('alpha:',a,' L1-ratio:',l)
#         print(eNet(a,l,train2_X3,train2_y,test2_X3,test2_y))

# %%
## tuned alpha based on validation set, then measure the performance for test set.
## Fixing l1-ratio = 0.3
para = [0,5960000]
rmse=100000
mae=1000000
corr=0
for a in para:
    print('alpha:',a)
    rmse0,mae0,corr0 = ridge(a,train1_X1,train1_y,val1_X1,val1_y)
    if rmse0< rmse:
        rmse=rmse0
        mae=mae0
        corr = corr0
        print('========================================')
        print('Best RMSE is updated! ' )
        print('The mean absolute error is: ',mae)
        print('The root mean squared error is: ',rmse)
        print('The correlation is: ',corr)
        print('----------------------------------------')
# Out:
# alpha: 0
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  22.738477373935684
# The root mean squared error is:  45.95805279347314
# The correlation is:  0.7576646272128614
# ----------------------------------------
# alpha: 5960000
# ========================================
# Best RMSE is updated!
# The mean absolute error is:  13.977523937370156
# The root mean squared error is:  27.349926569941225
# The correlation is:  0.7620075297251234
# ----------------------------------------
